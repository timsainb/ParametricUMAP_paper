# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import pandas as pd

# %% [markdown]
# ### load results
# - for each

# %%
# find the most recent

# %%
from pathlib2 import Path
from tfumap.paths import MODEL_DIR

# %%
len('cifar10_1.0_1024_1024____2020_08_06_23_12_19_608880__learned-metric'.split('_'))
# Out:
# 16

# %%
dataset = 'cifar10'

saved_networks = list((MODEL_DIR / 'semisupervised' / dataset).glob('*'))
location_df = pd.DataFrame(columns=['dataset', 'labels_per_class', 'projection_dims', 'umap_prop', 'timestamp', 'location', 'learned_metric'])
for i in saved_networks:
    if len(i.name.split('_')) == 14:
        ds, umap_prop, projection_dims, labels_per_class, _, _, _, y, m, d,h,m,s,f = i.name.split('_')
        timestamp = datetime.strptime('_'.join(i.name.split('_')[-7:]), "%Y_%m_%d_%H_%M_%S_%f")
        location_df.loc[len(location_df)] = [ds, labels_per_class, projection_dims, umap_prop, timestamp, i, False]
    if (len(i.name.split('_')) == 16) & ('learned-metric' in i.name) & ('augmented' not in i.name):
        ds, umap_prop, projection_dims, labels_per_class, _, _, _, y, m, d,h,m,s,f, _, _ = i.name.split('_')
        timestamp = datetime.strptime('_'.join(i.name.split('_')[-9:-2]), "%Y_%m_%d_%H_%M_%S_%f")
        location_df.loc[len(location_df)] = [ds, labels_per_class, projection_dims, umap_prop, timestamp, i, True]
    else:
        print(i.name)
location_df
# Out:
# cifar10_0.0_1024_full____2020_07_31_11_58_12_513181
# cifar10_0.0_1024_1____2020_07_31_11_58_46_973815
# cifar10_1.0_1024_16____2020_08_01_17_41_08_854427_augmented
# cifar10_0.0_1024_1____2020_08_01_17_13_01_516326_augmented
# cifar10_0.0_1024_4____2020_07_31_17_09_45_295605
# cifar10_0.0_1024_1024____2020_07_31_23_46_05_691262_augmented
# cifar10_1.0_1024_64____2020_08_06_00_52_19_004996__learned-metric_augmented
# cifar10_1.0_1024_1____2020_08_01_17_50_08_786179_augmented
# cifar10_1.0_1024_4____2020_08_01_17_37_09_358973_augmented
# cifar10_0.0_1024_256____2020_07_31_17_13_18_940447
# cifar10_0.0_1024_4____2020_07_31_23_46_05_373274_augmented
# cifar10_1.0_1024_16____2020_08_06_16_02_29_622118__learned-metric_augmented
# cifar10_1.0_1024_4____2020_08_06_15_59_01_968264__learned-metric_augmented
# cifar10_0.0_1024_1____2020_07_31_17_42_51_190569
# cifar10_0.0_1024_1024____2020_07_31_16_09_01_387660
# cifar10_0.0_1024_1024____2020_07_31_10_12_42_686456
# cifar10_1.0_1024_1____2020_07_31_23_16_12_117905
# cifar10_1.0_1024_64____2020_08_05_22_37_37_310401__learned-metric_augmented
# cifar10_1.0_1024_256____2020_08_01_17_41_43_385324_augmented
# cifar10_1.0_1024_1____2020_07_31_23_20_16_971845
# cifar10_1.0_1024_1024____2020_08_01_17_37_33_934668_augmented
# cifar10_1.0_1024_256____2020_08_06_16_00_22_032853__learned-metric_augmented
# cifar10_0.0_1024_1024____2020_07_31_23_42_12_718496_augmented
# cifar10_1.0_1024_256____2020_07_31_23_28_44_977693
# 0   cifar10             full            1024       0.0
# 1   cifar10                1            1024       0.0
# 2   cifar10               64            1024       1.0
# 3   cifar10                4            1024       0.0
# 4   cifar10               64            1024       1.0
# 5   cifar10               64            1024       1.0
# 6   cifar10               64            1024       1.0
# 7   cifar10               64            1024       1.0
# 8   cifar10              256            1024       0.0
# 9   cifar10                1            1024       0.0
# 10  cifar10             1024            1024       0.0
# 11  cifar10               64            1024       0.0
# 12  cifar10             1024            1024       0.0
# 13  cifar10                1            1024       1.0
# 14  cifar10                1            1024       1.0
# 15  cifar10               16            1024       1.0
# 16  cifar10                1            1024       1.0
# 17  cifar10              256            1024       1.0
# 18  cifar10              256            1024       1.0
# 19  cifar10             1024            1024       0.0
# 20  cifar10             1024            1024       0.0
# 21  cifar10             full            1024       0.0
# 22  cifar10             full            1024       0.0
# 23  cifar10             1024            1024       0.0
# 24  cifar10               64            1024       0.0
# 25  cifar10               64            1024       0.0
# 26  cifar10             1024            1024       0.0
# 27  cifar10             1024            1024       0.0
# 28  cifar10             1024            1024       1.0
# 29  cifar10               64            1024       1.0
# 30  cifar10                4            1024       0.0
# 31  cifar10                1            1024       0.0
# 32  cifar10               16            1024       0.0
# 33  cifar10               64            1024       1.0
# 34  cifar10               64            1024       1.0
# 35  cifar10             1024            1024       1.0
# 36  cifar10               16            1024       1.0
# 37  cifar10               16            1024       0.0
# 38  cifar10              256            1024       1.0
# 39  cifar10                1            1024       1.0
# 40  cifar10                4            1024       1.0
# 41  cifar10             1024            1024       1.0
# 42  cifar10               16            1024       0.0
# 43  cifar10                4            1024       1.0
# 44  cifar10                1            1024       0.0
# 45  cifar10             1024            1024       0.0
# 46  cifar10               64            1024       0.0
#
#                     timestamp  \
# 0  2020-07-31 11:58:12.513181
# 1  2020-07-31 11:58:46.973815
# 2  2020-08-05 15:23:35.058856
# 3  2020-07-31 17:09:45.295605
# 4  2020-08-05 15:07:44.177373
# 5  2020-08-05 22:36:39.898520
# 6  2020-08-06 10:21:03.506852
# 7  2020-08-05 00:26:13.171457
# 8  2020-07-31 17:13:18.940447
# 9  2020-07-31 17:42:51.190569
# 10 2020-07-31 16:09:01.387660
# 11 2020-08-05 00:29:31.626294
# 12 2020-07-31 10:12:42.686456
# 13 2020-07-31 23:16:12.117905
# 14 2020-08-06 23:28:49.457258
# 15 2020-08-06 23:29:03.406042
# 16 2020-07-31 23:20:16.971845
# 17 2020-07-31 23:28:44.977693
# 18 2020-08-06 23:22:46.724759
# 19 2020-07-31 11:33:20.515398
# 20 2020-07-31 11:57:35.147800
# 21 2020-07-31 17:08:19.712572
# 22 2020-07-31 23:38:50.878911
# 23 2020-07-31 12:00:41.252573
# 24 2020-08-05 00:11:16.986421
# 25 2020-07-31 17:11:05.811717
# 26 2020-07-31 10:57:01.987604
# 27 2020-07-31 11:50:34.800050
# 28 2020-08-06 23:12:19.608880
# 29 2020-08-05 13:01:02.543012
# 30 2020-07-31 17:42:46.440651
# 31 2020-07-31 23:11:45.033351
# 32 2020-07-31 17:10:08.950287
# 33 2020-08-06 23:29:11.146344
# 34 2020-07-31 23:31:00.587082
# 35 2020-07-31 23:29:10.185850
# 36 2020-07-31 23:27:52.575100
# 37 2020-07-31 17:41:06.036621
# 38 2020-08-01 08:45:34.067655
# 39 2020-07-31 17:47:37.793107
# 40 2020-07-31 23:27:13.012171
# 41 2020-08-01 08:45:50.445544
# 42 2020-07-31 17:42:43.175915
# 43 2020-08-06 23:28:54.856662
# 44 2020-07-31 17:09:12.554802
# 45 2020-07-31 11:45:13.178920
# 46 2020-08-04 23:59:02.344019
#
#                                              location learned_metric
# 0   /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 1   /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 2   /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 3   /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 4   /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 5   /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 6   /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 7   /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 8   /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 9   /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 10  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 11  /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 12  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 13  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 14  /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 15  /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 16  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 17  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 18  /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 19  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 20  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 21  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 22  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 23  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 24  /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 25  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 26  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 27  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 28  /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 29  /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 30  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 31  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 32  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 33  /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 34  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 35  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 36  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 37  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 38  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 39  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 40  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 41  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 42  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 43  /mnt/cube/tsainbur/Projects/github_repos/umap_...           True
# 44  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 45  /mnt/cube/tsainbur/Projects/github_repos/umap_...          False
# 46  /mnt/cube/tsainbur/Projects/github_repos/umap_...           True

# %% [markdown]
# #### grab the relavent results

# %%
dataset = 'cifar10'

label_sizes = [1, 4, 16, 64, 256, 1024]
projection_dims = 1024
umap_prop_list = [0.0, 1.0]
learned_metric_list = [True, False]

# %%
results_df = pd.DataFrame(columns = ['labels_per_class', 'accuracy', 'umap_prop', 'timestamp', 'learned_metric'])
for nex in label_sizes:
    for umap_prop in umap_prop_list:
        for learned_metric in learned_metric_list:
            subset_df = location_df[
                (location_df.dataset == dataset) & 
                (location_df.labels_per_class == str(nex)) & 
                (location_df.projection_dims == str(projection_dims)) & 
                (location_df.umap_prop == str(umap_prop) ) &
                (location_df.learned_metric.values == learned_metric ) 
            ]

            for idx, row in subset_df.sort_values(by='timestamp', ascending=False).iterrows():
                acc_list = list(row.location.glob('test_acc.npy'))
                if len(acc_list)> 0:
                    acc = np.load(acc_list[0])
                    acc = np.mean(acc)
                    results_df.loc[len(results_df)] = [nex, acc, umap_prop, row.timestamp, row.learned_metric]
                    break

# %%
results_df
# Out:
#    labels_per_class  accuracy  umap_prop                  timestamp  \
# 0                 1    0.1838        0.0 2020-07-31 23:11:45.033351
# 1                 1    0.1784        1.0 2020-08-06 23:28:49.457258
# 2                 1    0.1000        1.0 2020-07-31 17:47:37.793107
# 3                 4    0.1774        0.0 2020-07-31 17:42:46.440651
# 4                 4    0.1418        1.0 2020-08-06 23:28:54.856662
# 5                 4    0.1755        1.0 2020-07-31 23:27:13.012171
# 6                16    0.2919        0.0 2020-07-31 17:42:43.175915
# 7                16    0.3010        1.0 2020-08-06 23:29:03.406042
# 8                16    0.2474        1.0 2020-07-31 23:27:52.575100
# 9                64    0.3174        0.0 2020-07-31 17:11:05.811717
# 10               64    0.3342        1.0 2020-08-06 23:29:11.146344
# 11               64    0.3158        1.0 2020-07-31 23:31:00.587082
# 12              256    0.3926        0.0 2020-07-31 17:13:18.940447
# 13              256    0.4172        1.0 2020-08-06 23:22:46.724759
# 14              256    0.4360        1.0 2020-08-01 08:45:34.067655
# 15             1024    0.5624        0.0 2020-07-31 16:09:01.387660
# 16             1024    0.6045        1.0 2020-08-06 23:12:19.608880
# 17             1024    0.5380        1.0 2020-08-01 08:45:50.445544
#
#    learned_metric
# 0           False
# 1            True
# 2           False
# 3           False
# 4            True
# 5           False
# 6           False
# 7            True
# 8           False
# 9           False
# 10           True
# 11          False
# 12          False
# 13           True
# 14          False
# 15          False
# 16           True
# 17          False

# %%
import seaborn as sns

# %%
 results_df[results_df.umap_prop == '0.0']
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# Empty DataFrame
# Columns: [labels_per_class, accuracy, umap_prop, timestamp, learned_metric]
# Index: []

# %%
pal = sns.color_palette('Set1',3)
sns.palplot(pal)

# %%
from tfumap.paths import DATA_DIR, FIGURE_DIR, ensure_dir, save_fig

# %%
fig, ax = plt.subplots(figsize=(5,5))



#
color = pal[1]
mask = (results_df.umap_prop == 1.0) & (results_df.learned_metric == False)
nex = results_df[mask].labels_per_class.values.astype('int')
acc = results_df[mask].accuracy.values
ax.scatter(nex, acc, color=color, s=100)
ax.plot(nex, acc, linewidth = 5, alpha = 0.5, color=color, label = 'UMAP loss (data space)')

color = pal[0]
mask = (results_df.umap_prop == 0.0) & (results_df.learned_metric == False)
nex = results_df[mask].labels_per_class.values.astype('int')
acc = results_df[mask].accuracy.values
ax.scatter(nex, acc, color=color, s=100)
ax.plot(nex, acc, linewidth = 5, alpha = 0.5, color=color, label = 'Without UMAP loss')

ax.set_xscale('log')
ax.set_ylim([0,1])
ax.set_xticks(nex)
ax.set_xticklabels([str(i) for i in nex]);
ax.set_ylabel('Accuracy', fontsize=16)
ax.set_xlabel('Labeled training examples per class', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
[i.set_linewidth(4) for i in ax.spines.values()];
leg = ax.legend(fontsize=14)
leg.get_frame().set_linewidth(0.0)
#save_fig(FIGURE_DIR/'cifar10_semisupervised-augmented', save_pdf=True)

# %%
fig, ax = plt.subplots(figsize=(5,5))



color = pal[0]
mask = (results_df.umap_prop == 0.0) & (results_df.learned_metric == False)
nex = results_df[mask].labels_per_class.values.astype('int')
acc = results_df[mask].accuracy.values
ax.scatter(nex, acc, color=color, s=100)
ax.plot(nex, acc, linewidth = 5, alpha = 0.5, color=color, label = 'Baseline')

#
color = pal[2]
mask = (results_df.umap_prop == 1.0) & (results_df.learned_metric == True)
nex = results_df[mask].labels_per_class.values.astype('int')
acc = results_df[mask].accuracy.values
ax.scatter(nex, acc, color=color, s=100)
ax.plot(nex, acc, linewidth = 5, alpha = 0.5, color=color, label = '+ UMAP loss (latent space)')



ax.set_xscale('log')
ax.set_ylim([0,1])
ax.set_xticks(nex)
ax.set_xticklabels([str(i) for i in nex]);
ax.set_ylabel('Accuracy', fontsize=16)
ax.set_xlabel('Labeled training examples per class', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
[i.set_linewidth(4) for i in ax.spines.values()];
leg = ax.legend(fontsize=14)
leg.get_frame().set_linewidth(0.0)
save_fig(FIGURE_DIR/'cifar10_semisupervised-latent-umap-nonaugmented', save_pdf=True)
