# %% [markdown]
# #### Outline
# - for each dataset:
#     - load dataset;
#     - for each network:
#         - load network
#         - project 1000 test dataset samples
#         - save to metric dataframe

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)

# %%
import numpy as np
import pickle
import pandas as pd
import time
from umap import UMAP

# %%
from tfumap.umap import tfUMAP
import tensorflow as tf
from sklearn.decomposition import PCA
from openTSNE import TSNE
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
from tqdm.autonotebook import tqdm

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

# %%
output_dir = MODEL_DIR/'projections'

# %%
projection_speeds = pd.DataFrame(columns = ['method_', 'dimensions', 'dataset', 'speed', "nex"])

# %% [markdown]
# ### macosko2015

# %%
dataset = 'macosko2015'
dims = [50]

# %% [markdown]
# ##### load dataset

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

#dataset_address = 'http://file.biolab.si/opentsne/macosko_2015.pkl.gz'
# https://opentsne.readthedocs.io/en/latest/examples/01_simple_usage/01_simple_usage.html
# also see https://github.com/berenslab/rna-seq-tsne/blob/master/umi-datasets.ipynb

import gzip
import pickle

with gzip.open(DATA_DIR / 'macosko_2015.pkl.gz', "rb") as f:
    data = pickle.load(f)

x = data["pca_50"]
y = data["CellType1"].astype(str)

print("Data set contains %d samples with %d features" % x.shape)

from sklearn.model_selection import train_test_split

def zero_one_norm(x):
    return (x- np.min(x, axis=0))/ (np.max(x, axis=0)-np.min(x, axis=0))

x_norm = zero_one_norm(x)

X_train, X_test, Y_train, Y_test = train_test_split(x_norm, y, test_size=.1, random_state=42)

np.shape(X_train)

n_valid = 10000
X_valid = X_train[-n_valid:]
Y_valid = Y_train[-n_valid:]
X_train = X_train[:-n_valid]
Y_train = Y_train[:-n_valid]

X_train_flat = X_train

from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

Y_train = enc.fit_transform([[i] for i in Y_train]).flatten()

X_train_flat = X_train
X_test_flat = X_test
print(len(X_train), len(X_test), len(X_valid))
# Out:
# Data set contains 44808 samples with 50 features
# 30327 4481 10000

# %% [markdown]
# #### Network

# %% [markdown]
# ##### 2 dims

# %%
load_loc = output_dir / dataset / 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    encoder(X_test);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['network', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.2574630610179156
# seconds:  0.002170303137972951
# seconds:  0.0017843919340521097
# seconds:  0.00172641989775002
# seconds:  0.0017111101187765598
# seconds:  0.002237174892798066
# seconds:  0.0022244241554290056
# seconds:  0.0022942570503801107
# seconds:  0.0022107430268079042
# seconds:  0.0017905519343912601

# %%
##### Network CPU

with tf.device('/CPU:0'):
    n_repeats = 10
    times = []
    for i in tqdm(range(n_repeats)):
        start_time = time.monotonic()
        encoder(X_test);
        end_time = time.monotonic()
        print('seconds: ', end_time - start_time)
        times.append(end_time - start_time)
        projection_speeds.loc[len(projection_speeds)] = ['network-cpu', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.05977769708260894
# seconds:  0.004847739823162556
# seconds:  0.005114718107506633
# seconds:  0.005286332918331027
# seconds:  0.0054284571669995785
# seconds:  0.005149489035829902
# seconds:  0.005041016032919288
# seconds:  0.005160759901627898
# seconds:  0.004493069835007191
# seconds:  0.004703545942902565

# %% [markdown]
# ##### 64 dims

# %%
load_loc = output_dir / dataset /"64"/ 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    encoder(X_test);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['network', 64, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.04194766306318343
# seconds:  0.002163493074476719
# seconds:  0.0023062070831656456
# seconds:  0.002255275147035718
# seconds:  0.0022284151054918766
# seconds:  0.0018087918870151043
# seconds:  0.0018007908947765827
# seconds:  0.002295226091518998
# seconds:  0.0023006570991128683
# seconds:  0.001860274001955986

# %%
##### Network CPU

with tf.device('/CPU:0'):
    n_repeats = 10
    times = []
    for i in tqdm(range(n_repeats)):
        start_time = time.monotonic()
        encoder(X_test);
        end_time = time.monotonic()
        print('seconds: ', end_time - start_time)
        times.append(end_time - start_time)
        projection_speeds.loc[len(projection_speeds)] = ['network-cpu', 64, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.03173177712596953
# seconds:  0.0062287000473588705
# seconds:  0.00512987794354558
# seconds:  0.0049795531667768955
# seconds:  0.005220860941335559
# seconds:  0.005381984869018197
# seconds:  0.006303942063823342
# seconds:  0.006635800935328007
# seconds:  0.005075856810435653
# seconds:  0.004542571026831865

# %% [markdown]
# #### UMAP-learn

# %% [markdown]
# ##### 2 dims

# %%
embedder = UMAP(n_components = 2, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sat Jul 18 13:05:34 2020 Finding Nearest Neighbors
# Sat Jul 18 13:05:34 2020 Building RP forest with 14 trees
# Sat Jul 18 13:05:35 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# Sat Jul 18 13:05:44 2020 Finished Nearest Neighbor Search
# Sat Jul 18 13:05:47 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sat Jul 18 13:06:18 2020 Finished embedding

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['umap-learn', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  15.667166848899797
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.18031515693292
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.8012523220386356
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.196892966981977
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.7923419850412756
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.453657708130777
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.594372713007033
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.407586126821116
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.5674467359203845
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.433920468902215

# %%
projection_speeds
# Out:
#         method_ dimensions      dataset      speed   nex
# 0       network          2  macosko2015   0.257463  4481
# 1       network          2  macosko2015   0.002170  4481
# 2       network          2  macosko2015   0.001784  4481
# 3       network          2  macosko2015   0.001726  4481
# 4       network          2  macosko2015   0.001711  4481
# 5       network          2  macosko2015   0.002237  4481
# 6       network          2  macosko2015   0.002224  4481
# 7       network          2  macosko2015   0.002294  4481
# 8       network          2  macosko2015   0.002211  4481
# 9       network          2  macosko2015   0.001791  4481
# 10  network-cpu          2  macosko2015   0.059778  4481
# 11  network-cpu          2  macosko2015   0.004848  4481
# 12  network-cpu          2  macosko2015   0.005115  4481
# 13  network-cpu          2  macosko2015   0.005286  4481
# 14  network-cpu          2  macosko2015   0.005428  4481
# 15  network-cpu          2  macosko2015   0.005149  4481
# 16  network-cpu          2  macosko2015   0.005041  4481
# 17  network-cpu          2  macosko2015   0.005161  4481
# 18  network-cpu          2  macosko2015   0.004493  4481
# 19  network-cpu          2  macosko2015   0.004704  4481
# 20      network         64  macosko2015   0.041948  4481
# 21      network         64  macosko2015   0.002163  4481
# 22      network         64  macosko2015   0.002306  4481
# 23      network         64  macosko2015   0.002255  4481
# 24      network         64  macosko2015   0.002228  4481
# 25      network         64  macosko2015   0.001809  4481
# 26      network         64  macosko2015   0.001801  4481
# 27      network         64  macosko2015   0.002295  4481
# 28      network         64  macosko2015   0.002301  4481
# 29      network         64  macosko2015   0.001860  4481
# 30  network-cpu         64  macosko2015   0.031732  4481
# 31  network-cpu         64  macosko2015   0.006229  4481
# 32  network-cpu         64  macosko2015   0.005130  4481
# 33  network-cpu         64  macosko2015   0.004980  4481
# 34  network-cpu         64  macosko2015   0.005221  4481
# 35  network-cpu         64  macosko2015   0.005382  4481
# 36  network-cpu         64  macosko2015   0.006304  4481
# 37  network-cpu         64  macosko2015   0.006636  4481
# 38  network-cpu         64  macosko2015   0.005076  4481
# 39  network-cpu         64  macosko2015   0.004543  4481
# 40   umap-learn          2  macosko2015  15.667167  4481
# 41   umap-learn          2  macosko2015   4.180315  4481
# 42   umap-learn          2  macosko2015   3.801252  4481
# 43   umap-learn          2  macosko2015   4.196893  4481
# 44   umap-learn          2  macosko2015   3.792342  4481
# 45   umap-learn          2  macosko2015   4.453658  4481
# 46   umap-learn          2  macosko2015   3.594373  4481
# 47   umap-learn          2  macosko2015   4.407586  4481
# 48   umap-learn          2  macosko2015   3.567447  4481
# 49   umap-learn          2  macosko2015   4.433920  4481

# %% [markdown]
# ##### 64 dims

# %%
embedder = UMAP(n_components = 64, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, n_components=64, verbose=True)
# Construct fuzzy simplicial set
# Sat Jul 18 13:07:11 2020 Finding Nearest Neighbors
# Sat Jul 18 13:07:11 2020 Building RP forest with 14 trees
# Sat Jul 18 13:07:11 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# Sat Jul 18 13:07:13 2020 Finished Nearest Neighbor Search
# Sat Jul 18 13:07:13 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sat Jul 18 13:07:41 2020 Finished embedding

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['umap-learn', 64, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.355257257819176
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.864216635003686
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.6083944719284773
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.8601666390895844
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.831149390898645
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.630204062908888
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.869985952973366
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.6199187871534377
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.8667605409864336
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.610687900101766

# %%
projection_speeds
# Out:
#         method_ dimensions      dataset      speed   nex
# 0       network          2  macosko2015   0.257463  4481
# 1       network          2  macosko2015   0.002170  4481
# 2       network          2  macosko2015   0.001784  4481
# 3       network          2  macosko2015   0.001726  4481
# 4       network          2  macosko2015   0.001711  4481
# 5       network          2  macosko2015   0.002237  4481
# 6       network          2  macosko2015   0.002224  4481
# 7       network          2  macosko2015   0.002294  4481
# 8       network          2  macosko2015   0.002211  4481
# 9       network          2  macosko2015   0.001791  4481
# 10  network-cpu          2  macosko2015   0.059778  4481
# 11  network-cpu          2  macosko2015   0.004848  4481
# 12  network-cpu          2  macosko2015   0.005115  4481
# 13  network-cpu          2  macosko2015   0.005286  4481
# 14  network-cpu          2  macosko2015   0.005428  4481
# 15  network-cpu          2  macosko2015   0.005149  4481
# 16  network-cpu          2  macosko2015   0.005041  4481
# 17  network-cpu          2  macosko2015   0.005161  4481
# 18  network-cpu          2  macosko2015   0.004493  4481
# 19  network-cpu          2  macosko2015   0.004704  4481
# 20      network         64  macosko2015   0.041948  4481
# 21      network         64  macosko2015   0.002163  4481
# 22      network         64  macosko2015   0.002306  4481
# 23      network         64  macosko2015   0.002255  4481
# 24      network         64  macosko2015   0.002228  4481
# 25      network         64  macosko2015   0.001809  4481
# 26      network         64  macosko2015   0.001801  4481
# 27      network         64  macosko2015   0.002295  4481
# 28      network         64  macosko2015   0.002301  4481
# 29      network         64  macosko2015   0.001860  4481
# 30  network-cpu         64  macosko2015   0.031732  4481
# 31  network-cpu         64  macosko2015   0.006229  4481
# 32  network-cpu         64  macosko2015   0.005130  4481
# 33  network-cpu         64  macosko2015   0.004980  4481
# 34  network-cpu         64  macosko2015   0.005221  4481
# 35  network-cpu         64  macosko2015   0.005382  4481
# 36  network-cpu         64  macosko2015   0.006304  4481
# 37  network-cpu         64  macosko2015   0.006636  4481
# 38  network-cpu         64  macosko2015   0.005076  4481
# 39  network-cpu         64  macosko2015   0.004543  4481
# 40   umap-learn          2  macosko2015  15.667167  4481
# 41   umap-learn          2  macosko2015   4.180315  4481
# 42   umap-learn          2  macosko2015   3.801252  4481
# 43   umap-learn          2  macosko2015   4.196893  4481
# 44   umap-learn          2  macosko2015   3.792342  4481
# 45   umap-learn          2  macosko2015   4.453658  4481
# 46   umap-learn          2  macosko2015   3.594373  4481
# 47   umap-learn          2  macosko2015   4.407586  4481
# 48   umap-learn          2  macosko2015   3.567447  4481
# 49   umap-learn          2  macosko2015   4.433920  4481
# 50   umap-learn         64  macosko2015   4.355257  4481
# 51   umap-learn         64  macosko2015   3.864217  4481
# 52   umap-learn         64  macosko2015   3.608394  4481
# 53   umap-learn         64  macosko2015   3.860167  4481
# 54   umap-learn         64  macosko2015   3.831149  4481
# 55   umap-learn         64  macosko2015   3.630204  4481
# 56   umap-learn         64  macosko2015   3.869986  4481
# 57   umap-learn         64  macosko2015   3.619919  4481
# 58   umap-learn         64  macosko2015   3.866761  4481
# 59   umap-learn         64  macosko2015   3.610688  4481

# %% [markdown]
# #### PCA

# %% [markdown]
# ##### 2 dims

# %%
pca = PCA(n_components=2)
z = pca.fit_transform(X_train_flat)

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    pca.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['pca', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.0014454619958996773
# seconds:  0.0013370581436902285
# seconds:  0.0011735039297491312
# seconds:  0.0011858840007334948
# seconds:  0.0011814238969236612
# seconds:  0.0011741940397769213
# seconds:  0.0011680638417601585
# seconds:  0.0011674531269818544
# seconds:  0.0012008449994027615
# seconds:  0.0011656039860099554

# %%
projection_speeds
# Out:
#     method_ dimensions      dataset     speed   nex
# 0   network          2  macosko2015  0.257463  4481
# 1   network          2  macosko2015  0.002170  4481
# 2   network          2  macosko2015  0.001784  4481
# 3   network          2  macosko2015  0.001726  4481
# 4   network          2  macosko2015  0.001711  4481
# ..      ...        ...          ...       ...   ...
# 65      pca          2  macosko2015  0.001174  4481
# 66      pca          2  macosko2015  0.001168  4481
# 67      pca          2  macosko2015  0.001167  4481
# 68      pca          2  macosko2015  0.001201  4481
# 69      pca          2  macosko2015  0.001166  4481
#
# [70 rows x 5 columns]

# %% [markdown]
# ##### 64 dims

# %%
x_train_flat_padded = np.concatenate([X_train_flat, np.zeros((len(X_train_flat), 14))], axis=1)
X_test_flat_padded = np.concatenate([X_test_flat, np.zeros((len(X_test_flat), 14))], axis=1)

# %%
pca = PCA(n_components=64)
z = pca.fit_transform(x_train_flat_padded)

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    pca.transform(X_test_flat_padded);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['pca', 64, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.0028941440396010876
# seconds:  0.0017902308609336615
# seconds:  0.0018056221306324005
# seconds:  0.001770860981196165
# seconds:  0.0017668809741735458
# seconds:  0.001783912070095539
# seconds:  0.001784980995580554
# seconds:  0.0017701711039990187
# seconds:  0.0017756109591573477
# seconds:  0.0017782710492610931

# %%
projection_speeds
# Out:
#     method_ dimensions      dataset     speed   nex
# 0   network          2  macosko2015  0.257463  4481
# 1   network          2  macosko2015  0.002170  4481
# 2   network          2  macosko2015  0.001784  4481
# 3   network          2  macosko2015  0.001726  4481
# 4   network          2  macosko2015  0.001711  4481
# ..      ...        ...          ...       ...   ...
# 75      pca         64  macosko2015  0.001784  4481
# 76      pca         64  macosko2015  0.001785  4481
# 77      pca         64  macosko2015  0.001770  4481
# 78      pca         64  macosko2015  0.001776  4481
# 79      pca         64  macosko2015  0.001778  4481
#
# [80 rows x 5 columns]

# %% [markdown]
# #### TSNE

# %% [markdown]
# ##### 2 dims

# %%
tsne = TSNE(
    n_components = 2,
    n_jobs=32,
    verbose=True
)

# %%
embedding_train = tsne.fit(X_train_flat)
# Out:
# --------------------------------------------------------------------------------
# TSNE(n_jobs=32, neighbors=None, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#    --> Time elapsed: 10.11 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.38 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.09 seconds
# ===> Running optimization with exaggeration=12.00, lr=2527.25 for 250 iterations...
# Iteration   50, KL divergence 5.8205, 50 iterations in 1.3960 sec
# Iteration  100, KL divergence 5.3222, 50 iterations in 1.2890 sec
# Iteration  150, KL divergence 5.2496, 50 iterations in 1.2600 sec
# Iteration  200, KL divergence 5.2204, 50 iterations in 1.2814 sec
# Iteration  250, KL divergence 5.2056, 50 iterations in 1.2783 sec
#    --> Time elapsed: 6.51 seconds
# ===> Running optimization with exaggeration=1.00, lr=2527.25 for 500 iterations...
# Iteration   50, KL divergence 3.6400, 50 iterations in 1.2393 sec
# Iteration  100, KL divergence 3.2482, 50 iterations in 1.2282 sec
# Iteration  150, KL divergence 3.0520, 50 iterations in 1.5182 sec
# Iteration  200, KL divergence 2.9298, 50 iterations in 2.1680 sec
# Iteration  250, KL divergence 2.8457, 50 iterations in 3.0717 sec
# Iteration  300, KL divergence 2.7854, 50 iterations in 3.8714 sec
# Iteration  350, KL divergence 2.7407, 50 iterations in 4.9192 sec
# Iteration  400, KL divergence 2.7064, 50 iterations in 5.9317 sec
# Iteration  450, KL divergence 2.6794, 50 iterations in 7.0834 sec
# Iteration  500, KL divergence 2.6577, 50 iterations in 7.7325 sec
#    --> Time elapsed: 38.77 seconds

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedding_train.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['TSNE', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.83 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83006.5255, 50 iterations in 0.1605 sec
# Iteration  100, KL divergence 83072.7557, 50 iterations in 0.1370 sec
# Iteration  150, KL divergence 83118.0247, 50 iterations in 0.1354 sec
# Iteration  200, KL divergence 83143.5822, 50 iterations in 0.1354 sec
# Iteration  250, KL divergence 83165.7081, 50 iterations in 0.1370 sec
#    --> Time elapsed: 0.71 seconds
# seconds:  2.3207843399140984
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.94 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83006.5255, 50 iterations in 0.1420 sec
# Iteration  100, KL divergence 83072.7557, 50 iterations in 0.1432 sec
# Iteration  150, KL divergence 83118.0247, 50 iterations in 0.1347 sec
# Iteration  200, KL divergence 83143.5822, 50 iterations in 0.1743 sec
# Iteration  250, KL divergence 83165.7081, 50 iterations in 0.1322 sec
#    --> Time elapsed: 0.73 seconds
# seconds:  1.704643851146102
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.85 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83006.5255, 50 iterations in 0.1483 sec
# Iteration  100, KL divergence 83072.7557, 50 iterations in 0.1346 sec
# Iteration  150, KL divergence 83118.0247, 50 iterations in 0.1506 sec
# Iteration  200, KL divergence 83143.5822, 50 iterations in 0.1326 sec
# Iteration  250, KL divergence 83165.7081, 50 iterations in 0.1502 sec
#    --> Time elapsed: 0.72 seconds
# seconds:  1.608770500170067
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.83 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83006.5255, 50 iterations in 0.1669 sec
# Iteration  100, KL divergence 83072.7557, 50 iterations in 0.1522 sec
# Iteration  150, KL divergence 83118.0247, 50 iterations in 0.1362 sec
# Iteration  200, KL divergence 83143.5822, 50 iterations in 0.1434 sec
# Iteration  250, KL divergence 83165.7081, 50 iterations in 0.1326 sec
#    --> Time elapsed: 0.73 seconds
# seconds:  1.6016150231007487
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 1.05 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83006.5255, 50 iterations in 0.1396 sec
# Iteration  100, KL divergence 83072.7557, 50 iterations in 0.1624 sec
# Iteration  150, KL divergence 83118.0247, 50 iterations in 0.1353 sec
# Iteration  200, KL divergence 83143.5822, 50 iterations in 0.1486 sec
# Iteration  250, KL divergence 83165.7081, 50 iterations in 0.1432 sec
#    --> Time elapsed: 0.73 seconds
# seconds:  1.824111235095188
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.95 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83006.5255, 50 iterations in 0.1503 sec
# Iteration  100, KL divergence 83072.7557, 50 iterations in 0.1412 sec
# Iteration  150, KL divergence 83118.0247, 50 iterations in 0.1375 sec
# Iteration  200, KL divergence 83143.5822, 50 iterations in 0.1412 sec
# Iteration  250, KL divergence 83165.7081, 50 iterations in 0.1326 sec
#    --> Time elapsed: 0.70 seconds
# seconds:  1.7061668750829995
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.83 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83006.5255, 50 iterations in 0.1364 sec
# Iteration  100, KL divergence 83072.7557, 50 iterations in 0.1374 sec
# Iteration  150, KL divergence 83118.0247, 50 iterations in 0.1346 sec
# Iteration  200, KL divergence 83143.5822, 50 iterations in 0.1351 sec
# Iteration  250, KL divergence 83165.7081, 50 iterations in 0.1392 sec
#    --> Time elapsed: 0.68 seconds
# seconds:  1.553048370173201
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.95 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83006.5255, 50 iterations in 0.1468 sec
# Iteration  100, KL divergence 83072.7557, 50 iterations in 0.1387 sec
# Iteration  150, KL divergence 83118.0247, 50 iterations in 0.1364 sec
# Iteration  200, KL divergence 83143.5822, 50 iterations in 0.1362 sec
# Iteration  250, KL divergence 83165.7081, 50 iterations in 0.1348 sec
#    --> Time elapsed: 0.69 seconds
# seconds:  1.679678080137819
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.97 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83006.5255, 50 iterations in 0.1410 sec
# Iteration  100, KL divergence 83072.7557, 50 iterations in 0.1406 sec
# Iteration  150, KL divergence 83118.0247, 50 iterations in 0.1364 sec
# Iteration  200, KL divergence 83143.5822, 50 iterations in 0.1409 sec
# Iteration  250, KL divergence 83165.7081, 50 iterations in 0.1347 sec
#    --> Time elapsed: 0.69 seconds
# seconds:  1.695991741027683
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.95 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83006.5255, 50 iterations in 0.1460 sec
# Iteration  100, KL divergence 83072.7557, 50 iterations in 0.1458 sec
# Iteration  150, KL divergence 83118.0247, 50 iterations in 0.1384 sec
# Iteration  200, KL divergence 83143.5822, 50 iterations in 0.1477 sec
# Iteration  250, KL divergence 83165.7081, 50 iterations in 0.1439 sec
#    --> Time elapsed: 0.72 seconds
# seconds:  1.707785011967644

# %%
projection_speeds
# Out:
#     method_ dimensions      dataset     speed   nex
# 0   network          2  macosko2015  0.257463  4481
# 1   network          2  macosko2015  0.002170  4481
# 2   network          2  macosko2015  0.001784  4481
# 3   network          2  macosko2015  0.001726  4481
# 4   network          2  macosko2015  0.001711  4481
# ..      ...        ...          ...       ...   ...
# 85     TSNE          2  macosko2015  1.706167  4481
# 86     TSNE          2  macosko2015  1.553048  4481
# 87     TSNE          2  macosko2015  1.679678  4481
# 88     TSNE          2  macosko2015  1.695992  4481
# 89     TSNE          2  macosko2015  1.707785  4481
#
# [90 rows x 5 columns]

# %% [markdown]
# ### Save

# %%
save_loc = DATA_DIR / 'projection_speeds' / (dataset + '.pickle')
ensure_dir(save_loc)
projection_speeds.to_pickle(save_loc)
