# %% [markdown]
# #### Outline
# - for each dataset:
#     - load dataset;
#     - for each network:
#         - load network
#         - project 1000 test dataset samples
#         - save to metric dataframe

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=''
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=''

# %%
import numpy as np
import pickle
import pandas as pd
import time
from umap import UMAP

# %%
from tfumap.umap import tfUMAP
import tensorflow as tf
from sklearn.decomposition import PCA
from openTSNE import TSNE
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
from tqdm.autonotebook import tqdm

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

# %%
output_dir = MODEL_DIR/'projections'

# %%
projection_speeds = pd.DataFrame(columns = ['method_', 'dimensions', 'dataset', 'speed', "nex"])

# %% [markdown]
# ### FMNIST

# %%
dataset = 'cifar10'
dims = (32,32,3)

# %% [markdown]
# ##### load dataset

# %%
from tensorflow.keras.datasets import cifar10

# load dataset
(train_images, Y_train), (test_images, Y_test) = cifar10.load_data()
X_train = (train_images/255.).astype('float32')
X_test = (test_images/255.).astype('float32')
X_train = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))

# subset a validation set
n_valid = 10000
X_valid = X_train[-n_valid:]
Y_valid = Y_train[-n_valid:].flatten()
X_train = X_train[:-n_valid]
Y_train = Y_train[:-n_valid].flatten()
Y_test = Y_test.flatten()

print(len(X_train), len(X_valid), len(X_test))
# Out:
# 40000 10000 10000

# %%
X_test.shape
# Out:
# (10000, 3072)

# %%
X_test_flat = X_test

# %%
X_train_flat = X_train

# %%
X_test = X_test.reshape((10000, 32,32,3))

# %% [markdown]
# #### Network

# %% [markdown]
# ##### 2 dims

# %%
load_loc = output_dir / dataset / 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    encoder(X_test);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['network', 2, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.6012542841490358
# seconds:  0.5013506698887795
# seconds:  0.5005080159753561
# seconds:  0.48961735400371253
# seconds:  0.5211484869942069
# seconds:  0.48291740217246115
# seconds:  0.4844005540944636
# seconds:  0.49247688497416675
# seconds:  0.497127708978951
# seconds:  0.4983965049032122

# %%
##### Network CPU

with tf.device('/CPU:0'):
    n_repeats = 10
    times = []
    for i in tqdm(range(n_repeats)):
        start_time = time.monotonic()
        encoder(X_test);
        end_time = time.monotonic()
        print('seconds: ', end_time - start_time)
        times.append(end_time - start_time)
        projection_speeds.loc[len(projection_speeds)] = ['network-cpu', 2, dataset, end_time - start_time]
# Out:
#    method_ dimensions  dataset     speed
# 0  network          2  cifar10  0.601254
# 1  network          2  cifar10  0.501351
# 2  network          2  cifar10  0.500508
# 3  network          2  cifar10  0.489617
# 4  network          2  cifar10  0.521148
# 5  network          2  cifar10  0.482917
# 6  network          2  cifar10  0.484401
# 7  network          2  cifar10  0.492477
# 8  network          2  cifar10  0.497128
# 9  network          2  cifar10  0.498397

# %% [markdown]
# ##### 64 dims

# %%
load_loc = output_dir / dataset /"64"/ 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    encoder(X_test);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['network', 64, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.5710086468607187
# seconds:  0.5088594648987055
# seconds:  0.5286082709208131
# seconds:  0.5182931739836931
# seconds:  0.5071479850448668
# seconds:  0.5131123859900981
# seconds:  0.5106427951250225
# seconds:  0.5068614569026977
# seconds:  0.518206843174994
# seconds:  0.5020528400782496

# %%
##### Network CPU

with tf.device('/CPU:0'):
    n_repeats = 10
    times = []
    for i in tqdm(range(n_repeats)):
        start_time = time.monotonic()
        encoder(X_test);
        end_time = time.monotonic()
        print('seconds: ', end_time - start_time)
        times.append(end_time - start_time)
        projection_speeds.loc[len(projection_speeds)] = ['network-cpu', 64, dataset, end_time - start_time]
# Out:
#     method_ dimensions  dataset     speed
# 0   network          2  cifar10  0.601254
# 1   network          2  cifar10  0.501351
# 2   network          2  cifar10  0.500508
# 3   network          2  cifar10  0.489617
# 4   network          2  cifar10  0.521148
# 5   network          2  cifar10  0.482917
# 6   network          2  cifar10  0.484401
# 7   network          2  cifar10  0.492477
# 8   network          2  cifar10  0.497128
# 9   network          2  cifar10  0.498397
# 10  network         64  cifar10  0.571009
# 11  network         64  cifar10  0.508859
# 12  network         64  cifar10  0.528608
# 13  network         64  cifar10  0.518293
# 14  network         64  cifar10  0.507148
# 15  network         64  cifar10  0.513112
# 16  network         64  cifar10  0.510643
# 17  network         64  cifar10  0.506861
# 18  network         64  cifar10  0.518207
# 19  network         64  cifar10  0.502053

# %% [markdown]
# #### UMAP-learn

# %% [markdown]
# ##### 2 dims

# %%
embedder = UMAP(n_components = 2, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Wed Jul 15 15:05:02 2020 Finding Nearest Neighbors
# Wed Jul 15 15:05:03 2020 Building RP forest with 15 trees
# Wed Jul 15 15:05:05 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# Wed Jul 15 15:05:17 2020 Finished Nearest Neighbor Search
# Wed Jul 15 15:05:19 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Wed Jul 15 15:05:46 2020 Finished embedding

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['umap-learn', 2, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  24.000269999960437
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  10.875150758074597
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  12.785103488946334
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  10.743633478879929
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  10.787122157867998
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  12.406055805971846
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  11.077284459024668
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  10.664499601116404
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  13.00972669199109
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  11.652978420024738

# %%
projection_speeds
# Out:
#        method_ dimensions  dataset      speed
# 0      network          2  cifar10   0.601254
# 1      network          2  cifar10   0.501351
# 2      network          2  cifar10   0.500508
# 3      network          2  cifar10   0.489617
# 4      network          2  cifar10   0.521148
# 5      network          2  cifar10   0.482917
# 6      network          2  cifar10   0.484401
# 7      network          2  cifar10   0.492477
# 8      network          2  cifar10   0.497128
# 9      network          2  cifar10   0.498397
# 10     network         64  cifar10   0.571009
# 11     network         64  cifar10   0.508859
# 12     network         64  cifar10   0.528608
# 13     network         64  cifar10   0.518293
# 14     network         64  cifar10   0.507148
# 15     network         64  cifar10   0.513112
# 16     network         64  cifar10   0.510643
# 17     network         64  cifar10   0.506861
# 18     network         64  cifar10   0.518207
# 19     network         64  cifar10   0.502053
# 20  umap-learn          2  cifar10  24.000270
# 21  umap-learn          2  cifar10  10.875151
# 22  umap-learn          2  cifar10  12.785103
# 23  umap-learn          2  cifar10  10.743633
# 24  umap-learn          2  cifar10  10.787122
# 25  umap-learn          2  cifar10  12.406056
# 26  umap-learn          2  cifar10  11.077284
# 27  umap-learn          2  cifar10  10.664500
# 28  umap-learn          2  cifar10  13.009727
# 29  umap-learn          2  cifar10  11.652978

# %% [markdown]
# ##### 64 dims

# %%
embedder = UMAP(n_components = 64, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, n_components=64, verbose=True)
# Construct fuzzy simplicial set
# Wed Jul 15 15:07:56 2020 Finding Nearest Neighbors
# Wed Jul 15 15:07:56 2020 Building RP forest with 15 trees
# Wed Jul 15 15:07:58 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# Wed Jul 15 15:08:02 2020 Finished Nearest Neighbor Search
# Wed Jul 15 15:08:02 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Wed Jul 15 15:08:37 2020 Finished embedding

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['umap-learn', 64, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  12.429585800971836
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  12.76642105402425
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  12.842278184834868
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  11.852752375183627
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  12.543990853009745
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  13.186660406878218
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  14.542319196043536
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  12.56314766802825
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  11.089447791920975
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  12.120259294984862

# %%
projection_speeds
# Out:
#        method_ dimensions  dataset      speed
# 0      network          2  cifar10   0.601254
# 1      network          2  cifar10   0.501351
# 2      network          2  cifar10   0.500508
# 3      network          2  cifar10   0.489617
# 4      network          2  cifar10   0.521148
# 5      network          2  cifar10   0.482917
# 6      network          2  cifar10   0.484401
# 7      network          2  cifar10   0.492477
# 8      network          2  cifar10   0.497128
# 9      network          2  cifar10   0.498397
# 10     network         64  cifar10   0.571009
# 11     network         64  cifar10   0.508859
# 12     network         64  cifar10   0.528608
# 13     network         64  cifar10   0.518293
# 14     network         64  cifar10   0.507148
# 15     network         64  cifar10   0.513112
# 16     network         64  cifar10   0.510643
# 17     network         64  cifar10   0.506861
# 18     network         64  cifar10   0.518207
# 19     network         64  cifar10   0.502053
# 20  umap-learn          2  cifar10  24.000270
# 21  umap-learn          2  cifar10  10.875151
# 22  umap-learn          2  cifar10  12.785103
# 23  umap-learn          2  cifar10  10.743633
# 24  umap-learn          2  cifar10  10.787122
# 25  umap-learn          2  cifar10  12.406056
# 26  umap-learn          2  cifar10  11.077284
# 27  umap-learn          2  cifar10  10.664500
# 28  umap-learn          2  cifar10  13.009727
# 29  umap-learn          2  cifar10  11.652978
# 30  umap-learn         64  cifar10  12.429586
# 31  umap-learn         64  cifar10  12.766421
# 32  umap-learn         64  cifar10  12.842278
# 33  umap-learn         64  cifar10  11.852752
# 34  umap-learn         64  cifar10  12.543991
# 35  umap-learn         64  cifar10  13.186660
# 36  umap-learn         64  cifar10  14.542319
# 37  umap-learn         64  cifar10  12.563148
# 38  umap-learn         64  cifar10  11.089448
# 39  umap-learn         64  cifar10  12.120259

# %% [markdown]
# #### PCA

# %% [markdown]
# ##### 2 dims

# %%
pca = PCA(n_components=2)
z = pca.fit_transform(X_train_flat)

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    pca.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['pca', 2, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.06865169410593808
# seconds:  0.06343075609765947
# seconds:  0.06430793018080294
# seconds:  0.06356498994864523
# seconds:  0.06579376198351383
# seconds:  0.06408629403449595
# seconds:  0.06308056600391865
# seconds:  0.06559553695842624
# seconds:  0.06296488200314343
# seconds:  0.06479169405065477

# %%
projection_speeds
# Out:
#        method_ dimensions  dataset      speed
# 0      network          2  cifar10   0.601254
# 1      network          2  cifar10   0.501351
# 2      network          2  cifar10   0.500508
# 3      network          2  cifar10   0.489617
# 4      network          2  cifar10   0.521148
# 5      network          2  cifar10   0.482917
# 6      network          2  cifar10   0.484401
# 7      network          2  cifar10   0.492477
# 8      network          2  cifar10   0.497128
# 9      network          2  cifar10   0.498397
# 10     network         64  cifar10   0.571009
# 11     network         64  cifar10   0.508859
# 12     network         64  cifar10   0.528608
# 13     network         64  cifar10   0.518293
# 14     network         64  cifar10   0.507148
# 15     network         64  cifar10   0.513112
# 16     network         64  cifar10   0.510643
# 17     network         64  cifar10   0.506861
# 18     network         64  cifar10   0.518207
# 19     network         64  cifar10   0.502053
# 20  umap-learn          2  cifar10  24.000270
# 21  umap-learn          2  cifar10  10.875151
# 22  umap-learn          2  cifar10  12.785103
# 23  umap-learn          2  cifar10  10.743633
# 24  umap-learn          2  cifar10  10.787122
# 25  umap-learn          2  cifar10  12.406056
# 26  umap-learn          2  cifar10  11.077284
# 27  umap-learn          2  cifar10  10.664500
# 28  umap-learn          2  cifar10  13.009727
# 29  umap-learn          2  cifar10  11.652978
# 30  umap-learn         64  cifar10  12.429586
# 31  umap-learn         64  cifar10  12.766421
# 32  umap-learn         64  cifar10  12.842278
# 33  umap-learn         64  cifar10  11.852752
# 34  umap-learn         64  cifar10  12.543991
# 35  umap-learn         64  cifar10  13.186660
# 36  umap-learn         64  cifar10  14.542319
# 37  umap-learn         64  cifar10  12.563148
# 38  umap-learn         64  cifar10  11.089448
# 39  umap-learn         64  cifar10  12.120259
# 40         pca          2  cifar10   0.068652
# 41         pca          2  cifar10   0.063431
# 42         pca          2  cifar10   0.064308
# 43         pca          2  cifar10   0.063565
# 44         pca          2  cifar10   0.065794
# 45         pca          2  cifar10   0.064086
# 46         pca          2  cifar10   0.063081
# 47         pca          2  cifar10   0.065596
# 48         pca          2  cifar10   0.062965
# 49         pca          2  cifar10   0.064792

# %% [markdown]
# ##### 64 dims

# %%
pca = PCA(n_components=64)
z = pca.fit_transform(X_train_flat)

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    pca.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['pca', 64, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.07228238810785115
# seconds:  0.07668709405697882
# seconds:  0.07485091197304428
# seconds:  0.07794421003200114
# seconds:  0.07974905311129987
# seconds:  0.07419163291342556
# seconds:  0.0791001240722835
# seconds:  0.07585171004757285
# seconds:  0.07538590696640313
# seconds:  0.07671611593104899

# %%
projection_speeds
# Out:
#        method_ dimensions  dataset      speed
# 0      network          2  cifar10   0.601254
# 1      network          2  cifar10   0.501351
# 2      network          2  cifar10   0.500508
# 3      network          2  cifar10   0.489617
# 4      network          2  cifar10   0.521148
# 5      network          2  cifar10   0.482917
# 6      network          2  cifar10   0.484401
# 7      network          2  cifar10   0.492477
# 8      network          2  cifar10   0.497128
# 9      network          2  cifar10   0.498397
# 10     network         64  cifar10   0.571009
# 11     network         64  cifar10   0.508859
# 12     network         64  cifar10   0.528608
# 13     network         64  cifar10   0.518293
# 14     network         64  cifar10   0.507148
# 15     network         64  cifar10   0.513112
# 16     network         64  cifar10   0.510643
# 17     network         64  cifar10   0.506861
# 18     network         64  cifar10   0.518207
# 19     network         64  cifar10   0.502053
# 20  umap-learn          2  cifar10  24.000270
# 21  umap-learn          2  cifar10  10.875151
# 22  umap-learn          2  cifar10  12.785103
# 23  umap-learn          2  cifar10  10.743633
# 24  umap-learn          2  cifar10  10.787122
# 25  umap-learn          2  cifar10  12.406056
# 26  umap-learn          2  cifar10  11.077284
# 27  umap-learn          2  cifar10  10.664500
# 28  umap-learn          2  cifar10  13.009727
# 29  umap-learn          2  cifar10  11.652978
# 30  umap-learn         64  cifar10  12.429586
# 31  umap-learn         64  cifar10  12.766421
# 32  umap-learn         64  cifar10  12.842278
# 33  umap-learn         64  cifar10  11.852752
# 34  umap-learn         64  cifar10  12.543991
# 35  umap-learn         64  cifar10  13.186660
# 36  umap-learn         64  cifar10  14.542319
# 37  umap-learn         64  cifar10  12.563148
# 38  umap-learn         64  cifar10  11.089448
# 39  umap-learn         64  cifar10  12.120259
# 40         pca          2  cifar10   0.068652
# 41         pca          2  cifar10   0.063431
# 42         pca          2  cifar10   0.064308
# 43         pca          2  cifar10   0.063565
# 44         pca          2  cifar10   0.065794
# 45         pca          2  cifar10   0.064086
# 46         pca          2  cifar10   0.063081
# 47         pca          2  cifar10   0.065596
# 48         pca          2  cifar10   0.062965
# 49         pca          2  cifar10   0.064792
# 50         pca         64  cifar10   0.072282
# 51         pca         64  cifar10   0.076687
# 52         pca         64  cifar10   0.074851
# 53         pca         64  cifar10   0.077944
# 54         pca         64  cifar10   0.079749
# 55         pca         64  cifar10   0.074192
# 56         pca         64  cifar10   0.079100
# 57         pca         64  cifar10   0.075852
# 58         pca         64  cifar10   0.075386
# 59         pca         64  cifar10   0.076716

# %% [markdown]
# #### TSNE

# %% [markdown]
# ##### 2 dims

# %%
tsne = TSNE(
    n_components = 2,
    n_jobs=32,
    verbose=True
)

# %%
embedding_train = tsne.fit(X_train_flat)
# Out:
# --------------------------------------------------------------------------------
# TSNE(n_jobs=32, neighbors=None, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#    --> Time elapsed: 83.38 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.36 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 1.35 seconds
# ===> Running optimization with exaggeration=12.00, lr=3333.33 for 250 iterations...
# Iteration   50, KL divergence 6.8012, 50 iterations in 1.8006 sec
# Iteration  100, KL divergence 6.3838, 50 iterations in 3.5250 sec
# Iteration  150, KL divergence 6.5139, 50 iterations in 3.8239 sec
# Iteration  200, KL divergence 6.3266, 50 iterations in 5.8870 sec
# Iteration  250, KL divergence 6.3516, 50 iterations in 11.6224 sec
#    --> Time elapsed: 26.66 seconds
# ===> Running optimization with exaggeration=1.00, lr=3333.33 for 500 iterations...
# Iteration   50, KL divergence 4.5630, 50 iterations in 7.6965 sec
# Iteration  100, KL divergence 4.2771, 50 iterations in 1.8515 sec
# Iteration  150, KL divergence 4.1549, 50 iterations in 1.4570 sec
# Iteration  200, KL divergence 4.0800, 50 iterations in 1.6480 sec
# Iteration  250, KL divergence 4.0284, 50 iterations in 2.1468 sec
# Iteration  300, KL divergence 3.9904, 50 iterations in 2.6582 sec
# Iteration  350, KL divergence 3.9614, 50 iterations in 3.4055 sec
# Iteration  400, KL divergence 3.9386, 50 iterations in 3.7645 sec
# Iteration  450, KL divergence 3.9206, 50 iterations in 4.8606 sec
# Iteration  500, KL divergence 3.9055, 50 iterations in 5.2334 sec
#    --> Time elapsed: 34.73 seconds

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedding_train.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['TSNE', 2, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 10.57 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 193452.3546, 50 iterations in 0.2563 sec
# Iteration  100, KL divergence 193419.9573, 50 iterations in 0.2866 sec
# Iteration  150, KL divergence 193431.6214, 50 iterations in 0.2897 sec
# Iteration  200, KL divergence 193445.2527, 50 iterations in 0.2593 sec
# Iteration  250, KL divergence 193434.2710, 50 iterations in 0.2650 sec
#    --> Time elapsed: 1.36 seconds
# seconds:  12.148497946094722
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 10.70 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 193452.3546, 50 iterations in 0.2804 sec
# Iteration  100, KL divergence 193419.9573, 50 iterations in 0.2645 sec
# Iteration  150, KL divergence 193431.6214, 50 iterations in 0.2602 sec
# Iteration  200, KL divergence 193445.2527, 50 iterations in 0.2636 sec
# Iteration  250, KL divergence 193434.2710, 50 iterations in 0.2935 sec
#    --> Time elapsed: 1.36 seconds
# seconds:  12.128644997952506
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 10.66 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 193452.3546, 50 iterations in 0.2527 sec
# Iteration  100, KL divergence 193419.9573, 50 iterations in 0.2700 sec
# Iteration  150, KL divergence 193431.6214, 50 iterations in 0.2789 sec
# Iteration  200, KL divergence 193445.2527, 50 iterations in 0.2527 sec
# Iteration  250, KL divergence 193434.2710, 50 iterations in 0.2820 sec
#    --> Time elapsed: 1.34 seconds
# seconds:  12.042520754039288
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 10.58 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 193452.3546, 50 iterations in 0.2493 sec
# Iteration  100, KL divergence 193419.9573, 50 iterations in 0.2591 sec
# Iteration  150, KL divergence 193431.6214, 50 iterations in 0.2438 sec
# Iteration  200, KL divergence 193445.2527, 50 iterations in 0.2671 sec
# Iteration  250, KL divergence 193434.2710, 50 iterations in 0.2755 sec
#    --> Time elapsed: 1.30 seconds
# seconds:  11.923690238036215
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 10.54 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 193452.3546, 50 iterations in 0.2494 sec
# Iteration  100, KL divergence 193419.9573, 50 iterations in 0.2564 sec
# Iteration  150, KL divergence 193431.6214, 50 iterations in 0.2553 sec
# Iteration  200, KL divergence 193445.2527, 50 iterations in 0.2540 sec
# Iteration  250, KL divergence 193434.2710, 50 iterations in 0.2626 sec
#    --> Time elapsed: 1.28 seconds
# seconds:  11.873668506043032
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 10.63 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 193452.3546, 50 iterations in 0.2636 sec
# Iteration  100, KL divergence 193419.9573, 50 iterations in 0.2619 sec
# Iteration  150, KL divergence 193431.6214, 50 iterations in 0.2725 sec
# Iteration  200, KL divergence 193445.2527, 50 iterations in 0.2580 sec
# Iteration  250, KL divergence 193434.2710, 50 iterations in 0.2457 sec
#    --> Time elapsed: 1.30 seconds
# seconds:  11.99141823593527
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 11.32 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 193452.3546, 50 iterations in 0.2599 sec
# Iteration  100, KL divergence 193419.9573, 50 iterations in 0.2759 sec
# Iteration  150, KL divergence 193431.6214, 50 iterations in 0.2557 sec
# Iteration  200, KL divergence 193445.2527, 50 iterations in 0.2788 sec
# Iteration  250, KL divergence 193434.2710, 50 iterations in 0.2518 sec
#    --> Time elapsed: 1.32 seconds
# seconds:  12.699352340074256
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 10.56 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 193452.3546, 50 iterations in 0.2644 sec
# Iteration  100, KL divergence 193419.9573, 50 iterations in 0.2495 sec
# Iteration  150, KL divergence 193431.6214, 50 iterations in 0.2906 sec
# Iteration  200, KL divergence 193445.2527, 50 iterations in 0.2655 sec
# Iteration  250, KL divergence 193434.2710, 50 iterations in 0.2443 sec
#    --> Time elapsed: 1.31 seconds
# seconds:  11.923088914016262
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 10.74 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 193452.3546, 50 iterations in 0.2644 sec
# Iteration  100, KL divergence 193419.9573, 50 iterations in 0.2720 sec
# Iteration  150, KL divergence 193431.6214, 50 iterations in 0.2642 sec
# Iteration  200, KL divergence 193445.2527, 50 iterations in 0.2901 sec
# Iteration  250, KL divergence 193434.2710, 50 iterations in 0.2704 sec
#    --> Time elapsed: 1.36 seconds
# seconds:  12.163713356014341
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 10.56 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 193452.3546, 50 iterations in 0.2424 sec
# Iteration  100, KL divergence 193419.9573, 50 iterations in 0.2651 sec
# Iteration  150, KL divergence 193431.6214, 50 iterations in 0.2675 sec
# Iteration  200, KL divergence 193445.2527, 50 iterations in 0.2534 sec
# Iteration  250, KL divergence 193434.2710, 50 iterations in 0.2687 sec
#    --> Time elapsed: 1.30 seconds
# seconds:  11.907391268061474

# %%
projection_speeds
# Out:
#     method_ dimensions  dataset      speed
# 0   network          2  cifar10   0.601254
# 1   network          2  cifar10   0.501351
# 2   network          2  cifar10   0.500508
# 3   network          2  cifar10   0.489617
# 4   network          2  cifar10   0.521148
# ..      ...        ...      ...        ...
# 65     TSNE          2  cifar10  11.991418
# 66     TSNE          2  cifar10  12.699352
# 67     TSNE          2  cifar10  11.923089
# 68     TSNE          2  cifar10  12.163713
# 69     TSNE          2  cifar10  11.907391
#
# [70 rows x 4 columns]

# %% [markdown]
# ### Save

# %%
save_loc = DATA_DIR / 'projection_speeds' / (dataset + '.pickle')
ensure_dir(save_loc)
projection_speeds.to_pickle(save_loc)
