# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
print(gpu_devices)
tf.keras.backend.clear_session()
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### dataset information

# %%
from datetime import datetime

dataset = "cifar10"
dims = (32, 32, 3)
num_classes = 10
labels_per_class = 1024 # full
batch_size = 128
datestring = datetime.now().strftime("%Y_%m_%d_%H_%M_%S_%f")
datestring = (
    str(dataset)
    + "_"
    + str(labels_per_class)
    + "____"
    + datestring 
    + '_baseline_augmented'
)
print(datestring)
# Out:
# cifar10_1024____2020_08_09_22_24_33_866449_baseline_augmented

# %% [markdown]
# ### Load packages

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from IPython import display
import pandas as pd
import umap
import copy
import os, tempfile
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### Load dataset

# %%
from tfumap.load_datasets import load_CIFAR10, mask_labels
X_train, X_test, X_valid, Y_train, Y_test, Y_valid = load_CIFAR10(flatten=False)
X_train.shape
# Out:
# (40000, 32, 32, 3)

# %%
if labels_per_class == "full":
    X_labeled = X_train
    Y_masked = Y_labeled = Y_train
else:
    X_labeled, Y_labeled, Y_masked = mask_labels(
        X_train, Y_train, labels_per_class=labels_per_class
    )

# %% [markdown]
# ### Build network

# %%
from tensorflow.keras import datasets, layers, models
from tensorflow_addons.layers import WeightNormalization

def conv_block(filts, name, kernel_size = (3, 3), padding = "same", **kwargs):
    return WeightNormalization(
        layers.Conv2D(
            filts, kernel_size, activation=None, padding=padding, **kwargs
        ),
        name="conv"+name,
    )
#CNN13
#See: 
#https://github.com/vikasverma1077/ICT/blob/master/networks/lenet.py
#https://github.com/brain-research/realistic-ssl-evaluation

# %%
lr_alpha = 0.1
dropout_rate = 0.5
num_classes = 10
input_shape = (32, 32, 3)
model = models.Sequential()
model.add(tf.keras.Input(shape=input_shape))
### conv1a
name = '1a'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1b
name = '1b'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1c
name = '1c'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp1"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop1"))

### conv2a
name = '2a'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha))

### conv2b
name = '2b'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv2c
name = '2c'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp2"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop2"))

### conv3a
name = '3a'
model.add(conv_block(name = name, filts = 512, kernel_size = (3,3), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3b
name = '3b'
model.add(conv_block(name = name, filts = 256, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3c
name = '3c'
model.add(conv_block(name = name, filts = 128, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.AveragePooling2D(pool_size=(6, 6), strides=2, padding='valid'))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation=None, name='z'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc1'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc2'))
model.add(WeightNormalization(layers.Dense(num_classes, activation=None)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1a (WeightNormalization) (None, 32, 32, 128)       7297
# _________________________________________________________________
# bn1a (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1a (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1b (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1b (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1b (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1c (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1c (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1c (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# mp1 (MaxPooling2D)           (None, 16, 16, 128)       0
# _________________________________________________________________
# drop1 (Dropout)              (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2a (WeightNormalization) (None, 16, 16, 256)       590593
# _________________________________________________________________
# bn2a (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2b (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2b (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2b (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2c (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2c (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2c (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# mp2 (MaxPooling2D)           (None, 8, 8, 256)         0
# _________________________________________________________________
# drop2 (Dropout)              (None, 8, 8, 256)         0
# _________________________________________________________________
# conv3a (WeightNormalization) (None, 6, 6, 512)         2360833
# _________________________________________________________________
# bn3a (BatchNormalization)    (None, 6, 6, 512)         2048
# _________________________________________________________________
# lrelu3a (LeakyReLU)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv3b (WeightNormalization) (None, 6, 6, 256)         262913
# _________________________________________________________________
# bn3b (BatchNormalization)    (None, 6, 6, 256)         1024
# _________________________________________________________________
# lrelu3b (LeakyReLU)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv3c (WeightNormalization) (None, 6, 6, 128)         65921
# _________________________________________________________________
# bn3c (BatchNormalization)    (None, 6, 6, 128)         512
# _________________________________________________________________
# lrelu3c (LeakyReLU)          (None, 6, 6, 128)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# z (Dense)                    (None, 256)               33024
# _________________________________________________________________
# weight_normalization (Weight (None, 256)               131841
# _________________________________________________________________
# lrelufc1 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_1 (Weig (None, 256)               131841
# _________________________________________________________________
# lrelufc2 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_2 (Weig (None, 10)                5151
# =================================================================
# Total params: 6,549,034
# Trainable params: 3,292,308
# Non-trainable params: 3,256,726
# _________________________________________________________________

# %% [markdown]
# ### Augmentation

# %%
import tensorflow_addons as tfa
def augment(image, label):
    image = tf.squeeze(image) # Add 6 pixels of padding
    image = tf.image.resize_with_crop_or_pad(image, dims[0] + 6, dims[1] + 6) # crop 6 pixels
    image = tf.image.random_crop(image, size=dims)
    image = tf.image.random_brightness(image, max_delta=0.15)  # Random brightness
    image= tf.image.random_contrast(image, lower=0.6, upper=1.4)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_hue(image, 0.05, seed=None)
    #image = tf.image.random_jpeg_quality(image, 10, 100, seed=None)
    image = tfa.image.rotate(image, tf.squeeze(tf.random.uniform(shape = (1,1), minval=-.2, maxval=.2)), interpolation='BILINEAR')
    image = tfa.image.random_cutout(tf.expand_dims(image, 0), (8,8), constant_values=0.5)[0]
    image = tf.clip_by_value(image, 0, 1)
    return image, label

# %%
nex = 10
for i in range(5):
    fig, axs = plt.subplots(ncols=nex +1, figsize=((nex+1)*2, 2))
    axs[0].imshow(X_train[i])
    axs[0].axis('off')
    for ax in axs.flatten()[1:]:
        ax.imshow(augment(X_train[i], Y_train[i])[0])
        ax.axis('off')

# %% [markdown]
# ### train

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', min_delta=0, patience=50, verbose=0, mode='auto',
    baseline=None, restore_best_weights=False
)

# %%
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)
model.compile(tf.keras.optimizers.Adam(1e-3), loss = loss, metrics=['accuracy'])

# %%
Y_valid_one_hot = tf.keras.backend.one_hot(
    Y_valid, num_classes
)

# %%
Y_labeled_one_hot = tf.keras.backend.one_hot(
    Y_labeled, num_classes
)

# %%
train_ds = (
     tf.data.Dataset.from_tensor_slices((X_labeled, Y_labeled_one_hot))
    .shuffle(1000)
    .map(augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.experimental.AUTOTUNE)
)

# %%
history = model.fit(
    train_ds,
    epochs=500,
    validation_data=(X_valid, Y_valid_one_hot),
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/500
# 80/80 [==============================] - 23s 287ms/step - loss: 1.9429 - accuracy: 0.5096 - val_loss: 81.5725 - val_accuracy: 0.1002
# Epoch 2/500
# 80/80 [==============================] - 19s 243ms/step - loss: 1.8652 - accuracy: 0.4906 - val_loss: 2.7655 - val_accuracy: 0.1040
# Epoch 3/500
# 80/80 [==============================] - 21s 263ms/step - loss: 1.8758 - accuracy: 0.4896 - val_loss: 3.6489 - val_accuracy: 0.1025
# Epoch 4/500
# 80/80 [==============================] - 18s 219ms/step - loss: 1.9163 - accuracy: 0.4591 - val_loss: 11.6578 - val_accuracy: 0.1055
# Epoch 5/500
# 80/80 [==============================] - 21s 266ms/step - loss: 1.9170 - accuracy: 0.4257 - val_loss: 7.4684 - val_accuracy: 0.0974
# Epoch 6/500
# 80/80 [==============================] - 17s 210ms/step - loss: 1.9359 - accuracy: 0.4097 - val_loss: 8.9546 - val_accuracy: 0.1030
# Epoch 7/500
# 80/80 [==============================] - 20s 252ms/step - loss: 2.0109 - accuracy: 0.3476 - val_loss: 3.4978 - val_accuracy: 0.1082
# Epoch 8/500
# 80/80 [==============================] - 19s 231ms/step - loss: 1.9634 - accuracy: 0.3604 - val_loss: 3.3812 - val_accuracy: 0.1046
# Epoch 9/500
# 80/80 [==============================] - 19s 238ms/step - loss: 2.0750 - accuracy: 0.3149 - val_loss: 4.4938 - val_accuracy: 0.1022
# Epoch 10/500
# 80/80 [==============================] - 20s 252ms/step - loss: 2.1018 - accuracy: 0.2771 - val_loss: 5.1399 - val_accuracy: 0.1022
# Epoch 11/500
# 80/80 [==============================] - 17s 213ms/step - loss: 2.0761 - accuracy: 0.3005 - val_loss: 2.7776 - val_accuracy: 0.1629
# Epoch 12/500
# 80/80 [==============================] - 20s 251ms/step - loss: 2.0864 - accuracy: 0.2689 - val_loss: 3.4782 - val_accuracy: 0.1022
# Epoch 13/500
# 80/80 [==============================] - 17s 216ms/step - loss: 1.9972 - accuracy: 0.2837 - val_loss: 3.4252 - val_accuracy: 0.1022
# Epoch 14/500
# 80/80 [==============================] - 20s 250ms/step - loss: 2.1950 - accuracy: 0.2017 - val_loss: 2.5837 - val_accuracy: 0.1033
# Epoch 15/500
# 80/80 [==============================] - 19s 236ms/step - loss: 2.1446 - accuracy: 0.2053 - val_loss: 2.7580 - val_accuracy: 0.1029
# Epoch 16/500
# 80/80 [==============================] - 18s 227ms/step - loss: 2.3357 - accuracy: 0.1257 - val_loss: 2.9208 - val_accuracy: 0.1022
# Epoch 17/500
# 80/80 [==============================] - 20s 250ms/step - loss: 2.2255 - accuracy: 0.2035 - val_loss: 2.7837 - val_accuracy: 0.1137
# Epoch 18/500
# 80/80 [==============================] - 17s 211ms/step - loss: 2.0653 - accuracy: 0.2622 - val_loss: 3.4029 - val_accuracy: 0.1028
# Epoch 19/500
# 80/80 [==============================] - 20s 254ms/step - loss: 2.3220 - accuracy: 0.1345 - val_loss: 2.3413 - val_accuracy: 0.1348
# Epoch 20/500
# 80/80 [==============================] - 17s 217ms/step - loss: 2.0914 - accuracy: 0.2589 - val_loss: 2.7676 - val_accuracy: 0.1059
# Epoch 21/500
# 80/80 [==============================] - 19s 242ms/step - loss: 2.0566 - accuracy: 0.2794 - val_loss: 2.6665 - val_accuracy: 0.1024
# Epoch 22/500
# 80/80 [==============================] - 20s 248ms/step - loss: 2.0951 - accuracy: 0.2419 - val_loss: 3.0471 - val_accuracy: 0.1079
# Epoch 23/500
# 80/80 [==============================] - 20s 246ms/step - loss: 2.2476 - accuracy: 0.1354 - val_loss: 2.6920 - val_accuracy: 0.0973
# Epoch 24/500
# 80/80 [==============================] - 20s 250ms/step - loss: 2.3385 - accuracy: 0.1159 - val_loss: 2.4679 - val_accuracy: 0.1000
# Epoch 25/500
# 80/80 [==============================] - 17s 211ms/step - loss: 2.4825 - accuracy: 0.0561 - val_loss: 2.3219 - val_accuracy: 0.1102
# Epoch 26/500
# 80/80 [==============================] - 20s 251ms/step - loss: 2.3803 - accuracy: 0.0634 - val_loss: 2.3286 - val_accuracy: 0.1046
# Epoch 27/500
# 80/80 [==============================] - 18s 229ms/step - loss: 2.4083 - accuracy: 0.0633 - val_loss: 2.3120 - val_accuracy: 0.1088
# Epoch 28/500
# 80/80 [==============================] - 19s 232ms/step - loss: 2.3823 - accuracy: 0.0579 - val_loss: 2.3088 - val_accuracy: 0.1120
# Epoch 29/500
# 80/80 [==============================] - 20s 245ms/step - loss: 2.3586 - accuracy: 0.0735 - val_loss: 2.3328 - val_accuracy: 0.1133
# Epoch 30/500
# 80/80 [==============================] - 17s 218ms/step - loss: 2.3849 - accuracy: 0.0671 - val_loss: 2.3148 - val_accuracy: 0.1114
# Epoch 31/500
# 80/80 [==============================] - 20s 246ms/step - loss: 2.3642 - accuracy: 0.0634 - val_loss: 2.3013 - val_accuracy: 0.1165
# Epoch 32/500
# 80/80 [==============================] - 18s 224ms/step - loss: 2.3532 - accuracy: 0.0783 - val_loss: 2.3053 - val_accuracy: 0.1247
# Epoch 33/500
# 80/80 [==============================] - 19s 241ms/step - loss: 2.2649 - accuracy: 0.1173 - val_loss: 2.7990 - val_accuracy: 0.1067
# Epoch 34/500
# 80/80 [==============================] - 19s 241ms/step - loss: 2.3672 - accuracy: 0.1151 - val_loss: 2.3640 - val_accuracy: 0.1021
# Epoch 35/500
# 80/80 [==============================] - 18s 225ms/step - loss: 2.0178 - accuracy: 0.3252 - val_loss: 3.3107 - val_accuracy: 0.1049
# Epoch 36/500
# 80/80 [==============================] - 19s 241ms/step - loss: 2.1188 - accuracy: 0.2106 - val_loss: 2.5435 - val_accuracy: 0.1077
# Epoch 37/500
# 80/80 [==============================] - 18s 222ms/step - loss: 2.2278 - accuracy: 0.1565 - val_loss: 2.5601 - val_accuracy: 0.1167
# Epoch 38/500
# 80/80 [==============================] - 19s 242ms/step - loss: 1.9523 - accuracy: 0.3482 - val_loss: 2.3820 - val_accuracy: 0.1024
# Epoch 39/500
# 80/80 [==============================] - 19s 232ms/step - loss: 2.0340 - accuracy: 0.2546 - val_loss: 2.4502 - val_accuracy: 0.1003
# Epoch 40/500
# 80/80 [==============================] - 18s 230ms/step - loss: 2.3688 - accuracy: 0.1190 - val_loss: 2.9145 - val_accuracy: 0.1022
# Epoch 41/500
# 80/80 [==============================] - 20s 251ms/step - loss: 2.4527 - accuracy: 0.0758 - val_loss: 2.3226 - val_accuracy: 0.1013
# Epoch 42/500
# 80/80 [==============================] - 17s 212ms/step - loss: 2.3437 - accuracy: 0.0723 - val_loss: 2.3504 - val_accuracy: 0.1018
# Epoch 43/500
# 80/80 [==============================] - 20s 250ms/step - loss: 2.2089 - accuracy: 0.1780 - val_loss: 2.6509 - val_accuracy: 0.1003
# Epoch 44/500
# 80/80 [==============================] - 18s 219ms/step - loss: 2.2880 - accuracy: 0.1345 - val_loss: 2.3642 - val_accuracy: 0.0977
# Epoch 45/500
# 80/80 [==============================] - 20s 246ms/step - loss: 2.4141 - accuracy: 0.0639 - val_loss: 2.3079 - val_accuracy: 0.1025
# Epoch 46/500
# 80/80 [==============================] - 19s 238ms/step - loss: 2.1572 - accuracy: 0.2119 - val_loss: 2.6662 - val_accuracy: 0.1020
# Epoch 47/500
# 80/80 [==============================] - 18s 225ms/step - loss: 2.0244 - accuracy: 0.2747 - val_loss: 2.5892 - val_accuracy: 0.1003
# Epoch 48/500
# 80/80 [==============================] - 20s 249ms/step - loss: 2.0914 - accuracy: 0.2710 - val_loss: 3.1706 - val_accuracy: 0.1022
# Epoch 49/500
# 80/80 [==============================] - 17s 212ms/step - loss: 2.2601 - accuracy: 0.1975 - val_loss: 2.3167 - val_accuracy: 0.1119
# Epoch 50/500
# 80/80 [==============================] - 20s 250ms/step - loss: 2.2708 - accuracy: 0.1486 - val_loss: 2.3359 - val_accuracy: 0.1036
# Epoch 51/500
# 80/80 [==============================] - 18s 221ms/step - loss: 2.1944 - accuracy: 0.1981 - val_loss: 2.3986 - val_accuracy: 0.1002
# Epoch 52/500
# 80/80 [==============================] - 20s 247ms/step - loss: 2.2721 - accuracy: 0.1222 - val_loss: 2.4240 - val_accuracy: 0.1035
# Epoch 53/500
# 80/80 [==============================] - 19s 236ms/step - loss: 2.3251 - accuracy: 0.1011 - val_loss: 2.3288 - val_accuracy: 0.0976
# Epoch 54/500
# 80/80 [==============================] - 18s 224ms/step - loss: 2.2419 - accuracy: 0.1584 - val_loss: 2.4365 - val_accuracy: 0.1003
# Epoch 55/500
# 80/80 [==============================] - 20s 247ms/step - loss: 2.1603 - accuracy: 0.1824 - val_loss: 2.5772 - val_accuracy: 0.1022
# Epoch 56/500
# 80/80 [==============================] - 17s 213ms/step - loss: 2.0736 - accuracy: 0.2579 - val_loss: 2.6956 - val_accuracy: 0.1022
# Epoch 57/500
# 80/80 [==============================] - 20s 245ms/step - loss: 2.1665 - accuracy: 0.1967 - val_loss: 2.8924 - val_accuracy: 0.1022
# Epoch 58/500
# 80/80 [==============================] - 15s 187ms/step - loss: 2.1263 - accuracy: 0.2153 - val_loss: 3.2169 - val_accuracy: 0.1022
# Epoch 59/500
# 80/80 [==============================] - 16s 203ms/step - loss: 2.3520 - accuracy: 0.1077 - val_loss: 2.3378 - val_accuracy: 0.1005
# Epoch 60/500
# 80/80 [==============================] - 19s 232ms/step - loss: 2.2433 - accuracy: 0.1814 - val_loss: 2.3172 - val_accuracy: 0.1063
# Epoch 61/500
# 80/80 [==============================] - 17s 214ms/step - loss: 2.1999 - accuracy: 0.1813 - val_loss: 2.7489 - val_accuracy: 0.1022

# %% [markdown]
# ### evaluate

# %%
Y_test_one_hot = tf.keras.backend.one_hot(
    Y_test, num_classes
)
result = model.evaluate(X_test, Y_test_one_hot)
# Out:
# 313/313 [==============================] - 9s 30ms/step - loss: 2.7515 - accuracy: 0.1000

# %%
plt.semilogx(history.history['loss'])
plt.semilogx(history.history['val_loss'])

# %%
plt.semilogx(history.history['accuracy'])
plt.semilogx(history.history['val_accuracy'])

# %%
submodel = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
    )
z = submodel.predict(X_train)
np.shape(z)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))

# %%
predictions = model.predict(X_train)

# %%
mask = np.array(np.argmax(predictions, axis=1)) != Y_train.flatten()

# %%
fig, axs = plt.subplots(ncols = 5, figsize=(50,10))
axs[0].scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 1, cmap = plt.cm.tab10)
axs[1].scatter(embedding[:, 0], embedding[:, 1], c=np.argmax(predictions, axis=1), s= 1, alpha = 1, cmap = plt.cm.tab10)
axs[2].scatter(embedding[:, 0], embedding[:, 1], c=np.array(np.argmax(predictions, axis=1)) == Y_train.flatten(), s= 1, alpha = 1, cmap = plt.cm.viridis)
axs[3].scatter(embedding[mask, 0], embedding[mask, 1], c=Y_train.flatten()[mask], s= 10, alpha = 1, cmap = plt.cm.tab10)
axs[4].scatter(embedding[mask, 0], embedding[mask, 1], c=np.argmax(predictions, axis=1)[mask], s= 10, alpha = 1, cmap = plt.cm.tab10)
