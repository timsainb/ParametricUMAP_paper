# %% [markdown]
# #### Outline
# - for each dataset:
#     - load dataset;
#     - for each network:
#         - load network
#         - project training data
#         - project testing data
#         - train KNN classifier (k=1)
#         - save results to dataframe

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=''
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=''

# %%
import numpy as np
import pickle
import pandas as pd
import time
from umap import UMAP

# %%
from tfumap.umap import tfUMAP
import tensorflow as tf
from sklearn.decomposition import PCA
from openTSNE import TSNE
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from tqdm.autonotebook import tqdm

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

# %%
output_dir = MODEL_DIR/'projections'

# %%
KNN_results_df = pd.DataFrame(columns = ['method_', 'dimensions', 'dataset', '1NN_acc', '5NN_acc'])

# %% [markdown]
# ### MNIST

# %%
dataset = 'fmnist'
dims = (28,28,1)

# %% [markdown]
# ##### load dataset

# %%
from tensorflow.keras.datasets import fashion_mnist

# load dataset
(train_images, Y_train), (test_images, Y_test) = fashion_mnist.load_data()
X_train = (train_images/255.).astype('float32')
X_test = (test_images/255.).astype('float32')
X_train = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))

# subset a validation set
n_valid = 10000
X_valid = X_train[-n_valid:]
Y_valid = Y_train[-n_valid:]
X_train = X_train[:-n_valid]
Y_train = Y_train[:-n_valid]

# flatten X
X_train_flat = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test_flat = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))
X_valid_flat= X_valid.reshape((len(X_valid), np.product(np.shape(X_valid)[1:])))
print(len(X_train), len(X_valid), len(X_test))
# Out:
# 50000 10000 10000

# %% [markdown]
# #### Network

# %% [markdown]
# ##### 2 dims

# %%
load_loc = output_dir / dataset / 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
Z_train = embedder.transform(X_train_flat);
Z_test = embedder.transform(X_test_flat);

# %%
neigh5 = KNeighborsClassifier(n_neighbors=5)
neigh5.fit(Z_train, Y_train)
score_5nn = neigh5.score(Z_test, Y_test)
score_5nn
# Out:
# 0.7407

# %%
neigh1 = KNeighborsClassifier(n_neighbors=1)
neigh1.fit(Z_train, Y_train)
score_1nn = neigh1.score(Z_test, Y_test)

# %%
import matplotlib.pyplot as plt

# %%
KNN_results_df.loc[len(KNN_results_df)] = ['network', 2, dataset, score_1nn, score_5nn]

# %%
KNN_results_df
# Out:
#    method_ dimensions dataset  1NN_acc  5NN_acc
# 0  network          2  fmnist   0.6941   0.7407

# %%
fig, axs = plt.subplots(ncols=2, figsize=(14,7))
axs[0].scatter(Z_train[:,0], Z_train[:,1], c= Y_train, s = 0.1, cmap = plt.cm.tab10)
axs[1].scatter(Z_test[:,0], Z_test[:,1], c= Y_test, s = 1, cmap = plt.cm.tab10)

# %% [markdown]
# ##### 64 dims

# %%
load_loc = output_dir / dataset /"64"/ 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
Z_train = embedder.transform(X_train_flat);
Z_test = embedder.transform(X_test_flat);

neigh5 = KNeighborsClassifier(n_neighbors=5)
neigh5.fit(Z_train, Y_train)
score_5nn = neigh5.score(Z_test, Y_test)
score_5nn

neigh1 = KNeighborsClassifier(n_neighbors=1)
neigh1.fit(Z_train, Y_train)
score_1nn = neigh1.score(Z_test, Y_test)

KNN_results_df.loc[len(KNN_results_df)] = ['network', 64, dataset, score_1nn, score_5nn]

KNN_results_df
# Out:
#    method_ dimensions dataset  1NN_acc  5NN_acc
# 0  network          2  fmnist   0.6941   0.7407
# 1  network         64  fmnist   0.7431   0.7878

# %% [markdown]
# ### AE

# %% [markdown]
# ##### 2 dims

# %%
load_loc = output_dir / dataset / 'autoencoder'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    decoding_method = "autoencoder",
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
Z_train = embedder.transform(X_train_flat);
Z_test = embedder.transform(X_test_flat);

neigh5 = KNeighborsClassifier(n_neighbors=5)
neigh5.fit(Z_train, Y_train)
score_5nn = neigh5.score(Z_test, Y_test)
score_5nn

neigh1 = KNeighborsClassifier(n_neighbors=1)
neigh1.fit(Z_train, Y_train)
score_1nn = neigh1.score(Z_test, Y_test)

KNN_results_df.loc[len(KNN_results_df)] = ['autoencoder', 2, dataset, score_1nn, score_5nn]

KNN_results_df
# Out:
#        method_ dimensions dataset  1NN_acc  5NN_acc
# 0      network          2  fmnist   0.6941   0.7407
# 1      network         64  fmnist   0.7431   0.7878
# 2  autoencoder          2  fmnist   0.7083   0.7561

# %%
fig, axs = plt.subplots(ncols=2, figsize=(14,7))
axs[0].scatter(Z_train[:,0], Z_train[:,1], c= Y_train, s = 0.1, cmap = plt.cm.tab10)
axs[1].scatter(Z_test[:,0], Z_test[:,1], c= Y_test, s = 1, cmap = plt.cm.tab10)

# %% [markdown]
# ##### 64 dims

# %%
load_loc = output_dir / dataset /"64"/ 'autoencoder'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    decoding_method = "autoencoder",
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
Z_train = embedder.transform(X_train_flat);
Z_test = embedder.transform(X_test_flat);

neigh5 = KNeighborsClassifier(n_neighbors=5)
neigh5.fit(Z_train, Y_train)
score_5nn = neigh5.score(Z_test, Y_test)
score_5nn

neigh1 = KNeighborsClassifier(n_neighbors=1)
neigh1.fit(Z_train, Y_train)
score_1nn = neigh1.score(Z_test, Y_test)

KNN_results_df.loc[len(KNN_results_df)] = ['autoencoder', 64, dataset, score_1nn, score_5nn]

KNN_results_df
# Out:
#        method_ dimensions dataset  1NN_acc  5NN_acc
# 0      network          2  fmnist   0.6941   0.7407
# 1      network         64  fmnist   0.7431   0.7878
# 2  autoencoder          2  fmnist   0.7083   0.7561
# 3  autoencoder         64  fmnist   0.7772   0.8028

# %% [markdown]
# #### UMAP-learn

# %% [markdown]
# ##### 2 dims

# %%
embedder = UMAP(n_components = 2, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Thu Jul 16 23:56:06 2020 Finding Nearest Neighbors
# Thu Jul 16 23:56:06 2020 Building RP forest with 16 trees
# Thu Jul 16 23:56:08 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# Thu Jul 16 23:56:18 2020 Finished Nearest Neighbor Search
# Thu Jul 16 23:56:20 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Thu Jul 16 23:56:51 2020 Finished embedding

# %%
Z_train = embedder.transform(X_train_flat);
Z_test = embedder.transform(X_test_flat);

neigh5 = KNeighborsClassifier(n_neighbors=5)
neigh5.fit(Z_train, Y_train)
score_5nn = neigh5.score(Z_test, Y_test)
score_5nn

neigh1 = KNeighborsClassifier(n_neighbors=1)
neigh1.fit(Z_train, Y_train)
score_1nn = neigh1.score(Z_test, Y_test)

KNN_results_df.loc[len(KNN_results_df)] = ['umap-learn', 2, dataset, score_1nn, score_5nn]

KNN_results_df
# Out:
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
#        method_ dimensions dataset  1NN_acc  5NN_acc
# 0      network          2  fmnist   0.6941   0.7407
# 1      network         64  fmnist   0.7431   0.7878
# 2  autoencoder          2  fmnist   0.7083   0.7561
# 3  autoencoder         64  fmnist   0.7772   0.8028
# 4   umap-learn          2  fmnist   0.7144   0.7608

# %%
fig, axs = plt.subplots(ncols=2, figsize=(14,7))
axs[0].scatter(Z_train[:,0], Z_train[:,1], c= Y_train, s = 0.1, cmap = plt.cm.tab10)
axs[1].scatter(Z_test[:,0], Z_test[:,1], c= Y_test, s = 1, cmap = plt.cm.tab10)

# %% [markdown]
# ##### 64 dims

# %%
embedder = UMAP(n_components = 64, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, n_components=64, verbose=True)
# Construct fuzzy simplicial set
# Thu Jul 16 23:57:13 2020 Finding Nearest Neighbors
# Thu Jul 16 23:57:13 2020 Building RP forest with 16 trees
# Thu Jul 16 23:57:14 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# Thu Jul 16 23:57:16 2020 Finished Nearest Neighbor Search
# Thu Jul 16 23:57:16 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Thu Jul 16 23:57:59 2020 Finished embedding

# %%
Z_train = embedder.transform(X_train_flat);
Z_test = embedder.transform(X_test_flat);

neigh5 = KNeighborsClassifier(n_neighbors=5)
neigh5.fit(Z_train, Y_train)
score_5nn = neigh5.score(Z_test, Y_test)
score_5nn

neigh1 = KNeighborsClassifier(n_neighbors=1)
neigh1.fit(Z_train, Y_train)
score_1nn = neigh1.score(Z_test, Y_test)

KNN_results_df.loc[len(KNN_results_df)] = ['umap-learn', 64, dataset, score_1nn, score_5nn]

KNN_results_df
# Out:
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
#        method_ dimensions dataset  1NN_acc  5NN_acc
# 0      network          2  fmnist   0.6941   0.7407
# 1      network         64  fmnist   0.7431   0.7878
# 2  autoencoder          2  fmnist   0.7083   0.7561
# 3  autoencoder         64  fmnist   0.7772   0.8028
# 4   umap-learn          2  fmnist   0.7144   0.7608
# 5   umap-learn         64  fmnist   0.7682   0.8059

# %% [markdown]
# #### PCA

# %% [markdown]
# ##### 2 dims

# %%
pca = PCA(n_components=2)
z = pca.fit_transform(X_train_flat)

# %%
Z_train = pca.transform(X_train_flat);
Z_test = pca.transform(X_test_flat);

neigh5 = KNeighborsClassifier(n_neighbors=5)
neigh5.fit(Z_train, Y_train)
score_5nn = neigh5.score(Z_test, Y_test)
score_5nn

neigh1 = KNeighborsClassifier(n_neighbors=1)
neigh1.fit(Z_train, Y_train)
score_1nn = neigh1.score(Z_test, Y_test)

KNN_results_df.loc[len(KNN_results_df)] = ['PCA', 2, dataset, score_1nn, score_5nn]

KNN_results_df
# Out:
#        method_ dimensions dataset  1NN_acc  5NN_acc
# 0      network          2  fmnist   0.6941   0.7407
# 1      network         64  fmnist   0.7431   0.7878
# 2  autoencoder          2  fmnist   0.7083   0.7561
# 3  autoencoder         64  fmnist   0.7772   0.8028
# 4   umap-learn          2  fmnist   0.7144   0.7608
# 5   umap-learn         64  fmnist   0.7682   0.8059
# 6          PCA          2  fmnist   0.4467   0.5055

# %%
fig, axs = plt.subplots(ncols=2, figsize=(14,7))
axs[0].scatter(Z_train[:,0], Z_train[:,1], c= Y_train, s = 0.1, cmap = plt.cm.tab10)
axs[1].scatter(Z_test[:,0], Z_test[:,1], c= Y_test, s = 1, cmap = plt.cm.tab10)

# %% [markdown]
# ##### 64 dims

# %%
pca = PCA(n_components=64)
z = pca.fit_transform(X_train_flat)

# %%
Z_train = pca.transform(X_train_flat);
Z_test = pca.transform(X_test_flat);

neigh5 = KNeighborsClassifier(n_neighbors=5)
neigh5.fit(Z_train, Y_train)
score_5nn = neigh5.score(Z_test, Y_test)
score_5nn

neigh1 = KNeighborsClassifier(n_neighbors=1)
neigh1.fit(Z_train, Y_train)
score_1nn = neigh1.score(Z_test, Y_test)

KNN_results_df.loc[len(KNN_results_df)] = ['PCA', 64, dataset, score_1nn, score_5nn]

KNN_results_df
# Out:
#        method_ dimensions dataset  1NN_acc  5NN_acc
# 0      network          2  fmnist   0.6941   0.7407
# 1      network         64  fmnist   0.7431   0.7878
# 2  autoencoder          2  fmnist   0.7083   0.7561
# 3  autoencoder         64  fmnist   0.7772   0.8028
# 4   umap-learn          2  fmnist   0.7144   0.7608
# 5   umap-learn         64  fmnist   0.7682   0.8059
# 6          PCA          2  fmnist   0.4467   0.5055
# 7          PCA         64  fmnist   0.8398   0.8568

# %% [markdown]
# #### TSNE

# %% [markdown]
# ##### 2 dims

# %%
tsne = TSNE(
    n_components = 2,
    n_jobs=32,
    verbose=True
)

# %%
embedding_train = tsne.fit(X_train_flat)
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# --------------------------------------------------------------------------------
# TSNE(n_jobs=32, neighbors=None, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 37.35 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.42 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.48 seconds
# ===> Running optimization with exaggeration=12.00, lr=4166.67 for 250 iterations...
# Iteration   50, KL divergence 5.9443, 50 iterations in 1.6975 sec
# Iteration  100, KL divergence 5.4386, 50 iterations in 1.7610 sec
# Iteration  150, KL divergence 5.3136, 50 iterations in 1.7042 sec
# Iteration  200, KL divergence 5.2568, 50 iterations in 1.7369 sec
# Iteration  250, KL divergence 5.2246, 50 iterations in 1.7330 sec
#    --> Time elapsed: 8.63 seconds
# ===> Running optimization with exaggeration=1.00, lr=4166.67 for 500 iterations...
# Iteration   50, KL divergence 3.8578, 50 iterations in 1.6939 sec
# Iteration  100, KL divergence 3.3413, 50 iterations in 1.7186 sec
# Iteration  150, KL divergence 3.0753, 50 iterations in 2.0944 sec
# Iteration  200, KL divergence 2.9079, 50 iterations in 3.1569 sec
# Iteration  250, KL divergence 2.7922, 50 iterations in 4.0410 sec
# Iteration  300, KL divergence 2.7076, 50 iterations in 5.6690 sec
# Iteration  350, KL divergence 2.6437, 50 iterations in 6.6343 sec
# Iteration  400, KL divergence 2.5939, 50 iterations in 8.4462 sec
# Iteration  450, KL divergence 2.5536, 50 iterations in 9.0784 sec
# Iteration  500, KL divergence 2.5210, 50 iterations in 12.1995 sec
#    --> Time elapsed: 54.73 seconds

# %%
Z_train = np.array(embedding_train)
Z_test = embedding_train.transform(X_test_flat);
# Out:
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.30 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197800.4674, 50 iterations in 0.2856 sec
# Iteration  100, KL divergence 198044.2827, 50 iterations in 0.2701 sec
# Iteration  150, KL divergence 198181.8333, 50 iterations in 0.2724 sec
# Iteration  200, KL divergence 198288.9928, 50 iterations in 0.2830 sec
# Iteration  250, KL divergence 198361.3847, 50 iterations in 0.2877 sec
#    --> Time elapsed: 1.40 seconds

# %%
Z_train = np.array(embedding_train)
Z_test = embedding_train.transform(X_test_flat);

neigh5 = KNeighborsClassifier(n_neighbors=5)
neigh5.fit(Z_train, Y_train)
score_5nn = neigh5.score(Z_test, Y_test)
score_5nn

neigh1 = KNeighborsClassifier(n_neighbors=1)
neigh1.fit(Z_train, Y_train)
score_1nn = neigh1.score(Z_test, Y_test)

KNN_results_df.loc[len(KNN_results_df)] = ['TSNE', 2, dataset, score_1nn, score_5nn]

KNN_results_df
# Out:
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.40 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197800.4674, 50 iterations in 0.3086 sec
# Iteration  100, KL divergence 198044.2827, 50 iterations in 0.2832 sec
# Iteration  150, KL divergence 198181.8333, 50 iterations in 0.2786 sec
# Iteration  200, KL divergence 198288.9928, 50 iterations in 0.2865 sec
# Iteration  250, KL divergence 198361.3847, 50 iterations in 0.2824 sec
#    --> Time elapsed: 1.44 seconds
#        method_ dimensions dataset  1NN_acc  5NN_acc
# 0      network          2  fmnist   0.6941   0.7407
# 1      network         64  fmnist   0.7431   0.7878
# 2  autoencoder          2  fmnist   0.7083   0.7561
# 3  autoencoder         64  fmnist   0.7772   0.8028
# 4   umap-learn          2  fmnist   0.7144   0.7608
# 5   umap-learn         64  fmnist   0.7682   0.8059
# 6          PCA          2  fmnist   0.4467   0.5055
# 7          PCA         64  fmnist   0.8398   0.8568
# 8         TSNE          2  fmnist   0.7825   0.8039

# %%
fig, axs = plt.subplots(ncols=2, figsize=(14,7))
axs[0].scatter(Z_train[:,0], Z_train[:,1], c= Y_train, s = 0.1, cmap = plt.cm.tab10)
axs[1].scatter(Z_test[:,0], Z_test[:,1], c= Y_test, s = 1, cmap = plt.cm.tab10)

# %% [markdown]
# ### Save

# %%
save_loc = DATA_DIR / 'knn_classifier' / (dataset + '.pickle')
ensure_dir(save_loc)
KNN_results_df.to_pickle(save_loc)
