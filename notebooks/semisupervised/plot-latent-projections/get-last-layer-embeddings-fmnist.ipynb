# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=''#0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=''#0

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
print(gpu_devices)
tf.keras.backend.clear_session()
# Out:
# []

# %% [markdown]
# ### Load packages

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from IPython import display
import pandas as pd
import umap
import copy
import os, tempfile
import tensorflow_addons as tfa
import pickle
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
dataset = "fmnist"
n_latent_dims = 1024
augmented = False

# %%
from tfumap.semisupervised_keras import load_architecture, load_pretrained_weights, load_dataset

# %%
encoder, classifier, embedder = load_architecture(dataset, n_latent_dims)

# %%
from umap import UMAP

# %%
import seaborn as sns
tab20 = sns.color_palette('tab20', 20)
tab20_dark = tab20[::2]
tab20_light = tab20[1::2]
sns.palplot(tab20_dark)
sns.palplot(tab20_light)
from matplotlib.colors import ListedColormap
darkcmap = ListedColormap(sns.color_palette(tab20_dark).as_hex())
lightcmap = ListedColormap(sns.color_palette(tab20_light).as_hex())

# %%
from tfumap.paths import ensure_dir, DATA_DIR

# %%
for labels_per_class in tqdm([4, 16, 64, 256, 1024, 'full']):
    encoder, classifier = load_pretrained_weights(dataset, augmented, labels_per_class, encoder, classifier)
    # load data
    (
        X_train,
        X_test,
        X_labeled,
        Y_labeled,
        Y_masked,
        X_valid,
        Y_train,
        Y_test,
        Y_valid,
        Y_valid_one_hot,
        Y_labeled_one_hot,
        num_classes,
        dims
    ) = load_dataset(dataset, labels_per_class)
    
    last_layer_class = tf.keras.models.Model(
        classifier.input, [classifier.get_layer(name=classifier.layers[-2].name).get_output_at(0)],
    )
    z = encoder.predict(X_train, verbose=True)
    # test current acc
    train_predictions = classifier.predict(z, verbose=True)
    train_confidence = np.max(train_predictions, axis=1)
    train_predictions = np.argmax(train_predictions, axis=1)
    
    last_layer_act = last_layer_class.predict(z, verbose=True)
    llz = UMAP(verbose=True).fit_transform(last_layer_act)
    
    fig, axs = plt.subplots(ncols=3, figsize=(14, 4))

    axs[0].scatter(
        llz[:, 0],
        llz[:, 1],
        c=Y_train,
        s=1,
        alpha=0.1,
        cmap=plt.cm.tab10,
    )
    axs[1].scatter(
        llz[:, 0],
        llz[:, 1],
        c=train_predictions,
        s=1,
        alpha=0.1,
        cmap=lightcmap,
    )

    axs[2].scatter(
        llz[:, 0],
        llz[:, 1],
        c=train_confidence,
        s=1,
        alpha=0.1,
        cmap=plt.cm.viridis,
    )

    axs[1].scatter(
        llz[Y_masked != -1, 0],
        llz[Y_masked != -1, 1],
        c=Y_train[Y_masked != -1].flatten(),
        s=10,
        alpha=1,
        cmap=darkcmap,
        rasterized=True,
    )
    plt.show()
    
    ### save data
    # ensure dir
    save_dir = DATA_DIR / 'ssl_embeddings' / dataset / str(labels_per_class)
    ensure_dir(save_dir)
    # save predictions
    np.save(save_dir/'train_predictions.npy', train_predictions)
    # save confidence
    np.save(save_dir/'train_confidence.npy', train_confidence)
    # save last layer z
    np.save(save_dir/'last_layer_embeddings.npy', llz)
# Out:
# HBox(children=(IntProgress(value=0, max=6), HTML(value='')))
# WARNING: Logging before flag parsing goes to stderr.
# W0828 15:34:40.704520 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d749da0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d6feda0>).
# W0828 15:34:40.706220 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d760240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d70ce10>).
# W0828 15:34:40.727407 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb726ab7128> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241dc518>).
# W0828 15:34:40.730777 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241dc518> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7242ead30>).
# W0828 15:34:40.735052 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72427dbe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72427dfd0>).
# W0828 15:34:40.737689 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72427dfd0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72424a3c8>).
# W0828 15:34:40.741413 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb7241b2b38> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241e7b00>).
# W0828 15:34:40.744026 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241e7b00> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7241e7be0>).
# W0828 15:34:40.749924 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb724174668> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241745c0>).
# W0828 15:34:40.752552 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241745c0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb724174f98>).
# W0828 15:34:40.758078 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72411d710> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72411dcc0>).
# W0828 15:34:40.761880 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72411dcc0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72411df60>).
# W0828 15:34:40.768562 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb7240f1a58> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240f1cf8>).
# W0828 15:34:40.772213 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240f1cf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7240f1f98>).
# W0828 15:34:40.780947 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb724054198> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240547b8>).
# W0828 15:34:40.784719 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240547b8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7240549e8>).
# W0828 15:34:40.789837 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72402b588> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72402b898>).
# W0828 15:34:40.792296 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72402b898> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72402ba20>).
# W0828 15:34:40.795861 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d7ed5c0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb71d7ed8d0>).
# W0828 15:34:40.798341 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb71d7ed8d0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d7eda58>).
# 1563/1563 [==============================] - 208s 133ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Fri Aug 28 15:38:15 2020 Finding Nearest Neighbors
# Fri Aug 28 15:38:15 2020 Building RP forest with 16 trees
# Fri Aug 28 15:38:17 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# Fri Aug 28 15:38:29 2020 Finished Nearest Neighbor Search
# Fri Aug 28 15:38:32 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Fri Aug 28 15:39:24 2020 Finished embedding
# W0828 15:39:29.631866 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d749da0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d6feda0>).
# W0828 15:39:29.633810 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d760240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d70ce10>).
# W0828 15:39:29.688797 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb726ab7128> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241dc518>).
# W0828 15:39:29.694197 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241dc518> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7242ead30>).
# W0828 15:39:29.699459 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72427dbe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72427dfd0>).
# W0828 15:39:29.703179 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72427dfd0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72424a3c8>).
# W0828 15:39:29.708607 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb7241b2b38> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241e7b00>).
# W0828 15:39:29.712095 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241e7b00> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7241e7be0>).
# W0828 15:39:29.718823 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb724174668> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241745c0>).
# W0828 15:39:29.722035 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241745c0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb724174f98>).
# W0828 15:39:29.726803 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72411d710> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72411dcc0>).
# W0828 15:39:29.730642 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72411dcc0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72411df60>).
# W0828 15:39:29.735723 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb7240f1a58> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240f1cf8>).
# W0828 15:39:29.739257 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240f1cf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7240f1f98>).
# W0828 15:39:29.748062 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb724054198> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240547b8>).
# W0828 15:39:29.750821 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240547b8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7240549e8>).
# W0828 15:39:29.756979 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72402b588> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72402b898>).
# W0828 15:39:29.760736 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72402b898> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72402ba20>).
# W0828 15:39:29.766035 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d7ed5c0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb71d7ed8d0>).
# W0828 15:39:29.769662 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb71d7ed8d0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d7eda58>).
# 1563/1563 [==============================] - 205s 131ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 1s 936us/step
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Fri Aug 28 15:42:59 2020 Finding Nearest Neighbors
# Fri Aug 28 15:42:59 2020 Building RP forest with 16 trees
# Fri Aug 28 15:42:59 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# Fri Aug 28 15:43:01 2020 Finished Nearest Neighbor Search
# Fri Aug 28 15:43:01 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Fri Aug 28 15:44:19 2020 Finished embedding
# W0828 15:44:24.358717 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d749da0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d6feda0>).
# W0828 15:44:24.360811 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d760240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d70ce10>).
# W0828 15:44:24.424993 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb726ab7128> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241dc518>).
# W0828 15:44:24.429366 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241dc518> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7242ead30>).
# W0828 15:44:24.435965 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72427dbe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72427dfd0>).
# W0828 15:44:24.439761 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72427dfd0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72424a3c8>).
# W0828 15:44:24.446540 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb7241b2b38> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241e7b00>).
# W0828 15:44:24.450081 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241e7b00> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7241e7be0>).
# W0828 15:44:24.459428 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb724174668> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241745c0>).
# W0828 15:44:24.463886 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241745c0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb724174f98>).
# W0828 15:44:24.469036 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72411d710> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72411dcc0>).
# W0828 15:44:24.474377 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72411dcc0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72411df60>).
# W0828 15:44:24.479039 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb7240f1a58> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240f1cf8>).
# W0828 15:44:24.483517 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240f1cf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7240f1f98>).
# W0828 15:44:24.492147 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb724054198> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240547b8>).
# W0828 15:44:24.495885 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240547b8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7240549e8>).
# W0828 15:44:24.500726 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72402b588> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72402b898>).
# W0828 15:44:24.504925 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72402b898> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72402ba20>).
# W0828 15:44:24.509551 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d7ed5c0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb71d7ed8d0>).
# W0828 15:44:24.512793 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb71d7ed8d0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d7eda58>).
# 1030/1563 [==================>...........] - ETA: 1:10	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Fri Aug 28 15:48:57 2020 Finished embedding
# W0828 15:49:03.181612 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d749da0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d6feda0>).
# W0828 15:49:03.183397 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d760240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d70ce10>).
# W0828 15:49:03.260291 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb726ab7128> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241dc518>).
# W0828 15:49:03.264133 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241dc518> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7242ead30>).
# W0828 15:49:03.277438 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72427dbe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72427dfd0>).
# W0828 15:49:03.280879 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72427dfd0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72424a3c8>).
# W0828 15:49:03.304028 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb7241b2b38> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241e7b00>).
# W0828 15:49:03.312199 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241e7b00> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7241e7be0>).
# W0828 15:49:03.363476 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb724174668> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241745c0>).
# W0828 15:49:03.372709 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241745c0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb724174f98>).
# W0828 15:49:03.384392 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72411d710> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72411dcc0>).
# W0828 15:49:03.389710 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72411dcc0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72411df60>).
# W0828 15:49:03.394367 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb7240f1a58> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240f1cf8>).
# W0828 15:49:03.399285 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240f1cf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7240f1f98>).
# W0828 15:49:03.407568 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb724054198> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240547b8>).
# W0828 15:49:03.411697 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240547b8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7240549e8>).
# W0828 15:49:03.417225 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72402b588> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72402b898>).
# W0828 15:49:03.420420 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72402b898> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72402ba20>).
# W0828 15:49:03.425944 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d7ed5c0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb71d7ed8d0>).
# W0828 15:49:03.429355 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb71d7ed8d0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d7eda58>).
# 1563/1563 [==============================] - 204s 130ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Fri Aug 28 15:52:33 2020 Finding Nearest Neighbors
# Fri Aug 28 15:52:33 2020 Building RP forest with 16 trees
# Fri Aug 28 15:52:33 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# Fri Aug 28 15:52:35 2020 Finished Nearest Neighbor Search
# Fri Aug 28 15:52:36 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Fri Aug 28 15:53:39 2020 Finished embedding
# W0828 15:53:45.527505 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d749da0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d6feda0>).
# W0828 15:53:45.529139 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d760240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d70ce10>).
# W0828 15:53:45.558651 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb726ab7128> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241dc518>).
# W0828 15:53:45.561529 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241dc518> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7242ead30>).
# W0828 15:53:45.567077 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72427dbe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72427dfd0>).
# ...
# W0828 15:53:45.703212 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb724054198> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240547b8>).
# W0828 15:53:45.707226 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240547b8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7240549e8>).
# W0828 15:53:45.712958 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72402b588> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72402b898>).
# W0828 15:53:45.717347 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72402b898> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72402ba20>).
# W0828 15:53:45.723750 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d7ed5c0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb71d7ed8d0>).
# W0828 15:53:45.727592 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb71d7ed8d0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d7eda58>).
# 1272/1563 [=======================>......] - ETA: 36s
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 1563/1563 [==============================] - 184s 118ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Fri Aug 28 15:56:54 2020 Finding Nearest Neighbors
# Fri Aug 28 15:56:54 2020 Building RP forest with 16 trees
# Fri Aug 28 15:56:55 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# Fri Aug 28 15:56:56 2020 Finished Nearest Neighbor Search
# Fri Aug 28 15:56:57 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Fri Aug 28 15:58:15 2020 Finished embedding
# W0828 15:58:20.523184 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d749da0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d6feda0>).
# W0828 15:58:20.525337 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d760240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d70ce10>).
# W0828 15:58:20.553845 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb726ab7128> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241dc518>).
# W0828 15:58:20.557990 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241dc518> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7242ead30>).
# W0828 15:58:20.563233 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72427dbe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72427dfd0>).
# W0828 15:58:20.566954 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72427dfd0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72424a3c8>).
# W0828 15:58:20.572094 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb7241b2b38> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241e7b00>).
# W0828 15:58:20.575974 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241e7b00> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7241e7be0>).
# W0828 15:58:20.585215 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb724174668> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241745c0>).
# W0828 15:58:20.589018 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7241745c0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb724174f98>).
# W0828 15:58:20.594576 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72411d710> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72411dcc0>).
# W0828 15:58:20.599203 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72411dcc0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72411df60>).
# W0828 15:58:20.603637 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb7240f1a58> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240f1cf8>).
# W0828 15:58:20.607129 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240f1cf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7240f1f98>).
# W0828 15:58:20.615574 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb724054198> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240547b8>).
# W0828 15:58:20.619248 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb7240547b8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb7240549e8>).
# W0828 15:58:20.624251 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb72402b588> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72402b898>).
# W0828 15:58:20.627599 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb72402b898> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb72402ba20>).
# W0828 15:58:20.632634 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fb71d7ed5c0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb71d7ed8d0>).
# W0828 15:58:20.636111 140427800049472 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fb71d7ed8d0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fb71d7eda58>).
# 1563/1563 [==============================] - 139s 89ms/step
# 1563/1563 [==============================] - 2s 988us/step
# 1563/1563 [==============================] - 2s 1ms/step
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Fri Aug 28 16:00:44 2020 Finding Nearest Neighbors
# Fri Aug 28 16:00:44 2020 Building RP forest with 16 trees
# Fri Aug 28 16:00:45 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# Fri Aug 28 16:00:47 2020 Finished Nearest Neighbor Search
# Fri Aug 28 16:00:47 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Fri Aug 28 16:02:21 2020 Finished embedding
