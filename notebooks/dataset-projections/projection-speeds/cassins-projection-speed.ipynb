# %% [markdown]
# #### Outline
# - for each dataset:
#     - load dataset;
#     - for each network:
#         - load network
#         - project 1000 test dataset samples
#         - save to metric dataframe

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)

# %%
import numpy as np
import pickle
import pandas as pd
import time
from umap import UMAP

# %%
from tfumap.umap import tfUMAP
import tensorflow as tf
from sklearn.decomposition import PCA
from openTSNE import TSNE
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
from tqdm.autonotebook import tqdm

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

# %%
output_dir = MODEL_DIR/'projections'

# %%
projection_speeds = pd.DataFrame(columns = ['method_', 'dimensions', 'dataset', 'speed', "nex"])

# %% [markdown]
# ### cassins

# %%
dataset = 'cassins_dtw'
dims = (32,31,1)

# %% [markdown]
# ##### load dataset

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

syllable_df = pd.read_pickle(DATA_DIR/'cassins'/ 'cassins.pickle')

#syllable_df= syllable_df[:1000]

syllable_df[:3]

top_labels = (
    pd.DataFrame(
        {i: [np.sum(syllable_df.labels.values == i)] for i in syllable_df.labels.unique()}
    )
    .T.sort_values(by=0, ascending=False)[:20]
    .T
)
top_labels

syllable_df = syllable_df[syllable_df.labels.isin(top_labels.columns)]

syllable_df[:3]

syllable_df = syllable_df.reset_index()

syllable_df['subset'] = 'train'
syllable_df.loc[:1000, 'subset'] = 'valid'
syllable_df.loc[1000:1999, 'subset'] = 'test'
#syllable_df.loc[:100, 'subset'] = 'valid'
#syllable_df.loc[100:199, 'subset'] = 'test'

specs = np.array(list(syllable_df.spectrogram.values))
specs = np.array([np.concatenate([np.zeros((32,1)), i], axis=1) for i in tqdm(specs)])
specs.shape

syllable_df['spectrogram'] = syllable_df['spectrogram'].astype('object')
syllable_df['spectrogram'] = list(specs)

np.shape(syllable_df['spectrogram'].values[0])

len(syllable_df)

Y_train = np.array(list(syllable_df.labels.values[syllable_df.subset == 'train']))
Y_valid = np.array(list(syllable_df.labels.values[syllable_df.subset == 'valid']))
Y_test = np.array(list(syllable_df.labels.values[syllable_df.subset == 'test']))

X_train = np.array(list(syllable_df.spectrogram.values[syllable_df.subset == 'train'])) #/ 255.
X_valid = np.array(list(syllable_df.spectrogram.values[syllable_df.subset == 'valid']))# / 255.
X_test = np.array(list(syllable_df.spectrogram.values[syllable_df.subset == 'test'])) #/ 255.

X_train_flat = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test_flat = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))

from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
Y_train = enc.fit_transform([[i] for i in Y_train]).astype('int').flatten()
X_test = X_test.reshape((len(X_test), 32,32,1))
# Out:
# HBox(children=(IntProgress(value=0, max=26984), HTML(value='')))

# %% [markdown]
# #### Network

# %% [markdown]
# ##### 2 dims

# %%
load_loc = output_dir / dataset / 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    encoder(X_test);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['network', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  1.9986373430583626
# seconds:  0.007758233929052949
# seconds:  0.008959567872807384
# seconds:  0.0075960601679980755
# seconds:  0.009051150875166059
# seconds:  0.00730384117923677
# seconds:  0.007466196082532406
# seconds:  0.0073777439538389444
# seconds:  0.007055864203721285
# seconds:  0.008038301952183247

# %%
##### Network CPU

with tf.device('/CPU:0'):
    n_repeats = 10
    times = []
    for i in tqdm(range(n_repeats)):
        start_time = time.monotonic()
        encoder(X_test);
        end_time = time.monotonic()
        print('seconds: ', end_time - start_time)
        times.append(end_time - start_time)
        projection_speeds.loc[len(projection_speeds)] = ['network-cpu', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.22179583087563515
# seconds:  0.05232092319056392
# seconds:  0.05061970301903784
# seconds:  0.052772385999560356
# seconds:  0.05594308814033866
# seconds:  0.05203477409668267
# seconds:  0.04802542901597917
# seconds:  0.04842807003296912
# seconds:  0.048062809044495225
# seconds:  0.047522274078801274

# %% [markdown]
# ##### 64 dims

# %%
load_loc = output_dir / dataset /"64"/ 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    encoder(X_test);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['network', 64, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.20757481991313398
# seconds:  0.008206608006730676
# seconds:  0.010095322038978338
# seconds:  0.007917959010228515
# seconds:  0.00722349900752306
# seconds:  0.007565918145701289
# seconds:  0.007455145008862019
# seconds:  0.007130536017939448
# seconds:  0.007478926097974181
# seconds:  0.00735634402371943

# %%
##### Network CPU

with tf.device('/CPU:0'):
    n_repeats = 10
    times = []
    for i in tqdm(range(n_repeats)):
        start_time = time.monotonic()
        encoder(X_test);
        end_time = time.monotonic()
        print('seconds: ', end_time - start_time)
        times.append(end_time - start_time)
        projection_speeds.loc[len(projection_speeds)] = ['network-cpu', 64, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.20587171893566847
# seconds:  0.04768748488277197
# seconds:  0.04786087106913328
# seconds:  0.04897981300018728
# seconds:  0.048601401038467884
# seconds:  0.046968074049800634
# seconds:  0.048188708955422044
# seconds:  0.04788177995942533
# seconds:  0.04846215690486133
# seconds:  0.04742997791618109

# %% [markdown]
# #### UMAP-learn

# %% [markdown]
# ##### 2 dims

# %%
embedder = UMAP(n_components = 2, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sat Jul 18 13:23:48 2020 Finding Nearest Neighbors
# Sat Jul 18 13:23:48 2020 Building RP forest with 13 trees
# Sat Jul 18 13:23:49 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# Sat Jul 18 13:23:58 2020 Finished Nearest Neighbor Search
# Sat Jul 18 13:24:01 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sat Jul 18 13:24:25 2020 Finished embedding

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['umap-learn', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  14.819833575980738
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.252251919126138
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  2.8433641069568694
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.3151365811936557
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  2.8448272759560496
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.310884203063324
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  2.816177180968225
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.278716746950522
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  2.8272087380755693
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.278135846136138

# %%
projection_speeds
# Out:
#         method_ dimensions      dataset      speed   nex
# 0       network          2  cassins_dtw   1.998637  1000
# 1       network          2  cassins_dtw   0.007758  1000
# 2       network          2  cassins_dtw   0.008960  1000
# 3       network          2  cassins_dtw   0.007596  1000
# 4       network          2  cassins_dtw   0.009051  1000
# 5       network          2  cassins_dtw   0.007304  1000
# 6       network          2  cassins_dtw   0.007466  1000
# 7       network          2  cassins_dtw   0.007378  1000
# 8       network          2  cassins_dtw   0.007056  1000
# 9       network          2  cassins_dtw   0.008038  1000
# 10  network-cpu          2  cassins_dtw   0.221796  1000
# 11  network-cpu          2  cassins_dtw   0.052321  1000
# 12  network-cpu          2  cassins_dtw   0.050620  1000
# 13  network-cpu          2  cassins_dtw   0.052772  1000
# 14  network-cpu          2  cassins_dtw   0.055943  1000
# 15  network-cpu          2  cassins_dtw   0.052035  1000
# 16  network-cpu          2  cassins_dtw   0.048025  1000
# 17  network-cpu          2  cassins_dtw   0.048428  1000
# 18  network-cpu          2  cassins_dtw   0.048063  1000
# 19  network-cpu          2  cassins_dtw   0.047522  1000
# 20      network         64  cassins_dtw   0.207575  1000
# 21      network         64  cassins_dtw   0.008207  1000
# 22      network         64  cassins_dtw   0.010095  1000
# 23      network         64  cassins_dtw   0.007918  1000
# 24      network         64  cassins_dtw   0.007223  1000
# 25      network         64  cassins_dtw   0.007566  1000
# 26      network         64  cassins_dtw   0.007455  1000
# 27      network         64  cassins_dtw   0.007131  1000
# 28      network         64  cassins_dtw   0.007479  1000
# 29      network         64  cassins_dtw   0.007356  1000
# 30  network-cpu         64  cassins_dtw   0.205872  1000
# 31  network-cpu         64  cassins_dtw   0.047687  1000
# 32  network-cpu         64  cassins_dtw   0.047861  1000
# 33  network-cpu         64  cassins_dtw   0.048980  1000
# 34  network-cpu         64  cassins_dtw   0.048601  1000
# 35  network-cpu         64  cassins_dtw   0.046968  1000
# 36  network-cpu         64  cassins_dtw   0.048189  1000
# 37  network-cpu         64  cassins_dtw   0.047882  1000
# 38  network-cpu         64  cassins_dtw   0.048462  1000
# 39  network-cpu         64  cassins_dtw   0.047430  1000
# 40   umap-learn          2  cassins_dtw  14.819834  1000
# 41   umap-learn          2  cassins_dtw   3.252252  1000
# 42   umap-learn          2  cassins_dtw   2.843364  1000
# 43   umap-learn          2  cassins_dtw   3.315137  1000
# 44   umap-learn          2  cassins_dtw   2.844827  1000
# 45   umap-learn          2  cassins_dtw   3.310884  1000
# 46   umap-learn          2  cassins_dtw   2.816177  1000
# 47   umap-learn          2  cassins_dtw   3.278717  1000
# 48   umap-learn          2  cassins_dtw   2.827209  1000
# 49   umap-learn          2  cassins_dtw   3.278136  1000

# %% [markdown]
# ##### 64 dims

# %%
embedder = UMAP(n_components = 64, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, n_components=64, verbose=True)
# Construct fuzzy simplicial set
# Sat Jul 18 13:25:09 2020 Finding Nearest Neighbors
# Sat Jul 18 13:25:09 2020 Building RP forest with 13 trees
# Sat Jul 18 13:25:09 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# Sat Jul 18 13:25:10 2020 Finished Nearest Neighbor Search
# Sat Jul 18 13:25:11 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sat Jul 18 13:25:33 2020 Finished embedding

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['umap-learn', 64, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.8669534591026604
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  2.920220490079373
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.1979359490796924
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  2.953920155065134
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.1903764349408448
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  2.9221207690425217
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.213289937004447
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  2.909292022930458
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.1911234299186617
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  2.9130019589792937

# %%
projection_speeds
# Out:
#         method_ dimensions      dataset      speed   nex
# 0       network          2  cassins_dtw   1.998637  1000
# 1       network          2  cassins_dtw   0.007758  1000
# 2       network          2  cassins_dtw   0.008960  1000
# 3       network          2  cassins_dtw   0.007596  1000
# 4       network          2  cassins_dtw   0.009051  1000
# 5       network          2  cassins_dtw   0.007304  1000
# 6       network          2  cassins_dtw   0.007466  1000
# 7       network          2  cassins_dtw   0.007378  1000
# 8       network          2  cassins_dtw   0.007056  1000
# 9       network          2  cassins_dtw   0.008038  1000
# 10  network-cpu          2  cassins_dtw   0.221796  1000
# 11  network-cpu          2  cassins_dtw   0.052321  1000
# 12  network-cpu          2  cassins_dtw   0.050620  1000
# 13  network-cpu          2  cassins_dtw   0.052772  1000
# 14  network-cpu          2  cassins_dtw   0.055943  1000
# 15  network-cpu          2  cassins_dtw   0.052035  1000
# 16  network-cpu          2  cassins_dtw   0.048025  1000
# 17  network-cpu          2  cassins_dtw   0.048428  1000
# 18  network-cpu          2  cassins_dtw   0.048063  1000
# 19  network-cpu          2  cassins_dtw   0.047522  1000
# 20      network         64  cassins_dtw   0.207575  1000
# 21      network         64  cassins_dtw   0.008207  1000
# 22      network         64  cassins_dtw   0.010095  1000
# 23      network         64  cassins_dtw   0.007918  1000
# 24      network         64  cassins_dtw   0.007223  1000
# 25      network         64  cassins_dtw   0.007566  1000
# 26      network         64  cassins_dtw   0.007455  1000
# 27      network         64  cassins_dtw   0.007131  1000
# 28      network         64  cassins_dtw   0.007479  1000
# 29      network         64  cassins_dtw   0.007356  1000
# 30  network-cpu         64  cassins_dtw   0.205872  1000
# 31  network-cpu         64  cassins_dtw   0.047687  1000
# 32  network-cpu         64  cassins_dtw   0.047861  1000
# 33  network-cpu         64  cassins_dtw   0.048980  1000
# 34  network-cpu         64  cassins_dtw   0.048601  1000
# 35  network-cpu         64  cassins_dtw   0.046968  1000
# 36  network-cpu         64  cassins_dtw   0.048189  1000
# 37  network-cpu         64  cassins_dtw   0.047882  1000
# 38  network-cpu         64  cassins_dtw   0.048462  1000
# 39  network-cpu         64  cassins_dtw   0.047430  1000
# 40   umap-learn          2  cassins_dtw  14.819834  1000
# 41   umap-learn          2  cassins_dtw   3.252252  1000
# 42   umap-learn          2  cassins_dtw   2.843364  1000
# 43   umap-learn          2  cassins_dtw   3.315137  1000
# 44   umap-learn          2  cassins_dtw   2.844827  1000
# 45   umap-learn          2  cassins_dtw   3.310884  1000
# 46   umap-learn          2  cassins_dtw   2.816177  1000
# 47   umap-learn          2  cassins_dtw   3.278717  1000
# 48   umap-learn          2  cassins_dtw   2.827209  1000
# 49   umap-learn          2  cassins_dtw   3.278136  1000
# 50   umap-learn         64  cassins_dtw   3.866953  1000
# 51   umap-learn         64  cassins_dtw   2.920220  1000
# 52   umap-learn         64  cassins_dtw   3.197936  1000
# 53   umap-learn         64  cassins_dtw   2.953920  1000
# 54   umap-learn         64  cassins_dtw   3.190376  1000
# 55   umap-learn         64  cassins_dtw   2.922121  1000
# 56   umap-learn         64  cassins_dtw   3.213290  1000
# 57   umap-learn         64  cassins_dtw   2.909292  1000
# 58   umap-learn         64  cassins_dtw   3.191123  1000
# 59   umap-learn         64  cassins_dtw   2.913002  1000

# %% [markdown]
# #### PCA

# %% [markdown]
# ##### 2 dims

# %%
pca = PCA(n_components=2)
z = pca.fit_transform(X_train_flat)

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    pca.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['pca', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.004573963116854429
# seconds:  0.0063557850662618876
# seconds:  0.004374526906758547
# seconds:  0.004209551960229874
# seconds:  0.004284874070435762
# seconds:  0.004268313990905881
# seconds:  0.004245693096891046
# seconds:  0.004172991029918194
# seconds:  0.004197912057861686
# seconds:  0.004239782923832536

# %%
projection_speeds
# Out:
#     method_ dimensions      dataset     speed   nex
# 0   network          2  cassins_dtw  1.998637  1000
# 1   network          2  cassins_dtw  0.007758  1000
# 2   network          2  cassins_dtw  0.008960  1000
# 3   network          2  cassins_dtw  0.007596  1000
# 4   network          2  cassins_dtw  0.009051  1000
# ..      ...        ...          ...       ...   ...
# 65      pca          2  cassins_dtw  0.004268  1000
# 66      pca          2  cassins_dtw  0.004246  1000
# 67      pca          2  cassins_dtw  0.004173  1000
# 68      pca          2  cassins_dtw  0.004198  1000
# 69      pca          2  cassins_dtw  0.004240  1000
#
# [70 rows x 5 columns]

# %% [markdown]
# ##### 64 dims

# %%
pca = PCA(n_components=64)
z = pca.fit_transform(X_train_flat)

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    pca.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['pca', 64, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.005040086107328534
# seconds:  0.005261223064735532
# seconds:  0.005180489970371127
# seconds:  0.00519216014072299
# seconds:  0.005373456049710512
# seconds:  0.0051990600768476725
# seconds:  0.005407147808000445
# seconds:  0.0051269689574837685
# seconds:  0.005323165096342564
# seconds:  0.005099037894979119

# %%
projection_speeds
# Out:
#     method_ dimensions      dataset     speed   nex
# 0   network          2  cassins_dtw  1.998637  1000
# 1   network          2  cassins_dtw  0.007758  1000
# 2   network          2  cassins_dtw  0.008960  1000
# 3   network          2  cassins_dtw  0.007596  1000
# 4   network          2  cassins_dtw  0.009051  1000
# ..      ...        ...          ...       ...   ...
# 75      pca         64  cassins_dtw  0.005199  1000
# 76      pca         64  cassins_dtw  0.005407  1000
# 77      pca         64  cassins_dtw  0.005127  1000
# 78      pca         64  cassins_dtw  0.005323  1000
# 79      pca         64  cassins_dtw  0.005099  1000
#
# [80 rows x 5 columns]

# %% [markdown]
# #### TSNE

# %% [markdown]
# ##### 2 dims

# %%
tsne = TSNE(
    n_components = 2,
    n_jobs=32,
    verbose=True
)

# %%
embedding_train = tsne.fit(X_train_flat)
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# --------------------------------------------------------------------------------
# TSNE(n_jobs=32, neighbors=None, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 18.60 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.25 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.45 seconds
# ===> Running optimization with exaggeration=12.00, lr=2082.00 for 250 iterations...
# Iteration   50, KL divergence 5.1153, 50 iterations in 1.4122 sec
# Iteration  100, KL divergence 4.3927, 50 iterations in 1.4483 sec
# Iteration  150, KL divergence 4.1636, 50 iterations in 1.4167 sec
# Iteration  200, KL divergence 4.0462, 50 iterations in 1.4677 sec
# Iteration  250, KL divergence 3.9724, 50 iterations in 1.4516 sec
#    --> Time elapsed: 7.20 seconds
# ===> Running optimization with exaggeration=1.00, lr=2082.00 for 500 iterations...
# Iteration   50, KL divergence 3.0994, 50 iterations in 1.4066 sec
# Iteration  100, KL divergence 2.6222, 50 iterations in 1.4875 sec
# Iteration  150, KL divergence 2.3695, 50 iterations in 1.7790 sec
# Iteration  200, KL divergence 2.2130, 50 iterations in 2.7288 sec
# Iteration  250, KL divergence 2.1065, 50 iterations in 3.5515 sec
# Iteration  300, KL divergence 2.0300, 50 iterations in 4.8372 sec
# Iteration  350, KL divergence 1.9723, 50 iterations in 5.8303 sec
# Iteration  400, KL divergence 1.9283, 50 iterations in 7.7902 sec
# Iteration  450, KL divergence 1.8943, 50 iterations in 8.3606 sec
# Iteration  500, KL divergence 1.8669, 50 iterations in 9.7907 sec
#    --> Time elapsed: 47.57 seconds

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedding_train.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['TSNE', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.42 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 17068.6992, 50 iterations in 0.0636 sec
# Iteration  100, KL divergence 17098.0039, 50 iterations in 0.0627 sec
# Iteration  150, KL divergence 17113.9243, 50 iterations in 0.0625 sec
# Iteration  200, KL divergence 17126.0292, 50 iterations in 0.0620 sec
# Iteration  250, KL divergence 17137.4071, 50 iterations in 0.0642 sec
#    --> Time elapsed: 0.32 seconds
# seconds:  1.0166890290565789
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.68 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 17068.6992, 50 iterations in 0.0664 sec
# Iteration  100, KL divergence 17098.0039, 50 iterations in 0.0615 sec
# Iteration  150, KL divergence 17113.9243, 50 iterations in 0.0657 sec
# Iteration  200, KL divergence 17126.0292, 50 iterations in 0.0623 sec
# Iteration  250, KL divergence 17137.4071, 50 iterations in 0.0613 sec
#    --> Time elapsed: 0.32 seconds
# seconds:  1.0124214950483292
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.65 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 17068.6992, 50 iterations in 0.0691 sec
# Iteration  100, KL divergence 17098.0039, 50 iterations in 0.0646 sec
# Iteration  150, KL divergence 17113.9243, 50 iterations in 0.0600 sec
# Iteration  200, KL divergence 17126.0292, 50 iterations in 0.0591 sec
# Iteration  250, KL divergence 17137.4071, 50 iterations in 0.0595 sec
#    --> Time elapsed: 0.31 seconds
# seconds:  0.984712682897225
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.66 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 17068.6992, 50 iterations in 0.0631 sec
# Iteration  100, KL divergence 17098.0039, 50 iterations in 0.0597 sec
# Iteration  150, KL divergence 17113.9243, 50 iterations in 0.0598 sec
# Iteration  200, KL divergence 17126.0292, 50 iterations in 0.0600 sec
# Iteration  250, KL divergence 17137.4071, 50 iterations in 0.0651 sec
#    --> Time elapsed: 0.31 seconds
# seconds:  0.9957528219092637
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.54 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 17068.6992, 50 iterations in 0.0674 sec
# Iteration  100, KL divergence 17098.0039, 50 iterations in 0.0616 sec
# Iteration  150, KL divergence 17113.9243, 50 iterations in 0.0721 sec
# Iteration  200, KL divergence 17126.0292, 50 iterations in 0.0646 sec
# Iteration  250, KL divergence 17137.4071, 50 iterations in 0.0661 sec
#    --> Time elapsed: 0.33 seconds
# seconds:  0.8940186419058591
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.67 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 17068.6992, 50 iterations in 0.0698 sec
# Iteration  100, KL divergence 17098.0039, 50 iterations in 0.0620 sec
# Iteration  150, KL divergence 17113.9243, 50 iterations in 0.0669 sec
# Iteration  200, KL divergence 17126.0292, 50 iterations in 0.0601 sec
# Iteration  250, KL divergence 17137.4071, 50 iterations in 0.0603 sec
#    --> Time elapsed: 0.32 seconds
# seconds:  1.017817921936512
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.65 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 17068.6992, 50 iterations in 0.0732 sec
# Iteration  100, KL divergence 17098.0039, 50 iterations in 0.0675 sec
# Iteration  150, KL divergence 17113.9243, 50 iterations in 0.0625 sec
# Iteration  200, KL divergence 17126.0292, 50 iterations in 0.0604 sec
# Iteration  250, KL divergence 17137.4071, 50 iterations in 0.0597 sec
#    --> Time elapsed: 0.32 seconds
# seconds:  0.9885831840801984
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.66 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 17068.6992, 50 iterations in 0.0666 sec
# Iteration  100, KL divergence 17098.0039, 50 iterations in 0.0618 sec
# Iteration  150, KL divergence 17113.9243, 50 iterations in 0.0656 sec
# Iteration  200, KL divergence 17126.0292, 50 iterations in 0.0596 sec
# Iteration  250, KL divergence 17137.4071, 50 iterations in 0.0661 sec
#    --> Time elapsed: 0.32 seconds
# seconds:  0.9983355961740017
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.67 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 17068.6992, 50 iterations in 0.0645 sec
# Iteration  100, KL divergence 17098.0039, 50 iterations in 0.0627 sec
# Iteration  150, KL divergence 17113.9243, 50 iterations in 0.0655 sec
# Iteration  200, KL divergence 17126.0292, 50 iterations in 0.0618 sec
# Iteration  250, KL divergence 17137.4071, 50 iterations in 0.0611 sec
#    --> Time elapsed: 0.32 seconds
# seconds:  1.0015467088669538
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.66 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 17068.6992, 50 iterations in 0.0688 sec
# Iteration  100, KL divergence 17098.0039, 50 iterations in 0.0666 sec
# Iteration  150, KL divergence 17113.9243, 50 iterations in 0.0687 sec
# Iteration  200, KL divergence 17126.0292, 50 iterations in 0.0611 sec
# Iteration  250, KL divergence 17137.4071, 50 iterations in 0.0638 sec
#    --> Time elapsed: 0.33 seconds
# seconds:  1.0138210549484938

# %%
projection_speeds
# Out:
#     method_ dimensions      dataset     speed   nex
# 0   network          2  cassins_dtw  1.998637  1000
# 1   network          2  cassins_dtw  0.007758  1000
# 2   network          2  cassins_dtw  0.008960  1000
# 3   network          2  cassins_dtw  0.007596  1000
# 4   network          2  cassins_dtw  0.009051  1000
# ..      ...        ...          ...       ...   ...
# 85     TSNE          2  cassins_dtw  1.017818  1000
# 86     TSNE          2  cassins_dtw  0.988583  1000
# 87     TSNE          2  cassins_dtw  0.998336  1000
# 88     TSNE          2  cassins_dtw  1.001547  1000
# 89     TSNE          2  cassins_dtw  1.013821  1000
#
# [90 rows x 5 columns]

# %% [markdown]
# ### Save

# %%
save_loc = DATA_DIR / 'projection_speeds' / (dataset + '.pickle')
ensure_dir(save_loc)
projection_speeds.to_pickle(save_loc)
