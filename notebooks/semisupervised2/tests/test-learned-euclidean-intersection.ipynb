# %% [markdown]
# - take a dataset (fmnist)
# - train UMAP
# - load pretrained network
# - get latent embeddings
# - intersect

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
print(gpu_devices)
tf.keras.backend.clear_session()
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Load packages

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from IPython import display
import pandas as pd
import umap
import copy
import os, tempfile
import tensorflow_addons as tfa
import pickle
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### parameters

# %%
dataset = "fmnist"
labels_per_class = 4 # 'full'
n_latent_dims = 1024
confidence_threshold = 0.0 # minimum confidence to include in UMAP graph for learned metric
learned_metric = True # whether to use a learned metric, or Euclidean distance between datapoints

augmented = False #
min_dist= 0.001 # min_dist parameter for UMAP
negative_sample_rate = 5 # how many negative samples per positive sample 
batch_size = 128 # batch size 
optimizer = tf.keras.optimizers.Adam(1e-3) # the optimizer to train
optimizer = tfa.optimizers.MovingAverage(optimizer)
label_smoothing = 0.2 # how much label smoothing to apply to categorical crossentropy
max_umap_iterations = 500 # how many times, maximum, to recompute UMAP
max_epochs_per_graph = 10 # how many epochs maximum each graph trains for (without early stopping)
graph_patience = 10 # how many times without improvement to train a new graph
min_graph_delta = 0.0025 # minimum improvement on validation acc to consider an improvement for training

# %% [markdown]
# #### Load dataset

# %%
from tfumap.semisupervised_keras import load_dataset

# %%
(
    X_train,
    X_test,
    X_labeled,
    Y_labeled,
    Y_masked,
    X_valid,
    Y_train,
    Y_test,
    Y_valid,
    Y_valid_one_hot,
    Y_labeled_one_hot,
    num_classes,
    dims
) = load_dataset(dataset, labels_per_class)

# %% [markdown]
# ### load architecture

# %%
from tfumap.semisupervised_keras import load_architecture

# %%
encoder, classifier, embedder = load_architecture(dataset, n_latent_dims)

# %% [markdown]
# ### load pretrained weights

# %%
from tfumap.semisupervised_keras import load_pretrained_weights

# %%
encoder, classifier = load_pretrained_weights(dataset, augmented, labels_per_class, encoder, classifier)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0824 22:48:51.421830 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f5f680e52b0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f5f680e5748>).
# W0824 22:48:51.423394 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f5f680f4668> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f5f680a3da0>).
# W0824 22:48:51.445900 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f5f72efb5f8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f6bbf5048>).
# W0824 22:48:51.448719 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f6bbf5048> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f5f6bc26208>).
# W0824 22:48:51.452530 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f5f72e54cc0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f72e54940>).
# W0824 22:48:51.455261 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f72e54940> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f5f72e54898>).
# W0824 22:48:51.459016 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f5f6bbe0438> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f6bbe0748>).
# W0824 22:48:51.461707 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f6bbe0748> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f5f6bbe0898>).
# W0824 22:48:51.467789 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f5f682ecf60> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f682fc400>).
# W0824 22:48:51.470635 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f682fc400> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f5f682fc438>).
# W0824 22:48:51.474564 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f5f6829dbe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f682a1240>).
# W0824 22:48:51.479990 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f682a1240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f5f682a14a8>).
# W0824 22:48:51.485488 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f5f68271f98> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f6825b278>).
# W0824 22:48:51.489268 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f6825b278> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f5f6825b4e0>).
# W0824 22:48:51.496992 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f5f681d7668> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f681d75c0>).
# W0824 22:48:51.499658 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f681d75c0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f5f681d7f98>).
# W0824 22:48:51.504767 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f5f681aca58> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f681accf8>).
# W0824 22:48:51.508574 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f681accf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f5f681acfd0>).
# W0824 22:48:51.512523 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f5f68183a90> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f68183d30>).
# W0824 22:48:51.515253 140052675303232 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5f68183d30> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f5f68126cf8>).

# %% [markdown]
# #### compute pretrained accuracy

# %%
# test current acc
pretrained_predictions = classifier.predict(encoder.predict(X_test, verbose=True), verbose=True)
pretrained_predictions = np.argmax(pretrained_predictions, axis=1)
pretrained_acc = np.mean(pretrained_predictions == Y_test)
print('pretrained acc: {}'.format(pretrained_acc))
# Out:
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 2ms/step
# pretrained acc: 0.6068

# %% [markdown]
# ### get last layer activation

# %%
# model to grab last layer activations
last_layer_class = tf.keras.models.Model(
    classifier.input,
    [classifier.get_layer(name=classifier.layers[-2].name).get_output_at(0)],
)

# get encoder activations for X_train
enc_z = encoder.predict(X_train)

# get last layer activations for X_train
last_layer_z = last_layer_class.predict(enc_z)

# %% [markdown]
# ### get UMAP graphs

# %%
from umap import UMAP

# %%
embedder_last_layer = UMAP(verbose=True)
z_last_layer = embedder_last_layer.fit_transform(last_layer_z)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Mon Aug 24 22:56:31 2020 Finding Nearest Neighbors
# Mon Aug 24 22:56:31 2020 Building RP forest with 16 trees
# Mon Aug 24 22:56:31 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# Mon Aug 24 22:56:32 2020 Finished Nearest Neighbor Search
# Mon Aug 24 22:56:33 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Aug 24 22:57:19 2020 Finished embedding

# %%
plt.scatter(z_last_layer[:, 0], z_last_layer[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)

# %%
embedder_euc = UMAP(verbose=True)
z_x = embedder_euc.fit_transform(X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:]))))
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Mon Aug 24 22:57:21 2020 Finding Nearest Neighbors
# Mon Aug 24 22:57:21 2020 Building RP forest with 16 trees
# Mon Aug 24 22:57:22 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# Mon Aug 24 22:57:24 2020 Finished Nearest Neighbor Search
# Mon Aug 24 22:57:24 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Aug 24 22:58:10 2020 Finished embedding

# %%
plt.scatter(z_x[:, 0], z_x[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)

# %%
intersected_graph = embedder_euc.graph_ + embedder_last_layer.graph_ / 2

# %%
umap_intersect = UMAP(verbose=True, metric='precomputed')

# %%
z_intersect = umap_intersect.fit_transform(intersected_graph)
# Out:
# /mnt/cube/tsainbur/Projects/github_repos/umap/umap/umap_.py:1632: UserWarning: using precomputed metric; transform will be unavailable for new data and inverse_transform will be unavailable for all data
#   "using precomputed metric; transform will be unavailable for new data and inverse_transform "
# UMAP(dens_frac=0.0, dens_lambda=0.0, metric='precomputed', verbose=True)
# Construct fuzzy simplicial set
# Computing KNNs for sparse precomputed distances...
# Mon Aug 24 22:59:33 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Aug 24 23:00:23 2020 Finished embedding

# %%
plt.scatter(z_intersect[:, 0], z_intersect[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)

# %%
from umap.umap_ import simplicial_set_embedding, check_random_state

# %%
embed_graph
# Out:
# <50000x50000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2005454 stored elements in Compressed Sparse Row format>

# %%
random_state = check_random_state(42)

# %%
embed_graph = intersected_graph
embedding_ = simplicial_set_embedding(
            embedder_euc._raw_data,  # JH why raw data?
            embed_graph,
            embedder_euc.n_components,
            embedder_euc._initial_alpha,
            embedder_euc._a,
            embedder_euc._b,
            embedder_euc.repulsion_strength,
            embedder_euc.negative_sample_rate,
            0,
            embedder_euc.init,
            random_state,
            embedder_euc._input_distance_func,
            embedder_euc._metric_kwds,
            embedder_euc.densmap,
            embedder_euc._densmap_kwds,
            embedder_euc.output_dens,
            embedder_euc._output_distance_func,
            embedder_euc._output_metric_kwds,
            embedder_euc.output_metric in ("euclidean", "l2"),
            embedder_euc.random_state is None,
            embedder_euc.verbose,
        )
# Out:
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs

# %%
embedding_[0]
# Out:
# array([[-1.5419071,  3.125344 ],
#        [13.403752 ,  2.2285242],
#        [ 9.918091 ,  4.8620696],
#        ...,
#        [ 0.3623207,  7.9160995],
#        [ 9.530856 ,  9.281304 ],
#        [-1.1898581,  7.273007 ]], dtype=float32)

# %%
plt.scatter(embedding_[0][:, 0], embedding_[0][:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)

# %%
intersected_graph2 = embedder_euc.graph_ + embedder_last_layer.graph_ - embedder_euc.graph_ * embedder_last_layer.graph_

# %%
embed_graph = intersected_graph2
embedding_, aux_data = simplicial_set_embedding(
            embedder_euc._raw_data,  # JH why raw data?
            embed_graph,
            embedder_euc.n_components,
            embedder_euc._initial_alpha,
            embedder_euc._a,
            embedder_euc._b,
            embedder_euc.repulsion_strength,
            embedder_euc.negative_sample_rate,
            0,
            embedder_euc.init,
            random_state,
            embedder_euc._input_distance_func,
            embedder_euc._metric_kwds,
            embedder_euc.densmap,
            embedder_euc._densmap_kwds,
            embedder_euc.output_dens,
            embedder_euc._output_distance_func,
            embedder_euc._output_metric_kwds,
            embedder_euc.output_metric in ("euclidean", "l2"),
            embedder_euc.random_state is None,
            embedder_euc.verbose,
        )
# Out:
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs

# %%
plt.scatter(embedding_[:, 0], embedding_[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)

# %%
fig, axs = plt.subplots(ncols=3, figsize=(30,10))
ax = axs[0]
ax.scatter(z_x[:, 0], z_x[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.5, cmap = plt.cm.tab10)

ax = axs[1]
ax.scatter(z_last_layer[:, 0], z_last_layer[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.5, cmap = plt.cm.tab10)

ax = axs[2]
ax.scatter(embedding_[:, 0], embedding_[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.5, cmap = plt.cm.tab10)

# %%
from umap.umap_ import simplicial_set_embedding

# %%
simplicial_set_embedding(

# %%
plt.scatter(z_intersect[:, 0], z_intersect[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)

# %%
umap_graph_latent = build_fuzzy_simplicial_set(data, y=Y_masked, n_neighbors=n_neighbors,)
