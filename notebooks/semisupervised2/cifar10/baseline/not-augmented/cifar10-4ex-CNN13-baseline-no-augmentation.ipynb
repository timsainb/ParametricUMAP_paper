# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
print(gpu_devices)
tf.keras.backend.clear_session()
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### dataset information

# %%
from datetime import datetime

dataset = "cifar10"
dims = (32, 32, 3)
num_classes = 10
labels_per_class = 4 # full
batch_size = 128
datestring = datetime.now().strftime("%Y_%m_%d_%H_%M_%S_%f")
datestring = (
    str(dataset)
    + "_"
    + str(labels_per_class)
    + "____"
    + datestring 
    + '_baseline'
)
print(datestring)
# Out:
# cifar10_4____2020_08_09_22_13_28_904367_baseline

# %% [markdown]
# ### Load packages

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from IPython import display
import pandas as pd
import umap
import copy
import os, tempfile
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### Load dataset

# %%
from tfumap.load_datasets import load_CIFAR10, mask_labels
X_train, X_test, X_valid, Y_train, Y_test, Y_valid = load_CIFAR10(flatten=False)
X_train.shape
# Out:
# (40000, 32, 32, 3)

# %%
if labels_per_class == "full":
    X_labeled = X_train
    Y_masked = Y_labeled = Y_train
else:
    X_labeled, Y_labeled, Y_masked = mask_labels(
        X_train, Y_train, labels_per_class=labels_per_class
    )

# %% [markdown]
# ### Build network

# %%
from tensorflow.keras import datasets, layers, models
from tensorflow_addons.layers import WeightNormalization

def conv_block(filts, name, kernel_size = (3, 3), padding = "same", **kwargs):
    return WeightNormalization(
        layers.Conv2D(
            filts, kernel_size, activation=None, padding=padding, **kwargs
        ),
        name="conv"+name,
    )
#CNN13
#See: 
#https://github.com/vikasverma1077/ICT/blob/master/networks/lenet.py
#https://github.com/brain-research/realistic-ssl-evaluation

# %%
lr_alpha = 0.1
dropout_rate = 0.5
num_classes = 10
input_shape = (32, 32, 3)
model = models.Sequential()
model.add(tf.keras.Input(shape=input_shape))
### conv1a
name = '1a'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1b
name = '1b'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1c
name = '1c'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp1"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop1"))

### conv2a
name = '2a'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha))

### conv2b
name = '2b'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv2c
name = '2c'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp2"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop2"))

### conv3a
name = '3a'
model.add(conv_block(name = name, filts = 512, kernel_size = (3,3), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3b
name = '3b'
model.add(conv_block(name = name, filts = 256, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3c
name = '3c'
model.add(conv_block(name = name, filts = 128, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.AveragePooling2D(pool_size=(6, 6), strides=2, padding='valid'))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation=None, name='z'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc1'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc2'))
model.add(WeightNormalization(layers.Dense(num_classes, activation=None)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1a (WeightNormalization) (None, 32, 32, 128)       7297
# _________________________________________________________________
# bn1a (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1a (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1b (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1b (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1b (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1c (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1c (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1c (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# mp1 (MaxPooling2D)           (None, 16, 16, 128)       0
# _________________________________________________________________
# drop1 (Dropout)              (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2a (WeightNormalization) (None, 16, 16, 256)       590593
# _________________________________________________________________
# bn2a (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2b (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2b (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2b (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2c (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2c (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2c (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# mp2 (MaxPooling2D)           (None, 8, 8, 256)         0
# _________________________________________________________________
# drop2 (Dropout)              (None, 8, 8, 256)         0
# _________________________________________________________________
# conv3a (WeightNormalization) (None, 6, 6, 512)         2360833
# _________________________________________________________________
# bn3a (BatchNormalization)    (None, 6, 6, 512)         2048
# _________________________________________________________________
# lrelu3a (LeakyReLU)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv3b (WeightNormalization) (None, 6, 6, 256)         262913
# _________________________________________________________________
# bn3b (BatchNormalization)    (None, 6, 6, 256)         1024
# _________________________________________________________________
# lrelu3b (LeakyReLU)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv3c (WeightNormalization) (None, 6, 6, 128)         65921
# _________________________________________________________________
# bn3c (BatchNormalization)    (None, 6, 6, 128)         512
# _________________________________________________________________
# lrelu3c (LeakyReLU)          (None, 6, 6, 128)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# z (Dense)                    (None, 256)               33024
# _________________________________________________________________
# weight_normalization (Weight (None, 256)               131841
# _________________________________________________________________
# lrelufc1 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_1 (Weig (None, 256)               131841
# _________________________________________________________________
# lrelufc2 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_2 (Weig (None, 10)                5151
# =================================================================
# Total params: 6,549,034
# Trainable params: 3,292,308
# Non-trainable params: 3,256,726
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', min_delta=0, patience=50, verbose=0, mode='auto',
    baseline=None, restore_best_weights=False
)

# %%
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)

# %%
model.compile(tf.keras.optimizers.Adam(1e-4), loss = loss, metrics=['accuracy'])

# %%
Y_valid_one_hot = tf.keras.backend.one_hot(
    Y_valid, num_classes
)

# %%
Y_labeled_one_hot = tf.keras.backend.one_hot(
    Y_labeled, num_classes
)

# %%
history = model.fit(
    X_labeled,
    Y_labeled_one_hot,
    batch_size=batch_size,
    epochs=500,
    validation_data=(X_valid, Y_valid_one_hot),
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 5s 5s/step - loss: 2.4819 - accuracy: 0.1000 - val_loss: 22.2757 - val_accuracy: 0.0931
# Epoch 2/500
# 1/1 [==============================] - 4s 4s/step - loss: 2.2301 - accuracy: 0.1750 - val_loss: 14.2987 - val_accuracy: 0.0925
# Epoch 3/500
# 1/1 [==============================] - 5s 5s/step - loss: 2.1390 - accuracy: 0.1750 - val_loss: 19.9117 - val_accuracy: 0.1006
# Epoch 4/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.9666 - accuracy: 0.3500 - val_loss: 23.8438 - val_accuracy: 0.1003
# Epoch 5/500
# 1/1 [==============================] - 5s 5s/step - loss: 2.0473 - accuracy: 0.4000 - val_loss: 24.0364 - val_accuracy: 0.1017
# Epoch 6/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.8376 - accuracy: 0.5000 - val_loss: 22.6801 - val_accuracy: 0.1116
# Epoch 7/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.7173 - accuracy: 0.5250 - val_loss: 21.2535 - val_accuracy: 0.1269
# Epoch 8/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.7731 - accuracy: 0.5250 - val_loss: 21.1290 - val_accuracy: 0.1286
# Epoch 9/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.6763 - accuracy: 0.5250 - val_loss: 21.2613 - val_accuracy: 0.1240
# Epoch 10/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.6809 - accuracy: 0.6250 - val_loss: 21.9951 - val_accuracy: 0.1134
# Epoch 11/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.6235 - accuracy: 0.6000 - val_loss: 21.8950 - val_accuracy: 0.1074
# Epoch 12/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.5278 - accuracy: 0.7500 - val_loss: 21.7390 - val_accuracy: 0.1037
# Epoch 13/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.5419 - accuracy: 0.6750 - val_loss: 21.4917 - val_accuracy: 0.1030
# Epoch 14/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.5402 - accuracy: 0.6500 - val_loss: 20.4605 - val_accuracy: 0.1110
# Epoch 15/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.4275 - accuracy: 0.8000 - val_loss: 19.8017 - val_accuracy: 0.1215
# Epoch 16/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.4516 - accuracy: 0.7250 - val_loss: 19.1559 - val_accuracy: 0.1316
# Epoch 17/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.4039 - accuracy: 0.8000 - val_loss: 18.7067 - val_accuracy: 0.1336
# Epoch 18/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.3307 - accuracy: 0.7750 - val_loss: 18.1374 - val_accuracy: 0.1301
# Epoch 19/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.3190 - accuracy: 0.9250 - val_loss: 17.9144 - val_accuracy: 0.1247
# Epoch 20/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.4156 - accuracy: 0.7500 - val_loss: 17.7679 - val_accuracy: 0.1187
# Epoch 21/500
# 1/1 [==============================] - 3s 3s/step - loss: 1.3529 - accuracy: 0.8500 - val_loss: 17.7789 - val_accuracy: 0.1130
# Epoch 22/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.2604 - accuracy: 0.8750 - val_loss: 17.7727 - val_accuracy: 0.1105
# Epoch 23/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.2656 - accuracy: 0.9250 - val_loss: 17.5821 - val_accuracy: 0.1059
# Epoch 24/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.2707 - accuracy: 0.8500 - val_loss: 17.4596 - val_accuracy: 0.1070
# Epoch 25/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.1824 - accuracy: 0.9500 - val_loss: 17.2631 - val_accuracy: 0.1070
# Epoch 26/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.1952 - accuracy: 0.9250 - val_loss: 17.1507 - val_accuracy: 0.1058
# Epoch 27/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.1702 - accuracy: 0.9000 - val_loss: 17.1038 - val_accuracy: 0.1069
# Epoch 28/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.1786 - accuracy: 0.9250 - val_loss: 17.1401 - val_accuracy: 0.1067
# Epoch 29/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.1562 - accuracy: 0.8750 - val_loss: 17.0999 - val_accuracy: 0.1067
# Epoch 30/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.1642 - accuracy: 0.9000 - val_loss: 16.9162 - val_accuracy: 0.1070
# Epoch 31/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.1408 - accuracy: 0.9500 - val_loss: 16.5247 - val_accuracy: 0.1061
# Epoch 32/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.1385 - accuracy: 0.9750 - val_loss: 15.6241 - val_accuracy: 0.1056
# Epoch 33/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.0936 - accuracy: 0.9500 - val_loss: 14.7395 - val_accuracy: 0.1040
# Epoch 34/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.1020 - accuracy: 0.9750 - val_loss: 13.8474 - val_accuracy: 0.1032
# Epoch 35/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.0896 - accuracy: 1.0000 - val_loss: 12.9043 - val_accuracy: 0.1032
# Epoch 36/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.1256 - accuracy: 0.9500 - val_loss: 12.1440 - val_accuracy: 0.1019
# Epoch 37/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.0877 - accuracy: 0.9750 - val_loss: 11.4742 - val_accuracy: 0.1016
# Epoch 38/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.0982 - accuracy: 0.9500 - val_loss: 10.9066 - val_accuracy: 0.1011
# Epoch 39/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.0851 - accuracy: 1.0000 - val_loss: 10.5736 - val_accuracy: 0.1002
# Epoch 40/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.0870 - accuracy: 0.9750 - val_loss: 10.5917 - val_accuracy: 0.0988
# Epoch 41/500
# 1/1 [==============================] - 4s 4s/step - loss: 1.0398 - accuracy: 1.0000 - val_loss: 10.6726 - val_accuracy: 0.0986
# Epoch 42/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.0682 - accuracy: 0.9750 - val_loss: 10.8420 - val_accuracy: 0.0983
# Epoch 43/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.0326 - accuracy: 1.0000 - val_loss: 10.9799 - val_accuracy: 0.0991
# Epoch 44/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.0234 - accuracy: 1.0000 - val_loss: 11.0089 - val_accuracy: 0.1017
# Epoch 45/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.0570 - accuracy: 0.9750 - val_loss: 10.6029 - val_accuracy: 0.1028
# Epoch 46/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.0175 - accuracy: 1.0000 - val_loss: 10.1140 - val_accuracy: 0.1045
# Epoch 47/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.0421 - accuracy: 0.9750 - val_loss: 9.4547 - val_accuracy: 0.1058
# Epoch 48/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.0446 - accuracy: 1.0000 - val_loss: 8.8352 - val_accuracy: 0.1059
# Epoch 49/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.0385 - accuracy: 0.9750 - val_loss: 8.2744 - val_accuracy: 0.1069
# Epoch 50/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.0219 - accuracy: 1.0000 - val_loss: 7.4074 - val_accuracy: 0.1072
# Epoch 51/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.0033 - accuracy: 1.0000 - val_loss: 6.8011 - val_accuracy: 0.1084
# Epoch 52/500
# 1/1 [==============================] - 5s 5s/step - loss: 1.0175 - accuracy: 1.0000 - val_loss: 6.3508 - val_accuracy: 0.1123
# Epoch 53/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.9948 - accuracy: 1.0000 - val_loss: 5.9913 - val_accuracy: 0.1170
# Epoch 54/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9936 - accuracy: 1.0000 - val_loss: 5.8131 - val_accuracy: 0.1241
# Epoch 55/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9783 - accuracy: 1.0000 - val_loss: 5.7080 - val_accuracy: 0.1296
# Epoch 56/500
# 1/1 [==============================] - 7s 7s/step - loss: 0.9827 - accuracy: 1.0000 - val_loss: 5.5890 - val_accuracy: 0.1294
# Epoch 57/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9810 - accuracy: 1.0000 - val_loss: 5.4588 - val_accuracy: 0.1282
# Epoch 58/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9930 - accuracy: 1.0000 - val_loss: 5.3593 - val_accuracy: 0.1268
# Epoch 59/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.0068 - accuracy: 1.0000 - val_loss: 5.2515 - val_accuracy: 0.1243
# Epoch 60/500
# 1/1 [==============================] - 6s 6s/step - loss: 1.0355 - accuracy: 0.9750 - val_loss: 5.1943 - val_accuracy: 0.1213
# Epoch 61/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9700 - accuracy: 1.0000 - val_loss: 5.1694 - val_accuracy: 0.1202
# Epoch 62/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.9817 - accuracy: 1.0000 - val_loss: 5.1384 - val_accuracy: 0.1198
# Epoch 63/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.9907 - accuracy: 1.0000 - val_loss: 5.0157 - val_accuracy: 0.1222
# Epoch 64/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9996 - accuracy: 1.0000 - val_loss: 4.9094 - val_accuracy: 0.1256
# Epoch 65/500
# 1/1 [==============================] - 7s 7s/step - loss: 0.9859 - accuracy: 1.0000 - val_loss: 4.7672 - val_accuracy: 0.1317
# Epoch 66/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9932 - accuracy: 1.0000 - val_loss: 4.6366 - val_accuracy: 0.1367
# Epoch 67/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9897 - accuracy: 1.0000 - val_loss: 4.5484 - val_accuracy: 0.1410
# Epoch 68/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9825 - accuracy: 0.9750 - val_loss: 4.4652 - val_accuracy: 0.1444
# Epoch 69/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9510 - accuracy: 1.0000 - val_loss: 4.4002 - val_accuracy: 0.1498
# Epoch 70/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9569 - accuracy: 1.0000 - val_loss: 4.3257 - val_accuracy: 0.1528
# Epoch 71/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9803 - accuracy: 1.0000 - val_loss: 4.2714 - val_accuracy: 0.1547
# Epoch 72/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.9600 - accuracy: 1.0000 - val_loss: 4.2409 - val_accuracy: 0.1557
# Epoch 73/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9649 - accuracy: 1.0000 - val_loss: 4.1872 - val_accuracy: 0.1540
# Epoch 74/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9459 - accuracy: 1.0000 - val_loss: 4.1575 - val_accuracy: 0.1503
# Epoch 75/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9837 - accuracy: 1.0000 - val_loss: 4.1342 - val_accuracy: 0.1559
# Epoch 76/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9762 - accuracy: 1.0000 - val_loss: 4.0970 - val_accuracy: 0.1647
# Epoch 77/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9551 - accuracy: 1.0000 - val_loss: 4.0814 - val_accuracy: 0.1668
# Epoch 78/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9505 - accuracy: 1.0000 - val_loss: 4.0844 - val_accuracy: 0.1680
# Epoch 79/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9682 - accuracy: 1.0000 - val_loss: 4.0722 - val_accuracy: 0.1673
# Epoch 80/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9735 - accuracy: 1.0000 - val_loss: 4.0431 - val_accuracy: 0.1670
# Epoch 81/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9681 - accuracy: 0.9750 - val_loss: 4.0177 - val_accuracy: 0.1631
# Epoch 82/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9637 - accuracy: 1.0000 - val_loss: 4.0131 - val_accuracy: 0.1552
# Epoch 83/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9597 - accuracy: 1.0000 - val_loss: 4.0316 - val_accuracy: 0.1491
# Epoch 84/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.9446 - accuracy: 1.0000 - val_loss: 4.0468 - val_accuracy: 0.1453
# Epoch 85/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9441 - accuracy: 1.0000 - val_loss: 4.1151 - val_accuracy: 0.1417
# Epoch 86/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9486 - accuracy: 1.0000 - val_loss: 4.1566 - val_accuracy: 0.1412
# Epoch 87/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9592 - accuracy: 1.0000 - val_loss: 4.1575 - val_accuracy: 0.1412
# Epoch 88/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9531 - accuracy: 1.0000 - val_loss: 4.0751 - val_accuracy: 0.1450
# Epoch 89/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9541 - accuracy: 1.0000 - val_loss: 3.9845 - val_accuracy: 0.1496
# Epoch 90/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9381 - accuracy: 1.0000 - val_loss: 3.8976 - val_accuracy: 0.1549
# Epoch 91/500
# 1/1 [==============================] - 7s 7s/step - loss: 0.9478 - accuracy: 1.0000 - val_loss: 3.8235 - val_accuracy: 0.1604
# Epoch 92/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9356 - accuracy: 1.0000 - val_loss: 3.7780 - val_accuracy: 0.1629
# Epoch 93/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.9418 - accuracy: 1.0000 - val_loss: 3.7462 - val_accuracy: 0.1627
# Epoch 94/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.9309 - accuracy: 1.0000 - val_loss: 3.7285 - val_accuracy: 0.1640
# Epoch 95/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9451 - accuracy: 1.0000 - val_loss: 3.6837 - val_accuracy: 0.1638
# Epoch 96/500
# 1/1 [==============================] - 7s 7s/step - loss: 0.9388 - accuracy: 1.0000 - val_loss: 3.6564 - val_accuracy: 0.1613
# Epoch 97/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9436 - accuracy: 1.0000 - val_loss: 3.6321 - val_accuracy: 0.1608
# Epoch 98/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9275 - accuracy: 1.0000 - val_loss: 3.6188 - val_accuracy: 0.1626
# Epoch 99/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9411 - accuracy: 1.0000 - val_loss: 3.6263 - val_accuracy: 0.1625
# Epoch 100/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9465 - accuracy: 1.0000 - val_loss: 3.6312 - val_accuracy: 0.1625
# Epoch 101/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9291 - accuracy: 1.0000 - val_loss: 3.6516 - val_accuracy: 0.1632
# Epoch 102/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9310 - accuracy: 1.0000 - val_loss: 3.6859 - val_accuracy: 0.1624
# Epoch 103/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9453 - accuracy: 1.0000 - val_loss: 3.7297 - val_accuracy: 0.1632
# Epoch 104/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9359 - accuracy: 1.0000 - val_loss: 3.7519 - val_accuracy: 0.1606
# Epoch 105/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9384 - accuracy: 1.0000 - val_loss: 3.7685 - val_accuracy: 0.1605
# Epoch 106/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9265 - accuracy: 1.0000 - val_loss: 3.7853 - val_accuracy: 0.1597
# Epoch 107/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9275 - accuracy: 1.0000 - val_loss: 3.7753 - val_accuracy: 0.1569
# Epoch 108/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9462 - accuracy: 1.0000 - val_loss: 3.7494 - val_accuracy: 0.1563
# Epoch 109/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9411 - accuracy: 1.0000 - val_loss: 3.7209 - val_accuracy: 0.1580
# Epoch 110/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9315 - accuracy: 1.0000 - val_loss: 3.6880 - val_accuracy: 0.1582
# Epoch 111/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9400 - accuracy: 1.0000 - val_loss: 3.6633 - val_accuracy: 0.1595
# Epoch 112/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9342 - accuracy: 1.0000 - val_loss: 3.6355 - val_accuracy: 0.1601
# Epoch 113/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9498 - accuracy: 1.0000 - val_loss: 3.6282 - val_accuracy: 0.1618
# Epoch 114/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9160 - accuracy: 1.0000 - val_loss: 3.6235 - val_accuracy: 0.1616
# Epoch 115/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.9254 - accuracy: 1.0000 - val_loss: 3.6118 - val_accuracy: 0.1623
# Epoch 116/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9292 - accuracy: 1.0000 - val_loss: 3.5812 - val_accuracy: 0.1648
# Epoch 117/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9279 - accuracy: 1.0000 - val_loss: 3.5674 - val_accuracy: 0.1641
# Epoch 118/500
# 1/1 [==============================] - 6s 6s/step - loss: 0.9315 - accuracy: 1.0000 - val_loss: 3.5350 - val_accuracy: 0.1645
# Epoch 119/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9274 - accuracy: 1.0000 - val_loss: 3.5076 - val_accuracy: 0.1646
# Epoch 120/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9507 - accuracy: 0.9750 - val_loss: 3.4873 - val_accuracy: 0.1628
# Epoch 121/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9424 - accuracy: 1.0000 - val_loss: 3.4865 - val_accuracy: 0.1609
# Epoch 122/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9270 - accuracy: 1.0000 - val_loss: 3.4912 - val_accuracy: 0.1579
# Epoch 123/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.9267 - accuracy: 1.0000 - val_loss: 3.4936 - val_accuracy: 0.1546
# Epoch 124/500
# 1/1 [==============================] - 3s 3s/step - loss: 0.9319 - accuracy: 1.0000 - val_loss: 3.5037 - val_accuracy: 0.1529
# Epoch 125/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.9274 - accuracy: 1.0000 - val_loss: 3.5109 - val_accuracy: 0.1498
# Epoch 126/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.9194 - accuracy: 1.0000 - val_loss: 3.5092 - val_accuracy: 0.1499
# Epoch 127/500
# 1/1 [==============================] - 4s 4s/step - loss: 0.9286 - accuracy: 1.0000 - val_loss: 3.4913 - val_accuracy: 0.1520
# Epoch 128/500
# 1/1 [==============================] - 5s 5s/step - loss: 0.9214 - accuracy: 1.0000 - val_loss: 3.4735 - val_accuracy: 0.1522

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
submodel = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
    )
z = submodel.predict(X_train)
np.shape(z)
# Out:
# (40000, 256)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sun Aug  9 22:25:20 2020 Finding Nearest Neighbors
# Sun Aug  9 22:25:20 2020 Building RP forest with 15 trees
# Sun Aug  9 22:25:21 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# Sun Aug  9 22:25:31 2020 Finished Nearest Neighbor Search
# Sun Aug  9 22:25:34 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Aug  9 22:26:00 2020 Finished embedding

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)

# %%
z_valid = submodel.predict(X_valid)
np.shape(z_valid)
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z_valid.reshape(len(z_valid), np.product(np.shape(z_valid)[1:])))

plt.scatter(embedding[:, 0], embedding[:, 1], c=Y_valid.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sun Aug  9 22:26:08 2020 Finding Nearest Neighbors
# Sun Aug  9 22:26:08 2020 Building RP forest with 10 trees
# Sun Aug  9 22:26:08 2020 parallel NN descent for 13 iterations
# 	 0  /  13
# 	 1  /  13
# 	 2  /  13
# Sun Aug  9 22:26:09 2020 Finished Nearest Neighbor Search
# Sun Aug  9 22:26:09 2020 Construct embedding
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Sun Aug  9 22:26:36 2020 Finished embedding

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(embedding[:, 0], embedding[:, 1], c=Y_valid.flatten(), s= 1, alpha = 1, cmap = plt.cm.tab10)

# %%
predictions = model.predict(X_valid)

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(embedding[:, 0], embedding[:, 1], c=np.argmax(predictions, axis=1), s= 1, alpha = 1, cmap = plt.cm.tab10)

# %%
Y_test_one_hot = tf.keras.backend.one_hot(
    Y_test, num_classes
)
result = model.evaluate(X_test, Y_test_one_hot)
# Out:
# 313/313 [==============================] - 12s 37ms/step - loss: 3.4501 - accuracy: 0.1542

# %% [markdown]
# ### save results

# %%
# save score, valid embedding, weights, results

# %%
from tfumap.paths import MODEL_DIR, ensure_dir

# %%
save_folder = MODEL_DIR / 'semisupervised-keras' / dataset / str(labels_per_class) / datestring
ensure_dir(save_folder)

# %% [markdown]
# #### save weights

# %%
encoder = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
)

# %%
encoder.save_weights((save_folder / "encoder").as_posix())

# %%
classifier = tf.keras.models.Model(
        [tf.keras.Input(tensor=model.get_layer('weight_normalization').input)], [model.outputs[0]]
)
print([i.name for i in classifier.layers])
# Out:
# ['input_2', 'weight_normalization', 'lrelufc1', 'weight_normalization_1', 'lrelufc2', 'weight_normalization_2']

# %%
classifier.save_weights((save_folder / "classifier").as_posix())

# %% [markdown]
# #### save score

# %%
Y_test_one_hot = tf.keras.backend.one_hot(
    Y_test, num_classes
)
result = model.evaluate(X_test, Y_test_one_hot)
# Out:
# 313/313 [==============================] - 5s 15ms/step - loss: 3.4501 - accuracy: 0.1542

# %%
np.save(save_folder / 'test_loss.npy', result)

# %% [markdown]
# #### save embedding

# %%
z = encoder.predict(X_train)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))

plt.scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Mon Aug 10 09:29:22 2020 Finding Nearest Neighbors
# Mon Aug 10 09:29:22 2020 Building RP forest with 15 trees
# Mon Aug 10 09:29:23 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# Mon Aug 10 09:29:26 2020 Finished Nearest Neighbor Search
# Mon Aug 10 09:29:27 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Aug 10 09:30:18 2020 Finished embedding

# %%
np.save(save_folder / 'train_embedding.npy', embedding)

# %% [markdown]
# #### save results

# %%
import pickle

# %%
with open(save_folder / 'history.pickle', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
