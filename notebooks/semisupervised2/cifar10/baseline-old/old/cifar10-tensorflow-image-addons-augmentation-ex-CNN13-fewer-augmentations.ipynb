# %%
# http://localhost:8187/notebooks/tsainbur/Projects/github_repos/umap_tensorflow/Notebooks/semisupervised-learning/cifar10-CNN13-baseline-convnet-keras-semi-with-fc-layers.ipynb

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
print(gpu_devices)
tf.keras.backend.clear_session()
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### dataset information

# %%
from datetime import datetime

dataset = "cifar10"
dims = (32, 32, 3)
umap_prop = 1.0
num_classes = 10
PROJECTION_DIMS = 1024
labels_per_class = 'full' # full
batch_size = 128
datestring = datetime.now().strftime("%Y_%m_%d_%H_%M_%S_%f")
datestring = (
    str(dataset)
    + "_"
    + str(umap_prop)
    + "_"
    + str(PROJECTION_DIMS)
    + "_"
    + str(labels_per_class)
    + "____"
    + datestring 
    + '_baseline'
)
print(datestring)
# Out:
# cifar10_1.0_1024_full____2020_08_09_14_43_41_748610_baseline

# %% [markdown]
# ### Load packages

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from IPython import display
import pandas as pd
import umap
import copy
import os, tempfile
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### Load dataset

# %%
from tfumap.load_datasets import load_CIFAR10, mask_labels
X_train, X_test, X_valid, Y_train, Y_test, Y_valid = load_CIFAR10(flatten=False)
X_train.shape
# Out:
# (40000, 32, 32, 3)

# %%
if labels_per_class == "full":
    X_labeled = X_train
    Y_masked = Y_labeled = Y_train
else:
    X_labeled, Y_labeled, Y_masked = mask_labels(
        X_train, Y_train, labels_per_class=labels_per_class
    )

# %% [markdown]
# - https://medium.com/fenwicks/tutorial-2-94-accuracy-on-cifar10-in-2-minutes-7b5aaecd9cdd
# - https://colab.research.google.com/github/davidcpage/cifar10-fast/blob/master/bag_of_tricks.ipynb#scrollTo=n___bs94Rvm2
# - https://www.tensorflow.org/tutorials/images/data_augmentation#using_tfimage
# - https://github.com/tensorflow/models/pull/5906/files

# %%
import tensorflow_addons as tfa

# %%
import tensorflow_addons as tfa
def augment(image, label):
    image = tf.squeeze(image) # Add 6 pixels of padding
    image = tf.image.resize_with_crop_or_pad(image, dims[0] + 6, dims[1] + 6) # crop 6 pixels
    image = tf.image.random_crop(image, size=dims)
    image = tf.image.random_brightness(image, max_delta=0.15)  # Random brightness
    image= tf.image.random_contrast(image, lower=0.6, upper=1.4)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_hue(image, 0.05, seed=None)
    #image = tf.image.random_jpeg_quality(image, 10, 100, seed=None)
    image = tfa.image.rotate(image, tf.squeeze(tf.random.uniform(shape = (1,1), minval=-.2, maxval=.2)), interpolation='BILINEAR')
    image = tfa.image.random_cutout(tf.expand_dims(image, 0), (8,8), constant_values=0.5)[0]
    image = tf.clip_by_value(image, 0, 1)
    return image, label

# %%
nex = 10
for i in range(5):
    fig, axs = plt.subplots(ncols=nex +1, figsize=((nex+1)*2, 2))
    axs[0].imshow(X_train[i])
    axs[0].axis('off')
    for ax in axs.flatten()[1:]:
        ax.imshow(augment(X_train[i], Y_train[i])[0])
        ax.axis('off')

# %%
train_ds = (
     tf.data.Dataset.from_tensor_slices((X_labeled, Y_labeled))
    .shuffle(1000)
    .map(augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.experimental.AUTOTUNE)
)

# %%
train_ds
# Out:
# <PrefetchDataset shapes: ((None, 32, 32, 3), (None,)), types: (tf.float32, tf.uint8)>

# %%
for i in tqdm(iter(train_ds)):
    continue
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %% [markdown]
# ### Build network

# %%
from tensorflow_addons.layers import WeightNormalization

def conv_block(filts, name, kernel_size = (3, 3), padding = "same", **kwargs):
    return WeightNormalization(
        layers.Conv2D(
            filts, kernel_size, activation=None, padding=padding, **kwargs
        ),
        name="conv"+name,
    )

# %%
from tensorflow.keras import datasets, layers, models

# %%
"""CNN13
See: 
https://github.com/vikasverma1077/ICT/blob/master/networks/lenet.py
https://github.com/brain-research/realistic-ssl-evaluation

"""
lr_alpha = 0.1
dropout_rate = 0.5
num_classes = 10
input_shape = (32, 32, 3)
model = models.Sequential()
model.add(tf.keras.Input(shape=input_shape))
### conv1a
name = '1a'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1b
name = '1b'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1c
name = '1c'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp1"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop1"))

### conv2a
name = '2a'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha))

### conv2b
name = '2b'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv2c
name = '2c'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp2"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop2"))

### conv3a
name = '3a'
model.add(conv_block(name = name, filts = 512, kernel_size = (3,3), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3b
name = '3b'
model.add(conv_block(name = name, filts = 256, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3c
name = '3c'
model.add(conv_block(name = name, filts = 128, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.AveragePooling2D(pool_size=(6, 6), strides=2, padding='valid'))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation=None, name='z'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc1'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc2'))
model.add(WeightNormalization(layers.Dense(num_classes, activation=None)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1a (WeightNormalization) (None, 32, 32, 128)       7297
# _________________________________________________________________
# bn1a (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1a (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1b (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1b (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1b (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1c (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1c (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1c (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# mp1 (MaxPooling2D)           (None, 16, 16, 128)       0
# _________________________________________________________________
# drop1 (Dropout)              (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2a (WeightNormalization) (None, 16, 16, 256)       590593
# _________________________________________________________________
# bn2a (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2b (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2b (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2b (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2c (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2c (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2c (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# mp2 (MaxPooling2D)           (None, 8, 8, 256)         0
# _________________________________________________________________
# drop2 (Dropout)              (None, 8, 8, 256)         0
# _________________________________________________________________
# conv3a (WeightNormalization) (None, 6, 6, 512)         2360833
# _________________________________________________________________
# bn3a (BatchNormalization)    (None, 6, 6, 512)         2048
# _________________________________________________________________
# lrelu3a (LeakyReLU)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv3b (WeightNormalization) (None, 6, 6, 256)         262913
# _________________________________________________________________
# bn3b (BatchNormalization)    (None, 6, 6, 256)         1024
# _________________________________________________________________
# lrelu3b (LeakyReLU)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv3c (WeightNormalization) (None, 6, 6, 128)         65921
# _________________________________________________________________
# bn3c (BatchNormalization)    (None, 6, 6, 128)         512
# _________________________________________________________________
# lrelu3c (LeakyReLU)          (None, 6, 6, 128)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# z (Dense)                    (None, 256)               33024
# _________________________________________________________________
# weight_normalization (Weight (None, 256)               131841
# _________________________________________________________________
# lrelufc1 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_1 (Weig (None, 256)               131841
# _________________________________________________________________
# lrelufc2 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_2 (Weig (None, 10)                5151
# =================================================================
# Total params: 6,549,034
# Trainable params: 3,292,308
# Non-trainable params: 3,256,726
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', min_delta=0, patience=50, verbose=0, mode='auto',
    baseline=None, restore_best_weights=False
)

# %%
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)
model.compile(tf.keras.optimizers.Adam(1e-3), loss = loss, metrics=['accuracy'])

# %%
Y_valid_one_hot = tf.keras.backend.one_hot(
    Y_valid, num_classes
)

# %%
Y_labeled_one_hot = tf.keras.backend.one_hot(
    Y_labeled, num_classes
)

# %%
train_ds = (
     tf.data.Dataset.from_tensor_slices((X_labeled, Y_labeled_one_hot))
    .shuffle(1000)
    .map(augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.experimental.AUTOTUNE)
)

# %%
x1, y1 = next(iter(train_ds))

# %%
x1.shape, y1.shape
# Out:
# (TensorShape([128, 32, 32, 3]), TensorShape([128, 10]))

# %%
history = model.fit(
    train_ds,
    epochs=250,
    validation_data=(X_valid, Y_valid_one_hot),
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/250
# 313/313 [==============================] - 19s 61ms/step - loss: 2.0300 - accuracy: 0.3404 - val_loss: 1.8717 - val_accuracy: 0.4325
# Epoch 2/250
# 313/313 [==============================] - 19s 61ms/step - loss: 1.7576 - accuracy: 0.4910 - val_loss: 2.1094 - val_accuracy: 0.4189
# Epoch 3/250
# 313/313 [==============================] - 18s 59ms/step - loss: 1.6276 - accuracy: 0.5711 - val_loss: 1.5039 - val_accuracy: 0.6552
# Epoch 4/250
# 313/313 [==============================] - 17s 55ms/step - loss: 1.5446 - accuracy: 0.6200 - val_loss: 1.6142 - val_accuracy: 0.6197
# Epoch 5/250
# 313/313 [==============================] - 17s 55ms/step - loss: 1.4843 - accuracy: 0.6573 - val_loss: 1.5641 - val_accuracy: 0.6256
# Epoch 6/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.4348 - accuracy: 0.6841 - val_loss: 1.7910 - val_accuracy: 0.5815
# Epoch 7/250
# 313/313 [==============================] - 19s 60ms/step - loss: 1.4004 - accuracy: 0.7075 - val_loss: 1.5357 - val_accuracy: 0.6736
# Epoch 8/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.3710 - accuracy: 0.7239 - val_loss: 1.4207 - val_accuracy: 0.7114
# Epoch 9/250
# 313/313 [==============================] - 17s 55ms/step - loss: 1.3494 - accuracy: 0.7366 - val_loss: 1.3754 - val_accuracy: 0.7360
# Epoch 10/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.3262 - accuracy: 0.7501 - val_loss: 1.3647 - val_accuracy: 0.7438
# Epoch 11/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.3094 - accuracy: 0.7559 - val_loss: 1.3658 - val_accuracy: 0.7430
# Epoch 12/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.2972 - accuracy: 0.7642 - val_loss: 1.4639 - val_accuracy: 0.7054
# Epoch 13/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.2809 - accuracy: 0.7748 - val_loss: 1.2868 - val_accuracy: 0.7758
# Epoch 14/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.2668 - accuracy: 0.7813 - val_loss: 1.3209 - val_accuracy: 0.7567
# Epoch 15/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.2515 - accuracy: 0.7901 - val_loss: 1.2026 - val_accuracy: 0.8200
# Epoch 16/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.2444 - accuracy: 0.7938 - val_loss: 1.2986 - val_accuracy: 0.7709
# Epoch 17/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.2315 - accuracy: 0.8022 - val_loss: 1.2434 - val_accuracy: 0.8013
# Epoch 18/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.2208 - accuracy: 0.8075 - val_loss: 1.1876 - val_accuracy: 0.8279
# Epoch 19/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.2112 - accuracy: 0.8112 - val_loss: 1.1945 - val_accuracy: 0.8300
# Epoch 20/250
# 313/313 [==============================] - 17s 55ms/step - loss: 1.2004 - accuracy: 0.8180 - val_loss: 1.2600 - val_accuracy: 0.7975
# Epoch 21/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.1951 - accuracy: 0.8201 - val_loss: 1.1678 - val_accuracy: 0.8376
# Epoch 22/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.1908 - accuracy: 0.8243 - val_loss: 1.2746 - val_accuracy: 0.7975
# Epoch 23/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.1821 - accuracy: 0.8271 - val_loss: 1.1626 - val_accuracy: 0.8463
# Epoch 24/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.1708 - accuracy: 0.8350 - val_loss: 1.1543 - val_accuracy: 0.8469
# Epoch 25/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.1642 - accuracy: 0.8372 - val_loss: 1.2771 - val_accuracy: 0.7929
# Epoch 26/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.1582 - accuracy: 0.8421 - val_loss: 1.1809 - val_accuracy: 0.8377
# Epoch 27/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.1511 - accuracy: 0.8451 - val_loss: 1.1582 - val_accuracy: 0.8489
# Epoch 28/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.1514 - accuracy: 0.8450 - val_loss: 1.1357 - val_accuracy: 0.8586
# Epoch 29/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.1428 - accuracy: 0.8495 - val_loss: 1.1318 - val_accuracy: 0.8589
# Epoch 30/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.1355 - accuracy: 0.8535 - val_loss: 1.1121 - val_accuracy: 0.8655
# Epoch 31/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.1320 - accuracy: 0.8566 - val_loss: 1.1411 - val_accuracy: 0.8546
# Epoch 32/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.1262 - accuracy: 0.8595 - val_loss: 1.1779 - val_accuracy: 0.8430
# Epoch 33/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.1193 - accuracy: 0.8629 - val_loss: 1.1256 - val_accuracy: 0.8614
# Epoch 34/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.1178 - accuracy: 0.8641 - val_loss: 1.1359 - val_accuracy: 0.8571
# Epoch 35/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.1092 - accuracy: 0.8683 - val_loss: 1.1012 - val_accuracy: 0.8797
# Epoch 36/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.1080 - accuracy: 0.8694 - val_loss: 1.2300 - val_accuracy: 0.8185
# Epoch 37/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.1043 - accuracy: 0.8716 - val_loss: 1.0929 - val_accuracy: 0.8821
# Epoch 38/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.1012 - accuracy: 0.8734 - val_loss: 1.1215 - val_accuracy: 0.8630
# Epoch 39/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0961 - accuracy: 0.8773 - val_loss: 1.0831 - val_accuracy: 0.8843
# Epoch 40/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0908 - accuracy: 0.8784 - val_loss: 1.1322 - val_accuracy: 0.8632
# Epoch 41/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0877 - accuracy: 0.8791 - val_loss: 1.1048 - val_accuracy: 0.8804
# Epoch 42/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0837 - accuracy: 0.8810 - val_loss: 1.1248 - val_accuracy: 0.8653
# Epoch 43/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0827 - accuracy: 0.8826 - val_loss: 1.0903 - val_accuracy: 0.8810
# Epoch 44/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0793 - accuracy: 0.8830 - val_loss: 1.0915 - val_accuracy: 0.8861
# Epoch 45/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0765 - accuracy: 0.8878 - val_loss: 1.1567 - val_accuracy: 0.8507
# Epoch 46/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0717 - accuracy: 0.8887 - val_loss: 1.0716 - val_accuracy: 0.8928
# Epoch 47/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0684 - accuracy: 0.8903 - val_loss: 1.1367 - val_accuracy: 0.8651
# Epoch 48/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0663 - accuracy: 0.8916 - val_loss: 1.0699 - val_accuracy: 0.8941
# Epoch 49/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0671 - accuracy: 0.8918 - val_loss: 1.1259 - val_accuracy: 0.8667
# Epoch 50/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0584 - accuracy: 0.8959 - val_loss: 1.0593 - val_accuracy: 0.8977
# Epoch 51/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0576 - accuracy: 0.8954 - val_loss: 1.0922 - val_accuracy: 0.8799
# Epoch 52/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0560 - accuracy: 0.8983 - val_loss: 1.0616 - val_accuracy: 0.8986
# Epoch 53/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0511 - accuracy: 0.9014 - val_loss: 1.0626 - val_accuracy: 0.8997
# Epoch 54/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0461 - accuracy: 0.9023 - val_loss: 1.0972 - val_accuracy: 0.8807
# Epoch 55/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0483 - accuracy: 0.9022 - val_loss: 1.0509 - val_accuracy: 0.9028
# Epoch 56/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0445 - accuracy: 0.9038 - val_loss: 1.0892 - val_accuracy: 0.8841
# Epoch 57/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0431 - accuracy: 0.9052 - val_loss: 1.0716 - val_accuracy: 0.8906
# Epoch 58/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0403 - accuracy: 0.9060 - val_loss: 1.0600 - val_accuracy: 0.9016
# Epoch 59/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0356 - accuracy: 0.9087 - val_loss: 1.0781 - val_accuracy: 0.8916
# Epoch 60/250
# 313/313 [==============================] - 17s 55ms/step - loss: 1.0376 - accuracy: 0.9084 - val_loss: 1.0304 - val_accuracy: 0.9166
# Epoch 61/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0336 - accuracy: 0.9104 - val_loss: 1.0433 - val_accuracy: 0.9080
# Epoch 62/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0338 - accuracy: 0.9089 - val_loss: 1.0557 - val_accuracy: 0.9042
# Epoch 63/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0273 - accuracy: 0.9130 - val_loss: 1.0545 - val_accuracy: 0.8999
# Epoch 64/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0292 - accuracy: 0.9126 - val_loss: 1.0342 - val_accuracy: 0.9157
# Epoch 65/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0250 - accuracy: 0.9154 - val_loss: 1.0435 - val_accuracy: 0.9095
# Epoch 66/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0275 - accuracy: 0.9133 - val_loss: 1.0725 - val_accuracy: 0.8911
# Epoch 67/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0222 - accuracy: 0.9153 - val_loss: 1.0500 - val_accuracy: 0.9044
# Epoch 68/250
# 313/313 [==============================] - 17s 55ms/step - loss: 1.0226 - accuracy: 0.9161 - val_loss: 1.0648 - val_accuracy: 0.8996
# Epoch 69/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0230 - accuracy: 0.9153 - val_loss: 1.0520 - val_accuracy: 0.9025
# Epoch 70/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0174 - accuracy: 0.9181 - val_loss: 1.0459 - val_accuracy: 0.9077
# Epoch 71/250
# 313/313 [==============================] - 17s 55ms/step - loss: 1.0139 - accuracy: 0.9207 - val_loss: 1.0634 - val_accuracy: 0.9018
# Epoch 72/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0144 - accuracy: 0.9208 - val_loss: 1.0727 - val_accuracy: 0.8921
# Epoch 73/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0170 - accuracy: 0.9183 - val_loss: 1.0790 - val_accuracy: 0.8935
# Epoch 74/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0128 - accuracy: 0.9221 - val_loss: 1.0563 - val_accuracy: 0.9071
# Epoch 75/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0082 - accuracy: 0.9245 - val_loss: 1.0613 - val_accuracy: 0.9012
# Epoch 76/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0103 - accuracy: 0.9224 - val_loss: 1.0424 - val_accuracy: 0.9115
# Epoch 77/250
# 313/313 [==============================] - 17s 55ms/step - loss: 1.0065 - accuracy: 0.9244 - val_loss: 1.0238 - val_accuracy: 0.9228
# Epoch 78/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0061 - accuracy: 0.9246 - val_loss: 1.0408 - val_accuracy: 0.9103
# Epoch 79/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0026 - accuracy: 0.9250 - val_loss: 1.0295 - val_accuracy: 0.9194
# Epoch 80/250
# 313/313 [==============================] - 18s 56ms/step - loss: 1.0043 - accuracy: 0.9249 - val_loss: 1.0510 - val_accuracy: 0.9049
# Epoch 81/250
# 313/313 [==============================] - 17s 56ms/step - loss: 0.9985 - accuracy: 0.9291 - val_loss: 1.0191 - val_accuracy: 0.9220
# Epoch 82/250
# 313/313 [==============================] - 18s 56ms/step - loss: 0.9975 - accuracy: 0.9291 - val_loss: 1.0644 - val_accuracy: 0.9002
# Epoch 83/250
# 313/313 [==============================] - 17s 56ms/step - loss: 0.9989 - accuracy: 0.9287 - val_loss: 1.0402 - val_accuracy: 0.9112
# Epoch 84/250
# 313/313 [==============================] - 18s 56ms/step - loss: 0.9975 - accuracy: 0.9285 - val_loss: 1.0501 - val_accuracy: 0.9074
# Epoch 85/250
# 313/313 [==============================] - 18s 56ms/step - loss: 0.9956 - accuracy: 0.9309 - val_loss: 1.0370 - val_accuracy: 0.9165
# Epoch 86/250
# 313/313 [==============================] - 18s 56ms/step - loss: 0.9931 - accuracy: 0.9326 - val_loss: 1.0689 - val_accuracy: 0.8992
# Epoch 87/250
# 313/313 [==============================] - 17s 56ms/step - loss: 0.9915 - accuracy: 0.9325 - val_loss: 1.0345 - val_accuracy: 0.9161
# Epoch 88/250
# 313/313 [==============================] - 17s 56ms/step - loss: 0.9938 - accuracy: 0.9309 - val_loss: 1.0438 - val_accuracy: 0.9067
# Epoch 89/250
# 313/313 [==============================] - 17s 56ms/step - loss: 0.9932 - accuracy: 0.9319 - val_loss: 1.0441 - val_accuracy: 0.9085
# Epoch 90/250
# 313/313 [==============================] - 18s 56ms/step - loss: 0.9894 - accuracy: 0.9343 - val_loss: 1.0419 - val_accuracy: 0.9083
# Epoch 91/250
# 313/313 [==============================] - 18s 56ms/step - loss: 0.9894 - accuracy: 0.9347 - val_loss: 1.0409 - val_accuracy: 0.9121
# Epoch 92/250
# 313/313 [==============================] - 17s 56ms/step - loss: 0.9863 - accuracy: 0.9364 - val_loss: 1.0383 - val_accuracy: 0.9141
# Epoch 93/250
# 313/313 [==============================] - 18s 56ms/step - loss: 0.9890 - accuracy: 0.9337 - val_loss: 1.0265 - val_accuracy: 0.9154
# Epoch 94/250
# 313/313 [==============================] - 17s 55ms/step - loss: 0.9867 - accuracy: 0.9354 - val_loss: 1.0526 - val_accuracy: 0.9066
# Epoch 95/250
# 313/313 [==============================] - 18s 56ms/step - loss: 0.9836 - accuracy: 0.9375 - val_loss: 1.0315 - val_accuracy: 0.9170
# Epoch 96/250
# 313/313 [==============================] - 18s 56ms/step - loss: 0.9825 - accuracy: 0.9381 - val_loss: 1.0268 - val_accuracy: 0.9174
# Epoch 97/250
# 313/313 [==============================] - 17s 56ms/step - loss: 0.9829 - accuracy: 0.9389 - val_loss: 1.0240 - val_accuracy: 0.9192

# %%
Y_test_one_hot = tf.keras.backend.one_hot(
    Y_test, num_classes
)

# %%
result = model.evaluate(X_test, Y_test_one_hot)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 1.0483 - accuracy: 0.9092

# %%
plt.semilogx(history.history['loss'])
plt.semilogx(history.history['val_loss'])

# %%
plt.semilogx(history.history['accuracy'])
plt.semilogx(history.history['val_accuracy'])

# %%
submodel = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
    )
z = submodel.predict(X_train)
np.shape(z)
# Out:
# (40000, 256)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sun Aug  9 17:22:43 2020 Finding Nearest Neighbors
# Sun Aug  9 17:22:43 2020 Building RP forest with 15 trees
# Sun Aug  9 17:22:44 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# Sun Aug  9 17:22:45 2020 Finished Nearest Neighbor Search
# Sun Aug  9 17:22:45 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Aug  9 17:23:09 2020 Finished embedding

# %%
predictions = model.predict(X_train)

# %%
mask = np.array(np.argmax(predictions, axis=1)) != Y_train.flatten()

# %%
fig, axs = plt.subplots(ncols = 5, figsize=(50,10))
axs[0].scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 1, cmap = plt.cm.tab10)
axs[1].scatter(embedding[:, 0], embedding[:, 1], c=np.argmax(predictions, axis=1), s= 1, alpha = 1, cmap = plt.cm.tab10)
axs[2].scatter(embedding[:, 0], embedding[:, 1], c=np.array(np.argmax(predictions, axis=1)) == Y_train.flatten(), s= 1, alpha = 1, cmap = plt.cm.viridis)
axs[3].scatter(embedding[mask, 0], embedding[mask, 1], c=Y_train.flatten()[mask], s= 10, alpha = 1, cmap = plt.cm.tab10)
axs[4].scatter(embedding[mask, 0], embedding[mask, 1], c=np.argmax(predictions, axis=1)[mask], s= 10, alpha = 1, cmap = plt.cm.tab10)

# %%
z_valid = submodel.predict(X_valid)
np.shape(z_valid)
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z_valid.reshape(len(z_valid), np.product(np.shape(z_valid)[1:])))

plt.scatter(embedding[:, 0], embedding[:, 1], c=Y_valid.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sun Aug  9 17:20:43 2020 Finding Nearest Neighbors
# Sun Aug  9 17:20:43 2020 Building RP forest with 10 trees
# Sun Aug  9 17:20:44 2020 parallel NN descent for 13 iterations
# 	 0  /  13
# 	 1  /  13
# 	 2  /  13
# 	 3  /  13
# Sun Aug  9 17:20:45 2020 Finished Nearest Neighbor Search
# Sun Aug  9 17:20:45 2020 Construct embedding
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Sun Aug  9 17:21:10 2020 Finished embedding

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(embedding[:, 0], embedding[:, 1], c=Y_valid.flatten(), s= 1, alpha = 1, cmap = plt.cm.tab10)

# %%
predictions = model.predict(X_valid)

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(embedding[:, 0], embedding[:, 1], c=np.argmax(predictions, axis=1), s= 1, alpha = 1, cmap = plt.cm.tab10)
