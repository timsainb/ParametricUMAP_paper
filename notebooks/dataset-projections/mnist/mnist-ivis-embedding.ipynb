# %%
dataset = 'mnist'
algorithm = 'ivis'
n_components = 2

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ### load packages

# %%
from tfumap.umap import tfUMAP
# Out:
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
import umap
import pandas as pd

# %% [markdown]
# ### Load dataset

# %%
from tensorflow.keras.datasets import mnist

# %%
# load dataset
(train_images, Y_train), (test_images, Y_test) = mnist.load_data()
X_train = (train_images/255.).astype('float32')
X_test = (test_images/255.).astype('float32')
X_train = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))

# subset a validation set
n_valid = 10000
X_valid = X_train[-n_valid:]
Y_valid = Y_train[-n_valid:]
X_train = X_train[:-n_valid]
Y_train = Y_train[:-n_valid]

# flatten X
X_train_flat = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test_flat = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))
X_valid_flat= X_valid.reshape((len(X_valid), np.product(np.shape(X_valid)[1:])))
print(len(X_train), len(X_valid), len(X_test))
# Out:
# 50000 10000 10000

# %% [markdown]
# ### Create model and train

# %%
from ivis import Ivis
from sklearn.preprocessing import MinMaxScaler
from sklearn import datasets

# %%
X_scaled = MinMaxScaler().fit_transform(X_train_flat)

# %%
# Set ivis parameters
model = Ivis(embedding_dims=2)

# %%
# Generate embeddings
embeddings =z = model.fit_transform(X_scaled)
# Out:
#   1%|          | 578/50000 [00:00<00:08, 5776.05it/s]
# Building KNN index
# 100%|██████████| 50000/50000 [00:06<00:00, 7490.00it/s]
# Extracting KNN neighbours
# 100%|██████████| 50000/50000 [00:14<00:00, 3533.78it/s]
# Training neural network
# Epoch 1/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.2133
# Epoch 2/1000
# 391/391 [==============================] - 3s 6ms/step - loss: 0.1444
# Epoch 3/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.1315
# Epoch 4/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.1228
# Epoch 5/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.1156
# Epoch 6/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.1091
# Epoch 7/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.1047
# Epoch 8/1000
# 391/391 [==============================] - 3s 6ms/step - loss: 0.1039
# Epoch 9/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.1034
# Epoch 10/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.1003
# Epoch 11/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0986
# Epoch 12/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0979
# Epoch 13/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0943
# Epoch 14/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0963
# Epoch 15/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0936
# Epoch 16/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0922
# Epoch 17/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0928
# Epoch 18/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0924
# Epoch 19/1000
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0923
# Epoch 20/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0914
# Epoch 21/1000
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0901
# Epoch 22/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0911
# Epoch 23/1000
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0932
# Epoch 24/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0906
# Epoch 25/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0918
# Epoch 26/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0896
# Epoch 27/1000
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0916
# Epoch 28/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0887
# Epoch 29/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0892
# Epoch 30/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0880
# Epoch 31/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0861
# Epoch 32/1000
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0871
# Epoch 33/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0858
# Epoch 34/1000
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0892
# Epoch 35/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0874
# Epoch 36/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0850
# Epoch 37/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0877
# Epoch 38/1000
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0870
# Epoch 39/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0870
# Epoch 40/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0870
# Epoch 41/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0878
# Epoch 42/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0869
# Epoch 43/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0855
# Epoch 44/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0883
# Epoch 45/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0890
# Epoch 46/1000
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0865
# Epoch 47/1000
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0857
# Epoch 48/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0855
# Epoch 49/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0877
# Epoch 50/1000
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0852
# Epoch 51/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0864
# Epoch 52/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0868
# Epoch 53/1000
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0855
# Epoch 54/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0869
# Epoch 55/1000
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0866
# Epoch 56/1000
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0854
# 391/391 [==============================] - 1s 1ms/step

# %% [markdown]
# ### Plot model output

# %%
fig, ax = plt.subplots( figsize=(8, 8))
sc = ax.scatter(
    z[:, 0],
    z[:, 1],
    c=Y_train.astype(int)[:len(z)],
    cmap="tab10",
    s=0.1,
    alpha=0.5,
    rasterized=True,
)
ax.axis('equal')
ax.set_title("UMAP in Tensorflow embedding", fontsize=20)
plt.colorbar(sc, ax=ax);

# %% [markdown]
# ### Save output

# %%
from tfumap.paths import ensure_dir, MODEL_DIR

# %%
output_dir = MODEL_DIR/'projections'/ dataset / algorithm
ensure_dir(output_dir)

# %%
#vae.save(output_dir)

# %%
model.save_model(output_dir / 'iris.ivis')

# %%
#loss_df.to_pickle(output_dir / 'loss_df.pickle')

# %%
np.save(output_dir / 'z.npy', z)

# %% [markdown]
# ### compute metrics

# %%
X_test.shape
# Out:
# (10000, 784)

# %%
z_test = model.transform(X_test)
# Out:
# 79/79 [==============================] - 0s 1ms/step

# %% [markdown]
# #### silhouette

# %%
from tfumap.silhouette import silhouette_score_block

# %%
ss, sil_samp = silhouette_score_block(z, Y_train, n_jobs = -1)
ss
# Out:
# 0.10317030828187515

# %%
ss_test, sil_samp_test = silhouette_score_block(z_test, Y_test, n_jobs = -1)
ss_test
# Out:
# 0.11430772299849991

# %%
fig, axs = plt.subplots(ncols = 2, figsize=(10, 5))
axs[0].scatter(z[:, 0], z[:, 1], s=0.1, alpha=0.5, c=sil_samp, cmap=plt.cm.viridis)
axs[1].scatter(z_test[:, 0], z_test[:, 1], s=1, alpha=0.5, c=sil_samp_test, cmap=plt.cm.viridis)

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neigh5 = KNeighborsClassifier(n_neighbors=5)
neigh5.fit(z, Y_train)
score_5nn = neigh5.score(z_test, Y_test)
score_5nn
# Out:
# 0.7307

# %%
neigh1 = KNeighborsClassifier(n_neighbors=1)
neigh1.fit(z, Y_train)
score_1nn = neigh1.score(z_test, Y_test)
score_1nn
# Out:
# 0.6695

# %% [markdown]
# #### Trustworthiness

# %%
from sklearn.manifold import trustworthiness

# %%
tw = trustworthiness(X_train_flat[:10000], z[:10000])

# %%
tw_test = trustworthiness(X_test_flat[:10000], z_test[:10000])

# %%
tw, tw_test
# Out:
# (0.8882492834267414, 0.8860951361088871)

# %% [markdown]
# ### Save output metrics

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

# %% [markdown]
# #### train

# %%
metrics_df = pd.DataFrame(
    columns=[
        "dataset",
        "class_",
        "dim",
        "trustworthiness",
        "silhouette_score",
        "silhouette_samples",
    ]
)
metrics_df.loc[len(metrics_df)] = [dataset, 'scvis', n_components, tw, ss, sil_samp]
metrics_df
# Out:
#   dataset class_ dim  trustworthiness  silhouette_score  \
# 0   mnist  scvis   2         0.888249           0.10317
#
#                                   silhouette_samples
# 0  [-0.24303462447815852, 0.461984234466945, 0.11...

# %%
save_loc = DATA_DIR / 'projection_metrics' /  algorithm / 'train' / str(n_components) / (dataset + '.pickle')
ensure_dir(save_loc)
metrics_df.to_pickle(save_loc)

# %% [markdown]
# #### test

# %%
metrics_df_test = pd.DataFrame(
    columns=[
        "dataset",
        "class_",
        "dim",
        "trustworthiness",
        "silhouette_score",
        "silhouette_samples",
    ]
)
metrics_df_test.loc[len(metrics_df)] = [dataset, 'scvis', n_components, tw_test, ss_test, sil_samp_test]
metrics_df_test
# Out:
#   dataset class_ dim  trustworthiness  silhouette_score  \
# 1   mnist  scvis   2         0.886095          0.114308
#
#                                   silhouette_samples
# 1  [0.2501314920200145, 0.6034348813215611, 0.548...

# %%
save_loc = DATA_DIR / 'projection_metrics' / algorithm / 'test' / str(n_components) / (dataset + '.pickle')
ensure_dir(save_loc)
metrics_df.to_pickle(save_loc)

# %% [markdown]
# #### knn

# %%
nn_acc_df = pd.DataFrame(columns = ["method_","dimensions","dataset","1NN_acc","5NN_acc"])
nn_acc_df.loc[len(nn_acc_df)] = ['scvis', n_components, dataset,  score_1nn, score_5nn]
nn_acc_df
# Out:
#   method_ dimensions dataset  1NN_acc  5NN_acc
# 0   scvis          2   mnist   0.6695   0.7307

# %%
save_loc = DATA_DIR / 'knn_classifier' / algorithm / 'train' / str(n_components) / (dataset + '.pickle')
ensure_dir(save_loc)
nn_acc_df.to_pickle(save_loc)

# %% [markdown]
# ### Compute clustering quality

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import homogeneity_completeness_v_measure

# %%
def get_cluster_metrics(row, n_init=5):
    
    # load cluster information
    save_loc = DATA_DIR / 'clustering_metric_df'/ ('_'.join([row.class_, str(row.dim), row.dataset]) + '.pickle')
    print(save_loc)
    if save_loc.exists() and save_loc.is_file():
        
        cluster_df = pd.read_pickle(save_loc)
        return cluster_df
    
    # make cluster metric dataframe
    cluster_df = pd.DataFrame(
        columns=[
            "dataset",
            "class_",
            "dim",
            "silhouette",
            "homogeneity",
            "completeness",
            "v_measure",
            "init_",
            "n_clusters",
            "model",
        ]
    )
    y = row.train_label
    z = row.train_z
    n_labels = len(np.unique(y))
    for n_clusters in tqdm(np.arange(n_labels - int(n_labels / 2), n_labels + int(n_labels / 2)), leave=False, desc = 'n_clusters'):
        for init_ in tqdm(range(n_init), leave=False, desc='init'):
            kmeans = KMeans(n_clusters=n_clusters, random_state=init_).fit(z)
            clustered_y = kmeans.labels_
            homogeneity, completeness, v_measure = homogeneity_completeness_v_measure(
                y, clustered_y
            )
            ss, _ = silhouette_score_block(z, clustered_y)
            cluster_df.loc[len(cluster_df)] = [
                row.dataset,
                row.class_,
                row.dim,
                ss,
                homogeneity,
                completeness,
                v_measure,
                init_,
                n_clusters,
                kmeans,
            ]
    
     # save cluster df in case this fails somewhere
    ensure_dir(save_loc)
    cluster_df.to_pickle(save_loc)
    return cluster_df

# %%
projection_df = pd.DataFrame(columns = ['dataset', 'class_', 'train_z', 'train_label', 'dim'])
projection_df.loc[len(projection_df)] = [dataset, algorithm, z, Y_train, n_components]
projection_df
# Out:
#   dataset class_                                            train_z  \
# 0   mnist   ivis  [[0.25130323, 0.29446486], [5.192948, -1.27932...
#
#                                          train_label dim
# 0  [5, 0, 4, 1, 9, 2, 1, 3, 1, 4, 3, 5, 3, 6, 1, ...   2

# %%
get_cluster_metrics(projection_df.iloc[0], n_init=5)
# Out:
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/data/clustering_metric_df/ivis_2_mnist.pickle
# n_clusters:   0%|          | 0/10 [00:00<?, ?it/s]
# init:   0%|          | 0/5 [00:00<?, ?it/s]
# init:   0%|          | 0/5 [00:00<?, ?it/s]
# init:   0%|          | 0/5 [00:00<?, ?it/s]
# init:   0%|          | 0/5 [00:00<?, ?it/s]
# init:   0%|          | 0/5 [00:00<?, ?it/s]
# init:   0%|          | 0/5 [00:00<?, ?it/s]
# init:   0%|          | 0/5 [00:00<?, ?it/s]
# init:   0%|          | 0/5 [00:00<?, ?it/s]
# init:   0%|          | 0/5 [00:00<?, ?it/s]
# init:   0%|          | 0/5 [00:00<?, ?it/s]
#    dataset class_ dim  silhouette  homogeneity  completeness  v_measure init_  \
# 0    mnist   ivis   2    0.352001     0.380866      0.553720   0.451308     0
# 1    mnist   ivis   2    0.351788     0.380414      0.552883   0.450713     1
# 2    mnist   ivis   2    0.351988     0.380648      0.553366   0.451038     2
# 3    mnist   ivis   2    0.351983     0.380713      0.553441   0.451108     3
# 4    mnist   ivis   2    0.351701     0.380245      0.552586   0.450495     4
# 5    mnist   ivis   2    0.366995     0.448498      0.585035   0.507748     0
# 6    mnist   ivis   2    0.366455     0.443887      0.578646   0.502386     1
# 7    mnist   ivis   2    0.366898     0.445180      0.580482   0.503907     2
# 8    mnist   ivis   2    0.366673     0.447441      0.583724   0.506576     3
# 9    mnist   ivis   2    0.366644     0.447397      0.583668   0.506528     4
# 10   mnist   ivis   2    0.364179     0.452327      0.544669   0.494222     0
# 11   mnist   ivis   2    0.365157     0.451649      0.543681   0.493410     1
# 12   mnist   ivis   2    0.363173     0.453145      0.545528   0.495064     2
# 13   mnist   ivis   2    0.365911     0.450556      0.542259   0.492172     3
# 14   mnist   ivis   2    0.363032     0.453206      0.545568   0.495117     4
# 15   mnist   ivis   2    0.370568     0.476991      0.543757   0.508190     0
# 16   mnist   ivis   2    0.370091     0.477162      0.543380   0.508123     1
# 17   mnist   ivis   2    0.370417     0.476532      0.543126   0.507654     2
# 18   mnist   ivis   2    0.370382     0.476491      0.543054   0.507600     3
# 19   mnist   ivis   2    0.370146     0.477195      0.543485   0.508187     4
# 20   mnist   ivis   2    0.365013     0.501451      0.541960   0.520919     0
# 21   mnist   ivis   2    0.363586     0.496904      0.536647   0.516011     1
# 22   mnist   ivis   2    0.365063     0.499996      0.540718   0.519560     2
# 23   mnist   ivis   2    0.364899     0.501299      0.541730   0.520731     3
# 24   mnist   ivis   2    0.363717     0.498372      0.538441   0.517632     4
# 25   mnist   ivis   2    0.360429     0.491939      0.503916   0.497855     0
# 26   mnist   ivis   2    0.359887     0.494188      0.505862   0.499956     1
# 27   mnist   ivis   2    0.360546     0.493379      0.505464   0.499349     2
# 28   mnist   ivis   2    0.360023     0.494024      0.505791   0.499838     3
# 29   mnist   ivis   2    0.360023     0.494024      0.505791   0.499838     4
# 30   mnist   ivis   2    0.365802     0.498877      0.489727   0.494260     0
# 31   mnist   ivis   2    0.365720     0.499420      0.490236   0.494785     1
# 32   mnist   ivis   2    0.365968     0.496764      0.487772   0.492227     2
# 33   mnist   ivis   2    0.365817     0.498815      0.489680   0.494206     3
# 34   mnist   ivis   2    0.365709     0.499458      0.490268   0.494820     4
# 35   mnist   ivis   2    0.367252     0.518260      0.491288   0.504413     0
# 36   mnist   ivis   2    0.367381     0.517762      0.490900   0.503973     1
# 37   mnist   ivis   2    0.367407     0.520699      0.493587   0.506780     2
# 38   mnist   ivis   2    0.367521     0.521046      0.493884   0.507102     3
# 39   mnist   ivis   2    0.355092     0.519185      0.493341   0.505933     4
# 40   mnist   ivis   2    0.366839     0.526382      0.481645   0.503020     0
# 41   mnist   ivis   2    0.366854     0.526405      0.481642   0.503030     1
# 42   mnist   ivis   2    0.367077     0.527118      0.482078   0.503593     2
# 43   mnist   ivis   2    0.366831     0.526943      0.482069   0.503508     3
# 44   mnist   ivis   2    0.366875     0.526268      0.481517   0.502899     4
# 45   mnist   ivis   2    0.366368     0.549487      0.488493   0.517198     0
# 46   mnist   ivis   2    0.366334     0.549184      0.488400   0.517012     1
# 47   mnist   ivis   2    0.366508     0.550038      0.489058   0.517759     2
# 48   mnist   ivis   2    0.366212     0.550156      0.489131   0.517852     3
# 49   mnist   ivis   2    0.366437     0.549141      0.488406   0.516996     4
#
#    n_clusters                                  model
# 0           5   KMeans(n_clusters=5, random_state=0)
# 1           5   KMeans(n_clusters=5, random_state=1)
# 2           5   KMeans(n_clusters=5, random_state=2)
# 3           5   KMeans(n_clusters=5, random_state=3)
# 4           5   KMeans(n_clusters=5, random_state=4)
# 5           6   KMeans(n_clusters=6, random_state=0)
# 6           6   KMeans(n_clusters=6, random_state=1)
# 7           6   KMeans(n_clusters=6, random_state=2)
# 8           6   KMeans(n_clusters=6, random_state=3)
# 9           6   KMeans(n_clusters=6, random_state=4)
# 10          7   KMeans(n_clusters=7, random_state=0)
# 11          7   KMeans(n_clusters=7, random_state=1)
# 12          7   KMeans(n_clusters=7, random_state=2)
# 13          7   KMeans(n_clusters=7, random_state=3)
# 14          7   KMeans(n_clusters=7, random_state=4)
# 15          8                 KMeans(random_state=0)
# 16          8                 KMeans(random_state=1)
# 17          8                 KMeans(random_state=2)
# 18          8                 KMeans(random_state=3)
# 19          8                 KMeans(random_state=4)
# 20          9   KMeans(n_clusters=9, random_state=0)
# 21          9   KMeans(n_clusters=9, random_state=1)
# 22          9   KMeans(n_clusters=9, random_state=2)
# 23          9   KMeans(n_clusters=9, random_state=3)
# 24          9   KMeans(n_clusters=9, random_state=4)
# 25         10  KMeans(n_clusters=10, random_state=0)
# 26         10  KMeans(n_clusters=10, random_state=1)
# 27         10  KMeans(n_clusters=10, random_state=2)
# 28         10  KMeans(n_clusters=10, random_state=3)
# 29         10  KMeans(n_clusters=10, random_state=4)
# 30         11  KMeans(n_clusters=11, random_state=0)
# 31         11  KMeans(n_clusters=11, random_state=1)
# 32         11  KMeans(n_clusters=11, random_state=2)
# 33         11  KMeans(n_clusters=11, random_state=3)
# 34         11  KMeans(n_clusters=11, random_state=4)
# 35         12  KMeans(n_clusters=12, random_state=0)
# 36         12  KMeans(n_clusters=12, random_state=1)
# 37         12  KMeans(n_clusters=12, random_state=2)
# 38         12  KMeans(n_clusters=12, random_state=3)
# 39         12  KMeans(n_clusters=12, random_state=4)
# 40         13  KMeans(n_clusters=13, random_state=0)
# 41         13  KMeans(n_clusters=13, random_state=1)
# 42         13  KMeans(n_clusters=13, random_state=2)
# 43         13  KMeans(n_clusters=13, random_state=3)
# 44         13  KMeans(n_clusters=13, random_state=4)
# 45         14  KMeans(n_clusters=14, random_state=0)
# 46         14  KMeans(n_clusters=14, random_state=1)
# 47         14  KMeans(n_clusters=14, random_state=2)
# 48         14  KMeans(n_clusters=14, random_state=3)
# 49         14  KMeans(n_clusters=14, random_state=4)
