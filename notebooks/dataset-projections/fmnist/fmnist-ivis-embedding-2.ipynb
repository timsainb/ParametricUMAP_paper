# %%
dataset = 'fmnist'
algorithm = 'ivis'
n_components = 2

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ### load packages

# %%
from tfumap.umap import tfUMAP
# Out:
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
import umap
import pandas as pd

# %% [markdown]
# ### Load dataset

# %%
from tensorflow.keras.datasets import fashion_mnist

# load dataset
(train_images, Y_train), (test_images, Y_test) = fashion_mnist.load_data()
X_train = (train_images/255.).astype('float32')
X_test = (test_images/255.).astype('float32')
X_train = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))

# subset a validation set
n_valid = 10000
X_valid = X_train[-n_valid:]
Y_valid = Y_train[-n_valid:]
X_train = X_train[:-n_valid]
Y_train = Y_train[:-n_valid]

# flatten X
X_train_flat = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test_flat = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))
X_valid_flat= X_valid.reshape((len(X_valid), np.product(np.shape(X_valid)[1:])))
print(len(X_train), len(X_valid), len(X_test))
# Out:
# 50000 10000 10000

# %% [markdown]
# ### Create model and train

# %%
from ivis import Ivis
from sklearn.preprocessing import MinMaxScaler
from sklearn import datasets

# %%
dims = (28,28,1)

# %%
def create_model():
    """model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.BatchNormalization(input_shape=x_train.shape[1:]))
    model.add(tf.keras.layers.Conv2D(64, (5, 5), padding='same', activation='elu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2,2)))
    model.add(tf.keras.layers.Dropout(0.25))

    model.add(tf.keras.layers.BatchNormalization(input_shape=x_train.shape[1:]))
    model.add(tf.keras.layers.Conv2D(128, (5, 5), padding='same', activation='elu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.25))

    model.add(tf.keras.layers.BatchNormalization(input_shape=x_train.shape[1:]))
    model.add(tf.keras.layers.Conv2D(256, (5, 5), padding='same', activation='elu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

    model.add(tf.keras.layers.Flatten())
    """
    model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=dims),
    tf.keras.layers.Conv2D(
        filters=64, kernel_size=3, strides=(2, 2), activation="relu"
    ),
    tf.keras.layers.Conv2D(
        filters=128, kernel_size=3, strides=(2, 2), activation="relu"
    ),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation="relu"),
    tf.keras.layers.Dense(units=512, activation="relu"),
    #tf.keras.layers.Dense(units=n_components),
    ])
    return model

# %%
base_model = create_model()

# %%
X_train.shape
# Out:
# (50000, 784)

# %%
x_scaler = MinMaxScaler()
X_scaled = x_scaler.fit_transform(X_train).reshape([len(X_train)] + list(dims))

# %%
# Set ivis parameters
model = Ivis(model=base_model, embedding_dims=2)

# %%
# Generate embeddings
embeddings =z = model.fit_transform(X_scaled)
# Out:
#   0%|          | 138/50000 [00:00<00:43, 1159.28it/s]
# Building KNN index
# Flattening multidimensional input before building KNN index using Annoy
# 100%|██████████| 50000/50000 [00:15<00:00, 3237.39it/s]
# Extracting KNN neighbours
# Flattening data before retrieving KNN from index
# 100%|█████████▉| 49895/50000 [00:11<00:00, 4163.85it/s]
# Training neural network
# Epoch 1/1000
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0772
# Epoch 2/1000
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0552
# Epoch 3/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0522
# Epoch 4/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0505
# Epoch 5/1000
# 391/391 [==============================] - 4s 10ms/step - loss: 0.0480
# Epoch 6/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0468
# Epoch 7/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0467
# Epoch 8/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0449
# Epoch 9/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0438
# Epoch 10/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0445
# Epoch 11/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0438
# Epoch 12/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0433
# Epoch 13/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0428
# Epoch 14/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0408
# Epoch 15/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0438
# Epoch 16/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0428
# Epoch 17/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0415
# Epoch 18/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0403
# Epoch 19/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0403
# Epoch 20/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0413
# Epoch 21/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0418
# Epoch 22/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0385
# Epoch 23/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0365
# Epoch 24/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0395
# Epoch 25/1000
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0399
# Epoch 26/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0368
# Epoch 27/1000
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0394
# Epoch 28/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0379
# Epoch 29/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0386
# Epoch 30/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0399
# Epoch 31/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0375
# Epoch 32/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0383
# Epoch 33/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0378
# Epoch 34/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0406
# Epoch 35/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0372
# Epoch 36/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0370
# Epoch 37/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0380
# Epoch 38/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0370
# Epoch 39/1000
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0375
# Epoch 40/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0382
# Epoch 41/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0390
# Epoch 42/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0376
# Epoch 43/1000
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0378
# 391/391 [==============================] - 1s 2ms/step

# %% [markdown]
# ### Plot model output

# %%
fig, ax = plt.subplots( figsize=(8, 8))
sc = ax.scatter(
    z[:, 0],
    z[:, 1],
    c=Y_train.astype(int)[:len(z)],
    cmap="tab10",
    s=0.1,
    alpha=0.5,
    rasterized=True,
)
ax.axis('equal')
ax.set_title("UMAP in Tensorflow embedding", fontsize=20)
plt.colorbar(sc, ax=ax);

# %% [markdown]
# ### Save output

# %%
from tfumap.paths import ensure_dir, MODEL_DIR

# %%
output_dir = MODEL_DIR/'projections'/ dataset / algorithm
ensure_dir(output_dir)

# %%
#vae.save(output_dir)

# %%
model.save_model(output_dir / 'iris.ivis')

# %%
#loss_df.to_pickle(output_dir / 'loss_df.pickle')

# %%
np.save(output_dir / 'z.npy', z)

# %% [markdown]
# ### compute metrics

# %%
X_test.shape
# Out:
# (10000, 784)

# %%
z_test = model.transform(x_scaler.transform(X_test).reshape([len(X_test)]+ list(dims)))
# Out:
# 79/79 [==============================] - 0s 1ms/step

# %% [markdown]
# #### silhouette

# %%
from tfumap.silhouette import silhouette_score_block

# %%
ss, sil_samp = silhouette_score_block(z, Y_train, n_jobs = -1)
ss
# Out:
# 0.08819600381897753

# %%
ss_test, sil_samp_test = silhouette_score_block(z_test, Y_test, n_jobs = -1)
ss_test
# Out:
# 0.07918252805413452

# %%
fig, axs = plt.subplots(ncols = 2, figsize=(10, 5))
axs[0].scatter(z[:, 0], z[:, 1], s=0.1, alpha=0.5, c=sil_samp, cmap=plt.cm.viridis)
axs[1].scatter(z_test[:, 0], z_test[:, 1], s=1, alpha=0.5, c=sil_samp_test, cmap=plt.cm.viridis)

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neigh5 = KNeighborsClassifier(n_neighbors=5)
neigh5.fit(z, Y_train)
score_5nn = neigh5.score(z_test, Y_test)
score_5nn
# Out:
# 0.662

# %%
neigh1 = KNeighborsClassifier(n_neighbors=1)
neigh1.fit(z, Y_train)
score_1nn = neigh1.score(z_test, Y_test)
score_1nn
# Out:
# 0.6108

# %% [markdown]
# #### Trustworthiness

# %%
from sklearn.manifold import trustworthiness

# %%
tw = trustworthiness(X_train_flat[:10000], z[:10000])

# %%
tw_test = trustworthiness(X_test_flat[:10000], z_test[:10000])

# %%
tw, tw_test
# Out:
# (0.8855625860688551, 0.8817829863891113)

# %% [markdown]
# ### Save output metrics

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

# %% [markdown]
# #### train

# %%
metrics_df = pd.DataFrame(
    columns=[
        "dataset",
        "class_",
        "dim",
        "trustworthiness",
        "silhouette_score",
        "silhouette_samples",
    ]
)
metrics_df.loc[len(metrics_df)] = [dataset, algorithm, n_components, tw, ss, sil_samp]
metrics_df
# Out:
#   dataset class_ dim  trustworthiness  silhouette_score  \
# 0  fmnist   ivis   2         0.885563          0.088196
#
#                                   silhouette_samples
# 0  [0.4778306898578402, 0.5064542779065385, -0.49...

# %%
save_loc = DATA_DIR / 'projection_metrics' /  algorithm / 'train' / str(n_components) / (dataset + '.pickle')
ensure_dir(save_loc)
metrics_df.to_pickle(save_loc)

# %% [markdown]
# #### test

# %%
metrics_df_test = pd.DataFrame(
    columns=[
        "dataset",
        "class_",
        "dim",
        "trustworthiness",
        "silhouette_score",
        "silhouette_samples",
    ]
)
metrics_df_test.loc[len(metrics_df)] = [dataset, algorithm, n_components, tw_test, ss_test, sil_samp_test]
metrics_df_test
# Out:
#   dataset class_ dim  trustworthiness  silhouette_score  \
# 1  fmnist   ivis   2         0.881783          0.079183
#
#                                   silhouette_samples
# 1  [-0.07291031932570624, 0.2832782852341588, 0.4...

# %%
save_loc = DATA_DIR / 'projection_metrics' / algorithm / 'test' / str(n_components) / (dataset + '.pickle')
ensure_dir(save_loc)
metrics_df.to_pickle(save_loc)

# %% [markdown]
# #### knn

# %%
nn_acc_df = pd.DataFrame(columns = ["method_","dimensions","dataset","1NN_acc","5NN_acc"])
nn_acc_df.loc[len(nn_acc_df)] = [algorithm, n_components, dataset,  score_1nn, score_5nn]
nn_acc_df
# Out:
#   method_ dimensions dataset  1NN_acc  5NN_acc
# 0    ivis          2  fmnist   0.6108    0.662

# %%
save_loc = DATA_DIR / 'knn_classifier' / algorithm / 'train' / str(n_components) / (dataset + '.pickle')
ensure_dir(save_loc)
nn_acc_df.to_pickle(save_loc)

# %% [markdown]
# ### Compute clustering quality

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import homogeneity_completeness_v_measure

# %%
def get_cluster_metrics(row, n_init=5):
    
    # load cluster information
    save_loc = DATA_DIR / 'clustering_metric_df'/ ('_'.join([row.class_, str(row.dim), row.dataset]) + '.pickle')
    print(save_loc)
    if save_loc.exists() and save_loc.is_file():
        
        cluster_df = pd.read_pickle(save_loc)
        return cluster_df
    
    # make cluster metric dataframe
    cluster_df = pd.DataFrame(
        columns=[
            "dataset",
            "class_",
            "dim",
            "silhouette",
            "homogeneity",
            "completeness",
            "v_measure",
            "init_",
            "n_clusters",
            "model",
        ]
    )
    y = row.train_label
    z = row.train_z
    n_labels = len(np.unique(y))
    for n_clusters in tqdm(np.arange(n_labels - int(n_labels / 2), n_labels + int(n_labels / 2)), leave=False, desc = 'n_clusters'):
        for init_ in tqdm(range(n_init), leave=False, desc='init'):
            kmeans = KMeans(n_clusters=n_clusters, random_state=init_).fit(z)
            clustered_y = kmeans.labels_
            homogeneity, completeness, v_measure = homogeneity_completeness_v_measure(
                y, clustered_y
            )
            ss, _ = silhouette_score_block(z, clustered_y)
            cluster_df.loc[len(cluster_df)] = [
                row.dataset,
                row.class_,
                row.dim,
                ss,
                homogeneity,
                completeness,
                v_measure,
                init_,
                n_clusters,
                kmeans,
            ]
    
     # save cluster df in case this fails somewhere
    ensure_dir(save_loc)
    cluster_df.to_pickle(save_loc)
    return cluster_df

# %%
projection_df = pd.DataFrame(columns = ['dataset', 'class_', 'train_z', 'train_label', 'dim'])
projection_df.loc[len(projection_df)] = [dataset, algorithm, z, Y_train, n_components]
projection_df
# Out:
#   dataset class_                                            train_z  \
# 0  fmnist   ivis  [[11.355193, -0.5743056], [-4.4484715, 10.5330...
#
#                                          train_label dim
# 0  [9, 0, 0, 3, 0, 2, 7, 2, 5, 5, 0, 9, 5, 5, 7, ...   2

# %%
??get_cluster_metrics

# %%
get_cluster_metrics(projection_df.iloc[0], n_init=5)
# Out:
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/data/clustering_metric_df/ivis_2_fmnist.pickle
#    dataset class_ dim  silhouette  homogeneity  completeness  v_measure init_  \
# 0   fmnist   ivis   2    0.435481     0.439464      0.640221   0.521178     0
# 1   fmnist   ivis   2    0.435555     0.439706      0.640638   0.521487     1
# 2   fmnist   ivis   2    0.435461     0.439821      0.640629   0.521565     2
# 3   fmnist   ivis   2    0.435345     0.440055      0.640865   0.521807     3
# 4   fmnist   ivis   2    0.435595     0.439848      0.640856   0.521658     4
# 5   fmnist   ivis   2    0.427955     0.468138      0.621929   0.534185     0
# 6   fmnist   ivis   2    0.428595     0.468252      0.621914   0.534254     1
# 46  fmnist   ivis   2    0.385353     0.579716      0.518706   0.547516     1
# 47  fmnist   ivis   2    0.377149     0.577428      0.513488   0.543584     2
# 48  fmnist   ivis   2    0.387151     0.573257      0.511425   0.540579     3
# 49  fmnist   ivis   2    0.385712     0.572779      0.510150   0.539653     4
#
#    n_clusters                                  model
# 0           5   KMeans(n_clusters=5, random_state=0)
# 1           5   KMeans(n_clusters=5, random_state=1)
# 2           5   KMeans(n_clusters=5, random_state=2)
# 3           5   KMeans(n_clusters=5, random_state=3)
# 4           5   KMeans(n_clusters=5, random_state=4)
# 5           6   KMeans(n_clusters=6, random_state=0)
# 6           6   KMeans(n_clusters=6, random_state=1)
# 7           6   KMeans(n_clusters=6, random_state=2)
# 8           6   KMeans(n_clusters=6, random_state=3)
# 9           6   KMeans(n_clusters=6, random_state=4)
# 10          7   KMeans(n_clusters=7, random_state=0)
# 11          7   KMeans(n_clusters=7, random_state=1)
# 12          7   KMeans(n_clusters=7, random_state=2)
# 13          7   KMeans(n_clusters=7, random_state=3)
# 14          7   KMeans(n_clusters=7, random_state=4)
# 15          8                 KMeans(random_state=0)
# 16          8                 KMeans(random_state=1)
# 17          8                 KMeans(random_state=2)
# 18          8                 KMeans(random_state=3)
# 19          8                 KMeans(random_state=4)
# 20          9   KMeans(n_clusters=9, random_state=0)
# 21          9   KMeans(n_clusters=9, random_state=1)
# 22          9   KMeans(n_clusters=9, random_state=2)
# 23          9   KMeans(n_clusters=9, random_state=3)
# 24          9   KMeans(n_clusters=9, random_state=4)
# 25         10  KMeans(n_clusters=10, random_state=0)
# 26         10  KMeans(n_clusters=10, random_state=1)
# 27         10  KMeans(n_clusters=10, random_state=2)
# 28         10  KMeans(n_clusters=10, random_state=3)
# 29         10  KMeans(n_clusters=10, random_state=4)
# 30         11  KMeans(n_clusters=11, random_state=0)
# 31         11  KMeans(n_clusters=11, random_state=1)
# 32         11  KMeans(n_clusters=11, random_state=2)
# 33         11  KMeans(n_clusters=11, random_state=3)
# 34         11  KMeans(n_clusters=11, random_state=4)
# 35         12  KMeans(n_clusters=12, random_state=0)
# 36         12  KMeans(n_clusters=12, random_state=1)
# 37         12  KMeans(n_clusters=12, random_state=2)
# 38         12  KMeans(n_clusters=12, random_state=3)
# 39         12  KMeans(n_clusters=12, random_state=4)
# 40         13  KMeans(n_clusters=13, random_state=0)
# 41         13  KMeans(n_clusters=13, random_state=1)
# 42         13  KMeans(n_clusters=13, random_state=2)
# 43         13  KMeans(n_clusters=13, random_state=3)
# 44         13  KMeans(n_clusters=13, random_state=4)
# 45         14  KMeans(n_clusters=14, random_state=0)
# 46         14  KMeans(n_clusters=14, random_state=1)
# 47         14  KMeans(n_clusters=14, random_state=2)
# 48         14  KMeans(n_clusters=14, random_state=3)
# 49         14  KMeans(n_clusters=14, random_state=4)
