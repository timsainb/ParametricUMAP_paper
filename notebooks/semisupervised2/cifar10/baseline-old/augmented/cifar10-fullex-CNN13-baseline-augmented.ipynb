# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
print(gpu_devices)
tf.keras.backend.clear_session()
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### dataset information

# %%
from datetime import datetime

dataset = "cifar10"
dims = (32, 32, 3)
num_classes = 10
labels_per_class = 'full' # full
batch_size = 128
datestring = datetime.now().strftime("%Y_%m_%d_%H_%M_%S_%f")
datestring = (
    str(dataset)
    + "_"
    + str(labels_per_class)
    + "____"
    + datestring 
    + '_baseline_augmented'
)
print(datestring)
# Out:
# cifar10_full____2020_08_09_22_03_51_910408_baseline_augmented

# %% [markdown]
# ### Load packages

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from IPython import display
import pandas as pd
import umap
import copy
import os, tempfile
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### Load dataset

# %%
from tfumap.load_datasets import load_CIFAR10, mask_labels
X_train, X_test, X_valid, Y_train, Y_test, Y_valid = load_CIFAR10(flatten=False)
X_train.shape
# Out:
# (40000, 32, 32, 3)

# %%
if labels_per_class == "full":
    X_labeled = X_train
    Y_masked = Y_labeled = Y_train
else:
    X_labeled, Y_labeled, Y_masked = mask_labels(
        X_train, Y_train, labels_per_class=labels_per_class
    )

# %% [markdown]
# ### Build network

# %%
from tensorflow.keras import datasets, layers, models
from tensorflow_addons.layers import WeightNormalization

def conv_block(filts, name, kernel_size = (3, 3), padding = "same", **kwargs):
    return WeightNormalization(
        layers.Conv2D(
            filts, kernel_size, activation=None, padding=padding, **kwargs
        ),
        name="conv"+name,
    )
#CNN13
#See: 
#https://github.com/vikasverma1077/ICT/blob/master/networks/lenet.py
#https://github.com/brain-research/realistic-ssl-evaluation

# %%
lr_alpha = 0.1
dropout_rate = 0.5
num_classes = 10
input_shape = (32, 32, 3)
model = models.Sequential()
model.add(tf.keras.Input(shape=input_shape))
### conv1a
name = '1a'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1b
name = '1b'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1c
name = '1c'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp1"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop1"))

### conv2a
name = '2a'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha))

### conv2b
name = '2b'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv2c
name = '2c'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp2"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop2"))

### conv3a
name = '3a'
model.add(conv_block(name = name, filts = 512, kernel_size = (3,3), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3b
name = '3b'
model.add(conv_block(name = name, filts = 256, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3c
name = '3c'
model.add(conv_block(name = name, filts = 128, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.AveragePooling2D(pool_size=(6, 6), strides=2, padding='valid'))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation=None, name='z'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc1'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc2'))
model.add(WeightNormalization(layers.Dense(num_classes, activation=None)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1a (WeightNormalization) (None, 32, 32, 128)       7297
# _________________________________________________________________
# bn1a (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1a (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1b (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1b (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1b (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1c (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1c (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1c (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# mp1 (MaxPooling2D)           (None, 16, 16, 128)       0
# _________________________________________________________________
# drop1 (Dropout)              (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2a (WeightNormalization) (None, 16, 16, 256)       590593
# _________________________________________________________________
# bn2a (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2b (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2b (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2b (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2c (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2c (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2c (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# mp2 (MaxPooling2D)           (None, 8, 8, 256)         0
# _________________________________________________________________
# drop2 (Dropout)              (None, 8, 8, 256)         0
# _________________________________________________________________
# conv3a (WeightNormalization) (None, 6, 6, 512)         2360833
# _________________________________________________________________
# bn3a (BatchNormalization)    (None, 6, 6, 512)         2048
# _________________________________________________________________
# lrelu3a (LeakyReLU)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv3b (WeightNormalization) (None, 6, 6, 256)         262913
# _________________________________________________________________
# bn3b (BatchNormalization)    (None, 6, 6, 256)         1024
# _________________________________________________________________
# lrelu3b (LeakyReLU)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv3c (WeightNormalization) (None, 6, 6, 128)         65921
# _________________________________________________________________
# bn3c (BatchNormalization)    (None, 6, 6, 128)         512
# _________________________________________________________________
# lrelu3c (LeakyReLU)          (None, 6, 6, 128)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# z (Dense)                    (None, 256)               33024
# _________________________________________________________________
# weight_normalization (Weight (None, 256)               131841
# _________________________________________________________________
# lrelufc1 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_1 (Weig (None, 256)               131841
# _________________________________________________________________
# lrelufc2 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_2 (Weig (None, 10)                5151
# =================================================================
# Total params: 6,549,034
# Trainable params: 3,292,308
# Non-trainable params: 3,256,726
# _________________________________________________________________

# %% [markdown]
# ### Augmentation

# %%
import tensorflow_addons as tfa
def augment(image, label):
    image = tf.squeeze(image) # Add 6 pixels of padding
    image = tf.image.resize_with_crop_or_pad(image, dims[0] + 6, dims[1] + 6) # crop 6 pixels
    image = tf.image.random_crop(image, size=dims)
    image = tf.image.random_brightness(image, max_delta=0.15)  # Random brightness
    image= tf.image.random_contrast(image, lower=0.6, upper=1.4)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_hue(image, 0.05, seed=None)
    #image = tf.image.random_jpeg_quality(image, 10, 100, seed=None)
    image = tfa.image.rotate(image, tf.squeeze(tf.random.uniform(shape = (1,1), minval=-.2, maxval=.2)), interpolation='BILINEAR')
    image = tfa.image.random_cutout(tf.expand_dims(image, 0), (8,8), constant_values=0.5)[0]
    image = tf.clip_by_value(image, 0, 1)
    return image, label

# %%
nex = 10
for i in range(5):
    fig, axs = plt.subplots(ncols=nex +1, figsize=((nex+1)*2, 2))
    axs[0].imshow(X_train[i])
    axs[0].axis('off')
    for ax in axs.flatten()[1:]:
        ax.imshow(augment(X_train[i], Y_train[i])[0])
        ax.axis('off')

# %% [markdown]
# ### train

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', min_delta=0, patience=50, verbose=0, mode='auto',
    baseline=None, restore_best_weights=False
)

# %%
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)
model.compile(tf.keras.optimizers.Adam(1e-3), loss = loss, metrics=['accuracy'])

# %%
Y_valid_one_hot = tf.keras.backend.one_hot(
    Y_valid, num_classes
)

# %%
Y_labeled_one_hot = tf.keras.backend.one_hot(
    Y_labeled, num_classes
)

# %%
train_ds = (
     tf.data.Dataset.from_tensor_slices((X_labeled, Y_labeled_one_hot))
    .shuffle(1000)
    .map(augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.experimental.AUTOTUNE)
)

# %%
history = model.fit(
    train_ds,
    epochs=500,
    validation_data=(X_valid, Y_valid_one_hot),
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/500
# 313/313 [==============================] - 22s 69ms/step - loss: 2.0171 - accuracy: 0.3426 - val_loss: 2.5635 - val_accuracy: 0.2793
# Epoch 2/500
# 313/313 [==============================] - 20s 62ms/step - loss: 1.7339 - accuracy: 0.5032 - val_loss: 2.0620 - val_accuracy: 0.4481
# Epoch 3/500
# 313/313 [==============================] - 17s 56ms/step - loss: 1.6159 - accuracy: 0.5788 - val_loss: 1.6643 - val_accuracy: 0.6110
# Epoch 4/500
# 313/313 [==============================] - 17s 56ms/step - loss: 1.5282 - accuracy: 0.6295 - val_loss: 1.5531 - val_accuracy: 0.6362
# Epoch 5/500
# 313/313 [==============================] - 17s 56ms/step - loss: 1.4737 - accuracy: 0.6645 - val_loss: 1.6409 - val_accuracy: 0.5819
# Epoch 6/500
# 313/313 [==============================] - 18s 57ms/step - loss: 1.4313 - accuracy: 0.6876 - val_loss: 1.6858 - val_accuracy: 0.5897
# Epoch 7/500
# 313/313 [==============================] - 21s 68ms/step - loss: 1.3975 - accuracy: 0.7084 - val_loss: 1.5290 - val_accuracy: 0.6719
# Epoch 8/500
# 313/313 [==============================] - 28s 91ms/step - loss: 1.3655 - accuracy: 0.7262 - val_loss: 1.4774 - val_accuracy: 0.6915
# Epoch 9/500
# 313/313 [==============================] - 34s 110ms/step - loss: 1.3458 - accuracy: 0.7382 - val_loss: 1.4321 - val_accuracy: 0.7038
# Epoch 10/500
# 313/313 [==============================] - 34s 109ms/step - loss: 1.3214 - accuracy: 0.7528 - val_loss: 1.3253 - val_accuracy: 0.7568
# Epoch 11/500
# 313/313 [==============================] - 34s 107ms/step - loss: 1.3072 - accuracy: 0.7580 - val_loss: 1.2279 - val_accuracy: 0.8065
# Epoch 12/500
# 313/313 [==============================] - 34s 109ms/step - loss: 1.2875 - accuracy: 0.7705 - val_loss: 1.3875 - val_accuracy: 0.7335
# Epoch 13/500
500
# 313/313 [==============================] - 30s 95ms/step - loss: 0.9449 - accuracy: 0.9588 - val_loss: 1.0308 - val_accuracy: 0.9213
# Epoch 165/500
# 313/313 [==============================] - 29s 92ms/step - loss: 0.9405 - accuracy: 0.9606 - val_loss: 1.0320 - val_accuracy: 0.9195
# Epoch 166/500
# 313/313 [==============================] - 29s 93ms/step - loss: 0.9396 - accuracy: 0.9615 - val_loss: 1.0261 - val_accuracy: 0.9246
# Epoch 167/500
# 313/313 [==============================] - 30s 95ms/step - loss: 0.9404 - accuracy: 0.9604 - val_loss: 1.0337 - val_accuracy: 0.9208
# Epoch 168/500
# 313/313 [==============================] - 28s 91ms/step - loss: 0.9409 - accuracy: 0.9600 - val_loss: 1.0122 - val_accuracy: 0.9286
# Epoch 169/500
# 313/313 [==============================] - 29s 93ms/step - loss: 0.9400 - accuracy: 0.9605 - val_loss: 1.0092 - val_accuracy: 0.9284
# Epoch 170/500
# 313/313 [==============================] - 30s 94ms/step - loss: 0.9365 - accuracy: 0.9622 - val_loss: 1.0264 - val_accuracy: 0.9212
# Epoch 171/500
# 313/313 [==============================] - 29s 93ms/step - loss: 0.9362 - accuracy: 0.9620 - val_loss: 1.0192 - val_accuracy: 0.9243
# Epoch 172/500
# 313/313 [==============================] - 29s 94ms/step - loss: 0.9401 - accuracy: 0.9603 - val_loss: 1.0204 - val_accuracy: 0.9225
# Epoch 173/500
# 313/313 [==============================] - 29s 94ms/step - loss: 0.9421 - accuracy: 0.9604 - val_loss: 1.0208 - val_accuracy: 0.9255
# Epoch 174/500
# 313/313 [==============================] - 28s 91ms/step - loss: 0.9362 - accuracy: 0.9634 - val_loss: 1.0206 - val_accuracy: 0.9236
# Epoch 175/500
# 313/313 [==============================] - 30s 95ms/step - loss: 0.9374 - accuracy: 0.9618 - val_loss: 1.0153 - val_accuracy: 0.9281
# Epoch 176/500
# 313/313 [==============================] - 29s 91ms/step - loss: 0.9334 - accuracy: 0.9653 - val_loss: 1.0320 - val_accuracy: 0.9202
# Epoch 177/500
# 313/313 [==============================] - 29s 93ms/step - loss: 0.9364 - accuracy: 0.9628 - val_loss: 1.0138 - val_accuracy: 0.9300
# Epoch 178/500
# 313/313 [==============================] - 30s 94ms/step - loss: 0.9355 - accuracy: 0.9632 - val_loss: 1.0059 - val_accuracy: 0.9321
# Epoch 179/500
# 313/313 [==============================] - 28s 91ms/step - loss: 0.9363 - accuracy: 0.9625 - val_loss: 1.0282 - val_accuracy: 0.9206
# Epoch 180/500
# 313/313 [==============================] - 29s 94ms/step - loss: 0.9357 - accuracy: 0.9631 - val_loss: 1.0225 - val_accuracy: 0.9241
# Epoch 181/500
# 313/313 [==============================] - 29s 94ms/step - loss: 0.9348 - accuracy: 0.9636 - val_loss: 1.0264 - val_accuracy: 0.9223
# Epoch 182/500
# 313/313 [==============================] - 28s 91ms/step - loss: 0.9358 - accuracy: 0.9625 - val_loss: 1.0194 - val_accuracy: 0.9257
# Epoch 183/500
# 313/313 [==============================] - 30s 95ms/step - loss: 0.9348 - accuracy: 0.9636 - val_loss: 1.0261 - val_accuracy: 0.9224
# Epoch 184/500
# 313/313 [==============================] - 29s 92ms/step - loss: 0.9336 - accuracy: 0.9640 - val_loss: 1.0630 - val_accuracy: 0.9074
# Epoch 185/500
# 313/313 [==============================] - 29s 93ms/step - loss: 0.9342 - accuracy: 0.9633 - val_loss: 1.0209 - val_accuracy: 0.9245
# Epoch 186/500
# 313/313 [==============================] - 29s 94ms/step - loss: 0.9336 - accuracy: 0.9647 - val_loss: 1.0344 - val_accuracy: 0.9198
# Epoch 187/500
# 313/313 [==============================] - 28s 91ms/step - loss: 0.9321 - accuracy: 0.9651 - val_loss: 1.0222 - val_accuracy: 0.9214
# Epoch 188/500
# 313/313 [==============================] - 30s 94ms/step - loss: 0.9334 - accuracy: 0.9652 - val_loss: 1.0271 - val_accuracy: 0.9245
# Epoch 189/500
# 313/313 [==============================] - 29s 93ms/step - loss: 0.9333 - accuracy: 0.9636 - val_loss: 1.0099 - val_accuracy: 0.9300
# Epoch 190/500
# 313/313 [==============================] - 29s 93ms/step - loss: 0.9342 - accuracy: 0.9639 - val_loss: 1.0289 - val_accuracy: 0.9208
# Epoch 191/500
# 313/313 [==============================] - 30s 95ms/step - loss: 0.9320 - accuracy: 0.9652 - val_loss: 1.0041 - val_accuracy: 0.9318
# Epoch 192/500
# 313/313 [==============================] - 28s 91ms/step - loss: 0.9327 - accuracy: 0.9647 - val_loss: 1.0213 - val_accuracy: 0.9272
# Epoch 193/500
# 313/313 [==============================] - 29s 93ms/step - loss: 0.9321 - accuracy: 0.9654 - val_loss: 1.0157 - val_accuracy: 0.9269
# Epoch 194/500
# 313/313 [==============================] - 29s 94ms/step - loss: 0.9318 - accuracy: 0.9651 - val_loss: 1.0184 - val_accuracy: 0.9267
# Epoch 195/500
# 313/313 [==============================] - 29s 92ms/step - loss: 0.9298 - accuracy: 0.9664 - val_loss: 1.0067 - val_accuracy: 0.9312
# Epoch 196/500
# 313/313 [==============================] - 30s 95ms/step - loss: 0.9306 - accuracy: 0.9652 - val_loss: 1.0083 - val_accuracy: 0.9306
# Epoch 197/500
# 313/313 [==============================] - 29s 93ms/step - loss: 0.9307 - accuracy: 0.9662 - val_loss: 1.0083 - val_accuracy: 0.9307
# Epoch 198/500
# 313/313 [==============================] - 29s 91ms/step - loss: 0.9284 - accuracy: 0.9672 - val_loss: 1.0349 - val_accuracy: 0.9197
# Epoch 199/500
# 313/313 [==============================] - 30s 95ms/step - loss: 0.9296 - accuracy: 0.9671 - val_loss: 1.0306 - val_accuracy: 0.9229
# Epoch 200/500
# 313/313 [==============================] - 29s 92ms/step - loss: 0.9287 - accuracy: 0.9669 - val_loss: 1.0153 - val_accuracy: 0.9271
# Epoch 201/500
# 313/313 [==============================] - 29s 93ms/step - loss: 0.9313 - accuracy: 0.9654 - val_loss: 1.0103 - val_accuracy: 0.9307
# Epoch 202/500
# 313/313 [==============================] - 30s 94ms/step - loss: 0.9279 - accuracy: 0.9678 - val_loss: 1.0077 - val_accuracy: 0.9303
# Epoch 203/500
# 313/313 [==============================] - 29s 91ms/step - loss: 0.9298 - accuracy: 0.9659 - val_loss: 1.0259 - val_accuracy: 0.9232
# Epoch 204/500
# 313/313 [==============================] - 29s 94ms/step - loss: 0.9302 - accuracy: 0.9663 - val_loss: 1.0097 - val_accuracy: 0.9304
# Epoch 205/500
# 313/313 [==============================] - 29s 92ms/step - loss: 0.9274 - accuracy: 0.9675 - val_loss: 1.0146 - val_accuracy: 0.9274
# Epoch 206/500
# 313/313 [==============================] - 29s 92ms/step - loss: 0.9299 - accuracy: 0.9656 - val_loss: 1.0199 - val_accuracy: 0.9264

# %% [markdown]
# ### evaluate

# %%
Y_test_one_hot = tf.keras.backend.one_hot(
    Y_test, num_classes
)
result = model.evaluate(X_test, Y_test_one_hot)
# Out:
# 313/313 [==============================] - 4s 14ms/step - loss: 1.0422 - accuracy: 0.9154

# %%
plt.semilogx(history.history['loss'])
plt.semilogx(history.history['val_loss'])

# %%
plt.semilogx(history.history['accuracy'])
plt.semilogx(history.history['val_accuracy'])

# %%
submodel = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
    )
z = submodel.predict(X_train)
np.shape(z)
# Out:
# (40000, 256)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Mon Aug 10 00:02:34 2020 Finding Nearest Neighbors
# Mon Aug 10 00:02:34 2020 Building RP forest with 15 trees
# Mon Aug 10 00:02:36 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# Mon Aug 10 00:02:46 2020 Finished Nearest Neighbor Search
# Mon Aug 10 00:02:48 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Aug 10 00:03:13 2020 Finished embedding

# %%
predictions = model.predict(X_train)

# %%
mask = np.array(np.argmax(predictions, axis=1)) != Y_train.flatten()

# %%
fig, axs = plt.subplots(ncols = 5, figsize=(50,10))
axs[0].scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 1, cmap = plt.cm.tab10)
axs[1].scatter(embedding[:, 0], embedding[:, 1], c=np.argmax(predictions, axis=1), s= 1, alpha = 1, cmap = plt.cm.tab10)
axs[2].scatter(embedding[:, 0], embedding[:, 1], c=np.array(np.argmax(predictions, axis=1)) == Y_train.flatten(), s= 1, alpha = 1, cmap = plt.cm.viridis)
axs[3].scatter(embedding[mask, 0], embedding[mask, 1], c=Y_train.flatten()[mask], s= 10, alpha = 1, cmap = plt.cm.tab10)
axs[4].scatter(embedding[mask, 0], embedding[mask, 1], c=np.argmax(predictions, axis=1)[mask], s= 10, alpha = 1, cmap = plt.cm.tab10)

# %% [markdown]
# ### save results

# %%
# save score, valid embedding, weights, results

# %%
from tfumap.paths import MODEL_DIR, ensure_dir

# %%
save_folder = MODEL_DIR / 'semisupervised-keras' / dataset / str(labels_per_class) / datestring
ensure_dir(save_folder)

# %% [markdown]
# #### save weights

# %%
encoder = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
)

# %%
encoder.save_weights((save_folder / "encoder").as_posix())

# %%
classifier = tf.keras.models.Model(
        [tf.keras.Input(tensor=model.get_layer('weight_normalization').input)], [model.outputs[0]]
)
print([i.name for i in classifier.layers])
# Out:
# ['input_2', 'weight_normalization', 'lrelufc1', 'weight_normalization_1', 'lrelufc2', 'weight_normalization_2']

# %%
classifier.save_weights((save_folder / "classifier").as_posix())

# %%
model.save_weights((save_folder / "full_model").as_posix())

# %% [markdown]
# #### save score

# %%
Y_test_one_hot = tf.keras.backend.one_hot(
    Y_test, num_classes
)
result = model.evaluate(X_test, Y_test_one_hot)
# Out:
# 313/313 [==============================] - 5s 16ms/step - loss: 1.0422 - accuracy: 0.9154

# %%
np.save(save_folder / 'test_loss.npy', result)

# %% [markdown]
# #### save embedding

# %%
z = encoder.predict(X_train)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))

plt.scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Mon Aug 10 09:29:32 2020 Finding Nearest Neighbors
# Mon Aug 10 09:29:32 2020 Building RP forest with 15 trees
# Mon Aug 10 09:29:35 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# Mon Aug 10 09:29:39 2020 Finished Nearest Neighbor Search
# Mon Aug 10 09:29:40 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Aug 10 09:30:28 2020 Finished embedding

# %%
np.save(save_folder / 'train_embedding.npy', embedding)

# %% [markdown]
# #### save results

# %%
import pickle

# %%
with open(save_folder / 'history.pickle', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
