# %%
dataset = 'cifar10'
algorithm = 'ivis'
n_components = 2
dims = (32,32,3)

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ### load packages

# %%
from tfumap.umap import tfUMAP
# Out:
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
import umap
import pandas as pd

# %% [markdown]
# ### Load dataset

# %%
from tensorflow.keras.datasets import cifar10

# load dataset
(train_images, Y_train), (test_images, Y_test) = cifar10.load_data()
X_train = (train_images/255.).astype('float32')
X_test = (test_images/255.).astype('float32')
X_train = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))

# subset a validation set
n_valid = 10000
X_valid = X_train[-n_valid:]
Y_valid = Y_train[-n_valid:]
X_train = X_train[:-n_valid]
Y_train = Y_train[:-n_valid]

# flatten X
X_train_flat = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test_flat = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))
X_valid_flat= X_valid.reshape((len(X_valid), np.product(np.shape(X_valid)[1:])))
print(len(X_train), len(X_valid), len(X_test))
# Out:
# 40000 10000 10000

# %% [markdown]
# ### Create model and train

# %%
from ivis import Ivis
from sklearn.preprocessing import MinMaxScaler
from sklearn import datasets

# %%
def create_model():
    """model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.BatchNormalization(input_shape=x_train.shape[1:]))
    model.add(tf.keras.layers.Conv2D(64, (5, 5), padding='same', activation='elu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2,2)))
    model.add(tf.keras.layers.Dropout(0.25))

    model.add(tf.keras.layers.BatchNormalization(input_shape=x_train.shape[1:]))
    model.add(tf.keras.layers.Conv2D(128, (5, 5), padding='same', activation='elu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.25))

    model.add(tf.keras.layers.BatchNormalization(input_shape=x_train.shape[1:]))
    model.add(tf.keras.layers.Conv2D(256, (5, 5), padding='same', activation='elu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

    model.add(tf.keras.layers.Flatten())
    """
    model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=dims),
    tf.keras.layers.Conv2D(
        filters=32, kernel_size=3, strides=(2, 2), activation="relu"
    ),
    tf.keras.layers.Conv2D(
        filters=64, kernel_size=3, strides=(2, 2), activation="relu"
    ),
    tf.keras.layers.Conv2D(
        filters=128, kernel_size=3, strides=(2, 2), activation="relu"
    ),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation="relu"),
    #tf.keras.layers.Dense(units=n_components),
    ])
    return model

# %%
base_model = create_model()

# %%
X_train.shape
# Out:
# (40000, 3072)

# %%
x_scaler = MinMaxScaler()
X_scaled = x_scaler.fit_transform(X_train).reshape([len(X_train)] + list(dims))

# %%
# Set ivis parameters
model = Ivis(model=base_model, embedding_dims=2)

# %%
# Generate embeddings
embeddings =z = model.fit_transform(X_scaled)
# Out:
#   0%|          | 0/40000 [00:00<?, ?it/s]
# Building KNN index
# Flattening multidimensional input before building KNN index using Annoy
# 100%|██████████| 40000/40000 [00:38<00:00, 1041.22it/s]
# Extracting KNN neighbours
# Flattening data before retrieving KNN from index
# 100%|█████████▉| 39997/40000 [01:07<00:00, 592.56it/s]
# Training neural network
# Epoch 1/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.2415
# Epoch 2/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.2010
# Epoch 3/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.1966
# Epoch 4/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.1973
# Epoch 5/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.1931
# Epoch 6/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.1955
# Epoch 7/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1928
# Epoch 8/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1838
# Epoch 9/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1930
# Epoch 10/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1878
# Epoch 11/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1919
# Epoch 12/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1846
# Epoch 13/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1912
# Epoch 14/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1917
# Epoch 15/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1850
# Epoch 16/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.1900
# Epoch 17/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1840
# Epoch 18/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1831
# Epoch 19/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1854
# Epoch 20/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1850
# Epoch 21/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1855
# Epoch 22/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1846
# Epoch 23/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1867
# Epoch 24/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1857
# Epoch 25/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.1820
# Epoch 26/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1853
# Epoch 27/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1816
# Epoch 28/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1872
# Epoch 29/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1827
# Epoch 30/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1816
# Epoch 31/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1826
# Epoch 32/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1826
# Epoch 33/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1795
# Epoch 34/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1826
# Epoch 35/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1805
# Epoch 36/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1811
# Epoch 37/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.1857
# Epoch 38/1000
# 313/313 [==============================] - 4s 12ms/step - loss: 0.1803
# Epoch 39/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1821
# Epoch 40/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1802
# Epoch 41/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1797
# Epoch 42/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1823
# Epoch 43/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1806
# Epoch 44/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1774
# Epoch 45/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1834
# Epoch 46/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1789
# Epoch 47/1000
# 313/313 [==============================] - 4s 11ms/step - loss: 0.1788
# Epoch 48/1000
# 313/313 [==============================] - 4s 13ms/step - loss: 0.1801
# Epoch 49/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1798
# Epoch 50/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1785
# Epoch 51/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1780
# Epoch 52/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1822
# Epoch 53/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1784
# Epoch 54/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1816
# Epoch 55/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1834
# Epoch 56/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1788
# Epoch 57/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1795
# Epoch 58/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1787
# Epoch 59/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1837
# Epoch 60/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1796
# Epoch 61/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1767
# Epoch 62/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1833
# Epoch 63/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1808
# Epoch 64/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1826
# Epoch 65/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1764
# Epoch 66/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1800
# Epoch 67/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1740
# Epoch 68/1000
# 313/313 [==============================] - 3s 10ms/step - loss: 0.1775
# Epoch 69/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1773
# Epoch 70/1000
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1735
# Epoch 71/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1790
# Epoch 72/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1802
# Epoch 73/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1804
# Epoch 74/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1769
# Epoch 75/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1740
# Epoch 76/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1794
# Epoch 77/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1783
# Epoch 78/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1778
# Epoch 79/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1763
# Epoch 80/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1751
# Epoch 81/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1814
# Epoch 82/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1813
# Epoch 83/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1826
# Epoch 84/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1808
# Epoch 85/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1778
# Epoch 86/1000
# 313/313 [==============================] - 3s 9ms/step - loss: 0.1818
# Epoch 87/1000
# 313/313 [==============================] - 2s 7ms/step - loss: 0.1787
# Epoch 88/1000
# 313/313 [==============================] - 2s 8ms/step - loss: 0.1808
# Epoch 89/1000
# 313/313 [==============================] - 2s 8ms/step - loss: 0.1775
# Epoch 90/1000
# 313/313 [==============================] - 2s 8ms/step - loss: 0.1823
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# ### Plot model output

# %%
fig, ax = plt.subplots( figsize=(8, 8))
sc = ax.scatter(
    z[:, 0],
    z[:, 1],
    c=Y_train.astype(int)[:len(z)],
    cmap="tab10",
    s=0.1,
    alpha=0.5,
    rasterized=True,
)
ax.axis('equal')
ax.set_title("UMAP in Tensorflow embedding", fontsize=20)
plt.colorbar(sc, ax=ax);

# %% [markdown]
# ### Save output

# %%
from tfumap.paths import ensure_dir, MODEL_DIR

# %%
output_dir = MODEL_DIR/'projections'/ dataset / algorithm
ensure_dir(output_dir)

# %%
#vae.save(output_dir)

# %%
model.save_model(output_dir / 'iris.ivis')

# %%
#loss_df.to_pickle(output_dir / 'loss_df.pickle')

# %%
np.save(output_dir / 'z.npy', z)

# %% [markdown]
# ### compute metrics

# %%
X_test.shape
# Out:
# (10000, 3072)

# %%
z_test = model.transform(x_scaler.transform(X_test).reshape([len(X_test)]+ list(dims)))
# Out:
# 79/79 [==============================] - 0s 3ms/step

# %% [markdown]
# #### silhouette

# %%
from tfumap.silhouette import silhouette_score_block

# %%
ss, sil_samp = silhouette_score_block(z, Y_train, n_jobs = -1)
ss
# Out:
# -0.12606075033682135

# %%
ss_test, sil_samp_test = silhouette_score_block(z_test, Y_test, n_jobs = -1)
ss_test
# Out:
# -0.12734803982163134

# %%
fig, axs = plt.subplots(ncols = 2, figsize=(10, 5))
axs[0].scatter(z[:, 0], z[:, 1], s=0.1, alpha=0.5, c=sil_samp, cmap=plt.cm.viridis)
axs[1].scatter(z_test[:, 0], z_test[:, 1], s=1, alpha=0.5, c=sil_samp_test, cmap=plt.cm.viridis)

# %% [markdown]
# #### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neigh5 = KNeighborsClassifier(n_neighbors=5)
neigh5.fit(z, Y_train)
score_5nn = neigh5.score(z_test, Y_test)
score_5nn
# Out:
# /home/AD/tsainbur/anaconda3/envs/tfumap/lib/python3.7/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.1592

# %%
neigh1 = KNeighborsClassifier(n_neighbors=1)
neigh1.fit(z, Y_train)
score_1nn = neigh1.score(z_test, Y_test)
score_1nn
# Out:
# /home/AD/tsainbur/anaconda3/envs/tfumap/lib/python3.7/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.1445

# %% [markdown]
# #### Trustworthiness

# %%
from sklearn.manifold import trustworthiness

# %%
tw = trustworthiness(X_train_flat[:10000], z[:10000])

# %%
tw_test = trustworthiness(X_test_flat[:10000], z_test[:10000])

# %%
tw, tw_test
# Out:
# (0.7220507646116894, 0.7210236689351481)

# %% [markdown]
# ### Save output metrics

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

# %% [markdown]
# #### train

# %%
metrics_df = pd.DataFrame(
    columns=[
        "dataset",
        "class_",
        "dim",
        "trustworthiness",
        "silhouette_score",
        "silhouette_samples",
    ]
)
metrics_df.loc[len(metrics_df)] = [dataset, algorithm, n_components, tw, ss, sil_samp]
metrics_df
# Out:
#    dataset class_ dim  trustworthiness  silhouette_score  \
# 0  cifar10   ivis   2         0.722051         -0.126061
#
#                                   silhouette_samples
# 0  [0.011281506224357422, -0.25515483437992126, 0...

# %%
save_loc = DATA_DIR / 'projection_metrics' /  algorithm / 'train' / str(n_components) / (dataset + '.pickle')
ensure_dir(save_loc)
metrics_df.to_pickle(save_loc)

# %% [markdown]
# #### test

# %%
metrics_df_test = pd.DataFrame(
    columns=[
        "dataset",
        "class_",
        "dim",
        "trustworthiness",
        "silhouette_score",
        "silhouette_samples",
    ]
)
metrics_df_test.loc[len(metrics_df)] = [dataset, algorithm, n_components, tw_test, ss_test, sil_samp_test]
metrics_df_test
# Out:
#    dataset class_ dim  trustworthiness  silhouette_score  \
# 1  cifar10   ivis   2         0.721024         -0.127348
#
#                                   silhouette_samples
# 1  [-0.2257145899635574, 0.09581611347452662, 0.0...

# %%
save_loc = DATA_DIR / 'projection_metrics' / algorithm / 'test' / str(n_components) / (dataset + '.pickle')
ensure_dir(save_loc)
metrics_df.to_pickle(save_loc)

# %% [markdown]
# #### knn

# %%
nn_acc_df = pd.DataFrame(columns = ["method_","dimensions","dataset","1NN_acc","5NN_acc"])
nn_acc_df.loc[len(nn_acc_df)] = [algorithm, n_components, dataset,  score_1nn, score_5nn]
nn_acc_df
# Out:
#   method_ dimensions  dataset  1NN_acc  5NN_acc
# 0    ivis          2  cifar10   0.1445   0.1592

# %%
save_loc = DATA_DIR / 'knn_classifier' / algorithm / 'train' / str(n_components) / (dataset + '.pickle')
ensure_dir(save_loc)
nn_acc_df.to_pickle(save_loc)

# %% [markdown]
# ### Compute clustering quality

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import homogeneity_completeness_v_measure

# %%
def get_cluster_metrics(row, n_init=5):
    
    # load cluster information
    save_loc = DATA_DIR / 'clustering_metric_df'/ ('_'.join([row.class_, str(row.dim), row.dataset]) + '.pickle')
    print(save_loc)
    if save_loc.exists() and save_loc.is_file():
        
        cluster_df = pd.read_pickle(save_loc)
        return cluster_df
    
    # make cluster metric dataframe
    cluster_df = pd.DataFrame(
        columns=[
            "dataset",
            "class_",
            "dim",
            "silhouette",
            "homogeneity",
            "completeness",
            "v_measure",
            "init_",
            "n_clusters",
            "model",
        ]
    )
    y = row.train_label
    z = row.train_z
    n_labels = len(np.unique(y))
    for n_clusters in tqdm(np.arange(n_labels - int(n_labels / 2), n_labels + int(n_labels / 2)), leave=False, desc = 'n_clusters'):
        for init_ in tqdm(range(n_init), leave=False, desc='init'):
            kmeans = KMeans(n_clusters=n_clusters, random_state=init_).fit(z)
            clustered_y = kmeans.labels_
            homogeneity, completeness, v_measure = homogeneity_completeness_v_measure(
                np.array(y).flatten(), np.array(clustered_y).flatten()
            )
            ss, _ = silhouette_score_block(z, clustered_y)
            cluster_df.loc[len(cluster_df)] = [
                row.dataset,
                row.class_,
                row.dim,
                ss,
                homogeneity,
                completeness,
                v_measure,
                init_,
                n_clusters,
                kmeans,
            ]
    
     # save cluster df in case this fails somewhere
    ensure_dir(save_loc)
    cluster_df.to_pickle(save_loc)
    return cluster_df

# %%
projection_df = pd.DataFrame(columns = ['dataset', 'class_', 'train_z', 'train_label', 'dim'])
projection_df.loc[len(projection_df)] = [dataset, algorithm, z, Y_train, n_components]
projection_df
# Out:
#    dataset class_                                            train_z  \
# 0  cifar10   ivis  [[-0.82854414, -3.7049372], [-3.3354774, 0.148...
#
#                                          train_label dim
# 0  [[6], [9], [9], [4], [1], [1], [2], [7], [8], ...   2

# %%
??get_cluster_metrics

# %%
get_cluster_metrics(projection_df.iloc[0], n_init=5)
# Out:
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks
# 45  cifar10   ivis   2    0.325534     0.081826      0.072353   0.076799
# 46  cifar10   ivis   2    0.324674     0.081942      0.072431   0.076894
# 47  cifar10   ivis   2    0.325609     0.081812      0.072341   0.076786
# 48  cifar10   ivis   2    0.325688     0.081556      0.071842   0.076392
# 49  cifar10   ivis   2    0.325761     0.081949      0.072457   0.076911
#
#    init_ n_clusters                                  model
# 0      0          5   KMeans(n_clusters=5, random_state=0)
# 1      1          5   KMeans(n_clusters=5, random_state=1)
# 2      2          5   KMeans(n_clusters=5, random_state=2)
# 3      3          5   KMeans(n_clusters=5, random_state=3)
# 4      4          5   KMeans(n_clusters=5, random_state=4)
# 5      0          6   KMeans(n_clusters=6, random_state=0)
# 6      1          6   KMeans(n_clusters=6, random_state=1)
# 7      2          6   KMeans(n_clusters=6, random_state=2)
# 8      3          6   KMeans(n_clusters=6, random_state=3)
# 9      4          6   KMeans(n_clusters=6, random_state=4)
# 10     0          7   KMeans(n_clusters=7, random_state=0)
# 11     1          7   KMeans(n_clusters=7, random_state=1)
# 12     2          7   KMeans(n_clusters=7, random_state=2)
# 13     3          7   KMeans(n_clusters=7, random_state=3)
# 14     4          7   KMeans(n_clusters=7, random_state=4)
# 15     0          8                 KMeans(random_state=0)
# 16     1          8                 KMeans(random_state=1)
# 17     2          8                 KMeans(random_state=2)
# 18     3          8                 KMeans(random_state=3)
# 19     4          8                 KMeans(random_state=4)
# 20     0          9   KMeans(n_clusters=9, random_state=0)
# 21     1          9   KMeans(n_clusters=9, random_state=1)
# 22     2          9   KMeans(n_clusters=9, random_state=2)
# 23     3          9   KMeans(n_clusters=9, random_state=3)
# 24     4          9   KMeans(n_clusters=9, random_state=4)
# 25     0         10  KMeans(n_clusters=10, random_state=0)
# 26     1         10  KMeans(n_clusters=10, random_state=1)
# 27     2         10  KMeans(n_clusters=10, random_state=2)
# 28     3         10  KMeans(n_clusters=10, random_state=3)
# 29     4         10  KMeans(n_clusters=10, random_state=4)
# 30     0         11  KMeans(n_clusters=11, random_state=0)
# 31     1         11  KMeans(n_clusters=11, random_state=1)
# 32     2         11  KMeans(n_clusters=11, random_state=2)
# 33     3         11  KMeans(n_clusters=11, random_state=3)
# 34     4         11  KMeans(n_clusters=11, random_state=4)
# 35     0         12  KMeans(n_clusters=12, random_state=0)
# 36     1         12  KMeans(n_clusters=12, random_state=1)
# 37     2         12  KMeans(n_clusters=12, random_state=2)
# 38     3         12  KMeans(n_clusters=12, random_state=3)
# 39     4         12  KMeans(n_clusters=12, random_state=4)
# 40     0         13  KMeans(n_clusters=13, random_state=0)
# 41     1         13  KMeans(n_clusters=13, random_state=1)
# 42     2         13  KMeans(n_clusters=13, random_state=2)
# 43     3         13  KMeans(n_clusters=13, random_state=3)
# 44     4         13  KMeans(n_clusters=13, random_state=4)
# 45     0         14  KMeans(n_clusters=14, random_state=0)
# 46     1         14  KMeans(n_clusters=14, random_state=1)
# 47     2         14  KMeans(n_clusters=14, random_state=2)
# 48     3         14  KMeans(n_clusters=14, random_state=3)
# 49     4         14  KMeans(n_clusters=14, random_state=4)
