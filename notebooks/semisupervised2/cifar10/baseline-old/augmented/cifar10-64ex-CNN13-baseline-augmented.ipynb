# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
print(gpu_devices)
tf.keras.backend.clear_session()
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### dataset information

# %%
from datetime import datetime

dataset = "cifar10"
dims = (32, 32, 3)
num_classes = 10
labels_per_class = 64 # full
batch_size = 128
datestring = datetime.now().strftime("%Y_%m_%d_%H_%M_%S_%f")
datestring = (
    str(dataset)
    + "_"
    + str(labels_per_class)
    + "____"
    + datestring 
    + '_baseline_augmented'
)
print(datestring)
# Out:
# cifar10_64____2020_08_09_22_16_13_299376_baseline_augmented

# %% [markdown]
# ### Load packages

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from IPython import display
import pandas as pd
import umap
import copy
import os, tempfile
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### Load dataset

# %%
from tfumap.load_datasets import load_CIFAR10, mask_labels
X_train, X_test, X_valid, Y_train, Y_test, Y_valid = load_CIFAR10(flatten=False)
X_train.shape
# Out:
# (40000, 32, 32, 3)

# %%
if labels_per_class == "full":
    X_labeled = X_train
    Y_masked = Y_labeled = Y_train
else:
    X_labeled, Y_labeled, Y_masked = mask_labels(
        X_train, Y_train, labels_per_class=labels_per_class
    )

# %% [markdown]
# ### Build network

# %%
from tensorflow.keras import datasets, layers, models
from tensorflow_addons.layers import WeightNormalization

def conv_block(filts, name, kernel_size = (3, 3), padding = "same", **kwargs):
    return WeightNormalization(
        layers.Conv2D(
            filts, kernel_size, activation=None, padding=padding, **kwargs
        ),
        name="conv"+name,
    )
#CNN13
#See: 
#https://github.com/vikasverma1077/ICT/blob/master/networks/lenet.py
#https://github.com/brain-research/realistic-ssl-evaluation

# %%
lr_alpha = 0.1
dropout_rate = 0.5
num_classes = 10
input_shape = (32, 32, 3)
model = models.Sequential()
model.add(tf.keras.Input(shape=input_shape))
### conv1a
name = '1a'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1b
name = '1b'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1c
name = '1c'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp1"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop1"))

### conv2a
name = '2a'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha))

### conv2b
name = '2b'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv2c
name = '2c'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp2"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop2"))

### conv3a
name = '3a'
model.add(conv_block(name = name, filts = 512, kernel_size = (3,3), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3b
name = '3b'
model.add(conv_block(name = name, filts = 256, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3c
name = '3c'
model.add(conv_block(name = name, filts = 128, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.AveragePooling2D(pool_size=(6, 6), strides=2, padding='valid'))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation=None, name='z'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc1'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc2'))
model.add(WeightNormalization(layers.Dense(num_classes, activation=None)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1a (WeightNormalization) (None, 32, 32, 128)       7297
# _________________________________________________________________
# bn1a (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1a (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1b (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1b (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1b (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1c (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1c (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1c (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# mp1 (MaxPooling2D)           (None, 16, 16, 128)       0
# _________________________________________________________________
# drop1 (Dropout)              (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2a (WeightNormalization) (None, 16, 16, 256)       590593
# _________________________________________________________________
# bn2a (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2b (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2b (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2b (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2c (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2c (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2c (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# mp2 (MaxPooling2D)           (None, 8, 8, 256)         0
# _________________________________________________________________
# drop2 (Dropout)              (None, 8, 8, 256)         0
# _________________________________________________________________
# conv3a (WeightNormalization) (None, 6, 6, 512)         2360833
# _________________________________________________________________
# bn3a (BatchNormalization)    (None, 6, 6, 512)         2048
# _________________________________________________________________
# lrelu3a (LeakyReLU)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv3b (WeightNormalization) (None, 6, 6, 256)         262913
# _________________________________________________________________
# bn3b (BatchNormalization)    (None, 6, 6, 256)         1024
# _________________________________________________________________
# lrelu3b (LeakyReLU)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv3c (WeightNormalization) (None, 6, 6, 128)         65921
# _________________________________________________________________
# bn3c (BatchNormalization)    (None, 6, 6, 128)         512
# _________________________________________________________________
# lrelu3c (LeakyReLU)          (None, 6, 6, 128)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# z (Dense)                    (None, 256)               33024
# _________________________________________________________________
# weight_normalization (Weight (None, 256)               131841
# _________________________________________________________________
# lrelufc1 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_1 (Weig (None, 256)               131841
# _________________________________________________________________
# lrelufc2 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_2 (Weig (None, 10)                5151
# =================================================================
# Total params: 6,549,034
# Trainable params: 3,292,308
# Non-trainable params: 3,256,726
# _________________________________________________________________

# %% [markdown]
# ### Augmentation

# %%
import tensorflow_addons as tfa
def augment(image, label):
    image = tf.squeeze(image) # Add 6 pixels of padding
    image = tf.image.resize_with_crop_or_pad(image, dims[0] + 6, dims[1] + 6) # crop 6 pixels
    image = tf.image.random_crop(image, size=dims)
    image = tf.image.random_brightness(image, max_delta=0.15)  # Random brightness
    image= tf.image.random_contrast(image, lower=0.6, upper=1.4)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_hue(image, 0.05, seed=None)
    #image = tf.image.random_jpeg_quality(image, 10, 100, seed=None)
    image = tfa.image.rotate(image, tf.squeeze(tf.random.uniform(shape = (1,1), minval=-.2, maxval=.2)), interpolation='BILINEAR')
    image = tfa.image.random_cutout(tf.expand_dims(image, 0), (8,8), constant_values=0.5)[0]
    image = tf.clip_by_value(image, 0, 1)
    return image, label

# %%
nex = 10
for i in range(5):
    fig, axs = plt.subplots(ncols=nex +1, figsize=((nex+1)*2, 2))
    axs[0].imshow(X_train[i])
    axs[0].axis('off')
    for ax in axs.flatten()[1:]:
        ax.imshow(augment(X_train[i], Y_train[i])[0])
        ax.axis('off')

# %% [markdown]
# ### train

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', min_delta=0, patience=50, verbose=0, mode='auto',
    baseline=None, restore_best_weights=False
)

# %%
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)
model.compile(tf.keras.optimizers.Adam(1e-3), loss = loss, metrics=['accuracy'])

# %%
Y_valid_one_hot = tf.keras.backend.one_hot(
    Y_valid, num_classes
)

# %%
Y_labeled_one_hot = tf.keras.backend.one_hot(
    Y_labeled, num_classes
)

# %%
train_ds = (
     tf.data.Dataset.from_tensor_slices((X_labeled, Y_labeled_one_hot))
    .shuffle(1000)
    .map(augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.experimental.AUTOTUNE)
)

# %%
history = model.fit(
    train_ds,
    epochs=500,
    validation_data=(X_valid, Y_valid_one_hot),
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/500
# 5/5 [==============================] - 20s 4s/step - loss: 3.7562 - accuracy: 0.1141 - val_loss: 350.1942 - val_accuracy: 0.1022
# Epoch 2/500
# 5/5 [==============================] - 16s 3s/step - loss: 2.8441 - accuracy: 0.1594 - val_loss: 812.5144 - val_accuracy: 0.1022
# Epoch 3/500
# 5/5 [==============================] - 17s 3s/step - loss: 2.4072 - accuracy: 0.1781 - val_loss: 424.5515 - val_accuracy: 0.1420
# Epoch 4/500
# 5/5 [==============================] - 17s 3s/step - loss: 2.2581 - accuracy: 0.1922 - val_loss: 484.4252 - val_accuracy: 0.1014
# Epoch 5/500
# 5/5 [==============================] - 17s 3s/step - loss: 2.1763 - accuracy: 0.2484 - val_loss: 326.4706 - val_accuracy: 0.1007
# Epoch 6/500
# 5/5 [==============================] - 17s 3s/step - loss: 2.1203 - accuracy: 0.2766 - val_loss: 325.0464 - val_accuracy: 0.1002
# Epoch 7/500
# 5/5 [==============================] - 17s 3s/step - loss: 2.0732 - accuracy: 0.2891 - val_loss: 195.0006 - val_accuracy: 0.1021
# Epoch 8/500
# 5/5 [==============================] - 17s 3s/step - loss: 2.0483 - accuracy: 0.3109 - val_loss: 106.0021 - val_accuracy: 0.1062
# Epoch 9/500
# 5/5 [==============================] - 18s 4s/step - loss: 2.0608 - accuracy: 0.2797 - val_loss: 95.9056 - val_accuracy: 0.1346
# Epoch 10/500
# 5/5 [==============================] - 17s 3s/step - loss: 2.0851 - accuracy: 0.2719 - val_loss: 47.4618 - val_accuracy: 0.1446
# Epoch 11/500
# 5/5 [==============================] - 17s 3s/step - loss: 2.0462 - accuracy: 0.3031 - val_loss: 32.7255 - val_accuracy: 0.1144
# Epoch 12/500
# 5/5 [==============================] - 17s 3s/step - loss: 1.9609 - accuracy: 0.3469 - val_loss: 15.4256 - val_accuracy: 0.1642
# Epoch 13/500
# 5/5 [==============================] - 17s 3s/step - loss: 2.0058 - accuracy: 0.3422 - val_loss: 18.9507 - val_accuracy: 0.1201
# Epoch 14/500
# 5/5 [==============================] - 17s 3s/step - loss: 1.9471 - accuracy: 0.3781 - val_loss: 15.4769 - val_accuracy: 0.1715
# Epoch 15/500
# 5/5 [==============================] - 17s 3s/step - loss: 1.9236 - accuracy: 0.3906 - val_loss: 8.6917 - val_accuracy: 0.2025
# Epoch 16/500
# 5/5 [==============================] - 17s 3s/step - loss: 1.9019 - accuracy: 0.3938 - val_loss: 10.2731 - val_accuracy: 0.1848
# Epoch 17/500
# 5/5 [==============================] - 17s 3s/step - loss: 1.8981 - accuracy: 0.4000 - val_loss: 6.0204 - val_accuracy: 0.1940
# Epoch 18/500
# 5/5 [==============================] - 17s 3s/step - loss: 1.9051 - accuracy: 0.4125 - val_loss: 4.6434 - val_accuracy: 0.1737
# Epoch 19/500
# 5/5 [==============================] - 17s 3s/step - loss: 1
500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0376 - accuracy: 0.9500 - val_loss: 2.0048 - val_accuracy: 0.4662
# Epoch 139/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0287 - accuracy: 0.9563 - val_loss: 1.9489 - val_accuracy: 0.4786
# Epoch 140/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0388 - accuracy: 0.9563 - val_loss: 2.1127 - val_accuracy: 0.4243
# Epoch 141/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0332 - accuracy: 0.9594 - val_loss: 2.0637 - val_accuracy: 0.4583
# Epoch 142/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0388 - accuracy: 0.9500 - val_loss: 2.0939 - val_accuracy: 0.4541
# Epoch 143/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0493 - accuracy: 0.9469 - val_loss: 2.0528 - val_accuracy: 0.4523
# Epoch 144/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0388 - accuracy: 0.9453 - val_loss: 2.0934 - val_accuracy: 0.4490
# Epoch 145/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0145 - accuracy: 0.9641 - val_loss: 2.0626 - val_accuracy: 0.4398
# Epoch 146/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0276 - accuracy: 0.9594 - val_loss: 2.0438 - val_accuracy: 0.4637
# Epoch 147/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0357 - accuracy: 0.9563 - val_loss: 2.1021 - val_accuracy: 0.4464
# Epoch 148/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0159 - accuracy: 0.9656 - val_loss: 2.0754 - val_accuracy: 0.4552
# Epoch 149/500
# 5/5 [==============================] - 11s 2s/step - loss: 0.9992 - accuracy: 0.9766 - val_loss: 2.0443 - val_accuracy: 0.4526
# Epoch 150/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0089 - accuracy: 0.9703 - val_loss: 1.9564 - val_accuracy: 0.4749
# Epoch 151/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0053 - accuracy: 0.9656 - val_loss: 1.9708 - val_accuracy: 0.4707
# Epoch 152/500
# 5/5 [==============================] - 13s 3s/step - loss: 1.0159 - accuracy: 0.9656 - val_loss: 2.0569 - val_accuracy: 0.4360
# Epoch 153/500
# 5/5 [==============================] - 11s 2s/step - loss: 1.0206 - accuracy: 0.9547 - val_loss: 2.1021 - val_accuracy: 0.4182
# Epoch 154/500
# 5/5 [==============================] - 10s 2s/step - loss: 1.0183 - accuracy: 0.9672 - val_loss: 2.0840 - val_accuracy: 0.4263
# Epoch 155/500
# 5/5 [==============================] - 10s 2s/step - loss: 1.0232 - accuracy: 0.9594 - val_loss: 1.9992 - val_accuracy: 0.4550
# Epoch 156/500
# 5/5 [==============================] - 10s 2s/step - loss: 1.0241 - accuracy: 0.9484 - val_loss: 2.0370 - val_accuracy: 0.4595
# Epoch 157/500
# 5/5 [==============================] - 9s 2s/step - loss: 1.0072 - accuracy: 0.9703 - val_loss: 2.0161 - val_accuracy: 0.4467
# Epoch 158/500
# 5/5 [==============================] - 12s 2s/step - loss: 1.0078 - accuracy: 0.9641 - val_loss: 2.0222 - val_accuracy: 0.4586
# Epoch 159/500
# 5/5 [==============================] - 12s 2s/step - loss: 0.9990 - accuracy: 0.9750 - val_loss: 2.0146 - val_accuracy: 0.4630
# Epoch 160/500
# 5/5 [==============================] - 10s 2s/step - loss: 1.0178 - accuracy: 0.9688 - val_loss: 2.0347 - val_accuracy: 0.4642
# Epoch 161/500
# 5/5 [==============================] - 10s 2s/step - loss: 1.0198 - accuracy: 0.9594 - val_loss: 2.0256 - val_accuracy: 0.4607
# Epoch 162/500
# 5/5 [==============================] - 10s 2s/step - loss: 1.0099 - accuracy: 0.9688 - val_loss: 2.0350 - val_accuracy: 0.4542
# Epoch 163/500
# 5/5 [==============================] - 10s 2s/step - loss: 1.0037 - accuracy: 0.9719 - val_loss: 2.0982 - val_accuracy: 0.4404
# Epoch 164/500
# 5/5 [==============================] - 9s 2s/step - loss: 1.0093 - accuracy: 0.9656 - val_loss: 2.0465 - val_accuracy: 0.4570
# Epoch 165/500
# 5/5 [==============================] - 9s 2s/step - loss: 1.0060 - accuracy: 0.9688 - val_loss: 2.0078 - val_accuracy: 0.4519
# Epoch 166/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9987 - accuracy: 0.9734 - val_loss: 2.1318 - val_accuracy: 0.4434
# Epoch 167/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9945 - accuracy: 0.9688 - val_loss: 2.0958 - val_accuracy: 0.4458
# Epoch 168/500
# 5/5 [==============================] - 9s 2s/step - loss: 0.9728 - accuracy: 0.9828 - val_loss: 2.0275 - val_accuracy: 0.4536
# Epoch 169/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9930 - accuracy: 0.9719 - val_loss: 2.0195 - val_accuracy: 0.4534
# Epoch 170/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9787 - accuracy: 0.9766 - val_loss: 2.0146 - val_accuracy: 0.4660
# Epoch 171/500
# 5/5 [==============================] - 9s 2s/step - loss: 0.9863 - accuracy: 0.9750 - val_loss: 2.0072 - val_accuracy: 0.4611
# Epoch 172/500
# 5/5 [==============================] - 9s 2s/step - loss: 0.9811 - accuracy: 0.9766 - val_loss: 2.0539 - val_accuracy: 0.4451
# Epoch 173/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9672 - accuracy: 0.9844 - val_loss: 1.9595 - val_accuracy: 0.4729
# Epoch 174/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9785 - accuracy: 0.9828 - val_loss: 2.0086 - val_accuracy: 0.4733
# Epoch 175/500
# 5/5 [==============================] - 9s 2s/step - loss: 0.9794 - accuracy: 0.9797 - val_loss: 1.9719 - val_accuracy: 0.4700
# Epoch 176/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9803 - accuracy: 0.9812 - val_loss: 1.9957 - val_accuracy: 0.4536
# Epoch 177/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9924 - accuracy: 0.9766 - val_loss: 2.0734 - val_accuracy: 0.4418
# Epoch 178/500
# 5/5 [==============================] - 9s 2s/step - loss: 0.9798 - accuracy: 0.9766 - val_loss: 2.0191 - val_accuracy: 0.4485
# Epoch 179/500
# 5/5 [==============================] - 9s 2s/step - loss: 0.9803 - accuracy: 0.9797 - val_loss: 2.0745 - val_accuracy: 0.4473
# Epoch 180/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9852 - accuracy: 0.9734 - val_loss: 2.0160 - val_accuracy: 0.4608
# Epoch 181/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9853 - accuracy: 0.9750 - val_loss: 2.0796 - val_accuracy: 0.4373
# Epoch 182/500
# 5/5 [==============================] - 9s 2s/step - loss: 0.9650 - accuracy: 0.9906 - val_loss: 2.0023 - val_accuracy: 0.4541
# Epoch 183/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9732 - accuracy: 0.9781 - val_loss: 1.9890 - val_accuracy: 0.4645
# Epoch 184/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9725 - accuracy: 0.9812 - val_loss: 1.9984 - val_accuracy: 0.4601
# Epoch 185/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9578 - accuracy: 0.9922 - val_loss: 1.9740 - val_accuracy: 0.4761
# Epoch 186/500
# 5/5 [==============================] - 9s 2s/step - loss: 0.9686 - accuracy: 0.9828 - val_loss: 2.0181 - val_accuracy: 0.4570
# Epoch 187/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9644 - accuracy: 0.9875 - val_loss: 2.0008 - val_accuracy: 0.4786
# Epoch 188/500
# 5/5 [==============================] - 10s 2s/step - loss: 0.9765 - accuracy: 0.9750 - val_loss: 2.0094 - val_accuracy: 0.4620
# Epoch 189/500
# 5/5 [==============================] - 9s 2s/step - loss: 0.9728 - accuracy: 0.9828 - val_loss: 1.9851 - val_accuracy: 0.4709

# %% [markdown]
# ### evaluate

# %%
Y_test_one_hot = tf.keras.backend.one_hot(
    Y_test, num_classes
)
result = model.evaluate(X_test, Y_test_one_hot)
# Out:
# 313/313 [==============================] - 9s 29ms/step - loss: 1.9744 - accuracy: 0.4756

# %%
plt.semilogx(history.history['loss'])
plt.semilogx(history.history['val_loss'])

# %%
plt.semilogx(history.history['accuracy'])
plt.semilogx(history.history['val_accuracy'])

# %%
submodel = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
    )
z = submodel.predict(X_train)
np.shape(z)
# Out:
# (40000, 256)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sun Aug  9 23:00:57 2020 Finding Nearest Neighbors
# Sun Aug  9 23:00:57 2020 Building RP forest with 15 trees
# Sun Aug  9 23:00:58 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# Sun Aug  9 23:01:09 2020 Finished Nearest Neighbor Search
# Sun Aug  9 23:01:12 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Aug  9 23:01:37 2020 Finished embedding

# %%
predictions = model.predict(X_train)

# %%
mask = np.array(np.argmax(predictions, axis=1)) != Y_train.flatten()

# %%
fig, axs = plt.subplots(ncols = 5, figsize=(50,10))
axs[0].scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 1, cmap = plt.cm.tab10)
axs[1].scatter(embedding[:, 0], embedding[:, 1], c=np.argmax(predictions, axis=1), s= 1, alpha = 1, cmap = plt.cm.tab10)
axs[2].scatter(embedding[:, 0], embedding[:, 1], c=np.array(np.argmax(predictions, axis=1)) == Y_train.flatten(), s= 1, alpha = 1, cmap = plt.cm.viridis)
axs[3].scatter(embedding[mask, 0], embedding[mask, 1], c=Y_train.flatten()[mask], s= 10, alpha = 1, cmap = plt.cm.tab10)
axs[4].scatter(embedding[mask, 0], embedding[mask, 1], c=np.argmax(predictions, axis=1)[mask], s= 10, alpha = 1, cmap = plt.cm.tab10)

# %% [markdown]
# ### save results

# %%
# save score, valid embedding, weights, results

# %%
from tfumap.paths import MODEL_DIR, ensure_dir

# %%
save_folder = MODEL_DIR / 'semisupervised-keras' / dataset / str(labels_per_class) / datestring
ensure_dir(save_folder)

# %% [markdown]
# #### save weights

# %%
encoder = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
)

# %%
encoder.save_weights((save_folder / "encoder").as_posix())

# %%
classifier = tf.keras.models.Model(
        [tf.keras.Input(tensor=model.get_layer('weight_normalization').input)], [model.outputs[0]]
)
print([i.name for i in classifier.layers])
# Out:
# ['input_2', 'weight_normalization', 'lrelufc1', 'weight_normalization_1', 'lrelufc2', 'weight_normalization_2']

# %%
classifier.save_weights((save_folder / "classifier").as_posix())

# %%
model.save_weights((save_folder / "full_model").as_posix())

# %% [markdown]
# #### save score

# %%
Y_test_one_hot = tf.keras.backend.one_hot(
    Y_test, num_classes
)
result = model.evaluate(X_test, Y_test_one_hot)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 1.9744 - accuracy: 0.4756

# %%
np.save(save_folder / 'test_loss.npy', result)

# %% [markdown]
# #### save embedding

# %%
z = encoder.predict(X_train)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))

plt.scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Mon Aug 10 09:31:19 2020 Finding Nearest Neighbors
# Mon Aug 10 09:31:19 2020 Building RP forest with 15 trees
# Mon Aug 10 09:31:20 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# Mon Aug 10 09:31:22 2020 Finished Nearest Neighbor Search
# Mon Aug 10 09:31:22 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Aug 10 09:32:05 2020 Finished embedding

# %%
np.save(save_folder / 'train_embedding.npy', embedding)

# %% [markdown]
# #### save results

# %%
import pickle

# %%
with open(save_folder / 'history.pickle', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
