# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %% [markdown]
# ### load packages

# %%
from tfumap.umap import tfUMAP
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
import umap
import pandas as pd

# %% [markdown]
# ### Load dataset

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

# %%
anno_df = pd.read_csv(
    DATA_DIR / "celeba" / "CelebAMask-HQ" / "CelebAMask-HQ-attribute-anno.txt",
    header=1,
    delimiter=" ",
)
anno_df["id"] = [int(i[0].split(".")[0]) for i in anno_df.index.values]

# %%
hair_types = ['Black_Hair', 'Blond_Hair', 'Brown_Hair', 'Bald']
# make a category for hair color
anno_df['hair_category'] = None
for idx, row in tqdm(anno_df.iterrows(), total = len(anno_df)):
    hair_idx = np.where(row[hair_types] == 1)[0]
    if len(hair_idx) == 1:
        anno_df.loc[idx, 'hair_category']= hair_idx[0]
    elif len(hair_idx) > 1: 
        anno_df.loc[idx, 'hair_category']= -1
    else:
        anno_df.loc[idx, 'hair_category']= -2
# Out:
# HBox(children=(IntProgress(value=0, max=30000), HTML(value='')))

# %%
print(list(anno_df.columns))
# Out:
# ['5_o_Clock_Shadow', 'Arched_Eyebrows', 'Attractive', 'Bags_Under_Eyes', 'Bald', 'Bangs', 'Big_Lips', 'Big_Nose', 'Black_Hair', 'Blond_Hair', 'Blurry', 'Brown_Hair', 'Bushy_Eyebrows', 'Chubby', 'Double_Chin', 'Eyeglasses', 'Goatee', 'Gray_Hair', 'Heavy_Makeup', 'High_Cheekbones', 'Male', 'Mouth_Slightly_Open', 'Mustache', 'Narrow_Eyes', 'No_Beard', 'Oval_Face', 'Pale_Skin', 'Pointy_Nose', 'Receding_Hairline', 'Rosy_Cheeks', 'Sideburns', 'Smiling', 'Straight_Hair', 'Wavy_Hair', 'Wearing_Earrings', 'Wearing_Hat', 'Wearing_Lipstick', 'Wearing_Necklace', 'Wearing_Necktie', 'Young', 'id', 'hair_category']

# %%
faces_128_df = pd.read_pickle(DATA_DIR / 'celeba' / 'faces_128.pickle')

# %%
faces_128_df[:3]
# Out:
#                                                 face     id
# 0  [[[64, 64, 64], [64, 64, 64], [64, 64, 64], [6...  20142
# 1  [[[64, 64, 64], [64, 64, 64], [64, 64, 64], [6...   8126
# 2  [[[64, 64, 64], [64, 64, 64], [64, 64, 64], [6...  12655

# %%
from skimage.transform import resize

# %%
#imgs_64 = [resize(i, (64, 64)) for i in tqdm(faces_128_df.face.values)]

# %%
#faces_128_df['face'] = imgs_64

# %%
faces_128_df = pd.merge(faces_128_df, anno_df[['id', 'hair_category']], on=['id'])

# %%
len(faces_128_df)
# Out:
# 30000

# %%
faces_128_df['subset'] = 'train'
faces_128_df.loc[0:1000, 'subset'] = 'valid'
faces_128_df.loc[1000:1999, 'subset'] = 'test'

# %%
faces_128_df[:3]
# Out:
#                                                 face     id  hair_category  \
# 0  [[[64, 64, 64], [64, 64, 64], [64, 64, 64], [6...  20142              0
# 1  [[[64, 64, 64], [64, 64, 64], [64, 64, 64], [6...   8126              1
# 2  [[[64, 64, 64], [64, 64, 64], [64, 64, 64], [6...  12655              0
#
#   subset
# 0  valid
# 1  valid
# 2  valid

# %%
faces_128_df[-1:]
# Out:
#                                                     face     id  \
# 29999  [[[64, 64, 64], [64, 64, 64], [64, 64, 64], [6...  17714
#
#        hair_category subset
# 29999              0  train

# %%
{hair_types[int(i)]:np.sum(faces_128_df['hair_category'] == i) for i in faces_128_df.hair_category.unique() if i in [0, 1,2,3,4]}
# Out:
# {'Black_Hair': 6486, 'Blond_Hair': 4958, 'Bald': 706, 'Brown_Hair': 6657}

# %%
Y_train = np.array(list(faces_128_df.hair_category.values[faces_128_df.subset == 'train'])).astype('float32')
Y_valid = np.array(list(faces_128_df.hair_category.values[faces_128_df.subset == 'valid'])).astype('float32')
Y_test = np.array(list(faces_128_df.hair_category.values[faces_128_df.subset == 'test'])).astype('float32')

# %%
X_train = np.array(list(faces_128_df.face.values[faces_128_df.subset == 'train'])) / 255.
X_valid = np.array(list(faces_128_df.face.values[faces_128_df.subset == 'valid'])) / 255.
X_test = np.array(list(faces_128_df.face.values[faces_128_df.subset == 'test'])) / 255.

# %%
np.array(list(faces_128_df.face.values[faces_128_df.subset == 'train'])).shape
# Out:
# (28000, 128, 128, 3)

# %%
X_train_flat = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))

# %%
plt.imshow(X_train[0])

# %%
X_train_flat.shape, X_valid.shape, X_test.shape
# Out:
# ((28000, 49152), (1000, 128, 128, 3), (1000, 128, 128, 3))

# %% [markdown]
# ### define networks

# %%
dims = (128,128,3)
n_components = 512

# %%
encoder = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=dims),
    tf.keras.layers.Conv2D(
        filters=32, kernel_size=3, strides=(2, 2), activation="relu"
    ),
    tf.keras.layers.Conv2D(
        filters=64, kernel_size=3, strides=(2, 2), activation="relu"
    ),
    tf.keras.layers.Conv2D(
        filters=128, kernel_size=3, strides=(2, 2), activation="relu"
    ),
    tf.keras.layers.Conv2D(
        filters=256, kernel_size=3, strides=(2, 2), activation="relu"
    ),
    tf.keras.layers.Conv2D(
        filters=512, kernel_size=3, strides=(2, 2), activation="relu"
    ),
    tf.keras.layers.Conv2D(
        filters=512, kernel_size=3, strides=(2, 2), activation="relu"
    ),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=1024, activation="relu"),
    tf.keras.layers.Dense(units=n_components),
])

# %%
decoder = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(n_components)),
    tf.keras.layers.Dense(units=1024, activation="relu"),
    tf.keras.layers.Dense(units=2 * 2 * 512, activation="relu"),
    tf.keras.layers.Reshape(target_shape=(2, 2, 512)),
    tf.keras.layers.Conv2DTranspose(
        filters=512, kernel_size=3, strides=(2, 2), padding="SAME", activation="relu"
    ),
    tf.keras.layers.Conv2DTranspose(
        filters=512, kernel_size=3, strides=(2, 2), padding="SAME", activation="relu"
    ),
    tf.keras.layers.Conv2DTranspose(
        filters=256, kernel_size=3, strides=(2, 2), padding="SAME", activation="relu"
    ),
    tf.keras.layers.Conv2DTranspose(
        filters=128, kernel_size=3, strides=(2, 2), padding="SAME", activation="relu"
    ),
    tf.keras.layers.Conv2DTranspose(
        filters=64, kernel_size=3, strides=(2, 2), padding="SAME", activation="relu"
    ),
    tf.keras.layers.Conv2DTranspose(
        filters=32, kernel_size=3, strides=(2, 2), padding="SAME", activation="relu"
    ),
    tf.keras.layers.Conv2DTranspose(
        filters=32, kernel_size=3, strides=(1, 1), padding="SAME", activation="relu"
    ),
    tf.keras.layers.Conv2DTranspose(
        filters=3, kernel_size=3, strides=(1, 1), padding="SAME", activation="sigmoid"
    )
])

# %% [markdown]
# ### Create model and train

# %%
??tfUMAP

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=1,
    encoder=encoder,
    decoding_method="autoencoder", 
    decoder=decoder,
    valid_X = X_valid,
    valid_Y = Y_valid,
    dims = dims,
    n_components = n_components,
    batch_size= 100,
)

# %%
z = embedder.fit_transform(X_train_flat)
# Out:
# tfUMAP(batch_size=100,
#        decoder=<tensorflow.python.keras.engine.sequential.Sequential object at 0x7fb3a7799828>,
#        decoding_method='autoencoder', dims=(128, 128, 3),
#        encoder=<tensorflow.python.keras.engine.sequential.Sequential object at 0x7fb3a7872e80>,
#        negative_sample_rate=5,
#        optimizer=<tensorflow.python.keras.optimizer_v2.adam.Adam object at 0x7fb3a984fd68>,
#        tensorb...
#         0., -2.,  0., -2., -2., -2., -2., -2.,  0., -2.,  0.,  2.,  0.,
#         1.,  0., -2., -2., -2.,  0.,  2., -2.,  3.,  1.,  0.,  0.,  2.,
#         1., -2.,  2., -2.,  0.,  2.,  1., -2.,  1.,  2., -2.,  0., -2.,
#         2.,  1.,  1.,  2., -2., -2., -2., -2.,  0., -2.,  2.,  0.,  1.,
#         2.,  1., -2., -2.,  0., -2., -2., -2., -2.,  2.,  1., -2., -2.,
#        -2.,  1., -2., -2., -2., -2.,  2.,  0., -2.,  3.,  0.,  0., -2.,
#        -2.,  0., -2., -2.,  2.,  2., -2., -2.,  2.,  2.,  0.,  1., -2.,
#        -2.,  2.,  0.,  0.,  2., -2.,  0.,  0.,  2.,  2.,  0., -2.],
#       dtype=float32))
# Construct fuzzy simplicial set
# Wed Jul  8 22:48:22 2020 Finding Nearest Neighbors
# Wed Jul  8 22:48:23 2020 Building RP forest with 13 trees
# Wed Jul  8 22:48:40 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# Wed Jul  8 22:49:29 2020 Finished Nearest Neighbor Search
# Wed Jul  8 22:49:33 2020 Embedding with TensorFlow
# HBox(children=(IntProgress(value=0, description='epoch', max=1, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='batch', max=48360, style=ProgressStyle(description_width='ini…
# WARNING: Logging before flag parsing goes to stderr.
# W0709 01:02:08.345106 140412611057472 base_layer.py:1790] Layer conv2d is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# Thu Jul  9 01:02:08 2020 Finished embedding

# %% [markdown]
# ### Plot model output

# %%
fig, ax = plt.subplots( figsize=(8, 8))
sc = ax.scatter(
    z[:, 0],
    z[:, 1],
    c=Y_train.astype(int)[:len(z)],
    cmap="tab10",
    s=0.1,
    alpha=0.5,
    rasterized=True,
)
ax.axis('equal')
ax.set_title("UMAP in Tensorflow embedding", fontsize=20)
plt.colorbar(sc, ax=ax);

# %% [markdown]
# ### View loss

# %%
from tfumap.umap import retrieve_tensors
import seaborn as sns

# %%
loss_df = retrieve_tensors(embedder.tensorboard_logdir)
loss_df[:3]
# Out:
# ['umap_loss', 'recon_loss']
# ['recon_loss']
#       wall_time  step       val  group   variable
# 0  1.594274e+09     1  3.439886  train  umap_loss
# 1  1.594274e+09     2  1.922049  train  umap_loss
# 2  1.594274e+09     3  1.428181  train  umap_loss

# %%
loss_df.group.unique()
# Out:
# array(['train', 'valid'], dtype=object)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(20,5))
ax = axs[0]
sns.lineplot(x="step", y="val", hue="group", data=loss_df[loss_df.variable=='umap_loss'], ax = ax)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_title('UMAP loss')

ax = axs[1]
sns.lineplot(x="step", y="val", hue="group", data=loss_df[loss_df.variable=='recon_loss'], ax = ax)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_title('Reconstruction loss')
# Out:
# Text(0.5, 1.0, 'Reconstruction loss')

# %% [markdown]
# ### Save output

# %%
from tfumap.paths import ensure_dir, MODEL_DIR

# %%
output_dir = MODEL_DIR/'celeba'/ '128_512' 
ensure_dir(output_dir)

# %%
#embedder.save(output_dir)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-39-451f0683c772> in <module>
# ----> 1 embedder.save(output_dir)
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in save(self, save_location, verbose)
#     176         # save model.pkl
#     177         with open(os.path.join(save_location, "model.pkl"), "wb") as output:
# --> 178             pickle.dump(self, output, pickle.HIGHEST_PROTOCOL)
#     179         if verbose:
#     180             print("Pickle of model saved")
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in __getstate__(self)
#     171     def __getstate__(self):
#     172         # this function supports pickling, making sure that objects can be pickled
# --> 173         return dict((k, v) for (k, v) in self.__dict__.items() if self.should_pickle(v))
#     174
#     175     def save(self, save_location, verbose=True):
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in <genexpr>(.0)
#     171     def __getstate__(self):
#     172         # this function supports pickling, making sure that objects can be pickled
# --> 173         return dict((k, v) for (k, v) in self.__dict__.items() if self.should_pickle(v))
#     174
#     175     def save(self, save_location, verbose=True):
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in should_pickle(self, val)
#     159         # return True
#     160         try:
# --> 161             pickle.dumps(val)
#     162         except (
#     163             pickle.PicklingError,
#
# OverflowError: cannot serialize a bytes object larger than 4 GiB

# %%
import os

# %%
embedder.encoder.save(os.path.join(output_dir, "encoder"))
# Out:
# W0709 08:23:29.878223 140412611057472 deprecation.py:506] From /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# I0709 08:23:30.069621 140412611057472 builder_impl.py:775] Assets written to: /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/models/celeba/128_512/encoder/assets

# %%
import pickle

# %%
with open(os.path.join(output_dir, "model.pkl"), "w") as output:
    pickle.dump(embedder, output, protocol=4)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-43-35b844c34be5> in <module>
#       1 with open(os.path.join(output_dir, "model.pkl"), "w") as output:
# ----> 2     pickle.dump(embedder, output, protocol=4)
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in __getstate__(self)
#     171     def __getstate__(self):
#     172         # this function supports pickling, making sure that objects can be pickled
# --> 173         return dict((k, v) for (k, v) in self.__dict__.items() if self.should_pickle(v))
#     174
#     175     def save(self, save_location, verbose=True):
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in <genexpr>(.0)
#     171     def __getstate__(self):
#     172         # this function supports pickling, making sure that objects can be pickled
# --> 173         return dict((k, v) for (k, v) in self.__dict__.items() if self.should_pickle(v))
#     174
#     175     def save(self, save_location, verbose=True):
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in should_pickle(self, val)
#     159         # return True
#     160         try:
# --> 161             pickle.dumps(val)
#     162         except (
#     163             pickle.PicklingError,
#
# OverflowError: cannot serialize a bytes object larger than 4 GiB

# %%
pickle.dump(embedder, open(os.path.join(output_dir, "model.pkl"), 'w'), protocol=4)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-44-e2e039407ccb> in <module>
# ----> 1 pickle.dump(embedder, open(os.path.join(output_dir, "model.pkl"), 'w'), protocol=4)
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in __getstate__(self)
#     171     def __getstate__(self):
#     172         # this function supports pickling, making sure that objects can be pickled
# --> 173         return dict((k, v) for (k, v) in self.__dict__.items() if self.should_pickle(v))
#     174
#     175     def save(self, save_location, verbose=True):
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in <genexpr>(.0)
#     171     def __getstate__(self):
#     172         # this function supports pickling, making sure that objects can be pickled
# --> 173         return dict((k, v) for (k, v) in self.__dict__.items() if self.should_pickle(v))
#     174
#     175     def save(self, save_location, verbose=True):
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in should_pickle(self, val)
#     159         # return True
#     160         try:
# --> 161             pickle.dumps(val)
#     162         except (
#     163             pickle.PicklingError,
#
# OverflowError: cannot serialize a bytes object larger than 4 GiB

# %%
loss_df.to_pickle(output_dir / 'loss_df.pickle')

# %%
np.save(output_dir / 'z.npy', z)

# %% [markdown]
# ### View reconstructions on test data

# %%
z_test = embedder.transform(X_test)

# %%
np.shape(z_test)
# Out:
# (1000, 512)

# %%
X_test_recon = embedder.inverse_transform(z_test)

# %%
X_test_recon.max()
# Out:
# 0.99292433

# %%
X_test_recon.min()
# Out:
# 0.0010780612

# %%
nex = 10
fig, axs = plt.subplots(ncols=nex, nrows=2, figsize=(nex*3,2*3))
for i in range(nex):
    axs[0,i].imshow(X_test[i].reshape(128,128,3))
    axs[1,i].imshow(X_test_recon[i].reshape(128,128,3))
for ax in axs.flatten():
    ax.axis('off')

# %% [markdown]
# ### Interpolations on test data

# %%
nex = 10

# %%
interp_pts = np.linspace(0, 1, nex)

# %%
for i,j in zip(np.arange(0,5), np.arange(5,10)):
    z1 = z_test[i]
    z2 = z_test[j]
    z_interp = [z1*i + z2*(1-i) for i in interp_pts]
    x_interp = embedder.inverse_transform(np.array(z_interp))

    fig, axs = plt.subplots(ncols=nex, nrows=1, figsize=(nex*3,3))
    for i in range(nex):
        axs[i].imshow(x_interp[i].reshape(128,128,3))
    for ax in axs.flatten():
        ax.axis('off')

    plt.show()

# %% [markdown]
# ### Untangling latent factors

# %%
from statsmodels.api import OLS

# %%
faces_merged = pd.merge(anno_df, faces_128_df[['face', 'id']], on=['id'])

# %%
face_x = np.array(list(faces_merged['face'].values)) / 255.
face_z = embedder.transform(face_x)
face_z.shape
# Out:
# (30000, 512)

# %%
all_attr = faces_merged.drop(columns = ['id', 'hair_category', 'face'])
data_labels = 1.0*(all_attr == 1)
data_labels['bias'] = 1.0

# %%
model_z = OLS(face_z, data_labels)
result_z = model_z.fit()
result_z.params[:3]
# Out:
#                        0         1         2         3         4         5    \
# 5_o_Clock_Shadow -0.001561  0.006033  0.001588  0.070422 -0.002252 -0.007355
# Arched_Eyebrows  -0.001192  0.015911  0.000212 -0.019236  0.028093  0.012377
# Attractive       -0.002591 -0.024215  0.001162  0.036851  0.000442  0.012486
#
#                        6         7         8         9    ...       502  \
# 5_o_Clock_Shadow -0.068535 -0.000320  0.000277  0.000734  ... -0.031714
# Arched_Eyebrows  -0.002649  0.000142 -0.000209  0.000824  ...  0.015490
# Attractive       -0.042780  0.000155  0.001480  0.000640  ... -0.077119
#
#                        503       504       505       506       507       508  \
# 5_o_Clock_Shadow  0.000398 -0.000394  0.000524  0.000760 -0.000435 -0.000059
# Arched_Eyebrows  -0.000023 -0.000045 -0.000733 -0.000563 -0.000846  0.000482
# Attractive        0.000919  0.000056  0.000097  0.001756 -0.000718 -0.000050
#
#                        509       510       511
# 5_o_Clock_Shadow -0.001659 -0.001441 -0.005054
# Arched_Eyebrows  -0.000723 -0.000328  0.000365
# Attractive       -0.002319 -0.002306  0.004984
#
# [3 rows x 512 columns]

# %%
z_model = result_z.params.values[:-1]
z_labels = list(result_z.params.index)[:-1]
bias = result_z.params.loc['bias'].values

# %%
z_labels_bias = np.array([bias + i*1 for i in z_model])
x_labels = embedder.inverse_transform(np.array(z_labels_bias))
# Out:
# W0709 08:24:42.545371 140412611057472 base_layer.py:1790] Layer dense_2 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.

# %%
fig, axs = plt.subplots(ncols=8, nrows=5, figsize=(8*3,5*3))
for i, (lab, img) in tqdm(enumerate(zip(z_labels, x_labels))):
    ax = axs.flatten()[i]
    ax.imshow(img)
    ax.set_title(lab)
    ax.axis('off')
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
