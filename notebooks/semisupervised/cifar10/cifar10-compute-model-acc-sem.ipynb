# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
import numpy as np
from tfumap.semisupervised_keras import pretrained_networks
from tfumap.semisupervised_keras import load_architecture
from tfumap.paths import MODEL_DIR

# %%
from tfumap.semisupervised_keras import load_dataset

# %%
dataset = "cifar10"
n_latent_dims = 1024

# %%
(
    X_train,
    X_test,
    X_labeled,
    Y_labeled,
    Y_masked,
    X_valid,
    Y_train,
    Y_test,
    Y_valid,
    Y_valid_one_hot,
    Y_labeled_one_hot,
    num_classes,
    dims
) = load_dataset(dataset, 'full')

# %%
encoder, classifier, embedder = load_architecture(dataset, n_latent_dims)

# %%
aug_types = [
    "not_augmented",
    "augmented",
    "umap_euclidean",
    "umap_learned",
    "umap_augmented_learned",
    "umap_euclidean_augmented",
]

# %%
for labels_per_class in [4, 16, 64, 256, 1024, 'full']:
    for aug_str in aug_types:
        pretrained_weights_loc = pretrained_networks[dataset][aug_str][labels_per_class]
        load_folder = (
            MODEL_DIR
            / "semisupervised-keras"
            / dataset
            / str(labels_per_class)
            / pretrained_weights_loc
        )
        classifier.load_weights((load_folder / "classifier").as_posix())
        encoder.load_weights((load_folder / "encoder").as_posix())
        # test current acc
        pretrained_predictions = classifier.predict(encoder.predict(X_test, verbose=True), verbose=True)
        pretrained_predictions = np.argmax(pretrained_predictions, axis=1)
        pretrained_acc = pretrained_predictions == Y_test
        mean_acc = np.mean(pretrained_acc)
        sem_acc = np.std(pretrained_acc) / np.sqrt(len(pretrained_acc))
        np.save(load_folder / 'test_loss_SEM.npy', (mean_acc, sem_acc))
        print('pretrained acc: {} +- {}'.format(mean_acc, sem_acc))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1112 14:36:14.715609 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5415f400> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5415f898>).
# W1112 14:36:14.717746 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd54152860> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5440de10>).
# W1112 14:36:14.815083 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4b8ae748> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546ec4e0>).
# W1112 14:36:14.818117 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546ec4e0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd541ffc88>).
# W1112 14:36:14.821880 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd546d8518> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546d8080>).
# W1112 14:36:14.824577 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546d8080> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546d8978>).
# W1112 14:36:14.828322 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5449f588> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5449f898>).
# W1112 14:36:14.831006 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5449f898> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5449f9e8>).
# W1112 14:36:14.836917 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4b991cf8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4b98f320>).
# W1112 14:36:14.839612 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4b98f320> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd4b98f588>).
# W1112 14:36:14.843354 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd544fa160> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd544fa390>).
# W1112 14:36:14.846023 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd544fa390> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd544fa5f8>).
# W1112 14:36:14.849749 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4c1fa0b8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4c1fa3c8>).
# W1112 14:36:14.852434 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4c1fa3c8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd4c1fa630>).
# W1112 14:36:14.858322 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5411a7b8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5411acf8>).
# W1112 14:36:14.861004 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5411acf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546a50b8>).
# W1112 14:36:14.864732 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5464aba8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5464ae80>).
# W1112 14:36:14.867413 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5464ae80> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546510f0>).
# W1112 14:36:14.871127 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5477ebe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5477eeb8>).
# W1112 14:36:14.873806 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5477eeb8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd54742128>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.217 +- 0.004122026200790092
# W1112 14:36:20.299094 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5415f400> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5415f898>).
# W1112 14:36:20.301682 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd54152860> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5440de10>).
# W1112 14:36:20.432650 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4b8ae748> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546ec4e0>).
# W1112 14:36:20.436034 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546ec4e0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd541ffc88>).
# W1112 14:36:20.439958 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd546d8518> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546d8080>).
# W1112 14:36:20.442793 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546d8080> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546d8978>).
# W1112 14:36:20.446729 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5449f588> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5449f898>).
# W1112 14:36:20.449638 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5449f898> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5449f9e8>).
# W1112 14:36:20.455682 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4b991cf8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4b98f320>).
# W1112 14:36:20.458553 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4b98f320> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd4b98f588>).
# W1112 14:36:20.462465 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd544fa160> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd544fa390>).
# W1112 14:36:20.469417 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd544fa390> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd544fa5f8>).
# W1112 14:36:20.474421 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4c1fa0b8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4c1fa3c8>).
# W1112 14:36:20.477052 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4c1fa3c8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd4c1fa630>).
# W1112 14:36:20.483084 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5411a7b8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5411acf8>).
# W1112 14:36:20.485859 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5411acf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546a50b8>).
# W1112 14:36:20.489761 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5464aba8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5464ae80>).
# W1112 14:36:20.492538 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5464ae80> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546510f0>).
# W1112 14:36:20.496365 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5477ebe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5477eeb8>).
# W1112 14:36:20.499145 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5477eeb8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd54742128>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.2814 +- 0.004496821544157606
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.1895 +- 0.003919052819240894
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.1988 +- 0.003990971811476498
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.3509 +- 0.004772517050781485
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.2427 +- 0.004287151851754262
# W1112 14:36:37.290539 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5415f400> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5415f898>).
# W1112 14:36:37.292938 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd54152860> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5440de10>).
# W1112 14:36:37.411410 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4b8ae748> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546ec4e0>).
# W1112 14:36:37.414447 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546ec4e0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd541ffc88>).
# W1112 14:36:37.418388 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd546d8518> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546d8080>).
# W1112 14:36:37.421237 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546d8080> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546d8978>).
# W1112 14:36:37.425700 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5449f588> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5449f898>).
# W1112 14:36:37.428585 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5449f898> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5449f9e8>).
# W1112 14:36:37.435862 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4b991cf8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4b98f320>).
# W1112 14:36:37.439634 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4b98f320> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd4b98f588>).
# W1112 14:36:37.443478 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd544fa160> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd544fa390>).
# W1112 14:36:37.446266 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd544fa390> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd544fa5f8>).
# W1112 14:36:37.450068 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4c1fa0b8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4c1fa3c8>).
# W1112 14:36:37.452860 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4c1fa3c8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd4c1fa630>).
# W1112 14:36:37.459645 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5411a7b8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5411acf8>).
# W1112 14:36:37.462396 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5411acf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546a50b8>).
# W1112 14:36:37.466290 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5464aba8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5464ae80>).
# W1112 14:36:37.469545 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5464ae80> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546510f0>).
# W1112 14:36:37.474414 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5477ebe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5477eeb8>).
# W1112 14:36:37.477338 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5477eeb8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd54742128>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 2ms/step
# pretrained acc: 0.3019 +- 0.004590821168375
# W1112 14:36:40.675624 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5415f400> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5415f898>).
# W1112 14:36:40.677464 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd54152860> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5440de10>).
# W1112 14:36:40.776970 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4b8ae748> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546ec4e0>).
# W1112 14:36:40.779935 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546ec4e0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd541ffc88>).
# W1112 14:36:40.783957 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd546d8518> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546d8080>).
# W1112 14:36:40.786887 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546d8080> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546d8978>).
# W1112 14:36:40.790852 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5449f588> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5449f898>).
# W1112 14:36:40.793800 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5449f898> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5449f9e8>).
# W1112 14:36:40.801065 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4b991cf8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4b98f320>).
# W1112 14:36:40.804009 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4b98f320> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd4b98f588>).
# W1112 14:36:40.809138 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd544fa160> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd544fa390>).
# W1112 14:36:40.812631 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd544fa390> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd544fa5f8>).
# W1112 14:36:40.816613 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4c1fa0b8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4c1fa3c8>).
# W1112 14:36:40.819526 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4c1fa3c8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd4c1fa630>).
# W1112 14:36:40.825682 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5411a7b8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5411acf8>).
# W1112 14:36:40.828595 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5411acf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546a50b8>).
# W1112 14:36:40.832496 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5464aba8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5464ae80>).
# W1112 14:36:40.835289 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5464ae80> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546510f0>).
# W1112 14:36:40.839181 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5477ebe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5477eeb8>).
# W1112 14:36:40.842024 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5477eeb8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd54742128>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 2ms/step
# pretrained acc: 0.4042 +- 0.004907365484656712
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 2ms/step
# pretrained acc: 0.2867 +- 0.004522202007871829
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.306 +- 0.004608296865437383
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.5035 +- 0.004999877498499338
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.3794 +- 0.0048523771493980145
# W1112 14:36:57.524598 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5415f400> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5415f898>).
# W1112 14:36:57.527039 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd54152860> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5440de10>).
# W1112 14:36:57.635918 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4b8ae748> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546ec4e0>).
# W1112 14:36:57.638891 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546ec4e0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd541ffc88>).
# W1112 14:36:57.642508 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd546d8518> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546d8080>).
# W1112 14:36:57.645033 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546d8080> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546d8978>).
# W1112 14:36:57.648663 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5449f588> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5449f898>).
# ...
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd544fa390> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd544fa5f8>).
# W1112 14:37:58.106032 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4c1fa0b8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4c1fa3c8>).
# W1112 14:37:58.108874 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4c1fa3c8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd4c1fa630>).
# W1112 14:37:58.115992 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5411a7b8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5411acf8>).
# W1112 14:37:58.118945 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5411acf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546a50b8>).
# W1112 14:37:58.122848 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5464aba8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5464ae80>).
# W1112 14:37:58.125675 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5464ae80> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546510f0>).
# W1112 14:37:58.129592 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5477ebe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5477eeb8>).
# W1112 14:37:58.132437 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5477eeb8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd54742128>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.9049 +- 0.002933530125974506
# W1112 14:38:01.763670 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5415f400> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5415f898>).
# W1112 14:38:01.766200 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd54152860> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5440de10>).
# W1112 14:38:01.881853 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4b8ae748> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546ec4e0>).
# W1112 14:38:01.885491 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546ec4e0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd541ffc88>).
# W1112 14:38:01.890556 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd546d8518> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546d8080>).
# W1112 14:38:01.893530 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd546d8080> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546d8978>).
# W1112 14:38:01.897507 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5449f588> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5449f898>).
# W1112 14:38:01.900375 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5449f898> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd5449f9e8>).
# W1112 14:38:01.906340 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4b991cf8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4b98f320>).
# W1112 14:38:01.909104 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4b98f320> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd4b98f588>).
# W1112 14:38:01.912982 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd544fa160> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd544fa390>).
# W1112 14:38:01.915766 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd544fa390> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd544fa5f8>).
# W1112 14:38:01.919612 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd4c1fa0b8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4c1fa3c8>).
# W1112 14:38:01.922420 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd4c1fa3c8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd4c1fa630>).
# W1112 14:38:01.928753 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5411a7b8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5411acf8>).
# W1112 14:38:01.934270 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5411acf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546a50b8>).
# W1112 14:38:01.943220 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5464aba8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5464ae80>).
# W1112 14:38:01.947823 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5464ae80> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd546510f0>).
# W1112 14:38:01.953031 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7fbd5477ebe0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5477eeb8>).
# W1112 14:38:01.956897 140454179960640 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbd5477eeb8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fbd54742128>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.9332 +- 0.0024967530915170604
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.9129 +- 0.0028198154194911417
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.9118 +- 0.0028358554264983253
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.9324 +- 0.0025105824025512483
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.9319 +- 0.0025191742694779967
