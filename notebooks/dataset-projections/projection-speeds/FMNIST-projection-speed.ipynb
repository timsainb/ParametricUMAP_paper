# %% [markdown]
# #### Outline
# - for each dataset:
#     - load dataset;
#     - for each network:
#         - load network
#         - project 1000 test dataset samples
#         - save to metric dataframe

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=''
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=''

# %%
import numpy as np
import pickle
import pandas as pd
import time
from umap import UMAP

# %%
from tfumap.umap import tfUMAP
import tensorflow as tf
from sklearn.decomposition import PCA
from openTSNE import TSNE
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
from tqdm.autonotebook import tqdm

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

# %%
output_dir = MODEL_DIR/'projections'

# %%
projection_speeds = pd.DataFrame(columns = ['method_', 'dimensions', 'dataset', 'speed'])

# %% [markdown]
# ### FMNIST

# %%
dataset = 'fmnist'
dims = (28,28,1)

# %% [markdown]
# ##### load dataset

# %%
from tensorflow.keras.datasets import fashion_mnist

# load dataset
(train_images, Y_train), (test_images, Y_test) = fashion_mnist.load_data()
X_train = (train_images/255.).astype('float32')
X_test = (test_images/255.).astype('float32')
X_train = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))

# subset a validation set
n_valid = 10000
X_valid = X_train[-n_valid:]
Y_valid = Y_train[-n_valid:]
X_train = X_train[:-n_valid]
Y_train = Y_train[:-n_valid]

# flatten X
X_train_flat = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test_flat = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))
X_valid_flat= X_valid.reshape((len(X_valid), np.product(np.shape(X_valid)[1:])))
print(len(X_train), len(X_valid), len(X_test))
# Out:
# 50000 10000 10000

# %% [markdown]
# #### Network

# %% [markdown]
# ##### 2 dims

# %%
load_loc = output_dir / dataset / 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['network', 2, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.6665196269750595
# seconds:  0.570827400078997
# seconds:  0.5870037979912013
# seconds:  0.5799364240374416
# seconds:  0.5651483149267733
# seconds:  0.5651810250710696
# seconds:  0.5721099157817662
# seconds:  0.6015974411275238
# seconds:  0.578452100045979
# seconds:  0.5722668098751456

# %%
##### Network CPU

with tf.device('/CPU:0'):
    n_repeats = 10
    times = []
    for i in tqdm(range(n_repeats)):
        start_time = time.monotonic()
        embedder.transform(X_test_flat);
        end_time = time.monotonic()
        print('seconds: ', end_time - start_time)
        times.append(end_time - start_time)
        projection_speeds.loc[len(projection_speeds)] = ['network-cpu', 2, dataset, end_time - start_time]
# Out:
#    method_ dimensions dataset     speed
# 0  network          2  fmnist  0.666520
# 1  network          2  fmnist  0.570827
# 2  network          2  fmnist  0.587004
# 3  network          2  fmnist  0.579936
# 4  network          2  fmnist  0.565148
# 5  network          2  fmnist  0.565181
# 6  network          2  fmnist  0.572110
# 7  network          2  fmnist  0.601597
# 8  network          2  fmnist  0.578452
# 9  network          2  fmnist  0.572267

# %% [markdown]
# ##### 64 dims

# %%
load_loc = output_dir / dataset /"64"/ 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['network', 64, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.6324575650505722
# seconds:  0.5782665328588337
# seconds:  0.5873863671440631
# seconds:  0.5957047080155462
# seconds:  0.5778048790525645
# seconds:  0.619128986960277
# seconds:  0.5928229740820825
# seconds:  0.5797711350023746
# seconds:  0.5786726931110024
# seconds:  0.5829243750777096

# %%
##### Network CPU

with tf.device('/CPU:0'):
    n_repeats = 10
    times = []
    for i in tqdm(range(n_repeats)):
        start_time = time.monotonic()
        embedder.transform(X_test_flat);
        end_time = time.monotonic()
        print('seconds: ', end_time - start_time)
        times.append(end_time - start_time)
        projection_speeds.loc[len(projection_speeds)] = ['network-cpu', 64, dataset, end_time - start_time]
# Out:
#     method_ dimensions dataset     speed
# 0   network          2  fmnist  0.666520
# 1   network          2  fmnist  0.570827
# 2   network          2  fmnist  0.587004
# 3   network          2  fmnist  0.579936
# 4   network          2  fmnist  0.565148
# 5   network          2  fmnist  0.565181
# 6   network          2  fmnist  0.572110
# 7   network          2  fmnist  0.601597
# 8   network          2  fmnist  0.578452
# 9   network          2  fmnist  0.572267
# 10  network         64  fmnist  0.632458
# 11  network         64  fmnist  0.578267
# 12  network         64  fmnist  0.587386
# 13  network         64  fmnist  0.595705
# 14  network         64  fmnist  0.577805
# 15  network         64  fmnist  0.619129
# 16  network         64  fmnist  0.592823
# 17  network         64  fmnist  0.579771
# 18  network         64  fmnist  0.578673
# 19  network         64  fmnist  0.582924

# %% [markdown]
# #### UMAP-learn

# %% [markdown]
# ##### 2 dims

# %%
embedder = UMAP(n_components = 2, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Wed Jul 15 14:52:08 2020 Finding Nearest Neighbors
# Wed Jul 15 14:52:08 2020 Building RP forest with 16 trees
# Wed Jul 15 14:52:10 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# Wed Jul 15 14:52:19 2020 Finished Nearest Neighbor Search
# Wed Jul 15 14:52:22 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Wed Jul 15 14:53:09 2020 Finished embedding

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['umap-learn', 2, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  18.775295767001808
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.9559709338936955
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  6.092531468952075
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.910753069911152
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  6.669269030913711
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  6.054881794145331
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.86529841599986
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  6.5388427099678665
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.8280213959515095
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.11233323905617

# %%
projection_speeds
# Out:
#        method_ dimensions dataset      speed
# 0      network          2  fmnist   0.666520
# 1      network          2  fmnist   0.570827
# 2      network          2  fmnist   0.587004
# 3      network          2  fmnist   0.579936
# 4      network          2  fmnist   0.565148
# 5      network          2  fmnist   0.565181
# 6      network          2  fmnist   0.572110
# 7      network          2  fmnist   0.601597
# 8      network          2  fmnist   0.578452
# 9      network          2  fmnist   0.572267
# 10     network         64  fmnist   0.632458
# 11     network         64  fmnist   0.578267
# 12     network         64  fmnist   0.587386
# 13     network         64  fmnist   0.595705
# 14     network         64  fmnist   0.577805
# 15     network         64  fmnist   0.619129
# 16     network         64  fmnist   0.592823
# 17     network         64  fmnist   0.579771
# 18     network         64  fmnist   0.578673
# 19     network         64  fmnist   0.582924
# 20  umap-learn          2  fmnist  18.775296
# 21  umap-learn          2  fmnist   5.955971
# 22  umap-learn          2  fmnist   6.092531
# 23  umap-learn          2  fmnist   4.910753
# 24  umap-learn          2  fmnist   6.669269
# 25  umap-learn          2  fmnist   6.054882
# 26  umap-learn          2  fmnist   4.865298
# 27  umap-learn          2  fmnist   6.538843
# 28  umap-learn          2  fmnist   5.828021
# 29  umap-learn          2  fmnist   5.112333

# %% [markdown]
# ##### 64 dims

# %%
embedder = UMAP(n_components = 64, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, n_components=64, verbose=True)
# Construct fuzzy simplicial set
# Wed Jul 15 14:54:21 2020 Finding Nearest Neighbors
# Wed Jul 15 14:54:21 2020 Building RP forest with 16 trees
# Wed Jul 15 14:54:22 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# Wed Jul 15 14:54:24 2020 Finished Nearest Neighbor Search
# Wed Jul 15 14:54:24 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Wed Jul 15 14:55:22 2020 Finished embedding

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['umap-learn', 64, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  7.70125941792503
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  6.358414246933535
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.10625543887727
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  6.331699165981263
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  6.401941889896989
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.309716355986893
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  6.296957781072706
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  6.164989455137402
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.276717344997451
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  6.1216377769596875

# %%
projection_speeds
# Out:
#        method_ dimensions dataset      speed
# 0      network          2  fmnist   0.666520
# 1      network          2  fmnist   0.570827
# 2      network          2  fmnist   0.587004
# 3      network          2  fmnist   0.579936
# 4      network          2  fmnist   0.565148
# 5      network          2  fmnist   0.565181
# 6      network          2  fmnist   0.572110
# 7      network          2  fmnist   0.601597
# 8      network          2  fmnist   0.578452
# 9      network          2  fmnist   0.572267
# 10     network         64  fmnist   0.632458
# 11     network         64  fmnist   0.578267
# 12     network         64  fmnist   0.587386
# 13     network         64  fmnist   0.595705
# 14     network         64  fmnist   0.577805
# 15     network         64  fmnist   0.619129
# 16     network         64  fmnist   0.592823
# 17     network         64  fmnist   0.579771
# 18     network         64  fmnist   0.578673
# 19     network         64  fmnist   0.582924
# 20  umap-learn          2  fmnist  18.775296
# 21  umap-learn          2  fmnist   5.955971
# 22  umap-learn          2  fmnist   6.092531
# 23  umap-learn          2  fmnist   4.910753
# 24  umap-learn          2  fmnist   6.669269
# 25  umap-learn          2  fmnist   6.054882
# 26  umap-learn          2  fmnist   4.865298
# 27  umap-learn          2  fmnist   6.538843
# 28  umap-learn          2  fmnist   5.828021
# 29  umap-learn          2  fmnist   5.112333
# 30  umap-learn         64  fmnist   7.701259
# 31  umap-learn         64  fmnist   6.358414
# 32  umap-learn         64  fmnist   5.106255
# 33  umap-learn         64  fmnist   6.331699
# 34  umap-learn         64  fmnist   6.401942
# 35  umap-learn         64  fmnist   5.309716
# 36  umap-learn         64  fmnist   6.296958
# 37  umap-learn         64  fmnist   6.164989
# 38  umap-learn         64  fmnist   5.276717
# 39  umap-learn         64  fmnist   6.121638

# %% [markdown]
# #### PCA

# %% [markdown]
# ##### 2 dims

# %%
pca = PCA(n_components=2)
z = pca.fit_transform(X_train_flat)

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    pca.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['pca', 2, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.012142679886892438
# seconds:  0.015337032033130527
# seconds:  0.015329151879996061
# seconds:  0.016142185777425766
# seconds:  0.015245229937136173
# seconds:  0.016163286054506898
# seconds:  0.015217638807371259
# seconds:  0.015228929929435253
# seconds:  0.01610818412154913
# seconds:  0.015298180980607867

# %%
projection_speeds
# Out:
#        method_ dimensions dataset      speed
# 0      network          2  fmnist   0.666520
# 1      network          2  fmnist   0.570827
# 2      network          2  fmnist   0.587004
# 3      network          2  fmnist   0.579936
# 4      network          2  fmnist   0.565148
# 5      network          2  fmnist   0.565181
# 6      network          2  fmnist   0.572110
# 7      network          2  fmnist   0.601597
# 8      network          2  fmnist   0.578452
# 9      network          2  fmnist   0.572267
# 10     network         64  fmnist   0.632458
# 11     network         64  fmnist   0.578267
# 12     network         64  fmnist   0.587386
# 13     network         64  fmnist   0.595705
# 14     network         64  fmnist   0.577805
# 15     network         64  fmnist   0.619129
# 16     network         64  fmnist   0.592823
# 17     network         64  fmnist   0.579771
# 18     network         64  fmnist   0.578673
# 19     network         64  fmnist   0.582924
# 20  umap-learn          2  fmnist  18.775296
# 21  umap-learn          2  fmnist   5.955971
# 22  umap-learn          2  fmnist   6.092531
# 23  umap-learn          2  fmnist   4.910753
# 24  umap-learn          2  fmnist   6.669269
# 25  umap-learn          2  fmnist   6.054882
# 26  umap-learn          2  fmnist   4.865298
# 27  umap-learn          2  fmnist   6.538843
# 28  umap-learn          2  fmnist   5.828021
# 29  umap-learn          2  fmnist   5.112333
# 30  umap-learn         64  fmnist   7.701259
# 31  umap-learn         64  fmnist   6.358414
# 32  umap-learn         64  fmnist   5.106255
# 33  umap-learn         64  fmnist   6.331699
# 34  umap-learn         64  fmnist   6.401942
# 35  umap-learn         64  fmnist   5.309716
# 36  umap-learn         64  fmnist   6.296958
# 37  umap-learn         64  fmnist   6.164989
# 38  umap-learn         64  fmnist   5.276717
# 39  umap-learn         64  fmnist   6.121638
# 40         pca          2  fmnist   0.012143
# 41         pca          2  fmnist   0.015337
# 42         pca          2  fmnist   0.015329
# 43         pca          2  fmnist   0.016142
# 44         pca          2  fmnist   0.015245
# 45         pca          2  fmnist   0.016163
# 46         pca          2  fmnist   0.015218
# 47         pca          2  fmnist   0.015229
# 48         pca          2  fmnist   0.016108
# 49         pca          2  fmnist   0.015298

# %% [markdown]
# ##### 64 dims

# %%
pca = PCA(n_components=64)
z = pca.fit_transform(X_train_flat)

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    pca.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['pca', 64, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.01815981394611299
# seconds:  0.019492382183670998
# seconds:  0.01855977508239448
# seconds:  0.018594756023958325
# seconds:  0.018535224022343755
# seconds:  0.020074347965419292
# seconds:  0.01935253804549575
# seconds:  0.01946695218794048
# seconds:  0.01888064411468804
# seconds:  0.01951951300725341

# %%
projection_speeds
# Out:
#        method_ dimensions dataset      speed
# 0      network          2  fmnist   0.666520
# 1      network          2  fmnist   0.570827
# 2      network          2  fmnist   0.587004
# 3      network          2  fmnist   0.579936
# 4      network          2  fmnist   0.565148
# 5      network          2  fmnist   0.565181
# 6      network          2  fmnist   0.572110
# 7      network          2  fmnist   0.601597
# 8      network          2  fmnist   0.578452
# 9      network          2  fmnist   0.572267
# 10     network         64  fmnist   0.632458
# 11     network         64  fmnist   0.578267
# 12     network         64  fmnist   0.587386
# 13     network         64  fmnist   0.595705
# 14     network         64  fmnist   0.577805
# 15     network         64  fmnist   0.619129
# 16     network         64  fmnist   0.592823
# 17     network         64  fmnist   0.579771
# 18     network         64  fmnist   0.578673
# 19     network         64  fmnist   0.582924
# 20  umap-learn          2  fmnist  18.775296
# 21  umap-learn          2  fmnist   5.955971
# 22  umap-learn          2  fmnist   6.092531
# 23  umap-learn          2  fmnist   4.910753
# 24  umap-learn          2  fmnist   6.669269
# 25  umap-learn          2  fmnist   6.054882
# 26  umap-learn          2  fmnist   4.865298
# 27  umap-learn          2  fmnist   6.538843
# 28  umap-learn          2  fmnist   5.828021
# 29  umap-learn          2  fmnist   5.112333
# 30  umap-learn         64  fmnist   7.701259
# 31  umap-learn         64  fmnist   6.358414
# 32  umap-learn         64  fmnist   5.106255
# 33  umap-learn         64  fmnist   6.331699
# 34  umap-learn         64  fmnist   6.401942
# 35  umap-learn         64  fmnist   5.309716
# 36  umap-learn         64  fmnist   6.296958
# 37  umap-learn         64  fmnist   6.164989
# 38  umap-learn         64  fmnist   5.276717
# 39  umap-learn         64  fmnist   6.121638
# 40         pca          2  fmnist   0.012143
# 41         pca          2  fmnist   0.015337
# 42         pca          2  fmnist   0.015329
# 43         pca          2  fmnist   0.016142
# 44         pca          2  fmnist   0.015245
# 45         pca          2  fmnist   0.016163
# 46         pca          2  fmnist   0.015218
# 47         pca          2  fmnist   0.015229
# 48         pca          2  fmnist   0.016108
# 49         pca          2  fmnist   0.015298
# 50         pca         64  fmnist   0.018160
# 51         pca         64  fmnist   0.019492
# 52         pca         64  fmnist   0.018560
# 53         pca         64  fmnist   0.018595
# 54         pca         64  fmnist   0.018535
# 55         pca         64  fmnist   0.020074
# 56         pca         64  fmnist   0.019353
# 57         pca         64  fmnist   0.019467
# 58         pca         64  fmnist   0.018881
# 59         pca         64  fmnist   0.019520

# %% [markdown]
# #### TSNE

# %% [markdown]
# ##### 2 dims

# %%
tsne = TSNE(
    n_components = 2,
    n_jobs=32,
    verbose=True
)

# %%
embedding_train = tsne.fit(X_train_flat)
# Out:
# --------------------------------------------------------------------------------
# TSNE(n_jobs=32, neighbors=None, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#    --> Time elapsed: 36.72 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.41 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.48 seconds
# ===> Running optimization with exaggeration=12.00, lr=4166.67 for 250 iterations...
# Iteration   50, KL divergence 5.9436, 50 iterations in 1.6407 sec
# Iteration  100, KL divergence 5.4387, 50 iterations in 1.6313 sec
# Iteration  150, KL divergence 5.3138, 50 iterations in 1.6602 sec
# Iteration  200, KL divergence 5.2570, 50 iterations in 1.6842 sec
# Iteration  250, KL divergence 5.2247, 50 iterations in 1.6110 sec
#    --> Time elapsed: 8.23 seconds
# ===> Running optimization with exaggeration=1.00, lr=4166.67 for 500 iterations...
# Iteration   50, KL divergence 3.8565, 50 iterations in 1.6199 sec
# Iteration  100, KL divergence 3.3411, 50 iterations in 1.5053 sec
# Iteration  150, KL divergence 3.0753, 50 iterations in 2.0471 sec
# Iteration  200, KL divergence 2.9082, 50 iterations in 2.7860 sec
# Iteration  250, KL divergence 2.7928, 50 iterations in 3.9239 sec
# Iteration  300, KL divergence 2.7084, 50 iterations in 5.1969 sec
# Iteration  350, KL divergence 2.6445, 50 iterations in 6.0822 sec
# Iteration  400, KL divergence 2.5948, 50 iterations in 7.9321 sec
# Iteration  450, KL divergence 2.5549, 50 iterations in 8.5613 sec
# Iteration  500, KL divergence 2.5219, 50 iterations in 12.2083 sec
#    --> Time elapsed: 51.87 seconds

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedding_train.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['TSNE', 2, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 6.04 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.04 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197925.5359, 50 iterations in 0.2627 sec
# Iteration  100, KL divergence 198144.9919, 50 iterations in 0.2712 sec
# Iteration  150, KL divergence 198282.1556, 50 iterations in 0.2775 sec
# Iteration  200, KL divergence 198392.0414, 50 iterations in 0.2752 sec
# Iteration  250, KL divergence 198468.5677, 50 iterations in 0.2893 sec
#    --> Time elapsed: 1.38 seconds
# seconds:  7.755008135922253
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.37 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197925.5359, 50 iterations in 0.2804 sec
# Iteration  100, KL divergence 198144.9919, 50 iterations in 0.2711 sec
# Iteration  150, KL divergence 198282.1556, 50 iterations in 0.3011 sec
# Iteration  200, KL divergence 198392.0414, 50 iterations in 0.3190 sec
# Iteration  250, KL divergence 198468.5677, 50 iterations in 0.2858 sec
#    --> Time elapsed: 1.46 seconds
# seconds:  5.885064702946693
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.25 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197925.5359, 50 iterations in 0.2881 sec
# Iteration  100, KL divergence 198144.9919, 50 iterations in 0.2765 sec
# Iteration  150, KL divergence 198282.1556, 50 iterations in 0.2588 sec
# Iteration  200, KL divergence 198392.0414, 50 iterations in 0.2808 sec
# Iteration  250, KL divergence 198468.5677, 50 iterations in 0.3130 sec
#    --> Time elapsed: 1.42 seconds
# seconds:  5.729260824853554
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.43 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197925.5359, 50 iterations in 0.2720 sec
# Iteration  100, KL divergence 198144.9919, 50 iterations in 0.2664 sec
# Iteration  150, KL divergence 198282.1556, 50 iterations in 0.2790 sec
# Iteration  200, KL divergence 198392.0414, 50 iterations in 0.2553 sec
# Iteration  250, KL divergence 198468.5677, 50 iterations in 0.2614 sec
#    --> Time elapsed: 1.33 seconds
# seconds:  5.822072301991284
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.40 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197925.5359, 50 iterations in 0.2659 sec
# Iteration  100, KL divergence 198144.9919, 50 iterations in 0.2488 sec
# Iteration  150, KL divergence 198282.1556, 50 iterations in 0.2576 sec
# Iteration  200, KL divergence 198392.0414, 50 iterations in 0.2622 sec
# Iteration  250, KL divergence 198468.5677, 50 iterations in 0.2452 sec
#    --> Time elapsed: 1.28 seconds
# seconds:  5.7266346528194845
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.27 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197925.5359, 50 iterations in 0.2848 sec
# Iteration  100, KL divergence 198144.9919, 50 iterations in 0.2886 sec
# Iteration  150, KL divergence 198282.1556, 50 iterations in 0.2723 sec
# Iteration  200, KL divergence 198392.0414, 50 iterations in 0.2498 sec
# Iteration  250, KL divergence 198468.5677, 50 iterations in 0.2652 sec
#    --> Time elapsed: 1.36 seconds
# seconds:  5.69768271711655
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.49 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197925.5359, 50 iterations in 0.2653 sec
# Iteration  100, KL divergence 198144.9919, 50 iterations in 0.2523 sec
# Iteration  150, KL divergence 198282.1556, 50 iterations in 0.2608 sec
# Iteration  200, KL divergence 198392.0414, 50 iterations in 0.2762 sec
# Iteration  250, KL divergence 198468.5677, 50 iterations in 0.2482 sec
#    --> Time elapsed: 1.30 seconds
# seconds:  5.8482426260598
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.44 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197925.5359, 50 iterations in 0.2799 sec
# Iteration  100, KL divergence 198144.9919, 50 iterations in 0.2776 sec
# Iteration  150, KL divergence 198282.1556, 50 iterations in 0.2974 sec
# Iteration  200, KL divergence 198392.0414, 50 iterations in 0.2736 sec
# Iteration  250, KL divergence 198468.5677, 50 iterations in 0.2712 sec
#    --> Time elapsed: 1.40 seconds
# seconds:  5.8949349438771605
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.39 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197925.5359, 50 iterations in 0.2580 sec
# Iteration  100, KL divergence 198144.9919, 50 iterations in 0.2657 sec
# Iteration  150, KL divergence 198282.1556, 50 iterations in 0.2860 sec
# Iteration  200, KL divergence 198392.0414, 50 iterations in 0.3099 sec
# Iteration  250, KL divergence 198468.5677, 50 iterations in 0.2950 sec
#    --> Time elapsed: 1.42 seconds
# seconds:  5.865171876037493
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.60 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197925.5359, 50 iterations in 0.3008 sec
# Iteration  100, KL divergence 198144.9919, 50 iterations in 0.3544 sec
# Iteration  150, KL divergence 198282.1556, 50 iterations in 0.2926 sec
# Iteration  200, KL divergence 198392.0414, 50 iterations in 0.3051 sec
# Iteration  250, KL divergence 198468.5677, 50 iterations in 0.2750 sec
#    --> Time elapsed: 1.53 seconds
# seconds:  6.183753014076501

# %%
projection_speeds
# Out:
#     method_ dimensions dataset     speed
# 0   network          2  fmnist  0.666520
# 1   network          2  fmnist  0.570827
# 2   network          2  fmnist  0.587004
# 3   network          2  fmnist  0.579936
# 4   network          2  fmnist  0.565148
# ..      ...        ...     ...       ...
# 65     TSNE          2  fmnist  5.697683
# 66     TSNE          2  fmnist  5.848243
# 67     TSNE          2  fmnist  5.894935
# 68     TSNE          2  fmnist  5.865172
# 69     TSNE          2  fmnist  6.183753
#
# [70 rows x 4 columns]

# %% [markdown]
# ### Save

# %%
save_loc = DATA_DIR / 'projection_speeds' / (dataset + '.pickle')
ensure_dir(save_loc)
projection_speeds.to_pickle(save_loc)
