# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %% [markdown]
# ### load packages

# %%
from tfumap.umap import tfUMAP
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
import umap
import pandas as pd

# %% [markdown]
# ### Load dataset

# %%
from tensorflow.keras.datasets import mnist

# %%
# load dataset
(train_images, Y_train), (test_images, Y_test) = mnist.load_data()
X_train = (train_images/255.).astype('float32')
X_test = (test_images/255.).astype('float32')
X_train_flat = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test_flat = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))

# %% [markdown]
# ### Create model and train

# %%
embedder = tfUMAP(direct_embedding=True, verbose=True, negative_sample_rate=5)

# %%
z = embedder.fit_transform(X_train_flat)
# Out:
# Construct fuzzy simplicial set
# Thu Jul  2 14:55:03 2020 Finding Nearest Neighbors
# Thu Jul  2 14:55:03 2020 Building RP forest with 17 trees
# Thu Jul  2 14:55:04 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# 	 4  /  16
# Thu Jul  2 14:55:06 2020 Finished Nearest Neighbor Search
# Thu Jul  2 14:55:14 2020 Embedding with TensorFlow
# HBox(children=(IntProgress(value=0, description='epoch', max=50, style=ProgressStyle(description_width='initia…
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Thu Jul  2 14:56:31 2020 Finished embedding

# %% [markdown]
# ### Plot model output

# %%
fig, ax = plt.subplots( figsize=(8, 8))
sc = ax.scatter(
    z[:, 0],
    z[:, 1],
    c=Y_train.astype(int)[:len(z)],
    cmap="tab10",
    s=0.1,
    alpha=0.5,
    rasterized=True,
)
ax.axis('equal')
ax.set_title("UMAP in Tensorflow embedding", fontsize=20)
plt.colorbar(sc, ax=ax);

# %% [markdown]
# ### embed test data

# %%
np.shape(X_test_flat)
# Out:
# (10000, 784)

# %%
z_test = embedder.transform(X_test_flat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f6ee635a584c> in <module>
# ----> 1 z_test = embedder.transform(X_test_flat)
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in transform(self, X)
#     847         # embed using nearest neighbors method if embedding without a network
#     848         if self.direct_embedding:
# --> 849             return self.original_transform(X)
#     850
#     851         n_batches = np.ceil(len(X) / self.batch_size).astype(int)
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in original_transform(self, X)
#     825         network based.
#     826         """
# --> 827         return super().transform(X)
#     828
#     829     def original_inverse_transform(self, X):
#
# /mnt/cube/tsainbur/Projects/github_repos/umap/umap/umap_.py in transform(self, X)
#    2451             epsilon = 0.24 if self._knn_search_index._angular_trees else 0.12
#    2452             indices, dists = self._knn_search_index.query(
# -> 2453                 X, self.n_neighbors, epsilon=epsilon
#    2454             )
#    2455
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/pynndescent/pynndescent_.py in query(self, query_data, k, epsilon)
#    1221                 k,
#    1222                 self._raw_data,
# -> 1223                 self._search_forest,
#    1224                 self._search_graph.indptr,
#    1225                 self._search_graph.indices,
#
# AttributeError: 'NNDescent' object has no attribute '_search_forest'

# %%
fig, ax = plt.subplots( figsize=(8, 8))
sc = ax.scatter(
    z_test[:, 0],
    z_test[:, 1],
    c=Y_test.astype(int)[:len(z)],
    cmap="tab10",
    s=1.0,
    alpha=0.5,
    rasterized=True,
)
ax.axis('equal')
ax.set_title("Test embedding", fontsize=20)
plt.colorbar(sc, ax=ax);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-2bc6870c8cee> in <module>
# ----> 1 z_test = embedder.transform(X_test_flat)
#       2 fig, ax = plt.subplots( figsize=(8, 8))
#       3 sc = ax.scatter(
#       4     z_test[:, 0],
#       5     z_test[:, 1],
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in transform(self, X)
#     847         # embed using nearest neighbors method if embedding without a network
#     848         if self.direct_embedding:
# --> 849             return self.original_transform(X)
#     850
#     851         n_batches = np.ceil(len(X) / self.batch_size).astype(int)
#
# /mnt/cube/tsainbur/Projects/github_repos/umap_tf_networks/tfumap/umap.py in original_transform(self, X)
#     825         network based.
#     826         """
# --> 827         return super().transform(X)
#     828
#     829     def original_inverse_transform(self, X):
#
# /mnt/cube/tsainbur/Projects/github_repos/umap/umap/umap_.py in transform(self, X)
#    2451             epsilon = 0.24 if self._knn_search_index._angular_trees else 0.12
#    2452             indices, dists = self._knn_search_index.query(
# -> 2453                 X, self.n_neighbors, epsilon=epsilon
#    2454             )
#    2455
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/pynndescent/pynndescent_.py in query(self, query_data, k, epsilon)
#    1221                 k,
#    1222                 self._raw_data,
# -> 1223                 self._search_forest,
#    1224                 self._search_graph.indptr,
#    1225                 self._search_graph.indices,
#
# AttributeError: 'NNDescent' object has no attribute '_search_forest'

# %% [markdown]
# ### View loss

# %%
from tfumap.umap import retrieve_tensors
import seaborn as sns

# %%
loss_df = retrieve_tensors(embedder.tensorboard_logdir)
loss_df[:3]
# Out:
# ['umap_loss']
# []
#       wall_time  step       val  group   variable
# 0  1.593727e+09     1  0.296833  train  umap_loss
# 1  1.593727e+09     2  0.292541  train  umap_loss
# 2  1.593727e+09     3  0.288079  train  umap_loss

# %%
ax = sns.lineplot(x="step", y="val", hue="group", data=loss_df[loss_df.variable=='umap_loss'])
ax.set_xscale('log')

# %% [markdown]
# ### Compare to direct embedding with base UMAP

# %%
from umap import UMAP

# %%
z_umap = UMAP(verbose=True).fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Thu Jul  2 14:59:23 2020 Finding Nearest Neighbors
# Thu Jul  2 14:59:23 2020 Building RP forest with 17 trees
# Thu Jul  2 14:59:24 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# 	 4  /  16
# Thu Jul  2 14:59:26 2020 Finished Nearest Neighbor Search
# Thu Jul  2 14:59:27 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Thu Jul  2 15:00:19 2020 Finished embedding

# %%
### realign using procrustes 
from scipy.spatial import procrustes
z_align, z_umap_align, disparity = procrustes(z, z_umap)
print(disparity)
# Out:
# 0.05499664453762651

# %%
fig, axs = plt.subplots(ncols=2, figsize=(20, 8))
ax = axs[0]
sc = ax.scatter(
    z_align[:, 0],
    z_align[:, 1],
    c=Y_train.astype(int)[:len(z)],
    cmap="tab10",
    s=0.1,
    alpha=0.5,
    rasterized=True,
)
ax.axis('equal')
ax.set_title("UMAP in Tensorflow", fontsize=20)
#plt.colorbar(sc, ax=ax);

ax = axs[1]
sc = ax.scatter(
    z_umap_align[:, 0],
    z_umap_align[:, 1],
    c=Y_train.astype(int)[:len(z)],
    cmap="tab10",
    s=0.1,
    alpha=0.5,
    rasterized=True,
)
ax.axis('equal')
ax.set_title("UMAP with UMAP-learn", fontsize=20)
#plt.colorbar(sc, ax=ax);
# Out:
# Text(0.5, 1.0, 'UMAP with UMAP-learn')
