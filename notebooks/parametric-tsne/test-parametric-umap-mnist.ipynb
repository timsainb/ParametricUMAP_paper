# %%
### based on https://github.com/kylemcdonald/Parametric-t-SNE/blob/master/Parametric%20t-SNE%20(Keras).ipynb

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
print(gpu_devices)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tqdm.autonotebook import tqdm
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import categorical_crossentropy

# %% [markdown]
# ### MNIST

# %%
dataset = 'mnist'
dims = (28,28,1)

# %% [markdown]
# ##### load dataset

# %%
from tensorflow.keras.datasets import mnist

# load dataset
(train_images, Y_train), (test_images, Y_test) = mnist.load_data()
X_train = (train_images / 255.0).astype("float32")
X_test = (test_images / 255.0).astype("float32")
X_train = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))

# subset a validation set
n_valid = 10000
X_valid = X_train[-n_valid:]
Y_valid = Y_train[-n_valid:]
X_train = X_train[:-n_valid]
Y_train = Y_train[:-n_valid]

# flatten X
X_train_flat = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test_flat = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))
X_valid_flat = X_valid.reshape((len(X_valid), np.product(np.shape(X_valid)[1:])))
X_test = X_test.reshape((10000, 28, 28, 1))
print(len(X_train), len(X_valid), len(X_test))
# Out:
# 50000 10000 10000

# %% [markdown]
# ### Model

# %%
def Hbeta(D, beta):
    P = np.exp(-D * beta)
    sumP = np.sum(P)
    H = np.log(sumP) + beta * np.sum(np.multiply(D, P)) / sumP
    P = P / sumP
    return H, P


def x2p(X, u=15, tol=1e-4, print_iter=500, max_tries=50, verbose=0):
    # Initialize some variables
    n = X.shape[0]  # number of instances
    P = np.zeros((n, n))  # empty probability matrix
    beta = np.ones(n)  # empty precision vector
    logU = np.log(u)  # log of perplexity (= entropy)

    # Compute pairwise distances
    if verbose > 0:
        print("Computing pairwise distances...")
    sum_X = np.sum(np.square(X), axis=1)
    # note: translating sum_X' from matlab to numpy means using reshape to add a dimension
    D = sum_X + sum_X[:, None] + -2 * X.dot(X.T)

    # Run over all datapoints
    if verbose > 0:
        print("Computing P-values...")
    for i in range(n):

        if verbose > 1 and print_iter and i % print_iter == 0:
            print("Computed P-values {} of {} datapoints...".format(i, n))

        # Set minimum and maximum values for precision
        betamin = float("-inf")
        betamax = float("+inf")

        # Compute the Gaussian kernel and entropy for the current precision
        indices = np.concatenate((np.arange(0, i), np.arange(i + 1, n)))
        Di = D[i, indices]
        H, thisP = Hbeta(Di, beta[i])

        # Evaluate whether the perplexity is within tolerance
        Hdiff = H - logU
        tries = 0
        while abs(Hdiff) > tol and tries < max_tries:

            # If not, increase or decrease precision
            if Hdiff > 0:
                betamin = beta[i]
                if np.isinf(betamax):
                    beta[i] *= 2
                else:
                    beta[i] = (beta[i] + betamax) / 2
            else:
                betamax = beta[i]
                if np.isinf(betamin):
                    beta[i] /= 2
                else:
                    beta[i] = (beta[i] + betamin) / 2

            # Recompute the values
            H, thisP = Hbeta(Di, beta[i])
            Hdiff = H - logU
            tries += 1

        # Set the final row of P
        P[i, indices] = thisP

    if verbose > 0:
        print("Mean value of sigma: {}".format(np.mean(np.sqrt(1 / beta))))
        print("Minimum value of sigma: {}".format(np.min(np.sqrt(1 / beta))))
        print("Maximum value of sigma: {}".format(np.max(np.sqrt(1 / beta))))

    return P, beta

# %%
def compute_joint_probabilities(
    samples, batch_size=5000, d=2, perplexity=30, tol=1e-5, verbose=0
):
    v = d - 1

    # Initialize some variables
    n = samples.shape[0]
    batch_size = min(batch_size, n)

    # Precompute joint probabilities for all batches
    if verbose > 0:
        print("Precomputing P-values...")
    batch_count = int(n / batch_size)
    P = np.zeros((batch_count, batch_size, batch_size))
    for i, start in enumerate(tqdm(range(0, n - batch_size + 1, batch_size))):
        curX = samples[start : start + batch_size]  # select batch
        P[i], beta = x2p(
            curX, perplexity, tol, verbose=verbose
        )  # compute affinities using fixed perplexity
        P[i][np.isnan(P[i])] = 0  # make sure we don't have NaN's
        P[i] = P[i] + P[i].T  # / 2                             # make symmetric
        P[i] = P[i] / P[i].sum()  # obtain estimation of joint probabilities
        P[i] = np.maximum(P[i], np.finfo(P[i].dtype).eps)

    return P

# %%
batch_size = 5000

# %%
# %time  P = compute_joint_probabilities(X_train_flat, batch_size=batch_size, verbose=2)
# Out:
# Precomputing P-values...
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# Computing pairwise distances...
# Computing P-values...
# Computed P-values 0 of 5000 datapoints...
# Computed P-values 500 of 5000 datapoints...
# Computed P-values 1000 of 5000 datapoints...
# Computed P-values 1500 of 5000 datapoints...
# Computed P-values 2000 of 5000 datapoints...
# Computed P-values 2500 of 5000 datapoints...
# Computed P-values 3000 of 5000 datapoints...
# Computed P-values 3500 of 5000 datapoints...
# Computed P-values 4000 of 5000 datapoints...
# Computed P-values 4500 of 5000 datapoints...
# Mean value of sigma: 2.210395926597027
# Minimum value of sigma: 1.1465189822400297
# Maximum value of sigma: 3.423562241637291
# Computing pairwise distances...
# Computing P-values...
# Computed P-values 0 of 5000 datapoints...
# Computed P-values 500 of 5000 datapoints...
# Computed P-values 1000 of 5000 datapoints...
# Computed P-values 1500 of 5000 datapoints...
# Computed P-values 2000 of 5000 datapoints...
# Computed P-values 2500 of 5000 datapoints...
# Computed P-values 3000 of 5000 datapoints...
# Computed P-values 3500 of 5000 datapoints...
# Computed P-values 4000 of 5000 datapoints...
# Computed P-values 4500 of 5000 datapoints...
# Mean value of sigma: 2.2133320422641924
# Minimum value of sigma: 1.028104158803783
# Maximum value of sigma: 3.3874801273632515
# Computing pairwise distances...
# Computing P-values...
# Computed P-values 0 of 5000 datapoints...
# Computed P-values 500 of 5000 datapoints...
# Computed P-values 1000 of 5000 datapoints...
# Computed P-values 1500 of 5000 datapoints...
# Computed P-values 2000 of 5000 datapoints...
# Computed P-values 2500 of 5000 datapoints...
# Computed P-values 3000 of 5000 datapoints...
# Computed P-values 3500 of 5000 datapoints...
# Computed P-values 4000 of 5000 datapoints...
# Computed P-values 4500 of 5000 datapoints...
# Mean value of sigma: 2.254363937312274
# Minimum value of sigma: 1.0993403688963808
# Maximum value of sigma: 3.6720262251663818
# Computing pairwise distances...
# Computing P-values...
# Computed P-values 0 of 5000 datapoints...
# Computed P-values 500 of 5000 datapoints...
# Computed P-values 1000 of 5000 datapoints...
# Computed P-values 1500 of 5000 datapoints...
# Computed P-values 2000 of 5000 datapoints...
# Computed P-values 2500 of 5000 datapoints...
# Computed P-values 3000 of 5000 datapoints...
# Computed P-values 3500 of 5000 datapoints...
# Computed P-values 4000 of 5000 datapoints...
# Computed P-values 4500 of 5000 datapoints...
# Mean value of sigma: 2.2162078644773335
# Minimum value of sigma: 1.081392000059354
# Maximum value of sigma: 3.3301979665436727
# Computing pairwise distances...
# Computing P-values...
# Computed P-values 0 of 5000 datapoints...
# Computed P-values 500 of 5000 datapoints...
# Computed P-values 1000 of 5000 datapoints...
# Computed P-values 1500 of 5000 datapoints...
# Computed P-values 2000 of 5000 datapoints...
# Computed P-values 2500 of 5000 datapoints...
# Computed P-values 3000 of 5000 datapoints...
# Computed P-values 3500 of 5000 datapoints...
# Computed P-values 4000 of 5000 datapoints...
# Computed P-values 4500 of 5000 datapoints...
# Mean value of sigma: 2.247200240446076
# Minimum value of sigma: 1.061683289843211
# Maximum value of sigma: 3.476759114723516
# Computing pairwise distances...
# Computing P-values...
# Computed P-values 0 of 5000 datapoints...
# Computed P-values 500 of 5000 datapoints...
# Computed P-values 1000 of 5000 datapoints...
# Computed P-values 1500 of 5000 datapoints...
# Computed P-values 2000 of 5000 datapoints...
# Computed P-values 2500 of 5000 datapoints...
# Computed P-values 3000 of 5000 datapoints...
# Computed P-values 3500 of 5000 datapoints...
# Computed P-values 4000 of 5000 datapoints...
# Computed P-values 4500 of 5000 datapoints...
# Mean value of sigma: 2.181038068415593
# Minimum value of sigma: 0.9031738375276179
# Maximum value of sigma: 3.665544901255984
# Computing pairwise distances...
# Computing P-values...
# Computed P-values 0 of 5000 datapoints...
# Computed P-values 500 of 5000 datapoints...
# Computed P-values 1000 of 5000 datapoints...
# Computed P-values 1500 of 5000 datapoints...
# Computed P-values 2000 of 5000 datapoints...
# Computed P-values 2500 of 5000 datapoints...
# Computed P-values 3000 of 5000 datapoints...
# Computed P-values 3500 of 5000 datapoints...
# Computed P-values 4000 of 5000 datapoints...
# Computed P-values 4500 of 5000 datapoints...
# Mean value of sigma: 2.1962136441831337
# Minimum value of sigma: 1.0022621389059558
# Maximum value of sigma: 3.420674280853297
# Computing pairwise distances...
# Computing P-values...
# Computed P-values 0 of 5000 datapoints...
# Computed P-values 500 of 5000 datapoints...
# Computed P-values 1000 of 5000 datapoints...
# Computed P-values 1500 of 5000 datapoints...
# Computed P-values 2000 of 5000 datapoints...
# Computed P-values 2500 of 5000 datapoints...
# Computed P-values 3000 of 5000 datapoints...
# Computed P-values 3500 of 5000 datapoints...
# Computed P-values 4000 of 5000 datapoints...
# Computed P-values 4500 of 5000 datapoints...
# Mean value of sigma: 2.216737423713201
# Minimum value of sigma: 1.0503807230236393
# Maximum value of sigma: 3.3508994412507405
# Computing pairwise distances...
# Computing P-values...
# Computed P-values 0 of 5000 datapoints...
# Computed P-values 500 of 5000 datapoints...
# Computed P-values 1000 of 5000 datapoints...
# Computed P-values 1500 of 5000 datapoints...
# Computed P-values 2000 of 5000 datapoints...
# Computed P-values 2500 of 5000 datapoints...
# Computed P-values 3000 of 5000 datapoints...
# Computed P-values 3500 of 5000 datapoints...
# Computed P-values 4000 of 5000 datapoints...
# Computed P-values 4500 of 5000 datapoints...
# Mean value of sigma: 2.200239991624926
# Minimum value of sigma: 1.1353135977722875
# Maximum value of sigma: 3.3820576890069067
# Computing pairwise distances...
# Computing P-values...
# Computed P-values 0 of 5000 datapoints...
# Computed P-values 500 of 5000 datapoints...
# Computed P-values 1000 of 5000 datapoints...
# Computed P-values 1500 of 5000 datapoints...
# Computed P-values 2000 of 5000 datapoints...
# Computed P-values 2500 of 5000 datapoints...
# Computed P-values 3000 of 5000 datapoints...
# Computed P-values 3500 of 5000 datapoints...
# Computed P-values 4000 of 5000 datapoints...
# Computed P-values 4500 of 5000 datapoints...
# Mean value of sigma: 2.2134461707301147
# Minimum value of sigma: 1.0805969136944074
# Maximum value of sigma: 3.3211063109107593
#
# CPU times: user 1min 34s, sys: 2.9 s, total: 1min 37s
# Wall time: 49.5 s

# %%
P.shape
# Out:
# (10, 5000, 5000)

# %%
plt.matshow(P[0])

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

# %%
np.save(DATA_DIR/'P.npy', P)

# %%
n = batch_size
d = 2
v = d - 1.0
eps = 10e-15  # needs to be at least 10e-8 to get anything after Q /= K.sum(Q)
# P is the joint probabilities for this batch (Keras loss functions call this y_true)
# activations is the low-dimensional output (Keras loss functions call this y_pred)
def tsne(P, activations):
    sum_act = tf.math.reduce_sum(tf.math.square(activations), axis=1)
    Q = K.reshape(sum_act, [-1, 1]) + -2 * tf.keras.backend.dot(
        activations, tf.transpose(activations)
    )
    Q = (sum_act + Q) / v
    Q = tf.math.pow(1 + Q, -(v + 1) / 2)
    Q *= 1 - np.eye(n)
    Q /= tf.math.reduce_sum(Q)
    Q = tf.math.maximum(Q, eps)
    C = tf.math.log((P + eps) / (Q + eps))
    C = tf.math.reduce_sum(P * C)
    return C

# %% [markdown]
# ### Train model

# %%
from tensorflow.keras.layers import Dense
model = Sequential()
model.add(Dense(500, activation='relu', input_shape=(X_train_flat.shape[1],)))
model.add(Dense(500, activation='relu'))
model.add(Dense(2000, activation='relu'))
model.add(Dense(2))

# %%
sgd = SGD(lr=0.1)

# %%
# %time model.compile(loss=tsne, optimizer=sgd)
# Out:
# CPU times: user 82.1 ms, sys: 144 ms, total: 226 ms
# Wall time: 226 ms

# %%
Y_train_tsne = P.reshape(X_train.shape[0], -1)

# %%
Y_train_tsne.shape
# Out:
# (50000, 5000)

# %%
history = model.fit(X_train, Y_train_tsne, batch_size=batch_size, shuffle=False, nb_epoch=1000)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0719 18:40:27.337862 139792630003520 training.py:792] The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 50000 samples
# Epoch 1/1000
# 50000/50000 [==============================] - 7s 138us/sample - loss: 4.7117
# Epoch 2/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 4.1507
# Epoch 3/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 3.7544
# Epoch 4/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 3.5936
# Epoch 5/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 3.5143
# Epoch 6/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 3.4620
# Epoch 7/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 3.4239
# Epoch 8/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 3.3936
# Epoch 9/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 3.3677
# Epoch 10/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 3.3443
# Epoch 11/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 3.3221
# Epoch 12/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 3.3007
# Epoch 13/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 3.2797
# Epoch 14/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 3.2589
# Epoch 15/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 3.2384
# Epoch 16/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 3.2181
# Epoch 17/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 3.1982
# Epoch 18/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 3.1787
# Epoch 19/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 3.1596
# Epoch 20/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 3.1410
# Epoch 21/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 3.1227
# Epoch 22/1000
# 50000/50000 [==============================] - 1s 14us/sample - loss: 3.1048
# Epoch 23/1000
# 50000/50000 [==============================] - 1s 24us/sample - loss: 3.0872
# Epoch 24/1000
# 50000/50000 [==============================] - 1s 14us/sample - loss: 3.0699
# Epoch 25/1000
# 50000/50000 [==============================] - 1s 25us/sample - loss: 3.0528
# Epoch 26/1000
# 50000/50000 [==============================] - 1s 17us/sample - loss: 3.0360
# Epoch 27/1000
# 50000/50000 [==============================] - 1s 21us/sample - loss: 3.0195
# Epoch 28/1000
# 50000/50000 [==============================] - 1s 15us/sample - loss: 3.0036
# Epoch 29/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.9883
# Epoch 30/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.9736
# Epoch 31/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.9593
# Epoch 32/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.9454
# Epoch 33/1000
# 50000/50000 [==============================] - 1s 15us/sample - loss: 2.9319
# Epoch 34/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.9187
# Epoch 35/1000
# 50000/50000 [==============================] - 1s 15us/sample - loss: 2.9058
# Epoch 36/1000
# 50000/50000 [==============================] - 1s 25us/sample - loss: 2.8932
# Epoch 37/1000
# 50000/50000 [==============================] - 1s 19us/sample - loss: 2.8810
# Epoch 38/1000
# 50000/50000 [==============================] - 1s 25us/sample - loss: 2.8691
# Epoch 39/1000
# 50000/50000 [==============================] - 1s 14us/sample - loss: 2.8575
# Epoch 40/1000
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.8462
# Epoch 41/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.8352
# Epoch 42/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.8245
# Epoch 43/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.8141
# Epoch 44/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.8039
# Epoch 45/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.7939
# Epoch 46/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.7842
# Epoch 47/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.7746
# Epoch 48/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.7653
# Epoch 49/1000
# 50000/50000 [==============================] - 1s 15us/sample - loss: 2.7562
# Epoch 50/1000
# 50000/50000 [==============================] - 1s 14us/sample - loss: 2.7473
# Epoch 51/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.7386
# Epoch 52/1000
# 50000/50000 [==============================] - 1s 21us/sample - loss: 2.7300
# Epoch 53/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.7216
# Epoch 54/1000
# 50000/50000 [==============================] - 1s 19us/sample - loss: 2.7134
# Epoch 55/1000
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.7054
# Epoch 56/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.6975
# Epoch 57/1000
# 50000/50000 [==============================] - 1s 19us/sample - loss: 2.6898
# Epoch 58/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.6822
# Epoch 59/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.6748
# Epoch 60/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 2.6675
# Epoch 61/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.6604
# Epoch 62/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 2.6534
# Epoch 63/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.6465
# Epoch 64/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.6397
# Epoch 65/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.6330
# Epoch 66/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.6265
# Epoch 67/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.6200
# Epoch 68/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.6136
# Epoch 69/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.6074
# Epoch 70/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.6011
# Epoch 71/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.5950
# Epoch 72/1000
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.5890
# Epoch 73/1000
# 50000/50000 [==============================] - 1s 14us/sample - loss: 2.5830
# Epoch 74/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 2.5772
# Epoch 75/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.5715
# Epoch 76/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.5659
# Epoch 77/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.5603
# Epoch 78/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.5549
# Epoch 79/1000
# 50000/50000 [==============================] - 1s 18us/sample - loss: 2.5495
# Epoch 80/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.5442
# Epoch 81/1000
# 50000/50000 [==============================] - 1s 14us/sample - loss: 2.5390
# Epoch 82/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.5340
# Epoch 83/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.5290
# Epoch 84/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.5240
# Epoch 85/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.5192
# Epoch 86/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.5144
# Epoch 87/1000
# 50000/50000 [==============================] - 1s 14us/sample - loss: 2.5097
# Epoch 88/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.5051
# Epoch 89/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.5005
# Epoch 90/1000
# 50000/50000 [==============================] - 1s 15us/sample - loss: 2.4961
# Epoch 91/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4917
# Epoch 92/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4873
# Epoch 93/1000
# 50000/50000 [==============================] - 1s 15us/sample - loss: 2.4829
# Epoch 94/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4786
# Epoch 95/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 2.4746
# Epoch 96/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.4708
# Epoch 97/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4666
# Epoch 98/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4621
# Epoch 99/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4589
# Epoch 100/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 2.4546
# Epoch 101/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4506
# Epoch 102/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4501
# Epoch 103/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4457
# Epoch 104/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4390
# Epoch 105/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 2.4373
# Epoch 106/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4355
# Epoch 107/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4287
# Epoch 108/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 2.4265
# Epoch 109/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4297
# Epoch 110/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4217
# Epoch 111/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4137
# Epoch 112/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4169
# Epoch 113/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4129
# Epoch 114/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 2.4043
# Epoch 115/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.4051
# Epoch 116/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 2.4096
# Epoch 117/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.3979
# Epoch 118/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.3908
# Epoch 119/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 2.3978
# Epoch 120/1000
# 50000/50000 [==============================] - 1s 11us/sample - loss: 2.3901
# Epoch 121/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.3812
# Epoch 122/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.3859
# Epoch 123/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.3891
# Epoch 124/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 2.
1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8070
# Epoch 900/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8079
# Epoch 901/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8085
# Epoch 902/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8092
# Epoch 903/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8090
# Epoch 904/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8129
# Epoch 905/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8095
# Epoch 906/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8020
# Epoch 907/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8084
# Epoch 908/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8072
# Epoch 909/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8069
# Epoch 910/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8077
# Epoch 911/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.8078
# Epoch 912/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8039
# Epoch 913/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.8005
# Epoch 914/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7990
# Epoch 915/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8028
# Epoch 916/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8014
# Epoch 917/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8038
# Epoch 918/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8073
# Epoch 919/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7995
# Epoch 920/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8014
# Epoch 921/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8018
# Epoch 922/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8087
# Epoch 923/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8007
# Epoch 924/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8046
# Epoch 925/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8033
# Epoch 926/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8009
# Epoch 927/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8083
# Epoch 928/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8020
# Epoch 929/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8011
# Epoch 930/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8072
# Epoch 931/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8062
# Epoch 932/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8017
# Epoch 933/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8021
# Epoch 934/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7975
# Epoch 935/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7950
# Epoch 936/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8064
# Epoch 937/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7955
# Epoch 938/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.8020
# Epoch 939/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7930
# Epoch 940/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7938
# Epoch 941/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7977
# Epoch 942/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7934
# Epoch 943/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7999
# Epoch 944/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.8022
# Epoch 945/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8051
# Epoch 946/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7976
# Epoch 947/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7971
# Epoch 948/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7920
# Epoch 949/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7938
# Epoch 950/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7928
# Epoch 951/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7924
# Epoch 952/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7877
# Epoch 953/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7891
# Epoch 954/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7956
# Epoch 955/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7935
# Epoch 956/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7936
# Epoch 957/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7869
# Epoch 958/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7948
# Epoch 959/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7957
# Epoch 960/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7962
# Epoch 961/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.8047
# Epoch 962/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7884
# Epoch 963/1000
# 50000/50000 [==============================] - 1s 14us/sample - loss: 1.7962
# Epoch 964/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7942
# Epoch 965/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7956
# Epoch 966/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7910
# Epoch 967/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7893
# Epoch 968/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7956
# Epoch 969/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7879
# Epoch 970/1000
# 50000/50000 [==============================] - 1s 14us/sample - loss: 1.7932
# Epoch 971/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7911
# Epoch 972/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7902
# Epoch 973/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7953
# Epoch 974/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7928
# Epoch 975/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7914
# Epoch 976/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7905
# Epoch 977/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7823
# Epoch 978/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7921
# Epoch 979/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7875
# Epoch 980/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7884
# Epoch 981/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7837
# Epoch 982/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7901
# Epoch 983/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7874
# Epoch 984/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7834
# Epoch 985/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7887
# Epoch 986/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7867
# Epoch 987/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7879
# Epoch 988/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7945
# Epoch 989/1000
# 50000/50000 [==============================] - 1s 14us/sample - loss: 1.7860
# Epoch 990/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7953
# Epoch 991/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7874
# Epoch 992/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7841
# Epoch 993/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7967
# Epoch 994/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7845
# Epoch 995/1000
# 50000/50000 [==============================] - 1s 14us/sample - loss: 1.7909
# Epoch 996/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7803
# Epoch 997/1000
# 50000/50000 [==============================] - 1s 13us/sample - loss: 1.7879
# Epoch 998/1000
# 50000/50000 [==============================] - 1s 15us/sample - loss: 1.7893
# Epoch 999/1000
# 50000/50000 [==============================] - 1s 12us/sample - loss: 1.7850
# Epoch 1000/1000
# 50000/50000 [==============================] - 1s 14us/sample - loss: 1.7900

# %%
plt.plot(history.history['loss'])

# %%
z = model.predict(X_train_flat)

# %%
plt.figure(figsize=(10,10))
plt.scatter(z[:,0], z[:,1], s=1, c = Y_train, cmap = plt.cm.tab10)
