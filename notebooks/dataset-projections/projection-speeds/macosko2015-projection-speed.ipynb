# %% [markdown]
# #### Outline
# - for each dataset:
#     - load dataset;
#     - for each network:
#         - load network
#         - project 1000 test dataset samples
#         - save to metric dataframe

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=''
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=''

# %%
import numpy as np
import pickle
import pandas as pd
import time
from umap import UMAP

# %%
from tfumap.umap import tfUMAP
import tensorflow as tf
from sklearn.decomposition import PCA
from openTSNE import TSNE
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
from tqdm.autonotebook import tqdm

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

# %%
output_dir = MODEL_DIR/'projections'

# %%
projection_speeds = pd.DataFrame(columns = ['method_', 'dimensions', 'dataset', 'speed'])

# %% [markdown]
# ### macosko2015

# %%
dataset = 'macosko2015'
dims = [50]

# %% [markdown]
# ##### load dataset

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

#dataset_address = 'http://file.biolab.si/opentsne/macosko_2015.pkl.gz'
# https://opentsne.readthedocs.io/en/latest/examples/01_simple_usage/01_simple_usage.html
# also see https://github.com/berenslab/rna-seq-tsne/blob/master/umi-datasets.ipynb

import gzip
import pickle

with gzip.open(DATA_DIR / 'macosko_2015.pkl.gz', "rb") as f:
    data = pickle.load(f)

x = data["pca_50"]
y = data["CellType1"].astype(str)

print("Data set contains %d samples with %d features" % x.shape)

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=.1, random_state=42)

np.shape(X_train)

n_valid = 10000
X_valid = X_train[-n_valid:]
Y_valid = Y_train[-n_valid:]
X_train = X_train[:-n_valid]
Y_train = Y_train[:-n_valid]

X_train_flat = X_train

from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

Y_train = enc.fit_transform([[i] for i in Y_train]).flatten()
# Out:
# Data set contains 44808 samples with 50 features

# %%
X_train_flat = X_train
X_test_flat = X_test

# %%
X_train_flat.shape
# Out:
# (30327, 50)

# %%
X_test_flat.shape
# Out:
# (4481, 50)

# %% [markdown]
# #### Network

# %% [markdown]
# ##### 2 dims

# %%
load_loc = output_dir / dataset / 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['network', 2, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.15242197387851775
# seconds:  0.06260958802886307
# seconds:  0.06105130212381482
# seconds:  0.0655538928695023
# seconds:  0.06511583109386265
# seconds:  0.060955140041187406
# seconds:  0.06108091305941343
# seconds:  0.061254137894138694
# seconds:  0.06611824012361467
# seconds:  0.061310650082305074

# %%
##### Network CPU

with tf.device('/CPU:0'):
    n_repeats = 10
    times = []
    for i in tqdm(range(n_repeats)):
        start_time = time.monotonic()
        embedder.transform(X_test_flat);
        end_time = time.monotonic()
        print('seconds: ', end_time - start_time)
        times.append(end_time - start_time)
        projection_speeds.loc[len(projection_speeds)] = ['network-cpu', 2, dataset, end_time - start_time]
# Out:
#    method_ dimensions      dataset     speed
# 0  network          2  macosko2015  0.152422
# 1  network          2  macosko2015  0.062610
# 2  network          2  macosko2015  0.061051
# 3  network          2  macosko2015  0.065554
# 4  network          2  macosko2015  0.065116
# 5  network          2  macosko2015  0.060955
# 6  network          2  macosko2015  0.061081
# 7  network          2  macosko2015  0.061254
# 8  network          2  macosko2015  0.066118
# 9  network          2  macosko2015  0.061311

# %% [markdown]
# ##### 64 dims

# %%
load_loc = output_dir / dataset /"64"/ 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['network', 64, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.15086891991086304
# seconds:  0.07734775496646762
# seconds:  0.07673786813393235
# seconds:  0.08067622198723257
# seconds:  0.08221768704243004
# seconds:  0.08005523402243853
# seconds:  0.07999808294698596
# seconds:  0.07620651205070317
# seconds:  0.0768652621190995
# seconds:  0.07691968302242458

# %%
##### Network CPU

with tf.device('/CPU:0'):
    n_repeats = 10
    times = []
    for i in tqdm(range(n_repeats)):
        start_time = time.monotonic()
        embedder.transform(X_test_flat);
        end_time = time.monotonic()
        print('seconds: ', end_time - start_time)
        times.append(end_time - start_time)
        projection_speeds.loc[len(projection_speeds)] = ['network-cpu', 64, dataset, end_time - start_time]
# Out:
#     method_ dimensions      dataset     speed
# 0   network          2  macosko2015  0.152422
# 1   network          2  macosko2015  0.062610
# 2   network          2  macosko2015  0.061051
# 3   network          2  macosko2015  0.065554
# 4   network          2  macosko2015  0.065116
# 5   network          2  macosko2015  0.060955
# 6   network          2  macosko2015  0.061081
# 7   network          2  macosko2015  0.061254
# 8   network          2  macosko2015  0.066118
# 9   network          2  macosko2015  0.061311
# 10  network         64  macosko2015  0.150869
# 11  network         64  macosko2015  0.077348
# 12  network         64  macosko2015  0.076738
# 13  network         64  macosko2015  0.080676
# 14  network         64  macosko2015  0.082218
# 15  network         64  macosko2015  0.080055
# 16  network         64  macosko2015  0.079998
# 17  network         64  macosko2015  0.076207
# 18  network         64  macosko2015  0.076865
# 19  network         64  macosko2015  0.076920

# %% [markdown]
# #### UMAP-learn

# %% [markdown]
# ##### 2 dims

# %%
embedder = UMAP(n_components = 2, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Wed Jul 15 15:37:51 2020 Finding Nearest Neighbors
# Wed Jul 15 15:37:51 2020 Building RP forest with 14 trees
# Wed Jul 15 15:37:52 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# Wed Jul 15 15:38:01 2020 Finished Nearest Neighbor Search
# Wed Jul 15 15:38:04 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Wed Jul 15 15:38:37 2020 Finished embedding

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['umap-learn', 2, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  15.734487792942673
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.392539114924148
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.900813676882535
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.8757046640384942
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.355285373982042
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.8441448758821934
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.624291585991159
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.557013042969629
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.854517310159281
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.626427612034604

# %%
projection_speeds
# Out:
#        method_ dimensions      dataset      speed
# 0      network          2  macosko2015   0.152422
# 1      network          2  macosko2015   0.062610
# 2      network          2  macosko2015   0.061051
# 3      network          2  macosko2015   0.065554
# 4      network          2  macosko2015   0.065116
# 5      network          2  macosko2015   0.060955
# 6      network          2  macosko2015   0.061081
# 7      network          2  macosko2015   0.061254
# 8      network          2  macosko2015   0.066118
# 9      network          2  macosko2015   0.061311
# 10     network         64  macosko2015   0.150869
# 11     network         64  macosko2015   0.077348
# 12     network         64  macosko2015   0.076738
# 13     network         64  macosko2015   0.080676
# 14     network         64  macosko2015   0.082218
# 15     network         64  macosko2015   0.080055
# 16     network         64  macosko2015   0.079998
# 17     network         64  macosko2015   0.076207
# 18     network         64  macosko2015   0.076865
# 19     network         64  macosko2015   0.076920
# 20  umap-learn          2  macosko2015  15.734488
# 21  umap-learn          2  macosko2015   4.392539
# 22  umap-learn          2  macosko2015   3.900814
# 23  umap-learn          2  macosko2015   3.875705
# 24  umap-learn          2  macosko2015   4.355285
# 25  umap-learn          2  macosko2015   3.844145
# 26  umap-learn          2  macosko2015   3.624292
# 27  umap-learn          2  macosko2015   4.557013
# 28  umap-learn          2  macosko2015   3.854517
# 29  umap-learn          2  macosko2015   3.626428

# %% [markdown]
# ##### 64 dims

# %%
embedder = UMAP(n_components = 64, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, n_components=64, verbose=True)
# Construct fuzzy simplicial set
# Wed Jul 15 15:39:29 2020 Finding Nearest Neighbors
# Wed Jul 15 15:39:29 2020 Building RP forest with 14 trees
# Wed Jul 15 15:39:29 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# Wed Jul 15 15:39:31 2020 Finished Nearest Neighbor Search
# Wed Jul 15 15:39:31 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Wed Jul 15 15:40:08 2020 Finished embedding

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['umap-learn', 64, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.335240128915757
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.712620828999206
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.208247289992869
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.644822061993182
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.946813771966845
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.140890401089564
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.7006016271188855
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.006208311999217
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  3.9042201570700854
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.977823175955564

# %%
projection_speeds
# Out:
#        method_ dimensions      dataset      speed
# 0      network          2  macosko2015   0.152422
# 1      network          2  macosko2015   0.062610
# 2      network          2  macosko2015   0.061051
# 3      network          2  macosko2015   0.065554
# 4      network          2  macosko2015   0.065116
# 5      network          2  macosko2015   0.060955
# 6      network          2  macosko2015   0.061081
# 7      network          2  macosko2015   0.061254
# 8      network          2  macosko2015   0.066118
# 9      network          2  macosko2015   0.061311
# 10     network         64  macosko2015   0.150869
# 11     network         64  macosko2015   0.077348
# 12     network         64  macosko2015   0.076738
# 13     network         64  macosko2015   0.080676
# 14     network         64  macosko2015   0.082218
# 15     network         64  macosko2015   0.080055
# 16     network         64  macosko2015   0.079998
# 17     network         64  macosko2015   0.076207
# 18     network         64  macosko2015   0.076865
# 19     network         64  macosko2015   0.076920
# 20  umap-learn          2  macosko2015  15.734488
# 21  umap-learn          2  macosko2015   4.392539
# 22  umap-learn          2  macosko2015   3.900814
# 23  umap-learn          2  macosko2015   3.875705
# 24  umap-learn          2  macosko2015   4.355285
# 25  umap-learn          2  macosko2015   3.844145
# 26  umap-learn          2  macosko2015   3.624292
# 27  umap-learn          2  macosko2015   4.557013
# 28  umap-learn          2  macosko2015   3.854517
# 29  umap-learn          2  macosko2015   3.626428
# 30  umap-learn         64  macosko2015   5.335240
# 31  umap-learn         64  macosko2015   4.712621
# 32  umap-learn         64  macosko2015   4.208247
# 33  umap-learn         64  macosko2015   4.644822
# 34  umap-learn         64  macosko2015   4.946814
# 35  umap-learn         64  macosko2015   4.140890
# 36  umap-learn         64  macosko2015   4.700602
# 37  umap-learn         64  macosko2015   5.006208
# 38  umap-learn         64  macosko2015   3.904220
# 39  umap-learn         64  macosko2015   4.977823

# %% [markdown]
# #### PCA

# %% [markdown]
# ##### 2 dims

# %%
pca = PCA(n_components=2)
z = pca.fit_transform(X_train_flat)

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    pca.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['pca', 2, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.0010271200444549322
# seconds:  0.0009383170399814844
# seconds:  0.0009344569407403469
# seconds:  0.0009289770387113094
# seconds:  0.0009487872011959553
# seconds:  0.0009352071210741997
# seconds:  0.0009525769855827093
# seconds:  0.0009377868846058846
# seconds:  0.0009323679842054844
# seconds:  0.0009314969647675753

# %%
projection_speeds
# Out:
#        method_ dimensions      dataset      speed
# 0      network          2  macosko2015   0.152422
# 1      network          2  macosko2015   0.062610
# 2      network          2  macosko2015   0.061051
# 3      network          2  macosko2015   0.065554
# 4      network          2  macosko2015   0.065116
# 5      network          2  macosko2015   0.060955
# 6      network          2  macosko2015   0.061081
# 7      network          2  macosko2015   0.061254
# 8      network          2  macosko2015   0.066118
# 9      network          2  macosko2015   0.061311
# 10     network         64  macosko2015   0.150869
# 11     network         64  macosko2015   0.077348
# 12     network         64  macosko2015   0.076738
# 13     network         64  macosko2015   0.080676
# 14     network         64  macosko2015   0.082218
# 15     network         64  macosko2015   0.080055
# 16     network         64  macosko2015   0.079998
# 17     network         64  macosko2015   0.076207
# 18     network         64  macosko2015   0.076865
# 19     network         64  macosko2015   0.076920
# 20  umap-learn          2  macosko2015  15.734488
# 21  umap-learn          2  macosko2015   4.392539
# 22  umap-learn          2  macosko2015   3.900814
# 23  umap-learn          2  macosko2015   3.875705
# 24  umap-learn          2  macosko2015   4.355285
# 25  umap-learn          2  macosko2015   3.844145
# 26  umap-learn          2  macosko2015   3.624292
# 27  umap-learn          2  macosko2015   4.557013
# 28  umap-learn          2  macosko2015   3.854517
# 29  umap-learn          2  macosko2015   3.626428
# 30  umap-learn         64  macosko2015   5.335240
# 31  umap-learn         64  macosko2015   4.712621
# 32  umap-learn         64  macosko2015   4.208247
# 33  umap-learn         64  macosko2015   4.644822
# 34  umap-learn         64  macosko2015   4.946814
# 35  umap-learn         64  macosko2015   4.140890
# 36  umap-learn         64  macosko2015   4.700602
# 37  umap-learn         64  macosko2015   5.006208
# 38  umap-learn         64  macosko2015   3.904220
# 39  umap-learn         64  macosko2015   4.977823
# 40         pca          2  macosko2015   0.001027
# 41         pca          2  macosko2015   0.000938
# 42         pca          2  macosko2015   0.000934
# 43         pca          2  macosko2015   0.000929
# 44         pca          2  macosko2015   0.000949
# 45         pca          2  macosko2015   0.000935
# 46         pca          2  macosko2015   0.000953
# 47         pca          2  macosko2015   0.000938
# 48         pca          2  macosko2015   0.000932
# 49         pca          2  macosko2015   0.000931

# %% [markdown]
# ##### 64 dims

# %%
x_train_flat_padded = np.concatenate([X_train_flat, np.zeros((len(X_train_flat), 14))], axis=1)
X_test_flat_padded = np.concatenate([X_test_flat, np.zeros((len(X_test_flat), 14))], axis=1)

# %%
pca = PCA(n_components=64)
z = pca.fit_transform(x_train_flat_padded)

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    pca.transform(X_test_flat_padded);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['pca', 64, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.001996397040784359
# seconds:  0.0022262651473283768
# seconds:  0.0024269099812954664
# seconds:  0.0023763689678162336
# seconds:  0.002365178894251585
# seconds:  0.0024054499808698893
# seconds:  0.0023558679968118668
# seconds:  0.002367038046941161
# seconds:  0.0023865289986133575
# seconds:  0.002360638929530978

# %%
projection_speeds
# Out:
#        method_ dimensions      dataset      speed
# 0      network          2  macosko2015   0.152422
# 1      network          2  macosko2015   0.062610
# 2      network          2  macosko2015   0.061051
# 3      network          2  macosko2015   0.065554
# 4      network          2  macosko2015   0.065116
# 5      network          2  macosko2015   0.060955
# 6      network          2  macosko2015   0.061081
# 7      network          2  macosko2015   0.061254
# 8      network          2  macosko2015   0.066118
# 9      network          2  macosko2015   0.061311
# 10     network         64  macosko2015   0.150869
# 11     network         64  macosko2015   0.077348
# 12     network         64  macosko2015   0.076738
# 13     network         64  macosko2015   0.080676
# 14     network         64  macosko2015   0.082218
# 15     network         64  macosko2015   0.080055
# 16     network         64  macosko2015   0.079998
# 17     network         64  macosko2015   0.076207
# 18     network         64  macosko2015   0.076865
# 19     network         64  macosko2015   0.076920
# 20  umap-learn          2  macosko2015  15.734488
# 21  umap-learn          2  macosko2015   4.392539
# 22  umap-learn          2  macosko2015   3.900814
# 23  umap-learn          2  macosko2015   3.875705
# 24  umap-learn          2  macosko2015   4.355285
# 25  umap-learn          2  macosko2015   3.844145
# 26  umap-learn          2  macosko2015   3.624292
# 27  umap-learn          2  macosko2015   4.557013
# 28  umap-learn          2  macosko2015   3.854517
# 29  umap-learn          2  macosko2015   3.626428
# 30  umap-learn         64  macosko2015   5.335240
# 31  umap-learn         64  macosko2015   4.712621
# 32  umap-learn         64  macosko2015   4.208247
# 33  umap-learn         64  macosko2015   4.644822
# 34  umap-learn         64  macosko2015   4.946814
# 35  umap-learn         64  macosko2015   4.140890
# 36  umap-learn         64  macosko2015   4.700602
# 37  umap-learn         64  macosko2015   5.006208
# 38  umap-learn         64  macosko2015   3.904220
# 39  umap-learn         64  macosko2015   4.977823
# 40         pca          2  macosko2015   0.001027
# 41         pca          2  macosko2015   0.000938
# 42         pca          2  macosko2015   0.000934
# 43         pca          2  macosko2015   0.000929
# 44         pca          2  macosko2015   0.000949
# 45         pca          2  macosko2015   0.000935
# 46         pca          2  macosko2015   0.000953
# 47         pca          2  macosko2015   0.000938
# 48         pca          2  macosko2015   0.000932
# 49         pca          2  macosko2015   0.000931
# 50         pca         64  macosko2015   0.001996
# 51         pca         64  macosko2015   0.002226
# 52         pca         64  macosko2015   0.002427
# 53         pca         64  macosko2015   0.002376
# 54         pca         64  macosko2015   0.002365
# 55         pca         64  macosko2015   0.002405
# 56         pca         64  macosko2015   0.002356
# 57         pca         64  macosko2015   0.002367
# 58         pca         64  macosko2015   0.002387
# 59         pca         64  macosko2015   0.002361

# %% [markdown]
# #### TSNE

# %% [markdown]
# ##### 2 dims

# %%
tsne = TSNE(
    n_components = 2,
    n_jobs=32,
    verbose=True
)

# %%
embedding_train = tsne.fit(X_train_flat)
# Out:
# --------------------------------------------------------------------------------
# TSNE(n_jobs=32, neighbors=None, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#    --> Time elapsed: 9.73 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.32 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.08 seconds
# ===> Running optimization with exaggeration=12.00, lr=2527.25 for 250 iterations...
# Iteration   50, KL divergence 5.8146, 50 iterations in 1.2758 sec
# Iteration  100, KL divergence 5.2446, 50 iterations in 1.3230 sec
# Iteration  150, KL divergence 5.1509, 50 iterations in 1.3168 sec
# Iteration  200, KL divergence 5.1122, 50 iterations in 1.3505 sec
# Iteration  250, KL divergence 5.0914, 50 iterations in 1.3720 sec
#    --> Time elapsed: 6.64 seconds
# ===> Running optimization with exaggeration=1.00, lr=2527.25 for 500 iterations...
# Iteration   50, KL divergence 3.5878, 50 iterations in 1.4364 sec
# Iteration  100, KL divergence 3.1797, 50 iterations in 1.3553 sec
# Iteration  150, KL divergence 2.9765, 50 iterations in 1.5623 sec
# Iteration  200, KL divergence 2.8506, 50 iterations in 2.1569 sec
# Iteration  250, KL divergence 2.7646, 50 iterations in 3.1214 sec
# Iteration  300, KL divergence 2.7028, 50 iterations in 4.2507 sec
# Iteration  350, KL divergence 2.6569, 50 iterations in 5.2679 sec
# Iteration  400, KL divergence 2.6218, 50 iterations in 6.3771 sec
# Iteration  450, KL divergence 2.5944, 50 iterations in 7.2028 sec
# Iteration  500, KL divergence 2.5730, 50 iterations in 7.5450 sec
#    --> Time elapsed: 40.28 seconds

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedding_train.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['TSNE', 2, dataset, end_time - start_time]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.85 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83573.3050, 50 iterations in 0.1257 sec
# Iteration  100, KL divergence 83673.9513, 50 iterations in 0.1224 sec
# Iteration  150, KL divergence 83714.9859, 50 iterations in 0.1321 sec
# Iteration  200, KL divergence 83746.5617, 50 iterations in 0.1257 sec
# Iteration  250, KL divergence 83765.2234, 50 iterations in 0.1300 sec
#    --> Time elapsed: 0.64 seconds
# seconds:  2.302478270838037
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.98 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83573.3050, 50 iterations in 0.1396 sec
# Iteration  100, KL divergence 83673.9513, 50 iterations in 0.1474 sec
# Iteration  150, KL divergence 83714.9859, 50 iterations in 0.1398 sec
# Iteration  200, KL divergence 83746.5617, 50 iterations in 0.1325 sec
# Iteration  250, KL divergence 83765.2234, 50 iterations in 0.1449 sec
#    --> Time elapsed: 0.70 seconds
# seconds:  1.7149106450378895
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.95 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83573.3050, 50 iterations in 0.1381 sec
# Iteration  100, KL divergence 83673.9513, 50 iterations in 0.1370 sec
# Iteration  150, KL divergence 83714.9859, 50 iterations in 0.1391 sec
# Iteration  200, KL divergence 83746.5617, 50 iterations in 0.1329 sec
# Iteration  250, KL divergence 83765.2234, 50 iterations in 0.1497 sec
#    --> Time elapsed: 0.70 seconds
# seconds:  1.6796291819773614
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.98 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83573.3050, 50 iterations in 0.1478 sec
# Iteration  100, KL divergence 83673.9513, 50 iterations in 0.1351 sec
# Iteration  150, KL divergence 83714.9859, 50 iterations in 0.1395 sec
# Iteration  200, KL divergence 83746.5617, 50 iterations in 0.1347 sec
# Iteration  250, KL divergence 83765.2234, 50 iterations in 0.1328 sec
#    --> Time elapsed: 0.69 seconds
# seconds:  1.7065112399868667
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.95 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83573.3050, 50 iterations in 0.1391 sec
# Iteration  100, KL divergence 83673.9513, 50 iterations in 0.1382 sec
# Iteration  150, KL divergence 83714.9859, 50 iterations in 0.1450 sec
# Iteration  200, KL divergence 83746.5617, 50 iterations in 0.1398 sec
# Iteration  250, KL divergence 83765.2234, 50 iterations in 0.1353 sec
#    --> Time elapsed: 0.70 seconds
# seconds:  1.6797914458438754
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.85 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83573.3050, 50 iterations in 0.1474 sec
# Iteration  100, KL divergence 83673.9513, 50 iterations in 0.1368 sec
# Iteration  150, KL divergence 83714.9859, 50 iterations in 0.1363 sec
# Iteration  200, KL divergence 83746.5617, 50 iterations in 0.1517 sec
# Iteration  250, KL divergence 83765.2234, 50 iterations in 0.1536 sec
#    --> Time elapsed: 0.73 seconds
# seconds:  1.605844063917175
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.95 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83573.3050, 50 iterations in 0.1421 sec
# Iteration  100, KL divergence 83673.9513, 50 iterations in 0.1406 sec
# Iteration  150, KL divergence 83714.9859, 50 iterations in 0.1350 sec
# Iteration  200, KL divergence 83746.5617, 50 iterations in 0.1394 sec
# Iteration  250, KL divergence 83765.2234, 50 iterations in 0.1493 sec
#    --> Time elapsed: 0.71 seconds
# seconds:  1.692428849870339
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.97 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83573.3050, 50 iterations in 0.1418 sec
# Iteration  100, KL divergence 83673.9513, 50 iterations in 0.1427 sec
# Iteration  150, KL divergence 83714.9859, 50 iterations in 0.1489 sec
# Iteration  200, KL divergence 83746.5617, 50 iterations in 0.1388 sec
# Iteration  250, KL divergence 83765.2234, 50 iterations in 0.1416 sec
#    --> Time elapsed: 0.71 seconds
# seconds:  1.7144486769102514
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.86 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83573.3050, 50 iterations in 0.1580 sec
# Iteration  100, KL divergence 83673.9513, 50 iterations in 0.1379 sec
# Iteration  150, KL divergence 83714.9859, 50 iterations in 0.1352 sec
# Iteration  200, KL divergence 83746.5617, 50 iterations in 0.1702 sec
# Iteration  250, KL divergence 83765.2234, 50 iterations in 0.1601 sec
#    --> Time elapsed: 0.76 seconds
# seconds:  1.649606399005279
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.93 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 83573.3050, 50 iterations in 0.1409 sec
# Iteration  100, KL divergence 83673.9513, 50 iterations in 0.1382 sec
# Iteration  150, KL divergence 83714.9859, 50 iterations in 0.1756 sec
# Iteration  200, KL divergence 83746.5617, 50 iterations in 0.1412 sec
# Iteration  250, KL divergence 83765.2234, 50 iterations in 0.1371 sec
#    --> Time elapsed: 0.73 seconds
# seconds:  1.7064994850661606

# %%
projection_speeds
# Out:
#     method_ dimensions      dataset     speed
# 0   network          2  macosko2015  0.152422
# 1   network          2  macosko2015  0.062610
# 2   network          2  macosko2015  0.061051
# 3   network          2  macosko2015  0.065554
# 4   network          2  macosko2015  0.065116
# ..      ...        ...          ...       ...
# 65     TSNE          2  macosko2015  1.605844
# 66     TSNE          2  macosko2015  1.692429
# 67     TSNE          2  macosko2015  1.714449
# 68     TSNE          2  macosko2015  1.649606
# 69     TSNE          2  macosko2015  1.706499
#
# [70 rows x 4 columns]

# %% [markdown]
# ### Save

# %%
save_loc = DATA_DIR / 'projection_speeds' / (dataset + '.pickle')
ensure_dir(save_loc)
projection_speeds.to_pickle(save_loc)
