# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
print(gpu_devices)
tf.keras.backend.clear_session()
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### dataset information

# %%
from datetime import datetime

dataset = "cifar10"
dims = (32, 32, 3)
umap_prop = 1.0
num_classes = 10
PROJECTION_DIMS = 1024
labels_per_class = 'full' # full
batch_size = 128
datestring = datetime.now().strftime("%Y_%m_%d_%H_%M_%S_%f")
datestring = (
    str(dataset)
    + "_"
    + str(umap_prop)
    + "_"
    + str(PROJECTION_DIMS)
    + "_"
    + str(labels_per_class)
    + "____"
    + datestring 
    + '_baseline'
)
print(datestring)
# Out:
# cifar10_1.0_1024_full____2020_08_09_14_20_06_126620_baseline

# %% [markdown]
# ### Load packages

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from IPython import display
import pandas as pd
import umap
import copy
import os, tempfile
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### Load dataset

# %%
from tfumap.load_datasets import load_CIFAR10, mask_labels
X_train, X_test, X_valid, Y_train, Y_test, Y_valid = load_CIFAR10(flatten=False)
X_train.shape
# Out:
# (40000, 32, 32, 3)

# %%
if labels_per_class == "full":
    X_labeled = X_train
    Y_masked = Y_labeled = Y_train
else:
    X_labeled, Y_labeled, Y_masked = mask_labels(
        X_train, Y_train, labels_per_class=labels_per_class
    )

# %% [markdown]
# ### Build network

# %%
from tensorflow.keras import datasets, layers, models
from tensorflow_addons.layers import WeightNormalization

def conv_block(filts, name, kernel_size = (3, 3), padding = "same", **kwargs):
    return WeightNormalization(
        layers.Conv2D(
            filts, kernel_size, activation=None, padding=padding, **kwargs
        ),
        name="conv"+name,
    )
#CNN13
#See: 
#https://github.com/vikasverma1077/ICT/blob/master/networks/lenet.py
#https://github.com/brain-research/realistic-ssl-evaluation

# %%
lr_alpha = 0.1
dropout_rate = 0.5
num_classes = 10
input_shape = (32, 32, 3)
model = models.Sequential()
model.add(tf.keras.Input(shape=input_shape))
### conv1a
name = '1a'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1b
name = '1b'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1c
name = '1c'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp1"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop1"))

### conv2a
name = '2a'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha))

### conv2b
name = '2b'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv2c
name = '2c'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp2"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop2"))

### conv3a
name = '3a'
model.add(conv_block(name = name, filts = 512, kernel_size = (3,3), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3b
name = '3b'
model.add(conv_block(name = name, filts = 256, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3c
name = '3c'
model.add(conv_block(name = name, filts = 128, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.AveragePooling2D(pool_size=(6, 6), strides=2, padding='valid'))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation=None, name='z'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc1'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc2'))
model.add(WeightNormalization(layers.Dense(num_classes, activation=None)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1a (WeightNormalization) (None, 32, 32, 128)       7297
# _________________________________________________________________
# bn1a (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1a (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1b (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1b (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1b (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1c (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1c (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1c (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# mp1 (MaxPooling2D)           (None, 16, 16, 128)       0
# _________________________________________________________________
# drop1 (Dropout)              (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2a (WeightNormalization) (None, 16, 16, 256)       590593
# _________________________________________________________________
# bn2a (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2b (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2b (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2b (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2c (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2c (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2c (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# mp2 (MaxPooling2D)           (None, 8, 8, 256)         0
# _________________________________________________________________
# drop2 (Dropout)              (None, 8, 8, 256)         0
# _________________________________________________________________
# conv3a (WeightNormalization) (None, 6, 6, 512)         2360833
# _________________________________________________________________
# bn3a (BatchNormalization)    (None, 6, 6, 512)         2048
# _________________________________________________________________
# lrelu3a (LeakyReLU)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv3b (WeightNormalization) (None, 6, 6, 256)         262913
# _________________________________________________________________
# bn3b (BatchNormalization)    (None, 6, 6, 256)         1024
# _________________________________________________________________
# lrelu3b (LeakyReLU)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv3c (WeightNormalization) (None, 6, 6, 128)         65921
# _________________________________________________________________
# bn3c (BatchNormalization)    (None, 6, 6, 128)         512
# _________________________________________________________________
# lrelu3c (LeakyReLU)          (None, 6, 6, 128)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# z (Dense)                    (None, 256)               33024
# _________________________________________________________________
# weight_normalization (Weight (None, 256)               131841
# _________________________________________________________________
# lrelufc1 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_1 (Weig (None, 256)               131841
# _________________________________________________________________
# lrelufc2 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_2 (Weig (None, 10)                5151
# =================================================================
# Total params: 6,549,034
# Trainable params: 3,292,308
# Non-trainable params: 3,256,726
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', min_delta=0, patience=20, verbose=0, mode='auto',
    baseline=None, restore_best_weights=False
)

# %%
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)

# %%
model.compile(tf.keras.optimizers.Adam(1e-4), loss = loss, metrics=['accuracy'])

# %%
Y_valid_one_hot = tf.keras.backend.one_hot(
    Y_valid, num_classes
)

# %%
Y_labeled_one_hot = tf.keras.backend.one_hot(
    Y_labeled, num_classes
)

# %%
history = model.fit(
    X_labeled,
    Y_labeled_one_hot,
    batch_size=batch_size,
    epochs=250,
    validation_data=(X_valid, Y_valid_one_hot),
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/250
# 313/313 [==============================] - 16s 52ms/step - loss: 1.9662 - accuracy: 0.3861 - val_loss: 2.3848 - val_accuracy: 0.3744
# Epoch 2/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.6812 - accuracy: 0.5440 - val_loss: 1.9086 - val_accuracy: 0.4564
# Epoch 3/250
# 313/313 [==============================] - 16s 50ms/step - loss: 1.5670 - accuracy: 0.6133 - val_loss: 1.6605 - val_accuracy: 0.5799
# Epoch 4/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.4894 - accuracy: 0.6604 - val_loss: 1.5412 - val_accuracy: 0.6542
# Epoch 5/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.4272 - accuracy: 0.6989 - val_loss: 1.7302 - val_accuracy: 0.5579
# Epoch 6/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.3808 - accuracy: 0.7256 - val_loss: 1.4774 - val_accuracy: 0.6808
# Epoch 7/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.3456 - accuracy: 0.7466 - val_loss: 1.3649 - val_accuracy: 0.7457
# Epoch 8/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.3103 - accuracy: 0.7669 - val_loss: 1.4025 - val_accuracy: 0.7235
# Epoch 9/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.2849 - accuracy: 0.7815 - val_loss: 1.3184 - val_accuracy: 0.7705
# Epoch 10/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.2597 - accuracy: 0.7961 - val_loss: 1.2944 - val_accuracy: 0.7859
# Epoch 11/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.2391 - accuracy: 0.8092 - val_loss: 1.3500 - val_accuracy: 0.7573
# Epoch 12/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.2227 - accuracy: 0.8177 - val_loss: 1.3201 - val_accuracy: 0.7661
# Epoch 13/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.2062 - accuracy: 0.8268 - val_loss: 1.3376 - val_accuracy: 0.7563
# Epoch 14/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.1895 - accuracy: 0.8362 - val_loss: 1.2647 - val_accuracy: 0.8005
# Epoch 15/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.1737 - accuracy: 0.8458 - val_loss: 1.3092 - val_accuracy: 0.7718
# Epoch 16/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.1608 - accuracy: 0.8539 - val_loss: 1.2607 - val_accuracy: 0.8024
# Epoch 17/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.1441 - accuracy: 0.8626 - val_loss: 1.3110 - val_accuracy: 0.7722
# Epoch 18/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.1335 - accuracy: 0.8677 - val_loss: 1.2600 - val_accuracy: 0.8039
# Epoch 19/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.1254 - accuracy: 0.8725 - val_loss: 1.2315 - val_accuracy: 0.8127
# Epoch 20/250
# 313/313 [==============================] - 16s 51ms/step - loss: 1.1124 - accuracy: 0.8786 - val_loss: 1.2744 - val_accuracy: 0.7955
# Epoch 21/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.1018 - accuracy: 0.8849 - val_loss: 1.1819 - val_accuracy: 0.8458
# Epoch 22/250
# 313/313 [==============================] - 16s 51ms/step - loss: 1.0862 - accuracy: 0.8932 - val_loss: 1.2347 - val_accuracy: 0.8164
# Epoch 23/250
# 313/313 [==============================] - 17s 53ms/step - loss: 1.0828 - accuracy: 0.8946 - val_loss: 1.1866 - val_accuracy: 0.8428
# Epoch 24/250
# 313/313 [==============================] - 17s 53ms/step - loss: 1.0714 - accuracy: 0.9018 - val_loss: 1.2115 - val_accuracy: 0.8227
# Epoch 25/250
# 313/313 [==============================] - 19s 60ms/step - loss: 1.0624 - accuracy: 0.9070 - val_loss: 1.1818 - val_accuracy: 0.8416
# Epoch 26/250
# 313/313 [==============================] - 17s 56ms/step - loss: 1.0569 - accuracy: 0.9088 - val_loss: 1.1822 - val_accuracy: 0.8443
# Epoch 27/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.0483 - accuracy: 0.9143 - val_loss: 1.1892 - val_accuracy: 0.8409
# Epoch 28/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.0382 - accuracy: 0.9178 - val_loss: 1.1567 - val_accuracy: 0.8506
# Epoch 29/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.0350 - accuracy: 0.9192 - val_loss: 1.1638 - val_accuracy: 0.8506
# Epoch 30/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.0257 - accuracy: 0.9257 - val_loss: 1.1421 - val_accuracy: 0.8646
# Epoch 31/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.0200 - accuracy: 0.9280 - val_loss: 1.1556 - val_accuracy: 0.8586
# Epoch 32/250
# 313/313 [==============================] - 16s 50ms/step - loss: 1.0121 - accuracy: 0.9315 - val_loss: 1.1863 - val_accuracy: 0.8417
# Epoch 33/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.0084 - accuracy: 0.9341 - val_loss: 1.1595 - val_accuracy: 0.8523
# Epoch 34/250
# 313/313 [==============================] - 15s 49ms/step - loss: 1.0013 - accuracy: 0.9385 - val_loss: 1.1537 - val_accuracy: 0.8560
# Epoch 35/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9955 - accuracy: 0.9396 - val_loss: 1.1346 - val_accuracy: 0.8707
# Epoch 36/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9894 - accuracy: 0.9459 - val_loss: 1.2214 - val_accuracy: 0.8242
# Epoch 37/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9850 - accuracy: 0.9473 - val_loss: 1.1338 - val_accuracy: 0.8678
# Epoch 38/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9806 - accuracy: 0.9472 - val_loss: 1.1369 - val_accuracy: 0.8651
# Epoch 39/250
# 313/313 [==============================] - 16s 50ms/step - loss: 0.9794 - accuracy: 0.9488 - val_loss: 1.1558 - val_accuracy: 0.8559
# Epoch 40/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9711 - accuracy: 0.9534 - val_loss: 1.1650 - val_accuracy: 0.8571
# Epoch 41/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9700 - accuracy: 0.9528 - val_loss: 1.1448 - val_accuracy: 0.8639
# Epoch 42/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9651 - accuracy: 0.9563 - val_loss: 1.1299 - val_accuracy: 0.8707
# Epoch 43/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9593 - accuracy: 0.9592 - val_loss: 1.1573 - val_accuracy: 0.8538
# Epoch 44/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9570 - accuracy: 0.9596 - val_loss: 1.1374 - val_accuracy: 0.8648
# Epoch 45/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9555 - accuracy: 0.9606 - val_loss: 1.1151 - val_accuracy: 0.8758
# Epoch 46/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9519 - accuracy: 0.9625 - val_loss: 1.1237 - val_accuracy: 0.8728
# Epoch 47/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9491 - accuracy: 0.9639 - val_loss: 1.1151 - val_accuracy: 0.8772
# Epoch 48/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9454 - accuracy: 0.9663 - val_loss: 1.1289 - val_accuracy: 0.8719
# Epoch 49/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9437 - accuracy: 0.9668 - val_loss: 1.1327 - val_accuracy: 0.8690
# Epoch 50/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9411 - accuracy: 0.9678 - val_loss: 1.1187 - val_accuracy: 0.8766
# Epoch 51/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9372 - accuracy: 0.9703 - val_loss: 1.1578 - val_accuracy: 0.8569
# Epoch 52/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9373 - accuracy: 0.9695 - val_loss: 1.1293 - val_accuracy: 0.8716
# Epoch 53/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9345 - accuracy: 0.9704 - val_loss: 1.1267 - val_accuracy: 0.8716
# Epoch 54/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9331 - accuracy: 0.9714 - val_loss: 1.1585 - val_accuracy: 0.8595
# Epoch 55/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9318 - accuracy: 0.9709 - val_loss: 1.1293 - val_accuracy: 0.8698
# Epoch 56/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9298 - accuracy: 0.9725 - val_loss: 1.1580 - val_accuracy: 0.8581
# Epoch 57/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9253 - accuracy: 0.9749 - val_loss: 1.1378 - val_accuracy: 0.8690
# Epoch 58/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9254 - accuracy: 0.9739 - val_loss: 1.1141 - val_accuracy: 0.8781
# Epoch 59/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9237 - accuracy: 0.9760 - val_loss: 1.1050 - val_accuracy: 0.8829
# Epoch 60/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9206 - accuracy: 0.9773 - val_loss: 1.1262 - val_accuracy: 0.8734
# Epoch 61/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9197 - accuracy: 0.9771 - val_loss: 1.1095 - val_accuracy: 0.8792
# Epoch 62/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9182 - accuracy: 0.9779 - val_loss: 1.1190 - val_accuracy: 0.8789
# Epoch 63/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9197 - accuracy: 0.9772 - val_loss: 1.1292 - val_accuracy: 0.8733
# Epoch 64/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9181 - accuracy: 0.9781 - val_loss: 1.1228 - val_accuracy: 0.8737
# Epoch 65/250
# 313/313 [==============================] - 16s 50ms/step - loss: 0.9153 - accuracy: 0.9785 - val_loss: 1.1399 - val_accuracy: 0.8647
# Epoch 66/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9154 - accuracy: 0.9786 - val_loss: 1.1110 - val_accuracy: 0.8811
# Epoch 67/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9135 - accuracy: 0.9800 - val_loss: 1.1317 - val_accuracy: 0.8718
# Epoch 68/250
# 313/313 [==============================] - 16s 50ms/step - loss: 0.9118 - accuracy: 0.9814 - val_loss: 1.1492 - val_accuracy: 0.8668
# Epoch 69/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9128 - accuracy: 0.9794 - val_loss: 1.1098 - val_accuracy: 0.8805
# Epoch 70/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9109 - accuracy: 0.9808 - val_loss: 1.1253 - val_accuracy: 0.8770
# Epoch 71/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9109 - accuracy: 0.9803 - val_loss: 1.1224 - val_accuracy: 0.8790
# Epoch 72/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9082 - accuracy: 0.9825 - val_loss: 1.1392 - val_accuracy: 0.8692
# Epoch 73/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9080 - accuracy: 0.9824 - val_loss: 1.1067 - val_accuracy: 0.8851
# Epoch 74/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9066 - accuracy: 0.9826 - val_loss: 1.1299 - val_accuracy: 0.8738
# Epoch 75/250
# 313/313 [==============================] - 15s 49ms/step - loss: 0.9055 - accuracy: 0.9832 - val_loss: 1.1438 - val_accuracy: 0.8649
# Epoch 76/250
# 313/313 [==============================] - 16s 50ms/step - loss: 0.9060 - accuracy: 0.9830 - val_loss: 1.1107 - val_accuracy: 0.8826
# Epoch 77/250
# 313/313 [==============================] - 16s 51ms/step - loss: 0.9027 - accuracy: 0.9847 - val_loss: 1.1312 - val_accuracy: 0.8721
# Epoch 78/250
# 313/313 [==============================] - 30s 96ms/step - loss: 0.9036 - accuracy: 0.9841 - val_loss: 1.1201 - val_accuracy: 0.8782
# Epoch 79/250
# 313/313 [==============================] - 27s 88ms/step - loss: 0.9018 - accuracy: 0.9852 - val_loss: 1.1058 - val_accuracy: 0.8854
# Epoch 80/250
# 313/313 [==============================] - 28s 91ms/step - loss: 0.9049 - accuracy: 0.9832 - val_loss: 1.1105 - val_accuracy: 0.8835
# Epoch 81/250
# 158/313 [==============>...............] - ETA: 13s - loss: 0.9034 - accuracy: 0.9841
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-97f9889674ea> in <module>
#       5     epochs=250,
#       6     validation_data=(X_valid, Y_valid_one_hot),
# ----> 7     callbacks = [early_stopping]
#       8 )
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1101               logs = tmp_logs  # No error, now safe to assign to logs.
#    1102               end_step = step + data_handler.step_increment
# -> 1103               callbacks.on_train_batch_end(end_step, logs)
#    1104         epoch_logs = copy.copy(logs)
#    1105
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     438     """
#     439     if self._should_call_train_batch_hooks:
# --> 440       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     441
#     442   def on_test_batch_begin(self, batch, logs=None):
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     287       self._call_batch_begin_hook(mode, batch, logs)
#     288     elif hook == 'end':
# --> 289       self._call_batch_end_hook(mode, batch, logs)
#     290     else:
#     291       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     307       batch_time = time.time() - self._batch_start_time
#     308
# --> 309     self._call_batch_hook_helper(hook_name, batch, logs)
#     310
#     311     if self._check_timing:
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     343       else:
#     344         if numpy_logs is None:  # Only convert once.
# --> 345           numpy_logs = tf_utils.to_numpy_or_python_type(logs)
#     346         hook(batch, numpy_logs)
#     347
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#     536
# --> 537   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     538
#     539
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     531   def _to_single_numpy_or_python_type(t):
#     532     if isinstance(t, ops.Tensor):
# --> 533       x = t.numpy()
#     534       return x.item() if np.ndim(x) == 0 else x
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1061     """
#    1062     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1063     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1064     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1065
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1027   def _numpy(self):
#    1028     try:
# -> 1029       return self._numpy_internal()
#    1030     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1031       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d39fc314bafd> in <module>
# ----> 1 plt.plot(history.history['loss'])
#       2 plt.plot(history.history['val_loss'])
#
# NameError: name 'history' is not defined

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
submodel = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
    )
z = submodel.predict(X_train)
np.shape(z)
# Out:
# (40000, 256)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sun Aug  9 14:43:05 2020 Finding Nearest Neighbors
# Sun Aug  9 14:43:05 2020 Building RP forest with 15 trees
# Sun Aug  9 14:43:06 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# Sun Aug  9 14:43:17 2020 Finished Nearest Neighbor Search
# Sun Aug  9 14:43:19 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Aug  9 14:43:46 2020 Finished embedding

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)

# %%
z_valid = submodel.predict(X_valid)
np.shape(z_valid)
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z_valid.reshape(len(z_valid), np.product(np.shape(z_valid)[1:])))

plt.scatter(embedding[:, 0], embedding[:, 1], c=Y_valid.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sun Aug  9 14:44:34 2020 Finding Nearest Neighbors
# Sun Aug  9 14:44:34 2020 Building RP forest with 10 trees
# Sun Aug  9 14:44:34 2020 parallel NN descent for 13 iterations
# 	 0  /  13
# 	 1  /  13
# 	 2  /  13
# 	 3  /  13
# Sun Aug  9 14:44:35 2020 Finished Nearest Neighbor Search
# Sun Aug  9 14:44:35 2020 Construct embedding
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Sun Aug  9 14:44:52 2020 Finished embedding

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(embedding[:, 0], embedding[:, 1], c=Y_valid.flatten(), s= 1, alpha = 1, cmap = plt.cm.tab10)

# %%
predictions = model.predict(X_valid)

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(embedding[:, 0], embedding[:, 1], c=np.argmax(predictions, axis=1), s= 1, alpha = 1, cmap = plt.cm.tab10)
