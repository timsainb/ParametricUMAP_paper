# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
import numpy as np
from tfumap.semisupervised_keras import pretrained_networks
from tfumap.semisupervised_keras import load_architecture
from tfumap.paths import MODEL_DIR

# %%
from tfumap.semisupervised_keras import load_dataset

# %%
dataset = "fmnist"
n_latent_dims = 1024

# %%
(
    X_train,
    X_test,
    X_labeled,
    Y_labeled,
    Y_masked,
    X_valid,
    Y_train,
    Y_test,
    Y_valid,
    Y_valid_one_hot,
    Y_labeled_one_hot,
    num_classes,
    dims
) = load_dataset(dataset, 'full')

# %%
encoder, classifier, embedder = load_architecture(dataset, n_latent_dims)

# %%
aug_types = [
    "not_augmented",
    "augmented",
    "umap_euclidean",
    "umap_learned",
    "umap_augmented_learned",
    "umap_euclidean_augmented",
]

# %%
for labels_per_class in [4, 16, 64, 256, 1024, 'full']:
    for aug_str in aug_types:
        pretrained_weights_loc = pretrained_networks[dataset][aug_str][labels_per_class]
        load_folder = (
            MODEL_DIR
            / "semisupervised-keras"
            / dataset
            / str(labels_per_class)
            / pretrained_weights_loc
        )
        classifier.load_weights((load_folder / "classifier").as_posix())
        encoder.load_weights((load_folder / "encoder").as_posix())
        # test current acc
        pretrained_predictions = classifier.predict(encoder.predict(X_test, verbose=True), verbose=True)
        pretrained_predictions = np.argmax(pretrained_predictions, axis=1)
        pretrained_acc = pretrained_predictions == Y_test
        mean_acc = np.mean(pretrained_acc)
        sem_acc = np.std(pretrained_acc) / np.sqrt(len(pretrained_acc))
        np.save(load_folder / 'test_loss_SEM.npy', (mean_acc, sem_acc))
        print('pretrained acc: {} +- {}'.format(mean_acc, sem_acc))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1112 14:50:00.923120 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d646390> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d646828>).
# W1112 14:50:00.926978 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d61d7f0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d66bda0>).
# W1112 14:50:01.026499 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d727470> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d70e780>).
# W1112 14:50:01.030123 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d70e780> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169da143c8>).
# W1112 14:50:01.038447 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d6eea20> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d6eecf8>).
# W1112 14:50:01.044342 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d6eecf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d6ee6d8>).
# W1112 14:50:01.048183 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169cb0a518> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169cb0a828>).
# W1112 14:50:01.053445 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169cb0a828> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169cb0a978>).
# W1112 14:50:01.062080 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d5e3c88> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d5e62b0>).
# W1112 14:50:01.064716 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d5e62b0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d5e6518>).
# W1112 14:50:01.069164 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d8310f0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d831320>).
# W1112 14:50:01.071709 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d831320> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d831588>).
# W1112 14:50:01.076090 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d264048> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d264358>).
# W1112 14:50:01.078691 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d264358> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d2645c0>).
# W1112 14:50:01.086303 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d9b7748> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d9b76a0>).
# W1112 14:50:01.088822 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d9b76a0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d37e048>).
# W1112 14:50:01.092722 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d8aeb38> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d8aee10>).
# W1112 14:50:01.095576 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d8aee10> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d8b6080>).
# W1112 14:50:01.099447 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169da89b70> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169da89e48>).
# W1112 14:50:01.102744 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169da89e48> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169da990b8>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.6068 +- 0.004884606023007384
# W1112 14:50:06.367157 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d646390> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d646828>).
# W1112 14:50:06.370140 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d61d7f0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d66bda0>).
# W1112 14:50:06.494351 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d727470> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d70e780>).
# W1112 14:50:06.497753 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d70e780> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169da143c8>).
# W1112 14:50:06.501918 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d6eea20> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d6eecf8>).
# W1112 14:50:06.505160 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d6eecf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d6ee6d8>).
# W1112 14:50:06.510122 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169cb0a518> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169cb0a828>).
# W1112 14:50:06.513695 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169cb0a828> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169cb0a978>).
# W1112 14:50:06.520047 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d5e3c88> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d5e62b0>).
# W1112 14:50:06.522841 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d5e62b0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d5e6518>).
# W1112 14:50:06.526683 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d8310f0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d831320>).
# W1112 14:50:06.529801 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d831320> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d831588>).
# W1112 14:50:06.536365 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d264048> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d264358>).
# W1112 14:50:06.539916 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d264358> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d2645c0>).
# W1112 14:50:06.545988 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d9b7748> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d9b76a0>).
# W1112 14:50:06.549619 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d9b76a0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d37e048>).
# W1112 14:50:06.553529 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d8aeb38> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d8aee10>).
# W1112 14:50:06.556565 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d8aee10> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d8b6080>).
# W1112 14:50:06.560276 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169da89b70> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169da89e48>).
# W1112 14:50:06.563296 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169da89e48> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169da990b8>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 2ms/step
# pretrained acc: 0.692 +- 0.004616665463297075
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 2ms/step
# pretrained acc: 0.7144 +- 0.004516997232675708
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 2ms/step
# pretrained acc: 0.6286 +- 0.0048317909723000225
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 2ms/step
# pretrained acc: 0.747 +- 0.00434730951279064
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 2ms/step
# pretrained acc: 0.7373 +- 0.0044010079527308284
# W1112 14:50:22.243479 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d646390> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d646828>).
# W1112 14:50:22.245498 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d61d7f0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d66bda0>).
# W1112 14:50:22.343080 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d727470> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d70e780>).
# W1112 14:50:22.346766 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d70e780> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169da143c8>).
# W1112 14:50:22.351805 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d6eea20> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d6eecf8>).
# W1112 14:50:22.354663 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d6eecf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d6ee6d8>).
# W1112 14:50:22.358565 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169cb0a518> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169cb0a828>).
# W1112 14:50:22.361372 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169cb0a828> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169cb0a978>).
# W1112 14:50:22.367467 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d5e3c88> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d5e62b0>).
# W1112 14:50:22.370288 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d5e62b0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d5e6518>).
# W1112 14:50:22.374211 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d8310f0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d831320>).
# W1112 14:50:22.377055 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d831320> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d831588>).
# W1112 14:50:22.381027 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d264048> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d264358>).
# W1112 14:50:22.383909 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d264358> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d2645c0>).
# W1112 14:50:22.390107 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d9b7748> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d9b76a0>).
# W1112 14:50:22.392952 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d9b76a0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d37e048>).
# W1112 14:50:22.396921 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d8aeb38> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d8aee10>).
# W1112 14:50:22.399748 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d8aee10> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d8b6080>).
# W1112 14:50:22.403675 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169da89b70> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169da89e48>).
# W1112 14:50:22.406504 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169da89e48> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169da990b8>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 2ms/step
# pretrained acc: 0.7439 +- 0.0043647770848005505
# W1112 14:50:25.174007 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d646390> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d646828>).
# W1112 14:50:25.176677 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d61d7f0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d66bda0>).
# W1112 14:50:25.310905 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d727470> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d70e780>).
# W1112 14:50:25.316444 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d70e780> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169da143c8>).
# W1112 14:50:25.320313 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d6eea20> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d6eecf8>).
# W1112 14:50:25.323030 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d6eecf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d6ee6d8>).
# W1112 14:50:25.326810 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169cb0a518> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169cb0a828>).
# W1112 14:50:25.329509 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169cb0a828> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169cb0a978>).
# W1112 14:50:25.335439 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d5e3c88> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d5e62b0>).
# W1112 14:50:25.338144 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d5e62b0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d5e6518>).
# W1112 14:50:25.341921 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d8310f0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d831320>).
# W1112 14:50:25.344642 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d831320> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d831588>).
# W1112 14:50:25.348452 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d264048> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d264358>).
# W1112 14:50:25.351179 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d264358> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d2645c0>).
# W1112 14:50:25.357202 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d9b7748> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d9b76a0>).
# W1112 14:50:25.359956 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d9b76a0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d37e048>).
# W1112 14:50:25.363792 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d8aeb38> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d8aee10>).
# W1112 14:50:25.366522 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d8aee10> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d8b6080>).
# W1112 14:50:25.370427 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169da89b70> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169da89e48>).
# W1112 14:50:25.373172 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169da89e48> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169da990b8>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.7962 +- 0.004028219954272606
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.7845 +- 0.004111687609729124
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 2ms/step
# pretrained acc: 0.7425 +- 0.004372570754144522
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.8263 +- 0.0037885130328401935
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.8322 +- 0.003736885869276716
# W1112 14:50:40.994340 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d646390> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d646828>).
# W1112 14:50:40.997243 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d61d7f0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d66bda0>).
# W1112 14:50:41.388543 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d727470> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d70e780>).
# W1112 14:50:41.391506 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d70e780> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169da143c8>).
# W1112 14:50:41.395550 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d6eea20> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d6eecf8>).
# W1112 14:50:41.398518 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d6eecf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d6ee6d8>).
# W1112 14:50:41.402484 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169cb0a518> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169cb0a828>).
# ...
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d831320> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d831588>).
# W1112 14:51:38.023894 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d264048> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d264358>).
# W1112 14:51:38.026976 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d264358> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d2645c0>).
# W1112 14:51:38.033176 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d9b7748> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d9b76a0>).
# W1112 14:51:38.037562 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d9b76a0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d37e048>).
# W1112 14:51:38.041339 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d8aeb38> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d8aee10>).
# W1112 14:51:38.045333 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d8aee10> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d8b6080>).
# W1112 14:51:38.050541 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169da89b70> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169da89e48>).
# W1112 14:51:38.053475 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169da89e48> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169da990b8>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9427 +- 0.002324149521868161
# W1112 14:51:41.083451 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d646390> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d646828>).
# W1112 14:51:41.086169 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d61d7f0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d66bda0>).
# W1112 14:51:41.238535 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d727470> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d70e780>).
# W1112 14:51:41.241492 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d70e780> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169da143c8>).
# W1112 14:51:41.245244 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d6eea20> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d6eecf8>).
# W1112 14:51:41.248130 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d6eecf8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d6ee6d8>).
# W1112 14:51:41.252032 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169cb0a518> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169cb0a828>).
# W1112 14:51:41.254873 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169cb0a828> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169cb0a978>).
# W1112 14:51:41.260926 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d5e3c88> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d5e62b0>).
# W1112 14:51:41.263734 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d5e62b0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d5e6518>).
# W1112 14:51:41.267578 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d8310f0> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d831320>).
# W1112 14:51:41.270381 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d831320> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d831588>).
# W1112 14:51:41.274285 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d264048> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d264358>).
# W1112 14:51:41.277090 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d264358> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d2645c0>).
# W1112 14:51:41.285047 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d9b7748> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d9b76a0>).
# W1112 14:51:41.287845 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d9b76a0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d37e048>).
# W1112 14:51:41.292553 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169d8aeb38> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d8aee10>).
# W1112 14:51:41.296051 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169d8aee10> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169d8b6080>).
# W1112 14:51:41.300869 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f169da89b70> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169da89e48>).
# W1112 14:51:41.303779 139738279618368 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f169da89e48> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f169da990b8>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9488 +- 0.0022040544457884877
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9466 +- 0.0022482980229498045
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9443 +- 0.0022934147030138265
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9525 +- 0.0021270578271405786
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9521 +- 0.002135546534262365
