# %% [markdown]
# #### Outline
# - for each dataset:
#     - load dataset;
#     - for each network:
#         - load network
#         - project 1000 test dataset samples
#         - save to metric dataframe

# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU (this may not be needed on your computer)

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0

# %%
import numpy as np
import pickle
import pandas as pd
import time
from umap import UMAP

# %%
from tfumap.umap import tfUMAP
import tensorflow as tf
from sklearn.decomposition import PCA
from openTSNE import TSNE
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
from tqdm.autonotebook import tqdm

# %%
from tfumap.paths import ensure_dir, MODEL_DIR, DATA_DIR

# %%
output_dir = MODEL_DIR/'projections'

# %%
projection_speeds = pd.DataFrame(columns = ['method_', 'dimensions', 'dataset', 'speed', "nex"])

# %% [markdown]
# ### FMNIST

# %%
dataset = 'fmnist'
dims = (28,28,1)

# %% [markdown]
# ##### load dataset

# %%
from tensorflow.keras.datasets import fashion_mnist

# load dataset
(train_images, Y_train), (test_images, Y_test) = fashion_mnist.load_data()
X_train = (train_images/255.).astype('float32')
X_test = (test_images/255.).astype('float32')
X_train = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))

# subset a validation set
n_valid = 10000
X_valid = X_train[-n_valid:]
Y_valid = Y_train[-n_valid:]
X_train = X_train[:-n_valid]
Y_train = Y_train[:-n_valid]

# flatten X
X_train_flat = X_train.reshape((len(X_train), np.product(np.shape(X_train)[1:])))
X_test_flat = X_test.reshape((len(X_test), np.product(np.shape(X_test)[1:])))
X_valid_flat= X_valid.reshape((len(X_valid), np.product(np.shape(X_valid)[1:])))
X_test = X_test.reshape((10000, 28,28,1))
print(len(X_train), len(X_valid), len(X_test))
# Out:
# 50000 10000 10000

# %% [markdown]
# #### Network

# %% [markdown]
# ##### 2 dims

# %%
load_loc = output_dir / dataset / 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    encoder(X_test);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['network', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  1.523000975837931
# seconds:  0.0161127548199147
# seconds:  0.021156250033527613
# seconds:  0.018329129088670015
# seconds:  0.016372433165088296
# seconds:  0.015420375159010291
# seconds:  0.01771849114447832
# seconds:  0.015456926077604294
# seconds:  0.015544889029115438
# seconds:  0.015059004770591855

# %%
##### Network CPU

with tf.device('/CPU:0'):
    n_repeats = 10
    times = []
    for i in tqdm(range(n_repeats)):
        start_time = time.monotonic()
        encoder(X_test);
        end_time = time.monotonic()
        print('seconds: ', end_time - start_time)
        times.append(end_time - start_time)
        projection_speeds.loc[len(projection_speeds)] = ['network-cpu', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.2501369018573314
# seconds:  0.1769578589592129
# seconds:  0.1868099740240723
# seconds:  0.17968848906457424
# seconds:  0.182453908957541
# seconds:  0.18018855201080441
# seconds:  0.176207727054134
# seconds:  0.18667540093883872
# seconds:  0.18546372489072382
# seconds:  0.2119065779261291

# %% [markdown]
# ##### 64 dims

# %%
load_loc = output_dir / dataset /"64"/ 'network'

# %%
embedder = tfUMAP(
    direct_embedding=False,
    verbose=True,
    negative_sample_rate=5,
    training_epochs=5,
    batch_size = 100,
    dims = dims
)

# %%
encoder = tf.keras.models.load_model((load_loc / 'encoder').as_posix())
embedder.encoder = encoder

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    encoder(X_test);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['network', 64, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.21663769497536123
# seconds:  0.018942847149446607
# seconds:  0.01586881815455854
# seconds:  0.017651899019256234
# seconds:  0.018030270002782345
# seconds:  0.017754513071849942
# seconds:  0.01863340800628066
# seconds:  0.018833584152162075
# seconds:  0.01667224196717143
# seconds:  0.017112073954194784

# %%
##### Network CPU

with tf.device('/CPU:0'):
    n_repeats = 10
    times = []
    for i in tqdm(range(n_repeats)):
        start_time = time.monotonic()
        encoder(X_test);
        end_time = time.monotonic()
        print('seconds: ', end_time - start_time)
        times.append(end_time - start_time)
        projection_speeds.loc[len(projection_speeds)] = ['network-cpu', 64, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.28203710401430726
# seconds:  0.18293683184310794
# seconds:  0.1842855210416019
# seconds:  0.19608442205935717
# seconds:  0.19756417511962354
# seconds:  0.18991611409001052
# seconds:  0.18055140390060842
# seconds:  0.17655440815724432
# seconds:  0.17609573411755264
# seconds:  0.1744745068717748

# %% [markdown]
# #### UMAP-learn

# %% [markdown]
# ##### 2 dims

# %%
embedder = UMAP(n_components = 2, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sat Jul 18 12:14:13 2020 Finding Nearest Neighbors
# Sat Jul 18 12:14:13 2020 Building RP forest with 16 trees
# Sat Jul 18 12:14:15 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# Sat Jul 18 12:14:25 2020 Finished Nearest Neighbor Search
# Sat Jul 18 12:14:27 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sat Jul 18 12:14:57 2020 Finished embedding

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['umap-learn', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  17.635929187992588
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.941008719149977
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.159472896018997
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.948740841122344
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.178410801105201
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.135798450792208
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.973603046964854
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.254298451123759
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  4.954195645870641
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.16474288306199

# %%
projection_speeds
# Out:
#         method_ dimensions dataset      speed    nex
# 0       network          2  fmnist   1.523001  10000
# 1       network          2  fmnist   0.016113  10000
# 2       network          2  fmnist   0.021156  10000
# 3       network          2  fmnist   0.018329  10000
# 4       network          2  fmnist   0.016372  10000
# 5       network          2  fmnist   0.015420  10000
# 6       network          2  fmnist   0.017718  10000
# 7       network          2  fmnist   0.015457  10000
# 8       network          2  fmnist   0.015545  10000
# 9       network          2  fmnist   0.015059  10000
# 10  network-cpu          2  fmnist   0.250137  10000
# 11  network-cpu          2  fmnist   0.176958  10000
# 12  network-cpu          2  fmnist   0.186810  10000
# 13  network-cpu          2  fmnist   0.179688  10000
# 14  network-cpu          2  fmnist   0.182454  10000
# 15  network-cpu          2  fmnist   0.180189  10000
# 16  network-cpu          2  fmnist   0.176208  10000
# 17  network-cpu          2  fmnist   0.186675  10000
# 18  network-cpu          2  fmnist   0.185464  10000
# 19  network-cpu          2  fmnist   0.211907  10000
# 20      network         64  fmnist   0.216638  10000
# 21      network         64  fmnist   0.018943  10000
# 22      network         64  fmnist   0.015869  10000
# 23      network         64  fmnist   0.017652  10000
# 24      network         64  fmnist   0.018030  10000
# 25      network         64  fmnist   0.017755  10000
# 26      network         64  fmnist   0.018633  10000
# 27      network         64  fmnist   0.018834  10000
# 28      network         64  fmnist   0.016672  10000
# 29      network         64  fmnist   0.017112  10000
# 30  network-cpu         64  fmnist   0.282037  10000
# 31  network-cpu         64  fmnist   0.182937  10000
# 32  network-cpu         64  fmnist   0.184286  10000
# 33  network-cpu         64  fmnist   0.196084  10000
# 34  network-cpu         64  fmnist   0.197564  10000
# 35  network-cpu         64  fmnist   0.189916  10000
# 36  network-cpu         64  fmnist   0.180551  10000
# 37  network-cpu         64  fmnist   0.176554  10000
# 38  network-cpu         64  fmnist   0.176096  10000
# 39  network-cpu         64  fmnist   0.174475  10000
# 40   umap-learn          2  fmnist  17.635929  10000
# 41   umap-learn          2  fmnist   4.941009  10000
# 42   umap-learn          2  fmnist   5.159473  10000
# 43   umap-learn          2  fmnist   4.948741  10000
# 44   umap-learn          2  fmnist   5.178411  10000
# 45   umap-learn          2  fmnist   5.135798  10000
# 46   umap-learn          2  fmnist   4.973603  10000
# 47   umap-learn          2  fmnist   5.254298  10000
# 48   umap-learn          2  fmnist   4.954196  10000
# 49   umap-learn          2  fmnist   5.164743  10000

# %% [markdown]
# ##### 64 dims

# %%
embedder = UMAP(n_components = 64, verbose=True)
z_umap = embedder.fit_transform(X_train_flat)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, n_components=64, verbose=True)
# Construct fuzzy simplicial set
# Sat Jul 18 12:16:02 2020 Finding Nearest Neighbors
# Sat Jul 18 12:16:02 2020 Building RP forest with 16 trees
# Sat Jul 18 12:16:03 2020 parallel NN descent for 16 iterations
# 	 0  /  16
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# Sat Jul 18 12:16:05 2020 Finished Nearest Neighbor Search
# Sat Jul 18 12:16:05 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sat Jul 18 12:16:49 2020 Finished embedding

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedder.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['umap-learn', 64, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  6.194998310878873
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.266623386880383
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.183475145837292
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.071882104035467
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.239961565937847
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.081602743128315
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.265255504986271
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.029134667944163
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.29016419313848
# 	completed  0  /  100 epochs
# 	completed  10  /  100 epochs
# 	completed  20  /  100 epochs
# 	completed  30  /  100 epochs
# 	completed  40  /  100 epochs
# 	completed  50  /  100 epochs
# 	completed  60  /  100 epochs
# 	completed  70  /  100 epochs
# 	completed  80  /  100 epochs
# 	completed  90  /  100 epochs
# seconds:  5.331527506001294

# %%
projection_speeds
# Out:
#         method_ dimensions dataset      speed    nex
# 0       network          2  fmnist   1.523001  10000
# 1       network          2  fmnist   0.016113  10000
# 2       network          2  fmnist   0.021156  10000
# 3       network          2  fmnist   0.018329  10000
# 4       network          2  fmnist   0.016372  10000
# 5       network          2  fmnist   0.015420  10000
# 6       network          2  fmnist   0.017718  10000
# 7       network          2  fmnist   0.015457  10000
# 8       network          2  fmnist   0.015545  10000
# 9       network          2  fmnist   0.015059  10000
# 10  network-cpu          2  fmnist   0.250137  10000
# 11  network-cpu          2  fmnist   0.176958  10000
# 12  network-cpu          2  fmnist   0.186810  10000
# 13  network-cpu          2  fmnist   0.179688  10000
# 14  network-cpu          2  fmnist   0.182454  10000
# 15  network-cpu          2  fmnist   0.180189  10000
# 16  network-cpu          2  fmnist   0.176208  10000
# 17  network-cpu          2  fmnist   0.186675  10000
# 18  network-cpu          2  fmnist   0.185464  10000
# 19  network-cpu          2  fmnist   0.211907  10000
# 20      network         64  fmnist   0.216638  10000
# 21      network         64  fmnist   0.018943  10000
# 22      network         64  fmnist   0.015869  10000
# 23      network         64  fmnist   0.017652  10000
# 24      network         64  fmnist   0.018030  10000
# 25      network         64  fmnist   0.017755  10000
# 26      network         64  fmnist   0.018633  10000
# 27      network         64  fmnist   0.018834  10000
# 28      network         64  fmnist   0.016672  10000
# 29      network         64  fmnist   0.017112  10000
# 30  network-cpu         64  fmnist   0.282037  10000
# 31  network-cpu         64  fmnist   0.182937  10000
# 32  network-cpu         64  fmnist   0.184286  10000
# 33  network-cpu         64  fmnist   0.196084  10000
# 34  network-cpu         64  fmnist   0.197564  10000
# 35  network-cpu         64  fmnist   0.189916  10000
# 36  network-cpu         64  fmnist   0.180551  10000
# 37  network-cpu         64  fmnist   0.176554  10000
# 38  network-cpu         64  fmnist   0.176096  10000
# 39  network-cpu         64  fmnist   0.174475  10000
# 40   umap-learn          2  fmnist  17.635929  10000
# 41   umap-learn          2  fmnist   4.941009  10000
# 42   umap-learn          2  fmnist   5.159473  10000
# 43   umap-learn          2  fmnist   4.948741  10000
# 44   umap-learn          2  fmnist   5.178411  10000
# 45   umap-learn          2  fmnist   5.135798  10000
# 46   umap-learn          2  fmnist   4.973603  10000
# 47   umap-learn          2  fmnist   5.254298  10000
# 48   umap-learn          2  fmnist   4.954196  10000
# 49   umap-learn          2  fmnist   5.164743  10000
# 50   umap-learn         64  fmnist   6.194998  10000
# 51   umap-learn         64  fmnist   5.266623  10000
# 52   umap-learn         64  fmnist   5.183475  10000
# 53   umap-learn         64  fmnist   5.071882  10000
# 54   umap-learn         64  fmnist   5.239962  10000
# 55   umap-learn         64  fmnist   5.081603  10000
# 56   umap-learn         64  fmnist   5.265256  10000
# 57   umap-learn         64  fmnist   5.029135  10000
# 58   umap-learn         64  fmnist   5.290164  10000
# 59   umap-learn         64  fmnist   5.331528  10000

# %% [markdown]
# #### PCA

# %% [markdown]
# ##### 2 dims

# %%
pca = PCA(n_components=2)
z = pca.fit_transform(X_train_flat)

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    pca.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['pca', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.01146728009916842
# seconds:  0.023875259095802903
# seconds:  0.023056175094097853
# seconds:  0.023046415066346526
# seconds:  0.023067115806043148
# seconds:  0.021578952902927995
# seconds:  0.023042334942147136
# seconds:  0.023047995986416936
# seconds:  0.023027664981782436
# seconds:  0.0240302630700171

# %%
projection_speeds
# Out:
#     method_ dimensions dataset     speed    nex
# 0   network          2  fmnist  1.523001  10000
# 1   network          2  fmnist  0.016113  10000
# 2   network          2  fmnist  0.021156  10000
# 3   network          2  fmnist  0.018329  10000
# 4   network          2  fmnist  0.016372  10000
# ..      ...        ...     ...       ...    ...
# 65      pca          2  fmnist  0.021579  10000
# 66      pca          2  fmnist  0.023042  10000
# 67      pca          2  fmnist  0.023048  10000
# 68      pca          2  fmnist  0.023028  10000
# 69      pca          2  fmnist  0.024030  10000
#
# [70 rows x 5 columns]

# %% [markdown]
# ##### 64 dims

# %%
pca = PCA(n_components=64)
z = pca.fit_transform(X_train_flat)

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    pca.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['pca', 64, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# seconds:  0.01972310896962881
# seconds:  0.020001007011160254
# seconds:  0.019843593006953597
# seconds:  0.02003844897262752
# seconds:  0.020194053184241056
# seconds:  0.020864831982180476
# seconds:  0.019978526048362255
# seconds:  0.02000176697038114
# seconds:  0.019965047016739845
# seconds:  0.020434258971363306

# %%
projection_speeds
# Out:
#     method_ dimensions dataset     speed    nex
# 0   network          2  fmnist  1.523001  10000
# 1   network          2  fmnist  0.016113  10000
# 2   network          2  fmnist  0.021156  10000
# 3   network          2  fmnist  0.018329  10000
# 4   network          2  fmnist  0.016372  10000
# ..      ...        ...     ...       ...    ...
# 75      pca         64  fmnist  0.020865  10000
# 76      pca         64  fmnist  0.019979  10000
# 77      pca         64  fmnist  0.020002  10000
# 78      pca         64  fmnist  0.019965  10000
# 79      pca         64  fmnist  0.020434  10000
#
# [80 rows x 5 columns]

# %% [markdown]
# #### TSNE

# %% [markdown]
# ##### 2 dims

# %%
tsne = TSNE(
    n_components = 2,
    n_jobs=32,
    verbose=True
)

# %%
embedding_train = tsne.fit(X_train_flat)
# Out:
# --------------------------------------------------------------------------------
# TSNE(n_jobs=32, neighbors=None, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#    --> Time elapsed: 36.42 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.48 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.48 seconds
# ===> Running optimization with exaggeration=12.00, lr=4166.67 for 250 iterations...
# Iteration   50, KL divergence 5.9437, 50 iterations in 1.6770 sec
# Iteration  100, KL divergence 5.4383, 50 iterations in 1.6499 sec
# Iteration  150, KL divergence 5.3136, 50 iterations in 1.6637 sec
# Iteration  200, KL divergence 5.2569, 50 iterations in 1.6556 sec
# Iteration  250, KL divergence 5.2247, 50 iterations in 1.7098 sec
#    --> Time elapsed: 8.36 seconds
# ===> Running optimization with exaggeration=1.00, lr=4166.67 for 500 iterations...
# Iteration   50, KL divergence 3.8582, 50 iterations in 1.5851 sec
# Iteration  100, KL divergence 3.3417, 50 iterations in 1.6268 sec
# Iteration  150, KL divergence 3.0760, 50 iterations in 2.1215 sec
# Iteration  200, KL divergence 2.9086, 50 iterations in 2.9020 sec
# Iteration  250, KL divergence 2.7930, 50 iterations in 3.8054 sec
# Iteration  300, KL divergence 2.7084, 50 iterations in 5.3478 sec
# Iteration  350, KL divergence 2.6445, 50 iterations in 6.6641 sec
# Iteration  400, KL divergence 2.5946, 50 iterations in 7.6735 sec
# Iteration  450, KL divergence 2.5542, 50 iterations in 8.4291 sec
# Iteration  500, KL divergence 2.5216, 50 iterations in 11.4593 sec
#    --> Time elapsed: 51.62 seconds

# %%
n_repeats = 10
times = []
for i in tqdm(range(n_repeats)):
    start_time = time.monotonic()
    embedding_train.transform(X_test_flat);
    end_time = time.monotonic()
    print('seconds: ', end_time - start_time)
    times.append(end_time - start_time)
    projection_speeds.loc[len(projection_speeds)] = ['TSNE', 2, dataset, end_time - start_time, len(X_test)]
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.39 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197902.7177, 50 iterations in 0.2684 sec
# Iteration  100, KL divergence 198133.2713, 50 iterations in 0.3065 sec
# Iteration  150, KL divergence 198263.6537, 50 iterations in 0.2768 sec
# Iteration  200, KL divergence 198370.6803, 50 iterations in 0.3042 sec
# Iteration  250, KL divergence 198443.4647, 50 iterations in 0.3006 sec
#    --> Time elapsed: 1.46 seconds
# seconds:  6.186875977087766
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.43 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197902.7177, 50 iterations in 0.2641 sec
# Iteration  100, KL divergence 198133.2713, 50 iterations in 0.2765 sec
# Iteration  150, KL divergence 198263.6537, 50 iterations in 0.2725 sec
# Iteration  200, KL divergence 198370.6803, 50 iterations in 0.2786 sec
# Iteration  250, KL divergence 198443.4647, 50 iterations in 0.2634 sec
#    --> Time elapsed: 1.36 seconds
# seconds:  5.847559571964666
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.38 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197902.7177, 50 iterations in 0.2872 sec
# Iteration  100, KL divergence 198133.2713, 50 iterations in 0.2607 sec
# Iteration  150, KL divergence 198263.6537, 50 iterations in 0.2574 sec
# Iteration  200, KL divergence 198370.6803, 50 iterations in 0.2745 sec
# Iteration  250, KL divergence 198443.4647, 50 iterations in 0.2579 sec
#    --> Time elapsed: 1.34 seconds
# seconds:  5.777447527041659
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.43 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197902.7177, 50 iterations in 0.2876 sec
# Iteration  100, KL divergence 198133.2713, 50 iterations in 0.2622 sec
# Iteration  150, KL divergence 198263.6537, 50 iterations in 0.2630 sec
# Iteration  200, KL divergence 198370.6803, 50 iterations in 0.2636 sec
# Iteration  250, KL divergence 198443.4647, 50 iterations in 0.2752 sec
#    --> Time elapsed: 1.35 seconds
# seconds:  5.831522678025067
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.42 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197902.7177, 50 iterations in 0.2732 sec
# Iteration  100, KL divergence 198133.2713, 50 iterations in 0.2936 sec
# Iteration  150, KL divergence 198263.6537, 50 iterations in 0.2740 sec
# Iteration  200, KL divergence 198370.6803, 50 iterations in 0.2733 sec
# Iteration  250, KL divergence 198443.4647, 50 iterations in 0.2665 sec
#    --> Time elapsed: 1.38 seconds
# seconds:  5.856630611931905
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.47 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.04 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197902.7177, 50 iterations in 0.2790 sec
# Iteration  100, KL divergence 198133.2713, 50 iterations in 0.2674 sec
# Iteration  150, KL divergence 198263.6537, 50 iterations in 0.2675 sec
# Iteration  200, KL divergence 198370.6803, 50 iterations in 0.2583 sec
# Iteration  250, KL divergence 198443.4647, 50 iterations in 0.2607 sec
#    --> Time elapsed: 1.33 seconds
# seconds:  5.87143751909025
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.47 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197902.7177, 50 iterations in 0.3019 sec
# Iteration  100, KL divergence 198133.2713, 50 iterations in 0.2966 sec
# Iteration  150, KL divergence 198263.6537, 50 iterations in 0.2796 sec
# Iteration  200, KL divergence 198370.6803, 50 iterations in 0.2690 sec
# Iteration  250, KL divergence 198443.4647, 50 iterations in 0.2677 sec
#    --> Time elapsed: 1.42 seconds
# seconds:  5.966355197830126
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.28 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197902.7177, 50 iterations in 0.2824 sec
# Iteration  100, KL divergence 198133.2713, 50 iterations in 0.2841 sec
# Iteration  150, KL divergence 198263.6537, 50 iterations in 0.2793 sec
# Iteration  200, KL divergence 198370.6803, 50 iterations in 0.2744 sec
# Iteration  250, KL divergence 198443.4647, 50 iterations in 0.2756 sec
#    --> Time elapsed: 1.40 seconds
# seconds:  5.735305347945541
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.40 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197902.7177, 50 iterations in 0.2871 sec
# Iteration  100, KL divergence 198133.2713, 50 iterations in 0.2584 sec
# Iteration  150, KL divergence 198263.6537, 50 iterations in 0.2596 sec
# Iteration  200, KL divergence 198370.6803, 50 iterations in 0.2654 sec
# Iteration  250, KL divergence 198443.4647, 50 iterations in 0.2640 sec
#    --> Time elapsed: 1.34 seconds
# seconds:  5.793795495992526
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 4.24 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 197902.7177, 50 iterations in 0.2793 sec
# Iteration  100, KL divergence 198133.2713, 50 iterations in 0.2645 sec
# Iteration  150, KL divergence 198263.6537, 50 iterations in 0.2688 sec
# Iteration  200, KL divergence 198370.6803, 50 iterations in 0.2708 sec
# Iteration  250, KL divergence 198443.4647, 50 iterations in 0.2646 sec
#    --> Time elapsed: 1.35 seconds
# seconds:  5.635766983963549

# %%
projection_speeds
# Out:
#     method_ dimensions dataset     speed    nex
# 0   network          2  fmnist  1.523001  10000
# 1   network          2  fmnist  0.016113  10000
# 2   network          2  fmnist  0.021156  10000
# 3   network          2  fmnist  0.018329  10000
# 4   network          2  fmnist  0.016372  10000
# ..      ...        ...     ...       ...    ...
# 85     TSNE          2  fmnist  5.871438  10000
# 86     TSNE          2  fmnist  5.966355  10000
# 87     TSNE          2  fmnist  5.735305  10000
# 88     TSNE          2  fmnist  5.793795  10000
# 89     TSNE          2  fmnist  5.635767  10000
#
# [90 rows x 5 columns]

# %% [markdown]
# ### Save

# %%
save_loc = DATA_DIR / 'projection_speeds' / (dataset + '.pickle')
ensure_dir(save_loc)
projection_speeds.to_pickle(save_loc)
