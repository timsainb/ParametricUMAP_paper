# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
print(gpu_devices)
tf.keras.backend.clear_session()
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### dataset information

# %%
from datetime import datetime

dataset = "cifar10"
dims = (32, 32, 3)
num_classes = 10
labels_per_class = 4 # full
batch_size = 128
datestring = datetime.now().strftime("%Y_%m_%d_%H_%M_%S_%f")
datestring = (
    str(dataset)
    + "_"
    + str(labels_per_class)
    + "____"
    + datestring 
    + '_baseline_augmented'
)
print(datestring)
# Out:
# cifar10_4____2020_08_09_22_16_45_780732_baseline_augmented

# %% [markdown]
# ### Load packages

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from IPython import display
import pandas as pd
import umap
import copy
import os, tempfile
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### Load dataset

# %%
from tfumap.load_datasets import load_CIFAR10, mask_labels
X_train, X_test, X_valid, Y_train, Y_test, Y_valid = load_CIFAR10(flatten=False)
X_train.shape
# Out:
# (40000, 32, 32, 3)

# %%
if labels_per_class == "full":
    X_labeled = X_train
    Y_masked = Y_labeled = Y_train
else:
    X_labeled, Y_labeled, Y_masked = mask_labels(
        X_train, Y_train, labels_per_class=labels_per_class
    )

# %% [markdown]
# ### Build network

# %%
from tensorflow.keras import datasets, layers, models
from tensorflow_addons.layers import WeightNormalization

def conv_block(filts, name, kernel_size = (3, 3), padding = "same", **kwargs):
    return WeightNormalization(
        layers.Conv2D(
            filts, kernel_size, activation=None, padding=padding, **kwargs
        ),
        name="conv"+name,
    )
#CNN13
#See: 
#https://github.com/vikasverma1077/ICT/blob/master/networks/lenet.py
#https://github.com/brain-research/realistic-ssl-evaluation

# %%
lr_alpha = 0.1
dropout_rate = 0.5
num_classes = 10
input_shape = (32, 32, 3)
model = models.Sequential()
model.add(tf.keras.Input(shape=input_shape))
### conv1a
name = '1a'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1b
name = '1b'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1c
name = '1c'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp1"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop1"))

### conv2a
name = '2a'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha))

### conv2b
name = '2b'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv2c
name = '2c'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp2"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop2"))

### conv3a
name = '3a'
model.add(conv_block(name = name, filts = 512, kernel_size = (3,3), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3b
name = '3b'
model.add(conv_block(name = name, filts = 256, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3c
name = '3c'
model.add(conv_block(name = name, filts = 128, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.AveragePooling2D(pool_size=(6, 6), strides=2, padding='valid'))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation=None, name='z'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc1'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc2'))
model.add(WeightNormalization(layers.Dense(num_classes, activation=None)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1a (WeightNormalization) (None, 32, 32, 128)       7297
# _________________________________________________________________
# bn1a (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1a (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1b (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1b (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1b (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1c (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1c (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1c (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# mp1 (MaxPooling2D)           (None, 16, 16, 128)       0
# _________________________________________________________________
# drop1 (Dropout)              (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2a (WeightNormalization) (None, 16, 16, 256)       590593
# _________________________________________________________________
# bn2a (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2b (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2b (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2b (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2c (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2c (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2c (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# mp2 (MaxPooling2D)           (None, 8, 8, 256)         0
# _________________________________________________________________
# drop2 (Dropout)              (None, 8, 8, 256)         0
# _________________________________________________________________
# conv3a (WeightNormalization) (None, 6, 6, 512)         2360833
# _________________________________________________________________
# bn3a (BatchNormalization)    (None, 6, 6, 512)         2048
# _________________________________________________________________
# lrelu3a (LeakyReLU)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv3b (WeightNormalization) (None, 6, 6, 256)         262913
# _________________________________________________________________
# bn3b (BatchNormalization)    (None, 6, 6, 256)         1024
# _________________________________________________________________
# lrelu3b (LeakyReLU)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv3c (WeightNormalization) (None, 6, 6, 128)         65921
# _________________________________________________________________
# bn3c (BatchNormalization)    (None, 6, 6, 128)         512
# _________________________________________________________________
# lrelu3c (LeakyReLU)          (None, 6, 6, 128)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# z (Dense)                    (None, 256)               33024
# _________________________________________________________________
# weight_normalization (Weight (None, 256)               131841
# _________________________________________________________________
# lrelufc1 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_1 (Weig (None, 256)               131841
# _________________________________________________________________
# lrelufc2 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_2 (Weig (None, 10)                5151
# =================================================================
# Total params: 6,549,034
# Trainable params: 3,292,308
# Non-trainable params: 3,256,726
# _________________________________________________________________

# %% [markdown]
# ### Augmentation

# %%
import tensorflow_addons as tfa
def augment(image, label):
    image = tf.squeeze(image) # Add 6 pixels of padding
    image = tf.image.resize_with_crop_or_pad(image, dims[0] + 6, dims[1] + 6) # crop 6 pixels
    image = tf.image.random_crop(image, size=dims)
    image = tf.image.random_brightness(image, max_delta=0.15)  # Random brightness
    image= tf.image.random_contrast(image, lower=0.6, upper=1.4)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_hue(image, 0.05, seed=None)
    #image = tf.image.random_jpeg_quality(image, 10, 100, seed=None)
    image = tfa.image.rotate(image, tf.squeeze(tf.random.uniform(shape = (1,1), minval=-.2, maxval=.2)), interpolation='BILINEAR')
    image = tfa.image.random_cutout(tf.expand_dims(image, 0), (8,8), constant_values=0.5)[0]
    image = tf.clip_by_value(image, 0, 1)
    return image, label

# %%
nex = 10
for i in range(5):
    fig, axs = plt.subplots(ncols=nex +1, figsize=((nex+1)*2, 2))
    axs[0].imshow(X_train[i])
    axs[0].axis('off')
    for ax in axs.flatten()[1:]:
        ax.imshow(augment(X_train[i], Y_train[i])[0])
        ax.axis('off')

# %% [markdown]
# ### train

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', min_delta=0, patience=50, verbose=0, mode='auto',
    baseline=None, restore_best_weights=False
)

# %%
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)
model.compile(tf.keras.optimizers.Adam(1e-3), loss = loss, metrics=['accuracy'])

# %%
Y_valid_one_hot = tf.keras.backend.one_hot(
    Y_valid, num_classes
)

# %%
Y_labeled_one_hot = tf.keras.backend.one_hot(
    Y_labeled, num_classes
)

# %%
train_ds = (
     tf.data.Dataset.from_tensor_slices((X_labeled, Y_labeled_one_hot))
    .shuffle(1000)
    .map(augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.experimental.AUTOTUNE)
)

# %%
history = model.fit(
    train_ds,
    epochs=500,
    validation_data=(X_valid, Y_valid_one_hot),
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 22s 22s/step - loss: 2.4528 - accuracy: 0.0750 - val_loss: 249.1802 - val_accuracy: 0.1014
# Epoch 2/500
# 1/1 [==============================] - 17s 17s/step - loss: 3.5666 - accuracy: 0.2750 - val_loss: 829.5947 - val_accuracy: 0.0977
# Epoch 3/500
# 1/1 [==============================] - 17s 17s/step - loss: 5.7119 - accuracy: 0.1750 - val_loss: 517.3777 - val_accuracy: 0.1022
# Epoch 4/500
# 1/1 [==============================] - 17s 17s/step - loss: 3.5560 - accuracy: 0.2000 - val_loss: 801.1151 - val_accuracy: 0.1003
# Epoch 5/500
# 1/1 [==============================] - 17s 17s/step - loss: 2.8982 - accuracy: 0.2750 - val_loss: 753.3287 - val_accuracy: 0.0997
# Epoch 6/500
# 1/1 [==============================] - 17s 17s/step - loss: 2.8787 - accuracy: 0.2500 - val_loss: 821.6078 - val_accuracy: 0.0998
# Epoch 7/500
# 1/1 [==============================] - 17s 17s/step - loss: 2.6969 - accuracy: 0.2500 - val_loss: 1185.0007 - val_accuracy: 0.0997
# Epoch 8/500
# 1/1 [==============================] - 18s 18s/step - loss: 2.3652 - accuracy: 0.3250 - val_loss: 358.4907 - val_accuracy: 0.1136
# Epoch 9/500
# 1/1 [==============================] - 17s 17s/step - loss: 2.5074 - accuracy: 0.2750 - val_loss: 522.7656 - val_accuracy: 0.0956
# Epoch 10/500
# 1/1 [==============================] - 17s 17s/step - loss: 2.3032 - accuracy: 0.3500 - val_loss: 520.6265 - val_accuracy: 0.1119
# Epoch 11/500
# 1/1 [==============================] - 17s 17s/step - loss: 2.0842 - accuracy: 0.4000 - val_loss: 443.1880 - val_accuracy: 0.1119
# Epoch 12/500
# 1/1 [==============================] - 17s 17s/step - loss: 2.0758 - accuracy: 0.3250 - val_loss: 326.2340 - val_accuracy: 0.1495
# Epoch 13/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.8744 - accuracy: 0.5000 - val_loss: 276.9565 - val_accuracy: 0.1056
# Epoch 14/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.9189 - accuracy: 0.4750 - val_loss: 265.3217 - val_accuracy: 0.1017
# Epoch 15/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.8124 - accuracy: 0.4750 - val_loss: 221.4751 - val_accuracy: 0.1042
# Epoch 16/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.8797 - accuracy: 0.5000 - val_loss: 200.8589 - val_accuracy: 0.1073
# Epoch 17/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.8016 - accuracy: 0.4500 - val_loss: 199.8985 - val_accuracy: 0.1083
# Epoch 18/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.7926 - accuracy: 0.5250 - val_loss: 205.7988 - val_accuracy: 0.1049
# Epoch 19/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.7114 - accuracy: 0.5000 - val_loss: 231.8934 - val_accuracy: 0.1045
# Epoch 20/500
# 1/1 [==============================] - 18s 18s/step - loss: 1.7786 - accuracy: 0.4250 - val_loss: 196.6100 - val_accuracy: 0.1056
# Epoch 21/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.6599 - accuracy: 0.6000 - val_loss: 175.9521 - val_accuracy: 0.1056
# Epoch 22/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.5060 - accuracy: 0.7000 - val_loss: 216.8743 - val_accuracy: 0.1047
# Epoch 23/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.6460 - accuracy: 0.6000 - val_loss: 205.6678 - val_accuracy: 0.1082
# Epoch 24/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.6824 - accuracy: 0.5750 - val_loss: 160.7242 - val_accuracy: 0.1269
# Epoch 25/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.7432 - accuracy: 0.6000 - val_loss: 102.4110 - val_accuracy: 0.1541
# Epoch 26/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.6521 - accuracy: 0.6000 - val_loss: 75.3521 - val_accuracy: 0.1346
# Epoch 27/500
# 1/1 [==============================] - 18s 18s/step - loss: 1.6032 - accuracy: 0.6250 - val_loss: 86.2522 - val_accuracy: 0.1506
# Epoch 28/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.6178 - accuracy: 0.7000 - val_loss: 102.9035 - val_accuracy: 0.1438
# Epoch 29/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.7016 - accuracy: 0.5750 - val_loss: 97.6524 - val_accuracy: 0.1515
# Epoch 30/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.5457 - accuracy: 0.7000 - val_loss: 81.7592 - val_accuracy: 0.1145
# Epoch 31/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.4705 - accuracy: 0.6500 - val_loss: 100.5621 - val_accuracy: 0.1028
# Epoch 32/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.6293 - accuracy: 0.5500 - val_loss: 122.5973 - val_accuracy: 0.1471
# Epoch 33/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.4260 - accuracy: 0.7000 - val_loss: 141.4956 - val_accuracy: 0.1349
# Epoch 34/500
# 1/1 [==============================] - 18s 18s/step - loss: 1.4774 - accuracy: 0.7000 - val_loss: 109.4523 - val_accuracy: 0.1358
# Epoch 35/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.4238 - accuracy: 0.7500 - val_loss: 73.5369 - val_accuracy: 0.1499
# Epoch 36/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.3936 - accuracy: 0.7500 - val_loss: 59.2239 - val_accuracy: 0.1496
# Epoch 37/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.4770 - accuracy: 0.7250 - val_loss: 58.9743 - val_accuracy: 0.1356
# Epoch 38/500
# 1/1 [==============================] - 17s 17s/step - loss: 1.3596 - accuracy: 0.8250 - val_loss: 65.6295 - val_accuracy: 0.1325
# Epoch 39/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.3740 - accuracy: 0.7500 - val_loss: 69.1387 - val_accuracy: 0.1388
# Epoch 40/500
# 1/1 [==============================] - 15s 15s/step - loss: 1.3524 - accuracy: 0.7750 - val_loss: 67.7871 - val_accuracy: 0.1406
# Epoch 41/500
# 1/1 [==============================] - 15s 15s/step - loss: 1.4132 - accuracy: 0.8000 - val_loss: 59.6934 - val_accuracy: 0.1442
# Epoch 42/500
# 1/1 [==============================] - 15s 15s/step - loss: 1.3099 - accuracy: 0.7750 - val_loss: 52.9256 - val_accuracy: 0.1446
# Epoch 43/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.4687 - accuracy: 0.7000 - val_loss: 48.7998 - val_accuracy: 0.1480
# Epoch 44/500
# 1/1 [==============================] - 15s 15s/step - loss: 1.3130 - accuracy: 0.8250 - val_loss: 43.8663 - val_accuracy: 0.1436
# Epoch 45/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.3726 - accuracy: 0.7500 - val_loss: 37.8916 - val_accuracy: 0.1266
# Epoch 46/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.3057 - accuracy: 0.7750 - val_loss: 34.1058 - val_accuracy: 0.1195
# Epoch 47/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.2975 - accuracy: 0.7750 - val_loss: 30.5631 - val_accuracy: 0.1342
# Epoch 48/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.4222 - accuracy: 0.7500 - val_loss: 30.1956 - val_accuracy: 0.1435
# Epoch 49/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1787 - accuracy: 0.9000 - val_loss: 30.0030 - val_accuracy: 0.1445
# Epoch 50/500
# 1/1 [==============================] - 13s 13s/step - loss: 1.3382 - accuracy: 0.8000 - val_loss: 28.1464 - val_accuracy: 0.1525
# Epoch 51/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.4116 - accuracy: 0.7250 - val_loss: 26.2389 - val_accuracy: 0.1554
# Epoch 52/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.2197 - accuracy: 0.8750 - val_loss: 24.1450 - val_accuracy: 0.1507
# Epoch 53/500
# 1/1 [==============================] - 15s 15s/step - loss: 1.2540 - accuracy: 0.8500 - val_loss: 23.5558 - val_accuracy: 0.1472
# Epoch 54/500
# 1/1 [==============================] - 15s 15s/step - loss: 1.2284 - accuracy: 0.8750 - val_loss: 22.3764 - val_accuracy: 0.1428
# Epoch 55/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.3480 - accuracy: 0.6750 - val_loss: 21.4951 - val_accuracy: 0.1377
# Epoch 56/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.4104 - accuracy: 0.7000 - val_loss: 19.7209 - val_accuracy: 0.1339
# Epoch 57/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.2927 - accuracy: 0.8750 - val_loss: 17.7824 - val_accuracy: 0.1320
# Epoch 58/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.2660 - accuracy: 0.8500 - val_loss: 18.5180 - val_accuracy: 0.1464
# Epoch 59/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.2803 - accuracy: 0.8000 - val_loss: 20.1483 - val_accuracy: 0.1538
# Epoch 60/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.2208 - accuracy: 0.8250 - val_loss: 19.9010 - val_accuracy: 0.1529
# Epoch 61/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.2960 - accuracy: 0.8000 - val_loss: 18.2578 - val_accuracy: 0.1539
# Epoch 62/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.2474 - accuracy: 0.8000 - val_loss: 18.0686 - val_accuracy: 0.1597
# Epoch 63/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1950 - accuracy: 0.9000 - val_loss: 18.6877 - val_accuracy: 0.1645
# Epoch 64/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1579 - accuracy: 0.9000 - val_loss: 19.5999 - val_accuracy: 0.1635
# Epoch 65/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.3003 - accuracy: 0.8250 - val_loss: 19.3787 - val_accuracy: 0.1630
# Epoch 66/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1897 - accuracy: 0.9000 - val_loss: 16.5838 - val_accuracy: 0.1598
# Epoch 67/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1276 - accuracy: 0.9500 - val_loss: 14.1743 - val_accuracy: 0.1437
# Epoch 68/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.2193 - accuracy: 0.8250 - val_loss: 13.0296 - val_accuracy: 0.1395
# Epoch 69/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.2242 - accuracy: 0.8250 - val_loss: 11.7716 - val_accuracy: 0.1357
# Epoch 70/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1435 - accuracy: 0.9000 - val_loss: 10.5729 - val_accuracy: 0.1242
# Epoch 71/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1044 - accuracy: 0.9750 - val_loss: 9.6071 - val_accuracy: 0.1188
# Epoch 72/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1539 - accuracy: 0.9000 - val_loss: 9.1506 - val_accuracy: 0.1291
# Epoch 73/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1779 - accuracy: 0.8500 - val_loss: 9.3029 - val_accuracy: 0.1415
# Epoch 74/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1371 - accuracy: 0.9250 - val_loss: 9.6941 - val_accuracy: 0.1487
# Epoch 75/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1769 - accuracy: 0.8750 - val_loss: 9.9840 - val_accuracy: 0.1541
# Epoch 76/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1875 - accuracy: 0.8500 - val_loss: 10.2168 - val_accuracy: 0.1568
# Epoch 77/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1643 - accuracy: 0.8750 - val_loss: 10.3027 - val_accuracy: 0.1550
# Epoch 78/500
# 1/1 [==============================] - 15s 15s/step - loss: 1.2540 - accuracy: 0.8500 - val_loss: 10.5284 - val_accuracy: 0.1564
# Epoch 79/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1659 - accuracy: 0.9000 - val_loss: 9.9854 - val_accuracy: 0.1653
# Epoch 80/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1039 - accuracy: 0.9500 - val_loss: 9.2285 - val_accuracy: 0.1705
# Epoch 81/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0880 - accuracy: 0.9250 - val_loss: 9.2900 - val_accuracy: 0.1733
# Epoch 82/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1146 - accuracy: 0.8750 - val_loss: 9.6216 - val_accuracy: 0.1657
# Epoch 83/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0868 - accuracy: 0.9250 - val_loss: 9.7744 - val_accuracy: 0.1570
# Epoch 84/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0896 - accuracy: 0.9250 - val_loss: 9.7698 - val_accuracy: 0.1568
# Epoch 85/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1124 - accuracy: 0.9250 - val_loss: 10.0184 - val_accuracy: 0.1602
# Epoch 86/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1394 - accuracy: 0.9250 - val_loss: 9.9872 - val_accuracy: 0.1772
# Epoch 87/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0856 - accuracy: 0.9250 - val_loss: 9.3284 - val_accuracy: 0.1765
# Epoch 88/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0806 - accuracy: 0.9000 - val_loss: 9.2985 - val_accuracy: 0.1792
# Epoch 89/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1303 - accuracy: 0.8500 - val_loss: 9.5765 - val_accuracy: 0.1789
# Epoch 90/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1105 - accuracy: 0.9250 - val_loss: 10.5920 - val_accuracy: 0.1802
# Epoch 91/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1195 - accuracy: 0.8750 - val_loss: 11.2787 - val_accuracy: 0.1739
# Epoch 92/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0681 - accuracy: 0.9500 - val_loss: 11.1050 - val_accuracy: 0.1736
# Epoch 93/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0631 - accuracy: 0.9750 - val_loss: 9.8438 - val_accuracy: 0.1762
# Epoch 94/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0786 - accuracy: 0.9500 - val_loss: 8.5819 - val_accuracy: 0.1708
# Epoch 95/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0565 - accuracy: 0.9750 - val_loss: 7.6076 - val_accuracy: 0.1608
# Epoch 96/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0366 - accuracy: 0.9500 - val_loss: 7.2921 - val_accuracy: 0.1504
# Epoch 97/500
# 1/1 [==============================] - 15s 15s/step - loss: 1.0829 - accuracy: 0.9500 - val_loss: 7.0282 - val_accuracy: 0.1627
# Epoch 98/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0351 - accuracy: 0.9500 - val_loss: 6.7440 - val_accuracy: 0.1731
# Epoch 99/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0338 - accuracy: 0.9750 - val_loss: 6.8300 - val_accuracy: 0.1757
# Epoch 100/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0953 - accuracy: 0.9250 - val_loss: 6.3407 - val_accuracy: 0.1805
# Epoch 101/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0552 - accuracy: 0.9500 - val_loss: 6.0653 - val_accuracy: 0.1776
# Epoch 102/500
# 1/1 [==============================] - 13s 13s/step - loss: 1.0648 - accuracy: 0.9500 - val_loss: 6.1250 - val_accuracy: 0.1766
# Epoch 103/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0282 - accuracy: 0.9750 - val_loss: 6.2384 - val_accuracy: 0.1688
# Epoch 104/500
# 1/1 [==============================] - 15s 15s/step - loss: 1.0385 - accuracy: 0.9750 - val_loss: 6.6715 - val_accuracy: 0.1672
# Epoch 105/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0221 - accuracy: 1.0000 - val_loss: 7.0387 - val_accuracy: 0.1670
# Epoch 106/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0613 - accuracy: 0.9500 - val_loss: 6.9330 - val_accuracy: 0.1580
# Epoch 107/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0554 - accuracy: 0.9750 - val_loss: 6.6178 - val_accuracy: 0.1448
# Epoch 108/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1186 - accuracy: 0.9250 - val_loss: 6.0731 - val_accuracy: 0.1327
# Epoch 109/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0686 - accuracy: 0.9500 - val_loss: 5.6730 - val_accuracy: 0.1264
# Epoch 110/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0600 - accuracy: 0.9250 - val_loss: 5.5558 - val_accuracy: 0.1357
# Epoch 111/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0219 - accuracy: 0.9750 - val_loss: 5.6729 - val_accuracy: 0.1456
# Epoch 112/500
# 1/1 [==============================] - 14s 14s/step - loss: 0.9974 - accuracy: 1.0000 - val_loss: 5.7023 - val_accuracy: 0.1444
# Epoch 113/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.1714 - accuracy: 0.9000 - val_loss: 5.6112 - val_accuracy: 0.1485
# Epoch 114/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0246 - accuracy: 0.9500 - val_loss: 5.1545 - val_accuracy: 0.1476
# Epoch 115/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0119 - accuracy: 0.9750 - val_loss: 4.7911 - val_accuracy: 0.1396
# Epoch 116/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0185 - accuracy: 1.0000 - val_loss: 4.5755 - val_accuracy: 0.1346
# Epoch 117/500
# 1/1 [==============================] - 14s 14s/step - loss: 1.0120 - accuracy: 0.9750 - val_loss: 4.5388 - val_accuracy: 0.1308
# Epoch 118/500
# 1/1 [==============================] - 13s 13s/step - loss: 1.0060 - accuracy: 0.9750 - val_loss: 4.5369 - val_accuracy: 0.1337
# Epoch 119/500
# 1/1 [==============================] - 14s 14s/step - loss: 0.9632 - accuracy: 1.0000 - val_loss: 4.5289 - val_accuracy: 0.1391
# Epoch 120/500
# 1/1 [==============================] - 12s 12s/step - loss: 0.9535 - accuracy: 1.0000 - val_loss: 4.5285 - val_accuracy: 0.1418
# Epoch 121/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9897 - accuracy: 0.9500 - val_loss: 4.5706 - val_accuracy: 0.1450
# Epoch 122/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9577 - accuracy: 1.0000 - val_loss: 4.5678 - val_accuracy: 0.1463
# Epoch 123/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9750 - accuracy: 1.0000 - val_loss: 4.5047 - val_accuracy: 0.1460
# Epoch 124/500
# 1/1 [==============================] - 12s 12s/step - loss: 0.9676 - accuracy: 1.0000 - val_loss: 4.4305 - val_accuracy: 0.1467
# Epoch 125/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9451 - accuracy: 1.0000 - val_loss: 4.3745 - val_accuracy: 0.1481
# Epoch 126/500
# 1/1 [==============================] - 12s 12s/step - loss: 0.9788 - accuracy: 0.9750 - val_loss: 4.2898 - val_accuracy: 0.1499
# Epoch 127/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9659 - accuracy: 0.9750 - val_loss: 4.2173 - val_accuracy: 0.1476
# Epoch 128/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9918 - accuracy: 1.0000 - val_loss: 4.1339 - val_accuracy: 0.1518
# Epoch 129/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9788 - accuracy: 0.9750 - val_loss: 4.0792 - val_accuracy: 0.1579
# Epoch 130/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9711 - accuracy: 1.0000 - val_loss: 4.0400 - val_accuracy: 0.1653
# Epoch 131/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9821 - accuracy: 0.9750 - val_loss: 3.9052 - val_accuracy: 0.1716
# Epoch 132/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9948 - accuracy: 1.0000 - val_loss: 3.8233 - val_accuracy: 0.1658
# Epoch 133/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9625 - accuracy: 0.9750 - val_loss: 3.7844 - val_accuracy: 0.1602
# Epoch 134/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9627 - accuracy: 1.0000 - val_loss: 3.7751 - val_accuracy: 0.1560
# Epoch 135/500
# 1/1 [==============================] - 11s 11s/step - loss: 1.0201 - accuracy: 0.9500 - val_loss: 3.7503 - val_accuracy: 0.1649
# Epoch 136/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9675 - accuracy: 1.0000 - val_loss: 3.8229 - val_accuracy: 0.1695
# Epoch 137/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9811 - accuracy: 1.0000 - val_loss: 3.9516 - val_accuracy: 0.1718
# Epoch 138/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9958 - accuracy: 1.0000 - val_loss: 3.9603 - val_accuracy: 0.1681
# Epoch 139/500
# 1/1 [==============================] - 10s 10s/step - loss: 1.0272 - accuracy: 0.9500 - val_loss: 3.8869 - val_accuracy: 0.1568
# Epoch 140/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9848 - accuracy: 1.0000 - val_loss: 3.7940 - val_accuracy: 0.1523
# Epoch 141/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9806 - accuracy: 0.9500 - val_loss: 3.7267 - val_accuracy: 0.1409
# Epoch 142/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9864 - accuracy: 0.9750 - val_loss: 3.5587 - val_accuracy: 0.1453
# Epoch 143/500
# 1/1 [==============================] - 11s 11s/step - loss: 1.0623 - accuracy: 0.9250 - val_loss: 3.5062 - val_accuracy: 0.1499
# Epoch 144/500
# 1/1 [==============================] - 11s 11s/step - loss: 1.0043 - accuracy: 0.9500 - val_loss: 3.5323 - val_accuracy: 0.1500
# Epoch 145/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9604 - accuracy: 0.9750 - val_loss: 3.5609 - val_accuracy: 0.1486
# Epoch 146/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9888 - accuracy: 1.0000 - val_loss: 3.5821 - val_accuracy: 0.1483
# Epoch 147/500
# 1/1 [==============================] - 11s 11s/step - loss: 1.0130 - accuracy: 0.9500 - val_loss: 3.6266 - val_accuracy: 0.1564
# Epoch 148/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9452 - accuracy: 1.0000 - val_loss: 3.7441 - val_accuracy: 0.1599
# Epoch 149/500
# 1/1 [==============================] - 11s 11s/step - loss: 1.0012 - accuracy: 0.9750 - val_loss: 3.9830 - val_accuracy: 0.1640
# Epoch 150/500
# 1/1 [==============================] - 11s 11s/step - loss: 0.9636 - accuracy: 1.0000 - val_loss: 4.1524 - val_accuracy: 0.1587

# %% [markdown]
# ### evaluate

# %%
Y_test_one_hot = tf.keras.backend.one_hot(
    Y_test, num_classes
)
result = model.evaluate(X_test, Y_test_one_hot)
# Out:
# 313/313 [==============================] - 11s 35ms/step - loss: 4.2137 - accuracy: 0.1546

# %%
plt.semilogx(history.history['loss'])
plt.semilogx(history.history['val_loss'])

# %%
plt.semilogx(history.history['accuracy'])
plt.semilogx(history.history['val_accuracy'])

# %%
submodel = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
    )
z = submodel.predict(X_train)
np.shape(z)
# Out:
# (40000, 256)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sun Aug  9 22:54:21 2020 Finding Nearest Neighbors
# Sun Aug  9 22:54:21 2020 Building RP forest with 15 trees
# Sun Aug  9 22:54:22 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# Sun Aug  9 22:54:32 2020 Finished Nearest Neighbor Search
# Sun Aug  9 22:54:35 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Aug  9 22:55:03 2020 Finished embedding

# %%
predictions = model.predict(X_train)

# %%
mask = np.array(np.argmax(predictions, axis=1)) != Y_train.flatten()

# %%
fig, axs = plt.subplots(ncols = 5, figsize=(50,10))
axs[0].scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 1, cmap = plt.cm.tab10)
axs[1].scatter(embedding[:, 0], embedding[:, 1], c=np.argmax(predictions, axis=1), s= 1, alpha = 1, cmap = plt.cm.tab10)
axs[2].scatter(embedding[:, 0], embedding[:, 1], c=np.array(np.argmax(predictions, axis=1)) == Y_train.flatten(), s= 1, alpha = 1, cmap = plt.cm.viridis)
axs[3].scatter(embedding[mask, 0], embedding[mask, 1], c=Y_train.flatten()[mask], s= 10, alpha = 1, cmap = plt.cm.tab10)
axs[4].scatter(embedding[mask, 0], embedding[mask, 1], c=np.argmax(predictions, axis=1)[mask], s= 10, alpha = 1, cmap = plt.cm.tab10)

# %% [markdown]
# ### save results

# %%
# save score, valid embedding, weights, results

# %%
from tfumap.paths import MODEL_DIR, ensure_dir

# %%
save_folder = MODEL_DIR / 'semisupervised-keras' / dataset / str(labels_per_class) / datestring
ensure_dir(save_folder)

# %% [markdown]
# #### save weights

# %%
encoder = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
)

# %%
encoder.save_weights((save_folder / "encoder").as_posix())

# %%
classifier = tf.keras.models.Model(
        [tf.keras.Input(tensor=model.get_layer('weight_normalization').input)], [model.outputs[0]]
)
print([i.name for i in classifier.layers])
# Out:
# ['input_2', 'weight_normalization', 'lrelufc1', 'weight_normalization_1', 'lrelufc2', 'weight_normalization_2']

# %%
classifier.save_weights((save_folder / "classifier").as_posix())

# %%
model.save_weights((save_folder / "full_model").as_posix())

# %% [markdown]
# #### save score

# %%
Y_test_one_hot = tf.keras.backend.one_hot(
    Y_test, num_classes
)
result = model.evaluate(X_test, Y_test_one_hot)
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 4.2137 - accuracy: 0.1546

# %%
np.save(save_folder / 'test_loss.npy', result)

# %% [markdown]
# #### save embedding

# %%
z = encoder.predict(X_train)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))

plt.scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Mon Aug 10 09:31:55 2020 Finding Nearest Neighbors
# Mon Aug 10 09:31:55 2020 Building RP forest with 15 trees
# Mon Aug 10 09:31:57 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# Mon Aug 10 09:32:00 2020 Finished Nearest Neighbor Search
# Mon Aug 10 09:32:01 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Aug 10 09:32:36 2020 Finished embedding

# %%
np.save(save_folder / 'train_embedding.npy', embedding)

# %% [markdown]
# #### save results

# %%
import pickle

# %%
with open(save_folder / 'history.pickle', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
