# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0

# %%
import numpy as np
from tfumap.semisupervised_keras import pretrained_networks
from tfumap.semisupervised_keras import load_architecture
from tfumap.paths import MODEL_DIR

# %%
from tfumap.semisupervised_keras import load_dataset

# %%
dataset = "mnist"
n_latent_dims = 1024

# %%
(
    X_train,
    X_test,
    X_labeled,
    Y_labeled,
    Y_masked,
    X_valid,
    Y_train,
    Y_test,
    Y_valid,
    Y_valid_one_hot,
    Y_labeled_one_hot,
    num_classes,
    dims
) = load_dataset(dataset, 'full')

# %%
encoder, classifier, embedder = load_architecture(dataset, n_latent_dims)

# %%
aug_types = [
    "not_augmented",
    "augmented",
    "umap_euclidean",
    "umap_learned",
    "umap_augmented_learned",
    "umap_euclidean_augmented",
]

# %%
for labels_per_class in [4, 16, 64, 256, 1024, 'full']:
    for aug_str in aug_types:
        pretrained_weights_loc = pretrained_networks[dataset][aug_str][labels_per_class]
        load_folder = (
            MODEL_DIR
            / "semisupervised-keras"
            / dataset
            / str(labels_per_class)
            / pretrained_weights_loc
        )
        classifier.load_weights((load_folder / "classifier").as_posix())
        encoder.load_weights((load_folder / "encoder").as_posix())
        # test current acc
        pretrained_predictions = classifier.predict(encoder.predict(X_test, verbose=True), verbose=True)
        pretrained_predictions = np.argmax(pretrained_predictions, axis=1)
        pretrained_acc = pretrained_predictions == Y_test
        mean_acc = np.mean(pretrained_acc)
        sem_acc = np.std(pretrained_acc) / np.sqrt(len(pretrained_acc))
        np.save(load_folder / 'test_loss_SEM.npy', (mean_acc, sem_acc))
        print('pretrained acc: {} +- {}'.format(mean_acc, sem_acc))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1112 14:50:59.845838 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1cee6d8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1d129e8>).
# W1112 14:50:59.848712 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1ce82e8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d20abe80>).
# W1112 14:51:00.085269 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1da19e8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1e4c278>).
# W1112 14:51:00.089121 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1e4c278> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1fa86a0>).
# W1112 14:51:00.094338 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1fddf98> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1fdda90>).
# W1112 14:51:00.097384 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1fdda90> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1fdd978>).
# W1112 14:51:00.101487 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1af0860> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1af0b70>).
# W1112 14:51:00.104433 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1af0b70> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1af0cc0>).
# W1112 14:51:00.110726 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1c673c8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1c675f8>).
# W1112 14:51:00.113697 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1c675f8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1c67860>).
# W1112 14:51:00.117759 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d18df048> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d18df668>).
# W1112 14:51:00.120727 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d18df668> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d18df8d0>).
# W1112 14:51:00.124795 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1f7e390> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f7e6a0>).
# W1112 14:51:00.127813 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f7e6a0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1f7e908>).
# W1112 14:51:00.134148 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1eb1f60> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d19f3358>).
# W1112 14:51:00.137165 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d19f3358> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d19f3390>).
# W1112 14:51:00.141238 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1f30e80> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f38240>).
# W1112 14:51:00.144223 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f38240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1f38400>).
# W1112 14:51:00.148234 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d202aeb8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d2023208>).
# W1112 14:51:00.151194 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d2023208> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d2023400>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.8143 +- 0.003888643851010273
# W1112 14:51:05.647308 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1cee6d8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1d129e8>).
# W1112 14:51:05.649327 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1ce82e8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d20abe80>).
# W1112 14:51:05.803540 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1da19e8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1e4c278>).
# W1112 14:51:05.807257 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1e4c278> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1fa86a0>).
# W1112 14:51:05.811258 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1fddf98> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1fdda90>).
# W1112 14:51:05.814023 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1fdda90> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1fdd978>).
# W1112 14:51:05.817954 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1af0860> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1af0b70>).
# W1112 14:51:05.820735 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1af0b70> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1af0cc0>).
# W1112 14:51:05.827664 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1c673c8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1c675f8>).
# W1112 14:51:05.830515 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1c675f8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1c67860>).
# W1112 14:51:05.834270 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d18df048> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d18df668>).
# W1112 14:51:05.837094 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d18df668> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d18df8d0>).
# W1112 14:51:05.840899 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1f7e390> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f7e6a0>).
# W1112 14:51:05.843736 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f7e6a0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1f7e908>).
# W1112 14:51:05.849893 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1eb1f60> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d19f3358>).
# W1112 14:51:05.852706 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d19f3358> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d19f3390>).
# W1112 14:51:05.856574 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1f30e80> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f38240>).
# W1112 14:51:05.859274 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f38240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1f38400>).
# W1112 14:51:05.863183 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d202aeb8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d2023208>).
# W1112 14:51:05.865887 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d2023208> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d2023400>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.928 +- 0.002584879107424562
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9785 +- 0.001450439588538592
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.8325 +- 0.003734216785351381
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.955 +- 0.0020730412441627884
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9779 +- 0.0014700880925985352
# W1112 14:51:21.122730 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1cee6d8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1d129e8>).
# W1112 14:51:21.126235 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1ce82e8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d20abe80>).
# W1112 14:51:21.213243 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1da19e8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1e4c278>).
# W1112 14:51:21.217047 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1e4c278> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1fa86a0>).
# W1112 14:51:21.222039 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1fddf98> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1fdda90>).
# W1112 14:51:21.224786 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1fdda90> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1fdd978>).
# W1112 14:51:21.228785 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1af0860> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1af0b70>).
# W1112 14:51:21.232813 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1af0b70> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1af0cc0>).
# W1112 14:51:21.240845 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1c673c8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1c675f8>).
# W1112 14:51:21.243797 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1c675f8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1c67860>).
# W1112 14:51:21.247717 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d18df048> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d18df668>).
# W1112 14:51:21.250494 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d18df668> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d18df8d0>).
# W1112 14:51:21.254407 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1f7e390> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f7e6a0>).
# W1112 14:51:21.257228 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f7e6a0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1f7e908>).
# W1112 14:51:21.264454 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1eb1f60> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d19f3358>).
# W1112 14:51:21.267682 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d19f3358> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d19f3390>).
# W1112 14:51:21.271579 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1f30e80> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f38240>).
# W1112 14:51:21.274689 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f38240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1f38400>).
# W1112 14:51:21.279081 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d202aeb8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d2023208>).
# W1112 14:51:21.282774 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d2023208> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d2023400>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9548 +- 0.0020774253295846763
# W1112 14:51:24.010025 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1cee6d8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1d129e8>).
# W1112 14:51:24.011837 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1ce82e8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d20abe80>).
# W1112 14:51:24.126073 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1da19e8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1e4c278>).
# W1112 14:51:24.129376 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1e4c278> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1fa86a0>).
# W1112 14:51:24.133071 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1fddf98> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1fdda90>).
# W1112 14:51:24.135643 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1fdda90> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1fdd978>).
# W1112 14:51:24.139653 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1af0860> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1af0b70>).
# W1112 14:51:24.143817 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1af0b70> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1af0cc0>).
# W1112 14:51:24.153421 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1c673c8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1c675f8>).
# W1112 14:51:24.157505 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1c675f8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1c67860>).
# W1112 14:51:24.161554 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d18df048> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d18df668>).
# W1112 14:51:24.165150 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d18df668> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d18df8d0>).
# W1112 14:51:24.170350 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1f7e390> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f7e6a0>).
# W1112 14:51:24.173106 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f7e6a0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1f7e908>).
# W1112 14:51:24.178883 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1eb1f60> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d19f3358>).
# W1112 14:51:24.181457 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d19f3358> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d19f3390>).
# W1112 14:51:24.185817 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1f30e80> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f38240>).
# W1112 14:51:24.188333 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f38240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1f38400>).
# W1112 14:51:24.191968 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d202aeb8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d2023208>).
# W1112 14:51:24.194453 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d2023208> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d2023400>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9715 +- 0.0016639636414297037
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9836 +- 0.0012700803124212263
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9557 +- 0.002057608077355841
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9805 +- 0.0013827418414150922
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 1s 2ms/step
# pretrained acc: 0.9899 +- 0.0009998994949493674
# W1112 14:51:40.749233 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1cee6d8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1d129e8>).
# W1112 14:51:40.751491 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1ce82e8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d20abe80>).
# W1112 14:51:40.873659 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1da19e8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1e4c278>).
# W1112 14:51:40.876701 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1e4c278> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1fa86a0>).
# W1112 14:51:40.881779 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1fddf98> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1fdda90>).
# W1112 14:51:40.885159 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1fdda90> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1fdd978>).
# W1112 14:51:40.890328 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1af0860> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1af0b70>).
# ...
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d18df668> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d18df8d0>).
# W1112 14:52:37.078634 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1f7e390> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f7e6a0>).
# W1112 14:52:37.082127 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f7e6a0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1f7e908>).
# W1112 14:52:37.087931 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1eb1f60> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d19f3358>).
# W1112 14:52:37.091641 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d19f3358> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d19f3390>).
# W1112 14:52:37.099064 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1f30e80> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f38240>).
# W1112 14:52:37.102336 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f38240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1f38400>).
# W1112 14:52:37.106348 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d202aeb8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d2023208>).
# W1112 14:52:37.109246 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d2023208> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d2023400>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.9965 +- 0.0005905717568594016
# W1112 14:52:39.861105 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1cee6d8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1d129e8>).
# W1112 14:52:39.862894 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1ce82e8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d20abe80>).
# W1112 14:52:39.998439 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1da19e8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1e4c278>).
# W1112 14:52:40.001730 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1e4c278> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1fa86a0>).
# W1112 14:52:40.005674 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1fddf98> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1fdda90>).
# W1112 14:52:40.008575 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1fdda90> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1fdd978>).
# W1112 14:52:40.012522 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1af0860> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1af0b70>).
# W1112 14:52:40.015417 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1af0b70> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1af0cc0>).
# W1112 14:52:40.022593 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1c673c8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1c675f8>).
# W1112 14:52:40.025503 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1c675f8> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1c67860>).
# W1112 14:52:40.029491 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d18df048> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d18df668>).
# W1112 14:52:40.032343 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d18df668> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d18df8d0>).
# W1112 14:52:40.036184 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1f7e390> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f7e6a0>).
# W1112 14:52:40.038942 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f7e6a0> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1f7e908>).
# W1112 14:52:40.044962 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1eb1f60> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d19f3358>).
# W1112 14:52:40.047764 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d19f3358> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d19f3390>).
# W1112 14:52:40.051574 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d1f30e80> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f38240>).
# W1112 14:52:40.054308 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d1f38240> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d1f38400>).
# W1112 14:52:40.058145 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow_addons.layers.wrappers.WeightNormalization object at 0x7f05d202aeb8> and <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d2023208>).
# W1112 14:52:40.060892 139666144429888 base.py:272] Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f05d2023208> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f05d2023400>).
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.9963 +- 0.0006071498991188255
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.9964 +- 0.0005989190262464533
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.9957 +- 0.0006543324842921982
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.996 +- 0.0006311893535223802
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 0s 1ms/step
# pretrained acc: 0.9967 +- 0.0005735076285456018

# %%
mean_acc
# Out:
# 0.9967
