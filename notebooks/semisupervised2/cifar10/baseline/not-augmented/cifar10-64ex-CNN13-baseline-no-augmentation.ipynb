# %%
# reload packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Choose GPU

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_devices)>0:
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
print(gpu_devices)
tf.keras.backend.clear_session()
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### dataset information

# %%
from datetime import datetime

dataset = "cifar10"
dims = (32, 32, 3)
num_classes = 10
labels_per_class = 64 # full
batch_size = 128
datestring = datetime.now().strftime("%Y_%m_%d_%H_%M_%S_%f")
datestring = (
    str(dataset)
    + "_"
    + str(labels_per_class)
    + "____"
    + datestring 
    + '_baseline'
)
print(datestring)
# Out:
# cifar10_64____2020_08_09_22_14_33_994011_baseline

# %% [markdown]
# ### Load packages

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from IPython import display
import pandas as pd
import umap
import copy
import os, tempfile
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### Load dataset

# %%
from tfumap.load_datasets import load_CIFAR10, mask_labels
X_train, X_test, X_valid, Y_train, Y_test, Y_valid = load_CIFAR10(flatten=False)
X_train.shape
# Out:
# (40000, 32, 32, 3)

# %%
if labels_per_class == "full":
    X_labeled = X_train
    Y_masked = Y_labeled = Y_train
else:
    X_labeled, Y_labeled, Y_masked = mask_labels(
        X_train, Y_train, labels_per_class=labels_per_class
    )

# %% [markdown]
# ### Build network

# %%
from tensorflow.keras import datasets, layers, models
from tensorflow_addons.layers import WeightNormalization

def conv_block(filts, name, kernel_size = (3, 3), padding = "same", **kwargs):
    return WeightNormalization(
        layers.Conv2D(
            filts, kernel_size, activation=None, padding=padding, **kwargs
        ),
        name="conv"+name,
    )
#CNN13
#See: 
#https://github.com/vikasverma1077/ICT/blob/master/networks/lenet.py
#https://github.com/brain-research/realistic-ssl-evaluation

# %%
lr_alpha = 0.1
dropout_rate = 0.5
num_classes = 10
input_shape = (32, 32, 3)
model = models.Sequential()
model.add(tf.keras.Input(shape=input_shape))
### conv1a
name = '1a'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1b
name = '1b'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv1c
name = '1c'
model.add(conv_block(name = name, filts = 128, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp1"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop1"))

### conv2a
name = '2a'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha))

### conv2b
name = '2b'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv2c
name = '2c'
model.add(conv_block(name = name, filts = 256, kernel_size = (3,3), padding="same"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid', name="mp2"))
# dropout
model.add(layers.Dropout(dropout_rate, name="drop2"))

### conv3a
name = '3a'
model.add(conv_block(name = name, filts = 512, kernel_size = (3,3), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3b
name = '3b'
model.add(conv_block(name = name, filts = 256, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

### conv3c
name = '3c'
model.add(conv_block(name = name, filts = 128, kernel_size = (1,1), padding="valid"))
model.add(layers.BatchNormalization(name="bn"+name))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelu'+name))

# max pooling
model.add(layers.AveragePooling2D(pool_size=(6, 6), strides=2, padding='valid'))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation=None, name='z'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc1'))
model.add(WeightNormalization(layers.Dense(256, activation=None)))
model.add(layers.LeakyReLU(alpha=lr_alpha, name = 'lrelufc2'))
model.add(WeightNormalization(layers.Dense(num_classes, activation=None)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1a (WeightNormalization) (None, 32, 32, 128)       7297
# _________________________________________________________________
# bn1a (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1a (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1b (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1b (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1b (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# conv1c (WeightNormalization) (None, 32, 32, 128)       295297
# _________________________________________________________________
# bn1c (BatchNormalization)    (None, 32, 32, 128)       512
# _________________________________________________________________
# lrelu1c (LeakyReLU)          (None, 32, 32, 128)       0
# _________________________________________________________________
# mp1 (MaxPooling2D)           (None, 16, 16, 128)       0
# _________________________________________________________________
# drop1 (Dropout)              (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2a (WeightNormalization) (None, 16, 16, 256)       590593
# _________________________________________________________________
# bn2a (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2b (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2b (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2b (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2c (WeightNormalization) (None, 16, 16, 256)       1180417
# _________________________________________________________________
# bn2c (BatchNormalization)    (None, 16, 16, 256)       1024
# _________________________________________________________________
# lrelu2c (LeakyReLU)          (None, 16, 16, 256)       0
# _________________________________________________________________
# mp2 (MaxPooling2D)           (None, 8, 8, 256)         0
# _________________________________________________________________
# drop2 (Dropout)              (None, 8, 8, 256)         0
# _________________________________________________________________
# conv3a (WeightNormalization) (None, 6, 6, 512)         2360833
# _________________________________________________________________
# bn3a (BatchNormalization)    (None, 6, 6, 512)         2048
# _________________________________________________________________
# lrelu3a (LeakyReLU)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv3b (WeightNormalization) (None, 6, 6, 256)         262913
# _________________________________________________________________
# bn3b (BatchNormalization)    (None, 6, 6, 256)         1024
# _________________________________________________________________
# lrelu3b (LeakyReLU)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv3c (WeightNormalization) (None, 6, 6, 128)         65921
# _________________________________________________________________
# bn3c (BatchNormalization)    (None, 6, 6, 128)         512
# _________________________________________________________________
# lrelu3c (LeakyReLU)          (None, 6, 6, 128)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# z (Dense)                    (None, 256)               33024
# _________________________________________________________________
# weight_normalization (Weight (None, 256)               131841
# _________________________________________________________________
# lrelufc1 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_1 (Weig (None, 256)               131841
# _________________________________________________________________
# lrelufc2 (LeakyReLU)         (None, 256)               0
# _________________________________________________________________
# weight_normalization_2 (Weig (None, 10)                5151
# =================================================================
# Total params: 6,549,034
# Trainable params: 3,292,308
# Non-trainable params: 3,256,726
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', min_delta=0, patience=50, verbose=0, mode='auto',
    baseline=None, restore_best_weights=False
)

# %%
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.2, from_logits=True)

# %%
model.compile(tf.keras.optimizers.Adam(1e-4), loss = loss, metrics=['accuracy'])

# %%
Y_valid_one_hot = tf.keras.backend.one_hot(
    Y_valid, num_classes
)

# %%
Y_labeled_one_hot = tf.keras.backend.one_hot(
    Y_labeled, num_classes
)

# %%
history = model.fit(
    X_labeled,
    Y_labeled_one_hot,
    batch_size=batch_size,
    epochs=500,
    validation_data=(X_valid, Y_valid_one_hot),
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/500
# 2/5 [===========>..................] - ETA: 0s - loss: 2.4974 - accuracy: 0.0898
# WARNING: Logging before flag parsing goes to stderr.
# W0809 22:14:58.990566 139753210758976 callbacks.py:328] Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0251s vs `on_train_batch_end` time: 0.1307s). Check your callbacks.
# 5/5 [==============================] - 9s 2s/step - loss: 2.4133 - accuracy: 0.1297 - val_loss: 13.9804 - val_accuracy: 0.1289
# Epoch 2/500
# 5/5 [==============================] - 6s 1s/step - loss: 2.2359 - accuracy: 0.2078 - val_loss: 7.8654 - val_accuracy: 0.1418
# Epoch 3/500
# 5/5 [==============================] - 6s 1s/step - loss: 2.1394 - accuracy: 0.2547 - val_loss: 7.0266 - val_accuracy: 0.1689
# Epoch 4/500
# 5/5 [==============================] - 6s 1s/step - loss: 2.0853 - accuracy: 0.2719 - val_loss: 8.4616 - val_accuracy: 0.1379
# Epoch 5/500
# 5/5 [==============================] - 7s 1s/step - loss: 2.0525 - accuracy: 0.3016 - val_loss: 7.2589 - val_accuracy: 0.1642
# Epoch 6/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.9874 - accuracy: 0.3547 - val_loss: 5.3665 - val_accuracy: 0.1660
# Epoch 7/500
# 5/5 [==============================] - 6s 1s/step - loss: 1.9462 - accuracy: 0.3797 - val_loss: 5.7736 - val_accuracy: 0.1588
# Epoch 8/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.9255 - accuracy: 0.3938 - val_loss: 4.2336 - val_accuracy: 0.1913
# Epoch 9/500
# 5/5 [==============================] - 6s 1s/step - loss: 1.8650 - accuracy: 0.4203 - val_loss: 3.8678 - val_accuracy: 0.1837
# Epoch 10/500
# 5/5 [==============================] - 6s 1s/step - loss: 1.8360 - accuracy: 0.4375 - val_loss: 3.5700 - val_accuracy: 0.1540
# Epoch 11/500
# 5/5 [==============================] - 6s 1s/step - loss: 1.8215 - accuracy: 0.4750 - val_loss: 3.9862 - val_accuracy: 0.1491
# Epoch 12/500
# 5/5 [==============================] - 6s 1s/step - loss: 1.7961 - accuracy: 0.4625 - val_loss: 3.4289 - val_accuracy: 0.1825
# Epoch 13/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.7596 - accuracy: 0.4875 - val_loss: 3.3759 - val_accuracy: 0.1839
# Epoch 14/500
# 5/5 [==============================] - 6s 1s/step - loss: 1.7416 - accuracy: 0.5016 - val_loss: 3.2920 - val_accuracy: 0.2024
# Epoch 15/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.7171 - accuracy: 0.5375 - val_loss: 3.0813 - val_accuracy: 0.2373
# Epoch 16/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.7056 - accuracy: 0.5031 - val_loss: 3.1182 - val_accuracy: 0.2289
# Epoch 17/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.6744 - accuracy: 0.5531 - val_loss: 3.2910 - val_accuracy: 0.2240
# Epoch 18/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.6765 - accuracy: 0.5406 - val_loss: 2.9875 - val_accuracy: 0.2451
# Epoch 19/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.6562 - accuracy: 0.5688 - val_loss: 2.8848 - val_accuracy: 0.2604
# Epoch 20/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.6047 - accuracy: 0.6016 - val_loss: 3.0033 - val_accuracy: 0.2232
# Epoch 21/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.5787 - accuracy: 0.6109 - val_loss: 2.7890 - val_accuracy: 0.2565
# Epoch 22/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.5738 - accuracy: 0.6266 - val_loss: 2.6340 - val_accuracy: 0.2943
# Epoch 23/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.5646 - accuracy: 0.6078 - val_loss: 2.6959 - val_accuracy: 0.2732
# Epoch 24/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.5203 - accuracy: 0.6453 - val_loss: 2.8511 - val_accuracy: 0.2474
# Epoch 25/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.5143 - accuracy: 0.6438 - val_loss: 2.8724 - val_accuracy: 0.2719
# Epoch 26/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.5120 - accuracy: 0.6484 - val_loss: 2.5896 - val_accuracy: 0.2995
# Epoch 27/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.4741 - accuracy: 0.6641 - val_loss: 2.7669 - val_accuracy: 0.2683
# Epoch 28/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.4649 - accuracy: 0.6984 - val_loss: 2.6124 - val_accuracy: 0.2963
# Epoch 29/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.4500 - accuracy: 0.7047 - val_loss: 2.7524 - val_accuracy: 0.2879
# Epoch 30/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.4373 - accuracy: 0.7172 - val_loss: 2.4985 - val_accuracy: 0.3180
# Epoch 31/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.4297 - accuracy: 0.7141 - val_loss: 2.7432 - val_accuracy: 0.2811
# Epoch 32/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.3909 - accuracy: 0.7422 - val_loss: 2.8984 - val_accuracy: 0.2486
# Epoch 33/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.3741 - accuracy: 0.7609 - val_loss: 2.6598 - val_accuracy: 0.2883
# Epoch 34/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.3612 - accuracy: 0.7734 - val_loss: 2.4878 - val_accuracy: 0.3150
# Epoch 35/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.3645 - accuracy: 0.7594 - val_loss: 2.5426 - val_accuracy: 0.3006
# Epoch 36/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.3485 - accuracy: 0.7563 - val_loss: 2.8104 - val_accuracy: 0.2679
# Epoch 37/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.3104 - accuracy: 0.8031 - val_loss: 2.5881 - val_accuracy: 0.2975
# Epoch 38/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.2884 - accuracy: 0.8250 - val_loss: 2.4917 - val_accuracy: 0.3202
# Epoch 39/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.2934 - accuracy: 0.8109 - val_loss: 2.6233 - val_accuracy: 0.3092
# Epoch 40/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.2853 - accuracy: 0.8219 - val_loss: 2.7040 - val_accuracy: 0.3138
# Epoch 41/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.2720 - accuracy: 0.8328 - val_loss: 2.6254 - val_accuracy: 0.3226
# Epoch 42/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.2610 - accuracy: 0.8391 - val_loss: 2.5325 - val_accuracy: 0.3363
# Epoch 43/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.2429 - accuracy: 0.8609 - val_loss: 2.6008 - val_accuracy: 0.3210
# Epoch 44/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.2480 - accuracy: 0.8391 - val_loss: 2.5837 - val_accuracy: 0.3244
# Epoch 45/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.2134 - accuracy: 0.8797 - val_loss: 2.4982 - val_accuracy: 0.3537
# Epoch 46/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.2112 - accuracy: 0.8719 - val_loss: 2.4417 - val_accuracy: 0.3541
# Epoch 47/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.2178 - accuracy: 0.8625 - val_loss: 2.5559 - val_accuracy: 0.3316
# Epoch 48/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.1964 - accuracy: 0.8844 - val_loss: 2.4461 - val_accuracy: 0.3587
# Epoch 49/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.1718 - accuracy: 0.9031 - val_loss: 2.3902 - val_accuracy: 0.3660
# Epoch 50/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.1732 - accuracy: 0.9031 - val_loss: 2.4441 - val_accuracy: 0.3512
# Epoch 51/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.1711 - accuracy: 0.9187 - val_loss: 2.6190 - val_accuracy: 0.3276
# Epoch 52/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.1548 - accuracy: 0.9250 - val_loss: 2.4637 - val_accuracy: 0.3560
# Epoch 53/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.1544 - accuracy: 0.9094 - val_loss: 2.5794 - val_accuracy: 0.3343
# Epoch 54/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.1416 - accuracy: 0.9266 - val_loss: 2.6091 - val_accuracy: 0.3287
# Epoch 55/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.1288 - accuracy: 0.9219 - val_loss: 2.5933 - val_accuracy: 0.3390
# Epoch 56/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.1059 - accuracy: 0.9438 - val_loss: 2.5884 - val_accuracy: 0.3410
# Epoch 57/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.1195 - accuracy: 0.9422 - val_loss: 2.5367 - val_accuracy: 0.3440
# Epoch 58/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.1009 - accuracy: 0.9516 - val_loss: 2.5932 - val_accuracy: 0.3299
# Epoch 59/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.1028 - accuracy: 0.9375 - val_loss: 2.5523 - val_accuracy: 0.3426
# Epoch 60/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0951 - accuracy: 0.9516 - val_loss: 2.5534 - val_accuracy: 0.3425
# Epoch 61/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0924 - accuracy: 0.9641 - val_loss: 2.6041 - val_accuracy: 0.3343
# Epoch 62/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0828 - accuracy: 0.9594 - val_loss: 2.5458 - val_accuracy: 0.3464
# Epoch 63/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0680 - accuracy: 0.9641 - val_loss: 2.5181 - val_accuracy: 0.3479
# Epoch 64/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0651 - accuracy: 0.9672 - val_loss: 2.4536 - val_accuracy: 0.3564
# Epoch 65/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0623 - accuracy: 0.9734 - val_loss: 2.4926 - val_accuracy: 0.3466
# Epoch 66/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0546 - accuracy: 0.9766 - val_loss: 2.5287 - val_accuracy: 0.3432
# Epoch 67/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0453 - accuracy: 0.9812 - val_loss: 2.5327 - val_accuracy: 0.3405
# Epoch 68/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0634 - accuracy: 0.9750 - val_loss: 2.5320 - val_accuracy: 0.3468
# Epoch 69/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0598 - accuracy: 0.9703 - val_loss: 2.5382 - val_accuracy: 0.3492
# Epoch 70/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0475 - accuracy: 0.9719 - val_loss: 2.5483 - val_accuracy: 0.3525
# Epoch 71/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0511 - accuracy: 0.9797 - val_loss: 2.6251 - val_accuracy: 0.3264
# Epoch 72/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0491 - accuracy: 0.9891 - val_loss: 2.5522 - val_accuracy: 0.3408
# Epoch 73/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0458 - accuracy: 0.9750 - val_loss: 2.5436 - val_accuracy: 0.3489
# Epoch 74/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0557 - accuracy: 0.9688 - val_loss: 2.6262 - val_accuracy: 0.3376
# Epoch 75/500
# 5/5 [==============================] - 7s 1s/step - loss: 1.0361 - accuracy: 0.9734 - val_loss: 2.5527 - val_accuracy: 0.3463
# Epoch 76/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0237 - accuracy: 0.9906 - val_loss: 2.5385 - val_accuracy: 0.3496
# Epoch 77/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0225 - accuracy: 0.9812 - val_loss: 2.5450 - val_accuracy: 0.3492
# Epoch 78/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0222 - accuracy: 0.9875 - val_loss: 2.6011 - val_accuracy: 0.3424
# Epoch 79/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0265 - accuracy: 0.9859 - val_loss: 2.5554 - val_accuracy: 0.3450
# Epoch 80/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0158 - accuracy: 0.9937 - val_loss: 2.4894 - val_accuracy: 0.3610
# Epoch 81/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0089 - accuracy: 0.9891 - val_loss: 2.5464 - val_accuracy: 0.3523
# Epoch 82/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0207 - accuracy: 0.9875 - val_loss: 2.5998 - val_accuracy: 0.3487
# Epoch 83/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0125 - accuracy: 0.9922 - val_loss: 2.5944 - val_accuracy: 0.3380
# Epoch 84/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9951 - accuracy: 0.9984 - val_loss: 2.5719 - val_accuracy: 0.3419
# Epoch 85/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9968 - accuracy: 0.9953 - val_loss: 2.5470 - val_accuracy: 0.3476
# Epoch 86/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9882 - accuracy: 0.9953 - val_loss: 2.5554 - val_accuracy: 0.3536
# Epoch 87/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9923 - accuracy: 0.9953 - val_loss: 2.5071 - val_accuracy: 0.3574
# Epoch 88/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9979 - accuracy: 0.9953 - val_loss: 2.5298 - val_accuracy: 0.3486
# Epoch 89/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9887 - accuracy: 0.9922 - val_loss: 2.5273 - val_accuracy: 0.3558
# Epoch 90/500
# 5/5 [==============================] - 7s 1s/step - loss: 0.9870 - accuracy: 0.9969 - val_loss: 2.5484 - val_accuracy: 0.3527
# Epoch 91/500
# 5/5 [==============================] - 8s 2s/step - loss: 1.0018 - accuracy: 0.9922 - val_loss: 2.5346 - val_accuracy: 0.3507
# Epoch 92/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9868 - accuracy: 0.9953 - val_loss: 2.5172 - val_accuracy: 0.3580
# Epoch 93/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9855 - accuracy: 0.9953 - val_loss: 2.5125 - val_accuracy: 0.3546
# Epoch 94/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9719 - accuracy: 1.0000 - val_loss: 2.5171 - val_accuracy: 0.3513
# Epoch 95/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9774 - accuracy: 0.9953 - val_loss: 2.5522 - val_accuracy: 0.3476
# Epoch 96/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9743 - accuracy: 0.9984 - val_loss: 2.5402 - val_accuracy: 0.3460
# Epoch 97/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9800 - accuracy: 0.9953 - val_loss: 2.4968 - val_accuracy: 0.3558
# Epoch 98/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9703 - accuracy: 0.9984 - val_loss: 2.5251 - val_accuracy: 0.3465
# Epoch 99/500
# 5/5 [==============================] - 8s 2s/step - loss: 0.9769 - accuracy: 0.9922 - val_loss: 2.5427 - val_accuracy: 0.3442

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
submodel = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
    )
z = submodel.predict(X_train)
np.shape(z)
# Out:
# (40000, 256)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sun Aug  9 22:28:31 2020 Finding Nearest Neighbors
# Sun Aug  9 22:28:31 2020 Building RP forest with 15 trees
# Sun Aug  9 22:28:33 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# Sun Aug  9 22:28:43 2020 Finished Nearest Neighbor Search
# Sun Aug  9 22:28:45 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sun Aug  9 22:29:11 2020 Finished embedding

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)

# %%
z_valid = submodel.predict(X_valid)
np.shape(z_valid)
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z_valid.reshape(len(z_valid), np.product(np.shape(z_valid)[1:])))

plt.scatter(embedding[:, 0], embedding[:, 1], c=Y_valid.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Sun Aug  9 22:29:22 2020 Finding Nearest Neighbors
# Sun Aug  9 22:29:22 2020 Building RP forest with 10 trees
# Sun Aug  9 22:29:22 2020 parallel NN descent for 13 iterations
# 	 0  /  13
# 	 1  /  13
# 	 2  /  13
# 	 3  /  13
# Sun Aug  9 22:29:22 2020 Finished Nearest Neighbor Search
# Sun Aug  9 22:29:23 2020 Construct embedding
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Sun Aug  9 22:29:40 2020 Finished embedding

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(embedding[:, 0], embedding[:, 1], c=Y_valid.flatten(), s= 1, alpha = 1, cmap = plt.cm.tab10)

# %%
predictions = model.predict(X_valid)

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(embedding[:, 0], embedding[:, 1], c=np.argmax(predictions, axis=1), s= 1, alpha = 1, cmap = plt.cm.tab10)

# %%
Y_test_one_hot = tf.keras.backend.one_hot(
    Y_test, num_classes
)
result = model.evaluate(X_test, Y_test_one_hot)
# Out:
# 313/313 [==============================] - 15s 49ms/step - loss: 2.5522 - accuracy: 0.3430

# %% [markdown]
# ### save results

# %%
# save score, valid embedding, weights, results

# %%
from tfumap.paths import MODEL_DIR, ensure_dir

# %%
save_folder = MODEL_DIR / 'semisupervised-keras' / dataset / str(labels_per_class) / datestring
ensure_dir(save_folder)

# %% [markdown]
# #### save weights

# %%
encoder = tf.keras.models.Model(
        [model.inputs[0]], [model.get_layer('z').output]
)

# %%
encoder.save_weights((save_folder / "encoder").as_posix())

# %%
classifier = tf.keras.models.Model(
        [tf.keras.Input(tensor=model.get_layer('weight_normalization').input)], [model.outputs[0]]
)
print([i.name for i in classifier.layers])
# Out:
# ['input_2', 'weight_normalization', 'lrelufc1', 'weight_normalization_1', 'lrelufc2', 'weight_normalization_2']

# %%
classifier.save_weights((save_folder / "classifier").as_posix())

# %% [markdown]
# #### save score

# %%
Y_test_one_hot = tf.keras.backend.one_hot(
    Y_test, num_classes
)
result = model.evaluate(X_test, Y_test_one_hot)
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 2.5522 - accuracy: 0.3430

# %%
np.save(save_folder / 'test_loss.npy', result)

# %% [markdown]
# #### save embedding

# %%
z = encoder.predict(X_train)

# %%
reducer = umap.UMAP(verbose=True)

embedding = reducer.fit_transform(z.reshape(len(z), np.product(np.shape(z)[1:])))

plt.scatter(embedding[:, 0], embedding[:, 1], c=Y_train.flatten(), s= 1, alpha = 0.1, cmap = plt.cm.tab10)
# Out:
# UMAP(dens_frac=0.0, dens_lambda=0.0, verbose=True)
# Construct fuzzy simplicial set
# Mon Aug 10 09:29:01 2020 Finding Nearest Neighbors
# Mon Aug 10 09:29:01 2020 Building RP forest with 15 trees
# Mon Aug 10 09:29:03 2020 parallel NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# Mon Aug 10 09:29:05 2020 Finished Nearest Neighbor Search
# Mon Aug 10 09:29:05 2020 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Mon Aug 10 09:29:47 2020 Finished embedding

# %%
np.save(save_folder / 'train_embedding.npy', embedding)

# %% [markdown]
# #### save results

# %%
import pickle

# %%
with open(save_folder / 'history.pickle', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
